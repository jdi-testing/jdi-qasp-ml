# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'HTML5_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/html5_dataset')

# %%
DATASET_NAME = 'html-test-jdi'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/html5.html'
PREDICT_URL = 'http://localhost:5050/html5-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 2
# HEADLESS = True

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click() #path to elements packs
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[1]/a").click() #path to mui
        sleep(2.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(2.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2022-01-14 11:27:45,362 -INFO - dataset_builder.py:100 - Dataset name: html-test-jdi
# 2022-01-14 11:27:45,367 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2022-01-14 11:27:45,372 -INFO - dataset_builder.py:152 - Creating driver
# 2022-01-14 11:27:46,391 -INFO - dataset_builder.py:164 - Chrome web driver is created
# ipykernel_launcher:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2022-01-14 11:27:53,658 -INFO - common.py:22 - Window maximized
# 2022-01-14 11:27:55,661 -INFO - dataset_builder.py:167 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/images/html-test-jdi.png
# 2022-01-14 11:28:00,936 -INFO - dataset_builder.py:211 - Collect features using JS script
# 2022-01-14 11:28:01,583 -INFO - dataset_builder.py:219 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/html/html-test-jdi.html
# 2022-01-14 11:28:01,602 -INFO - dataset_builder.py:231 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/df/html-test-jdi.pkl
# 2022-01-14 11:28:01,606 -INFO - dataset_builder.py:234 - No attributes: (255, 14)
# 2022-01-14 11:28:01,701 -INFO - dataset_builder.py:125 - Close web driver

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset'

# %%
d = pd.DataFrame(dataset_json)
d[d.html.apply(lambda x: True if '<input type="button"' in x else False)].tail(3)
# Out:
#                                             attributes  displayed  \
# 206                             {'class': 'html-left'}       True
# 208  {'class': 'uui-button red', 'onclick': 'alert(...       True
# 211  {'class': 'uui-button grey', 'disabled': '', '...       True
#
#                        element_id     height  \
# 206  9730198051488809437227718096  477.59375
# 208  1621457538488809434600478656   34.00000
# 211  2189455590488809437844347308   34.00000
#
#                                                   html onmouseenter  \
# 206  <div class="html-left">\n                     ...         None
# 208  <input type="button" value="Big Red Button-Inp...         None
# 211  <input type="button" value="Disabled Button-In...         None
#
#     onmouseover                     parent_id  \
# 206        None  3901363003488809431344369954
# 208        None  9730198051488809437227718096
# 211        None  9730198051488809437227718096
#
#                                                  style tag_name  \
# 206  [accent-color, align-content, align-items, ali...      DIV
# 208  [accent-color, align-content, align-items, ali...    INPUT
# 211  [accent-color, align-content, align-items, ali...    INPUT
#
#                                                   text       width      x  \
# 206  BUTTON\n\n\n\n\nTAG BUTTON\nBIG BLUE BUTTON\n\...  283.187500  363.0
# 208                                                     163.421875  363.0
# 211                                                     171.906250  363.0
#
#               y
# 206  378.187500
# 208  417.984375
# 211  469.984375

# %%
from utils.dataset import HTML5_JDNDataset
dataset = HTML5_JDNDataset(
        datasets_list=[DATASET_NAME],
        dataset_type="html5",
        rebalance_and_shuffle=False,
    )
# Out:
# Build tree features: 100%|██████████| 668/668 [00:00<00:00, 1729.82it/s]i-qasp-ml/data/html5_dataset/df/html-test-jdi.pkl]
# 100%|██████████| 1/1 [00:01<00:00,  1.15s/it, /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/df/html-test-jdi.pkl]
# 2022-01-14 11:28:03,255 -INFO - dataset.py:210 - self.df.shape: (668, 33)
# 2022-01-14 11:28:03,256 -INFO - dataset.py:101 - Check for duplicates...
# 2022-01-14 11:28:03,258 -INFO - dataset.py:105 - Check for duplicates is OK
# 2022-01-14 11:28:03,258 -INFO - dataset.py:214 - Calculating features...
# 2022-01-14 11:28:03,330 -INFO - dataset_collector.py:177 - X: (668, 79)
# 2022-01-14 11:28:03,331 -INFO - dataset.py:218 - Features have calculated succesfully!

# %%
print(dataset.df.shape)
print(dataset.X.shape)
# Out:
# (668, 33)
# (668, 79)

# %%
pkl_filename = "DT_model.pkl"
with open(f"{model_path}/{pkl_filename}", "rb") as file:
    model = pickle.load(file)

# %%
model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 17,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
html5_classes_path = "/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/classes.txt"
with open(html5_classes_path, "r") as f:
        lines = f.readlines()
        encoder_dict = {line.strip(): i for i, line in enumerate(lines)}
        decoder_dict = {v: k for k, v in encoder_dict.items()}

# %%
# pd.Series(model.predict(dataset.X)).apply(lambda x: decoder_dict[x]).unique()

# %%
res_dataset = dataset.X.copy()
res_dataset.shape
# Out:
# (668, 79)

# %%
res_dataset["pred"] = pd.Series(model.predict(res_dataset)).apply(lambda x: decoder_dict.get(x, "n/a")).values
res_dataset.head()
# Out:
#                               tag_HTML  tag_HEAD  tag_META  tag_TITLE  \
# element_id
# 0024463564488809438580995526         0         0         0          0
# 0026715852488809434250541624         0         0         0          0
# 0028349406488809442181836765         0         0         0          0
# 0055142883488809441418693699         0         0         0          0
# 0106609968488809438808649291         0         0         0          0
#
#                               tag_STYLE  tag_BODY  tag_DIV  tag_LABEL  \
# element_id
# 0024463564488809438580995526          0         0        0          0
# 0026715852488809434250541624          0         0        0          0
# 0028349406488809442181836765          0         0        0          0
# 0055142883488809441418693699          0         0        0          0
# 0106609968488809438808649291          0         0        0          0
#
#                               tag_INPUT  tag_DATALIST  ...  type_range  \
# element_id                                             ...
# 0024463564488809438580995526          0             0  ...           0
# 0026715852488809434250541624          0             0  ...           0
# 0028349406488809442181836765          0             0  ...           0
# 0055142883488809441418693699          1             0  ...           0
# 0106609968488809438808649291          0             0  ...           0
#
#                               type_radio  type_month  type_checkbox  \
# element_id
# 0024463564488809438580995526           0           0              0
# 0026715852488809434250541624           0           0              0
# 0028349406488809442181836765           0           0              0
# 0055142883488809441418693699           0           0              0
# 0106609968488809438808649291           0           0              0
#
#                               type_reset  type_number  type_week  \
# element_id
# 0024463564488809438580995526           0            0          0
# 0026715852488809434250541624           0            0          0
# 0028349406488809442181836765           0            0          0
# 0055142883488809441418693699           0            0          0
# 0106609968488809438808649291           0            0          0
#
#                               is_checkbox_in_childs  is_radio_in_childs  \
# element_id
# 0024463564488809438580995526                      0                   0
# 0026715852488809434250541624                      0                   0
# 0028349406488809442181836765                      0                   0
# 0055142883488809441418693699                      0                   0
# 0106609968488809438808649291                      0                   0
#
#                                           pred
# element_id
# 0024463564488809438580995526               n/a
# 0026715852488809434250541624              link
# 0028349406488809442181836765              text
# 0055142883488809441418693699  datetimeselector
# 0106609968488809438808649291              link
#
# [5 rows x 80 columns]

# %%
res_dataset.pred.unique()
# Out:
# array(['n/a', 'link', 'text', 'datetimeselector', 'textfield', 'title',
#        'label', 'datalist', 'radiobutton', 'checkbox', 'checklist',
#        'range', 'button', 'multiselector', 'colorpicker', 'fileinput',
#        'progressbar', 'numberselector', 'multidropdown', 'dropdown',
#        'textarea', 'radiobuttongroup'], dtype=object)

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '0480191731488809445853593321',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 3816.75,
#   'width': 283.1875,
#   'height': 130.0,
#   'predicted_label': 'checklist',
#   'predicted_probability': 1.0,
#   'sort_key': 36814.375},
#  {'element_id': '8838836636488809449983126796',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 4129.546875,
#   'width': 283.1875,
#   'height': 104.0,
#   'predicted_label': 'radiobuttongroup',
#   'predicted_probability': 1.0,
#   'sort_key': 29451.5},
#  {'element_id': '9504463097488809437571355140',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 186.0,
#   'width': 283.1875,
#   'height': 79.1875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 22424.91015625},
#  {'element_id': '6468272811488809430791639364',
#   'is_hidden': 0,
#   'x': 696.203125,
#   'y': 1359.375,
#   'width': 610.796875,
#   'height': 36.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 21988.6875},
#  {'element_id': '0597502396488809438125191175',
#   'is_hidden': 0,
#   'x': 696.203125,
#   'y': 1257.375,
#   'width': 610.796875,
#   'height': 36.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 21988.6875},
#  {'element_id': '9828215581488809430374537947',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 275.1875,
#   'width': 283.1875,
#   'height': 72.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 20389.5},
#  {'element_id': '8205940865488809436844124544',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 1561.375,
#   'width': 224.0,
#   'height': 56.0,
#   'predicted_label': 'textarea',
#   'predicted_probability': 1.0,
#   'sort_key': 12544.0},
#  {'element_id': '3891519902488809449901950116',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3028.359375,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '8021772508488809442084948450',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5031.9375,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '2131371230488809448894871385',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5723.125,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '6127250404488809448901470357',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4597.140625,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '7425501716488809440067647616',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4859.140625,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '2449331372488809440474935882',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5377.53125,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '3896949844488809435887254424',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2145.96875,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '6485812426488809434417774520',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 388.1875,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '1343482541488809440827971194',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5204.734375,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '6638357739488809440859876386',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2374.765625,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '8620617062488809430171884897',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1548.375,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '4108755181488809449189914830',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5550.328125,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '1545925500488809440561216735',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5895.921875,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '0423976435488809445692974702',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2687.5625,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '0552030855488809438614216485',
#   'is_hidden': 0,
#   'x': 696.203125,
#   'y': 1143.578125,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '5663113004488809443054818771',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3313.15625,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '0197665939488809447771421738',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4139.546875,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '9900582113488809441377783267',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4340.34375,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '2763069336488809430065207596',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1889.171875,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '9657812519488809432962492427',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 886.78125,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '5706193690488809445209881392',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3826.75,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '3015653986488809449561582039',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3569.953125,
#   'width': 610.796875,
#   'height': 19.796875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12091.8693847656},
#  {'element_id': '3713401631488809447521292603',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5981.71875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6805458110488809435421719826',
#   'is_hidden': 0,
#   'x': 696.203125,
#   'y': 1331.375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3876229557488809433273473321',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 529.984375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6674572769488809448484226753',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3342.953125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3053440421488809443215305848',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5234.53125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6992637427488809446779208471',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4370.140625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '7361174507488809444389408079',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4916.9375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3484205676488809431749875387',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2231.765625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '2990747414488809444348794238',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2460.5625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6613985025488809442075528460',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5836.921875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '7406381112488809449656994027',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5463.328125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6858173839488809444128948726',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3058.15625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6877612458488809447816893546',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3683.75,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3334153360488809440335399019',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4538.140625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3098827294488809441970947646',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2885.359375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '7078666052488809444950330430',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5262.53125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6908140411488809440406081251',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2628.5625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '7234205484488809431247282581',
#   'is_hidden': 0,
#   'x': 696.203125,
#   'y': 1303.375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3379429082488809442303593952',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4169.34375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3148664870488809438451882063',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1578.171875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3979742738488809436603215707',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1084.578125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3392979632488809448738502578',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5780.921875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3449298327488809445873823379',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4626.9375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3097286864488809444979553645',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3086.15625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3397825054488809443861333872',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4454.140625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3407613770488809447209597415',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3767.75,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3408260819488809442264727813',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5407.328125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '7332143129488809442135942817',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3884.546875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '7357733252488809439098336038',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1662.171875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '3970987801488809444803910921',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2941.359375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4218970232488809431033335528',
#   'is_hidden': 0,
#   'x': 696.203125,
#   'y': 1173.375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4052408137488809437974913011',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2030.96875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6522125809488809445850981048',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5953.71875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4822189968488809442371715429',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2572.5625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5772987044488809445023684824',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5145.734375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0028349406488809442181836765',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4482.140625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5769233909488809445753031975',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4888.9375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4946324145488809448359780306',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3627.75,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5091356135488809442824508291',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3739.75,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5115617183488809447960904687',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5435.328125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5223353631488809436076840191',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1974.96875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5236069584488809441282803478',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4281.34375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5256113636488809439734850596',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1946.96875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5256702137488809441834553521',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5318.53125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5274845894488809436450616962',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2175.765625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5278793871488809449197760417',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5808.921875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5664234995488809437653827629',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2203.765625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5384220126488809434104184040',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2086.96875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5630610768488809442939290910',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4510.140625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5394079126488809449798804962',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5664.125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4814904622488809445527436991',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3482.953125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4779057844488809446274259808',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5290.53125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4747619493488809440676714151',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2717.359375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6287202498488809442813841726',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3856.546875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4103160905488809447581417249',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2404.5625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6520584863488809443077234017',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4972.9375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '2847382232488809449262915888',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4398.140625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4280229615488809445067247991',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4197.34375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6393117073488809430130959289',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1056.578125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6372451820488809441285995551',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2432.5625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6340116521488809432990814119',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1028.578125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6240091231488809441189149308',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2600.5625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5785096960488809447772408023',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4052.546875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4442927394488809432619154812',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2002.96875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4449777253488809433920997401',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1718.171875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4480195248488809437929526809',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1830.171875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '6115903506488809443736412289',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5925.71875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4668010162488809434087340970',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1774.171875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4700001048488809431157329575',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 585.984375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '4716368015488809434943013914',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2315.765625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '2889052177488809436877599400',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 417.984375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9951820954488809442347279980',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5580.125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '1251416890488809448386146122',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4225.34375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9413996917488809442989522652',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3170.15625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9278159633488809448799485595',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3142.15625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0747693071488809442259851714',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2773.359375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0760197262488809446226780119',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3198.15625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9201132007488809449674102546',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2969.359375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9151001815488809430088743641',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1634.171875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0821123753488809431234183414',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2259.765625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0855143582488809445118682826',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3711.75,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '8950634157488809449196848999',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2488.5625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '1139969310488809440072653906',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3226.15625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '8806626016488809449566879129',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3599.75,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '8737879864488809440787345843',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3426.953125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '7495020275488809442315691125',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4024.546875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '1348341435488809445966548531',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3398.953125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '8546805159488809436151776724',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2287.765625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '8529240237488809448987731539',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4682.9375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '1554526813488809432654310592',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 501.984375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '1555947282488809449178648801',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3655.75,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9358270131488809443193835871',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4944.9375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0610667877488809435460293343',
#   'is_hidden': 0,
#   'x': 696.203125,
#   'y': 1433.375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '8511052314488809440086073471',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4426.140625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9414776926488809435410125482',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 916.578125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9922025167488809445160626409',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4654.9375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0136765480488809443534899086',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2544.5625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0138146826488809440033130450',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4253.34375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0183032523488809447565371771',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3454.953125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0186220910488809443219249583',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2745.359375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0228179207488809443951179754',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3114.15625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9586483690488809441134100685',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5608.125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0259593142488809434067107315',
#   'is_hidden': 0,
#   'x': 696.203125,
#   'y': 1461.375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9574913679488809446661597083',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5491.328125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9571760334488809445689837144',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2913.359375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9559097292488809442170084686',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3968.546875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9512771709488809446675400548',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2829.359375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0410912019488809443426557559',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3510.953125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0452788577488809439100199010',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 944.578125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0532871254488809440238127988',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3996.546875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '0541720799488809445154161940',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5089.734375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '9448364295488809445889913624',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 6009.71875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '1586767860488809442659322869',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3370.953125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5505068838488809442637146530',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3912.546875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '1590898972488809439301331425',
#   'is_hidden': 0,
#   'x': 696.203125,
#   'y': 1229.375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '2535893153488809448382751455',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3254.15625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '2050091536488809447698998877',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2857.359375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '8055709606488809442303127903',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 3940.546875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '8480949889488809435571384746',
#   'is_hidden': 0,
#   'x': 696.203125,
#   'y': 1405.375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '2343486852488809445044012131',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2801.359375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '7763453133488809439397132655',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1918.96875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '2526588654488809437661666779',
#   'is_hidden': 0,
#   'x': 696.203125,
#   'y': 1489.375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '2566188472488809439833455635',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2058.96875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '8226008181488809435456803075',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1802.171875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '7664615618488809440681811663',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 4080.546875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '2588183216488809443368802875',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5117.734375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '2709573745488809436387214645',
#   'is_hidden': 0,
#   'x': 696.203125,
#   'y': 1201.375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '7645201309488809434973329083',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 473.984375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '2757786399488809439918657641',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 972.578125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '7599633308488809433411489018',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1000.578125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '1954079118488809438246421121',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 445.984375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '7815633852488809430108154633',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1746.171875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '1894181708488809440151999028',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5061.734375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '1847387706488809441231671402',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 2516.5625,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '1658903357488809443203830252',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5752.921875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '1677528183488809439066964132',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1606.171875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '8422627334488809430470097699',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 557.984375,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '1737678261488809441814018902',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 5636.125,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '8319495321488809430702128624',
#   'is_hidden': 1,
#   'x': 696.203125,
#   'y': 1690.171875,
#   'width': 610.796875,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10994.34375},
#  {'element_id': '5093123667488809449645794328',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 5435.328125,
#   'width': 492.015625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8856.28125},
#  {'element_id': '9564697022488809432822742619',
#   'is_hidden': 0,
#   'x': 502.859375,
#   'y': 0.0,
#   'width': 140.484375,
#   'height': 60.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8429.0625},
#  {'element_id': '9122173062488809440870064242',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 3884.546875,
#   'width': 462.5,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8325.0},
#  {'element_id': '4119585462488809443750009385',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 3627.75,
#   'width': 462.5,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8325.0},
#  {'element_id': '3399298657488809440945751494',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 5953.71875,
#   'width': 453.765625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8167.78125},
#  {'element_id': '4525465631488809442534494760',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 5262.53125,
#   'width': 446.53125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8037.5625},
#  {'element_id': '0183700913488809445901919713',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 4654.9375,
#   'width': 440.375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7926.75},
#  {'element_id': '4920917696488809447700574879',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 5780.921875,
#   'width': 438.15625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7886.8125},
#  {'element_id': '4785445438488809447828771114',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 4197.34375,
#   'width': 437.609375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7876.96875},
#  {'element_id': '7652664297488809446685975096',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 4426.140625,
#   'width': 436.59375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7858.6875},
#  {'element_id': '3579315784488809443554072511',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 5608.125,
#   'width': 434.1875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7815.375},
#  {'element_id': '2040429290488809433708426526',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 142.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '2604057542488809430059304449',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 60.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '3092752224488809439561460160',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 224.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '0756499875488809431427890874',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 183.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '5959042434488809431198079644',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 101.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '8446550511488809435072879455',
#   'is_hidden': 0,
#   'x': 730.34375,
#   'y': 1229.375,
#   'width': 429.484375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7730.71875},
#  {'element_id': '6834255088488809434985339990',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 1974.96875,
#   'width': 425.265625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7654.78125},
#  {'element_id': '0211499150488809436959567846',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 453.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '6242494402488809438919512304',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 415.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '9564132820488809430505434243',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 529.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '2574034904488809430149027214',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 263.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '6179602751488809432249831416',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 567.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '0360767324488809436200984858',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 301.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '7179230021488809436727543293',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 491.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '6947999555488809434335910341',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 377.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '1790204335488809435985451390',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 339.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '7285850070488809440839116565',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 4944.9375,
#   'width': 421.25,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7582.5},
#  {'element_id': '6047784624488809431485286646',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 1634.171875,
#   'width': 418.15625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7526.8125},
#  {'element_id': '3773895328488809443589931296',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 3398.953125,
#   'width': 413.75,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7447.5},
#  {'element_id': '5454025295488809447214048731',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 5089.734375,
#   'width': 410.484375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7388.71875},
#  {'element_id': '0026715852488809434250541624',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 445.984375,
#   'width': 410.3125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7385.625},
#  {'element_id': '4309785647488809448487817116',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 3559.953125,
#   'width': 283.1875,
#   'height': 26.0,
#   'predicted_label': 'checklist',
#   'predicted_probability': 1.0,
#   'sort_key': 7362.875},
#  {'element_id': '8830624368488809433096785061',
#   'is_hidden': 0,
#   'x': 287.453125,
#   'y': 0.0,
#   'width': 121.859375,
#   'height': 60.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7311.5625},
#  {'element_id': '8202649290488809440841558776',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 2460.5625,
#   'width': 405.03125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7290.5625},
#  {'element_id': '8028334264488809447185259180',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 2773.359375,
#   'width': 405.03125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7290.5625},
#  {'element_id': '0558370867488809445407891129',
#   'is_hidden': 1,
#   'x': 730.34375,
#   'y': 3114.15625,
#   'width': 405.03125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7290.5625},
#  {'element_id': '5749859798488809446610229033',
#   'is_hidden': 1,
#   'x': 728.453125,
#   'y': 5407.328125,
#   'width': 404.25,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7276.5},
# ...
#   'predicted_label': 'colorpicker',
#   'predicted_probability': 1.0,
#   'sort_key': 1350.0},
#  {'element_id': '8488826839488809447050128827',
#   'is_hidden': 1,
#   'x': 378.8125,
#   'y': 3871.75,
#   'width': 74.65625,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1343.8125},
#  {'element_id': '4328151344488809433591979927',
#   'is_hidden': 0,
#   'x': 363.0,
#   'y': 1160.578125,
#   'width': 74.65625,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1343.8125},
#  {'element_id': '1521591249488809430907329837',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 2175.375,
#   'width': 72.1875,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1299.375},
#  {'element_id': '2571363183488809443333486492',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 4789.140625,
#   'width': 69.5,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1251.0},
#  {'element_id': '8743309741488809445819794924',
#   'is_hidden': 1,
#   'x': 378.8125,
#   'y': 3923.75,
#   'width': 69.5,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1251.0},
#  {'element_id': '9467283558488809449982796029',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 5716.515625,
#   'width': 65.234375,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1174.21875},
#  {'element_id': '1428891614488809449236807901',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 4589.140625,
#   'width': 63.046875,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1134.84375},
#  {'element_id': '9877162451488809431134200440',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 876.78125,
#   'width': 61.609375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1108.96875},
#  {'element_id': '9072359471488809449947825926',
#   'is_hidden': 1,
#   'x': 378.8125,
#   'y': 4210.546875,
#   'width': 56.28125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1013.0625},
#  {'element_id': '4650248797488809442478383562',
#   'is_hidden': 1,
#   'x': 378.8125,
#   'y': 3897.75,
#   'width': 55.703125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1002.65625},
#  {'element_id': '1479063785488809447995877887',
#   'is_hidden': 1,
#   'x': 378.8125,
#   'y': 4158.546875,
#   'width': 53.75,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 967.5},
#  {'element_id': '0585626889488809443182776177',
#   'is_hidden': 0,
#   'x': 1385.890625,
#   'y': 14961.0,
#   'width': 64.109375,
#   'height': 15.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 961.640625},
#  {'element_id': '6938737451488809441580582237',
#   'is_hidden': 1,
#   'x': 378.8125,
#   'y': 3845.75,
#   'width': 46.328125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 833.90625},
#  {'element_id': '8535274408488809447798423609',
#   'is_hidden': 1,
#   'x': 378.8125,
#   'y': 4184.546875,
#   'width': 45.578125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 820.40625},
#  {'element_id': '8788988974488809438233185215',
#   'is_hidden': 0,
#   'x': 1430.0,
#   'y': 20.0,
#   'width': 40.0,
#   'height': 20.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 800.0},
#  {'element_id': '0621667481488809442665700442',
#   'is_hidden': 1,
#   'x': 378.8125,
#   'y': 4132.546875,
#   'width': 41.859375,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 753.46875},
#  {'element_id': '5641574847488809448652483732',
#   'is_hidden': 1,
#   'x': 389.734375,
#   'y': 4637.140625,
#   'width': 100.0,
#   'height': 7.0,
#   'predicted_label': 'range',
#   'predicted_probability': 1.0,
#   'sort_key': 700.0},
#  {'element_id': '0147611027488809444052884097',
#   'is_hidden': 1,
#   'x': 493.40625,
#   'y': 4707.140625,
#   'width': 30.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 660.0},
#  {'element_id': '7243083888488809443564176329',
#   'is_hidden': 1,
#   'x': 550.1875,
#   'y': 4748.140625,
#   'width': 30.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 660.0},
#  {'element_id': '8618913983488809447065865416',
#   'is_hidden': 1,
#   'x': 428.859375,
#   'y': 4587.140625,
#   'width': 30.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 660.0},
#  {'element_id': '2779720456488809440338045063',
#   'is_hidden': 1,
#   'x': 494.90625,
#   'y': 4666.140625,
#   'width': 30.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 660.0},
#  {'element_id': '6786774061488809444995942789',
#   'is_hidden': 0,
#   'x': 1322.71875,
#   'y': 14961.0,
#   'width': 30.265625,
#   'height': 15.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 453.984375},
#  {'element_id': '0307983984488809448509424175',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 3563.953125,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '0306263659488809447626223018',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 4185.546875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '9079700377488809444254280193',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 4159.546875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '0773676266488809448454662509',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 3872.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '1156342644488809444135320045',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 3820.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '5119311263488809445983410180',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 3898.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '5459340703488809448869139688',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 3846.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '5411037188488809445963581699',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 3924.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '6481121444488809448171249084',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 4133.546875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '4413246137488809441324015200',
#   'is_hidden': 1,
#   'x': 363.0,
#   'y': 4211.546875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '5568594264488809449457902220',
#   'is_hidden': 1,
#   'x': 512.984375,
#   'y': 3053.765625,
#   'width': 1.0,
#   'height': 1.0,
#   'predicted_label': 'multidropdown',
#   'predicted_probability': 1.0,
#   'sort_key': 1.0},
#  {'element_id': '5388921669488809442339875676',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9877962634488809430878556902',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0106609968488809438808649291',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6663281369488809438337217786',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5301901236488809448472165317',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6763785829488809433747084286',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5336505394488809445018730660',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9350920087488809433371909757',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9825871045488809438593920522',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5488803597488809439344774451',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3876402160488809443971444654',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9539763974488809438489922017',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6924759113488809435465011798',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6418990151488809443538338469',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6646882468488809431326800071',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6990086264488809433108355344',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3251627777488809439829033904',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4248353213488809433309181425',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8106202025488809441262918987',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4361581778488809431531769002',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7759851793488809430134371496',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1906847800488809430899463768',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1732054480488809439900291179',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8321041239488809430254703203',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6153065396488809448371161041',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7715577835488809443840517531',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5437717509488809436295436626',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4185126124488809437599801716',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7507822227488809432782818520',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1189326317488809431398991204',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2957613077488809430927469112',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1120033205488809445556769011',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3035553434488809449052420422',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8943886362488809442870793727',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5886240742488809449985793723',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3966229381488809438350532016',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7267277802488809433828505860',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6420783873488809442461432781',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3245614735488809445740621268',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0996431442488809443837925955',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3773698460488809434232542567',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0}]
# CPU times: user 119 ms, sys: 12.8 ms, total: 132 ms
# Wall time: 1.91 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id  is_hidden           x            y  \
# 0  0480191731488809445853593321          1  363.000000  3816.750000
# 1  8838836636488809449983126796          1  363.000000  4129.546875
# 2  9504463097488809437571355140          1  363.000000   186.000000
# 3  6468272811488809430791639364          0  696.203125  1359.375000
# 4  0597502396488809438125191175          0  696.203125  1257.375000
#
#         width    height   predicted_label  predicted_probability  \
# 0  283.187500  130.0000         checklist                    1.0
# 1  283.187500  104.0000  radiobuttongroup                    1.0
# 2  283.187500   79.1875             title                    1.0
# 3  610.796875   36.0000              text                    1.0
# 4  610.796875   36.0000              text                    1.0
#
#        sort_key tag_name
# 0  36814.375000      DIV
# 1  29451.500000      DIV
# 2  22424.910156       H1
# 3  21988.687500        P
# 4  21988.687500        P

# %%
predictions_df.predicted_label.unique()
# Out:
# array(['checklist', 'radiobuttongroup', 'title', 'text', 'textarea',
#        'link', 'datetimeselector', 'numberselector', 'button',
#        'fileinput', 'multiselector', 'label', 'textfield', 'datalist',
#        'progressbar', 'dropdown', 'range', 'colorpicker', 'checkbox',
#        'radiobutton', 'multidropdown'], dtype=object)

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
        # if r.is_hidden==0:
                patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
                axes.add_patch(patch)
                axes.text(r.x*2, r.y*2, 
                        str(r.predicted_label) + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                        backgroundcolor='black', 
                        color='white',
                        bbox=dict(alpha=0.5))
