# %%
import sys
import re
import os
from datetime import datetime
from time import sleep
from IPython.display import display, clear_output, HTML

# set working dir
WORKING_DIR = re.sub('jdi-qasp-ml.*$','',os.path.normpath(os.getcwd())) + 'jdi-qasp-ml'
os.chdir(WORKING_DIR)

import utils
from utils import *
import torch
import pandas as pd
import numpy as np
import torch
from glob import glob
import selenium
from tqdm.auto import tqdm

START_TS = datetime.now()
display(HTML(f'{START_TS} - Current working directory: <b>{WORKING_DIR}</b>'))

import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

import numba
# Out:
# 2021-06-10 12:01:09,629 -INFO - config:config.py:16 - Module utils.config was loaded
# 2021-06-10 12:01:09,631 -INFO - common:common.py:618 - Module utils.common is loaded...
# 2021-06-10 12:01:09,633 -INFO - hidden:hidden.py:121 - hidden module is loaded
# 2021-06-10 12:01:09,635 -INFO - dataset_builder:dataset_builder.py:207 - dataset package is loaded...
# 2021-06-10 12:01:10,258 -INFO - dataset:dataset.py:653 - dataset module is loaded...
# 2021-06-10 12:01:10.259575 - Current working directory: <b>D:\DataScience\!WORK\jdi-qasp-ml</b>

# %%
from utils import get_all_elements, iou_xywh, screenshot, maximize_window, get_parents_list, build_tree_dict, DatasetBuilder

# %%
selenium.__version__
# Out:
# '3.141.0'

# %% [markdown]
# # Parameters

# %%
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
HEADLESS = True #False

# %%
with open('dataset/classes.txt', 'r') as f:
    decoder_dict = { i:s.strip() for i, s in  enumerate(f.readlines())}
decoder_dict
# Out:
# {0: 'button',
#  1: 'link',
#  2: 'textfield',
#  3: 'dropdown',
#  4: 'checkbox',
#  5: 'radiobutton',
#  6: 'textarea',
#  7: 'fileinput',
#  8: 'iframe',
#  9: 'range',
#  10: 'progressbar',
#  11: 'datetimeselector',
#  12: 'colorpicker',
#  13: 'numberselector',
#  14: 'selector',
#  15: 'table',
#  16: 'slider-toggle',
#  17: 'slider',
#  18: 'tree-node',
#  19: 'steper',
#  20: 'tab',
#  21: 'n/a'}

# %% [markdown]
# # Generate dataset

# %%
DATASET_NAME = 'simple-table'
class JDIDatasetBuilder(DatasetBuilder):

    def setUp(self, driver):
        self.logger.info(f'getting page')
        driver.get(SITE_URL)
        
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        
        driver.find_element_by_link_text("Service").click()
        driver.find_element_by_link_text("Simple Table").click()
        maximize_window(driver=driver)
        

with JDIDatasetBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True) as builder:
    elements_df = builder.dataset
    plt.imshow(plt.imread(f'dataset/images/{DATASET_NAME}.png'))
# Out:
# 2021-06-10 12:01:10,371 -INFO - dataset_builder:dataset_builder.py:77 - Dataset name: simple-table
# 2021-06-10 12:01:10,372 -INFO - dataset_builder:dataset_builder.py:86 - Create directories to save the dataset
# 2021-06-10 12:01:10,373 -INFO - dataset_builder:dataset_builder.py:123 - Creating driver
# 2021-06-10 12:01:11,550 -INFO - dataset_builder:dataset_builder.py:131 - Chrome web driver is created
# 2021-06-10 12:01:11,550 -INFO - <ipython-input-6-392c34354c4f>:<ipython-input-6-392c34354c4f>:5 - getting page
# 2021-06-10 12:01:22,096 -INFO - common:common.py:75 - Window maximized
# 2021-06-10 12:01:22,097 -INFO - dataset_builder:dataset_builder.py:134 - save scrinshot: dataset/images/simple-table.png
# 2021-06-10 12:01:22,242 -INFO - dataset_builder:dataset_builder.py:178 - Collect features using JS script
# 2021-06-10 12:01:22,642 -INFO - dataset_builder:dataset_builder.py:186 - Save html to dataset/html/simple-table.html
# 2021-06-10 12:01:22,649 -INFO - dataset_builder:dataset_builder.py:196 - Save parquet to dataset/df/simple-table.parquet
# 2021-06-10 12:01:22,653 -INFO - dataset_builder:dataset_builder.py:198 - No attributes: (314, 13)
# 2021-06-10 12:01:22,812 -INFO - dataset_builder:dataset_builder.py:101 - Close web driver

# %%
df = pd.read_parquet(f'dataset/df/{DATASET_NAME}.parquet')

# %%
df = build_features(df)
# Out:
# 2021-06-10 12:01:23,276 -INFO - hidden:hidden.py:107 - build field "is_hidden"

# %%
elements_dict = build_elements_dict(df)

# %%
df[['tag_name', 'element_id', 'parent_id', 'upper_sibling', 'lower_sibling', 'displayed', 'is_hidden', 'x', 'y', 'width', 'height']]
# Out:
#     tag_name                    element_id                     parent_id  \
# 0       HTML  2617502933156822460153819529                          None
# 1       HEAD  7834860721156822467683198525  2617502933156822460153819529
# 2       META  8519021078156822465021495363  7834860721156822467683198525
# 3      TITLE  2953497250156822466761725424  7834860721156822467683198525
# 4       META  3310340280156822465770358341  7834860721156822467683198525
# ..       ...                           ...                           ...
# 552       LI  6220668244156822466432271852  1930077659156822461791847955
# 553        A  5996082587156822469503686198  6220668244156822466432271852
# 554   SCRIPT  0282980711156822463123901763  9513258682156822461133902957
# 555   SCRIPT  3704282148156822464722210661  9513258682156822461133902957
# 556   SCRIPT  2912525444156822461016663501  9513258682156822461133902957
#
#                     upper_sibling                 lower_sibling  displayed  \
# 0                            None                          None       True
# 1                            None  9513258682156822461133902957      False
# 2                            None  2953497250156822466761725424      False
# 3    8519021078156822465021495363  3310340280156822465770358341      False
# 4    2953497250156822466761725424  4859441199156822466373079181      False
# ..                            ...                           ...        ...
# 552  6852418105156822465541246107                          None       True
# 553                          None                          None       True
# 554  3463411494156822468819587510  3704282148156822464722210661      False
# 555  0282980711156822463123901763  2912525444156822461016663501      False
# 556  3704282148156822464722210661                          None      False
#
#      is_hidden            x       y        width  height
# 0            0     0.000000     0.0  1183.000000  2593.0
# 1            0     0.000000     0.0     0.000000     0.0
# 2            0     0.000000     0.0     0.000000     0.0
# 3            0     0.000000     0.0     0.000000     0.0
# 4            0     0.000000     0.0     0.000000     0.0
# ..         ...          ...     ...          ...     ...
# 552          0  1115.890625  2571.0    64.109375    15.0
# 553          0  1115.890625  2571.0    64.109375    15.0
# 554          1     0.000000     0.0     0.000000     0.0
# 555          1     0.000000     0.0     0.000000     0.0
# 556          1     0.000000     0.0     0.000000     0.0
#
# [557 rows x 11 columns]

# %%
# img = load_gray_image(f'dataset/images/{DATASET_NAME}.png')
# img_height, img_width = img.shape
# print(img_width, img_height)
# plt.figure(figsize=(15, 100))
# plt.imshow(img, cmap='gray')

# %%
predictions_df = rule_base_predict(df)
print(predictions_df.shape)
# predictions_df
# Out:
# 2021-06-10 12:01:23,768 -INFO - common:common.py:491 - Num radio buttons found: 0
# 2021-06-10 12:01:23,771 -INFO - common:common.py:495 - Num radio2 buttons found: 0
# 2021-06-10 12:01:23,773 -INFO - common:common.py:502 - Num checkboxes found: 0
# 2021-06-10 12:01:23,776 -INFO - common:common.py:509 - Num comboboxes/dropdowns found: 0
# 2021-06-10 12:01:23,778 -INFO - common:common.py:520 - Num textfields found: 2
# 2021-06-10 12:01:23,781 -INFO - common:common.py:525 - Num texfields for numbers found: 0
# 2021-06-10 12:01:23,784 -INFO - common:common.py:530 - Num ranges found: 0
# 2021-06-10 12:01:23,786 -INFO - common:common.py:535 - Num ordinary text inputs found: 0
# 2021-06-10 12:01:23,788 -INFO - common:common.py:538 - Num buttons found: 2
# 2021-06-10 12:01:23,789 -INFO - common:common.py:543 - Num buttons1 found: 1
# 2021-06-10 12:01:23,793 -INFO - common:common.py:548 - Num buttons2 (Material-UI) found: 0
# 2021-06-10 12:01:23,794 -INFO - common:common.py:553 - Num links found: 52
# (36, 8)

# %%
img = load_gray_image(f'dataset/images/{DATASET_NAME}.png')
img_height, img_width = img.shape
print(img_width, img_height)
plt.figure(figsize=(15, 100))
plt.imshow(img, cmap='gray')
axes = plt.gca()

for _, r in predictions_df.iterrows():
    
    patch = patches.Rectangle((r.x, r.y), r.width, r.height, linewidth=2, alpha = .3, facecolor = 'red', edgecolor ='black')
    axes.add_patch(patch)
    plt.text(r.x, r.y, 
             decoder_dict[r.label] + ':',  ## + r.element_id, 
             fontsize = 10, 
             color = 'white', 
             backgroundcolor='black',
             alpha=1.)
# Out:
# 1200 2610

# %% [markdown]
# # Generate and Save Labels

# %%
# labels = build_to_yolo(df = predictions_df, img_width=img_width, img_heght=img_height)
# labels

# %%
# labeled_df = pd.DataFrame(labels, columns=['label', 'x', 'y', 'width', 'height'])
# labeled_df.label = labeled_df.label.astype(int)
# display(labeled_df)
# labeled_df.to_csv(f'dataset/annotations/{DATASET_NAME}.txt', header=False, sep=' ', index=False)

# %% [markdown]
# # Preview Labels

# %%
boxes_df = pd.read_csv(f'dataset/annotations/{DATASET_NAME}.txt', sep=' ', names = ['label', 'x', 'y', 'width', 'height'])
boxes_df
boxes_df['box'] = boxes_df.apply(lambda r: from_yolo(r.x, r.y, r.width, r.height, img_width=img_width, img_height=img_height), axis=1)
boxes_df.head()
# Out:
#    label         x         y     width    height                 box
# 0      0  0.841667  0.010728  0.016667  0.007663  (1000, 17, 20, 20)
# 1      1  0.051250  0.010920  0.072500  0.007280    (18, 19, 87, 19)
# 2      1  0.211250  0.011303  0.054167  0.021839    (220, 1, 65, 56)
# 3      1  0.289583  0.011303  0.102500  0.021839   (285, 1, 122, 56)
# 4      1  0.378750  0.011303  0.077500  0.021839    (407, 1, 93, 56)

# %%
img = load_gray_image(f'dataset/images/{DATASET_NAME}.png')
img_height, img_width = img.shape
print(img_width, img_height)
plt.figure(figsize=(15, 100))
plt.imshow(img, cmap='gray')
axes = plt.gca()

for i, r in boxes_df.iterrows():
    x, y, w, h = from_yolo(r.x, r.y, r.width, r.height, img_width=img_width, img_height=img_height)    
    patch = patches.Rectangle((x, y), w, h, linewidth=2, alpha = .3, facecolor = 'red', edgecolor ='black')
    axes.add_patch(patch)
    plt.text(x, y, 
             f'({i})' + decoder_dict[r.label] + ':',  ## + r.element_id, 
             fontsize = 10, 
             color = 'white', 
             backgroundcolor='black',
             alpha=1.)
# Out:
# 1200 2610

# %%
# df = pd.read_parquet(f'dataset/df/{DATASET_NAME}.parquet')
df.columns
# Out:
# Index(['attributes', 'displayed', 'element_id', 'height', 'onmouseenter',
#        'onmouseover', 'parent_id', 'style', 'tag_name', 'text', 'width', 'x',
#        'y', 'is_hidden', 'upper_sibling', 'lower_sibling', 'siblings'],
#       dtype='object')

# %%
df = assign_labels(df=df, annotations_file_path=f'dataset/annotations/{DATASET_NAME}.txt', img_width=img_width, img_height=img_height)
# Out:
# 2021-06-10 12:01:25,402 -INFO - labels:labels.py:41 - Assign labels from annotation file: dataset/annotations/simple-table.txt
# 2021-06-10 12:01:25,404 -INFO - labels:labels.py:43 - Getting image size
# 2021-06-10 12:01:25,405 -INFO - labels:labels.py:45 - Image size (w,h): (1200, 2610)
# 2021-06-10 12:01:25,405 -INFO - labels:labels.py:50 - {'button': 0, 'link': 1, 'textfield': 2, 'dropdown': 3, 'checkbox': 4, 'radiobutton': 5, 'textarea': 6, 'fileinput': 7, 'iframe': 8, 'range': 9, 'progressbar': 10, 'datetimeselector': 11, 'colorpicker': 12, 'numberselector': 13, 'selector': 14, 'table': 15, 'slider-toggle': 16, 'slider': 17, 'tree-node': 18, 'steper': 19, 'tab': 20, 'n/a': 21}
# 2021-06-10 12:01:25,406 -INFO - labels:labels.py:58 - getting "n/a" class code
# 2021-06-10 12:01:25,406 -INFO - labels:labels.py:65 - "n/a" class code: 21
# 2021-06-10 12:01:25,408 -INFO - labels:labels.py:75 - 46 annotation has been read
# Assign labels:   0%|          | 0/46 [00:00<?, ?it/s]
# 2021-06-10 12:01:28,066 -INFO - labels:labels.py:124 - labels_df: Index(['idx', 'label', 'annotation_line_no', 'iou', 'tag', 'label_text'], dtype='object')
# 2021-06-10 12:01:28,067 -INFO - labels:labels.py:127 - 46 labels have been assigned

# %%
# df = build_labels(df=df, annotations_file_path=f'dataset/annotations/{DATASET_NAME}.txt', img_width=0, img_height=0)

# %%
df.label.value_counts()
# Out:
# 21    511
# 1      37
# 15      8
# 0       1
# Name: label, dtype: int64

# %%
img = load_gray_image(f'dataset/images/{DATASET_NAME}.png')
img_height, img_width = img.shape
print(img_width, img_height)
plt.figure(figsize=(15, 100))
plt.imshow(img, cmap='gray')
axes = plt.gca()

for _, r in df[df.label_text != 'n/a'].iterrows():
    x, y, w, h = r.x, r.y, r.width, r.height  
    patch = patches.Rectangle((x, y), w, h, linewidth=2, alpha = .3, facecolor = 'red', edgecolor ='black')
    
    # print(r.tag_name, r.label_text, (x,y,w,h), r.element_id)
    
    axes.add_patch(patch)
    plt.text(x, y, 
             decoder_dict[r.label] + ':' + r.tag_name, # + ':' + str((x, y, w, h)),  ## + r.element_id, 
             fontsize = 10, 
             color = 'white', 
             backgroundcolor='black',
             alpha=1.)
# Out:
# 1200 2610
