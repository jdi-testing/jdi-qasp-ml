# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'HTML5_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/html5_dataset')

# %%
DATASET_NAME = 'cbracco'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://cbracco.github.io/html5-test-page/'
PREDICT_URL = 'http://localhost:5050/html5-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 2
# HEADLESS = True

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2022-01-25 15:38:06,544 -INFO - dataset_builder.py:100 - Dataset name: cbracco
# 2022-01-25 15:38:06,545 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2022-01-25 15:38:06,547 -INFO - dataset_builder.py:152 - Creating driver
# 2022-01-25 15:38:07,418 -INFO - dataset_builder.py:164 - Chrome web driver is created
# 2022-01-25 15:38:08,446 -INFO - common.py:22 - Window maximized
# 2022-01-25 15:38:15,449 -INFO - dataset_builder.py:167 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/images/cbracco.png
# 2022-01-25 15:38:21,566 -INFO - dataset_builder.py:211 - Collect features using JS script
# 2022-01-25 15:38:21,931 -INFO - dataset_builder.py:219 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/html/cbracco.html
# 2022-01-25 15:38:21,940 -INFO - dataset_builder.py:231 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/df/cbracco.pkl
# 2022-01-25 15:38:21,944 -INFO - dataset_builder.py:234 - No attributes: (301, 14)
# 2022-01-25 15:38:21,971 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '3060354668143015738114027681',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 3405.453125,
#   'width': 1484.0,
#   'height': 484.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 718256.0},
#  {'element_id': '4388473115143015746326695219',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7460.796875,
#   'width': 1452.0,
#   'height': 130.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 188760.0},
#  {'element_id': '7748549603143015739922589157',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1836.375,
#   'width': 579.1875,
#   'height': 152.0,
#   'predicted_label': 'table',
#   'predicted_probability': 1.0,
#   'sort_key': 88036.5},
#  {'element_id': '9548816000143015738482479146',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 21.4375,
#   'width': 1484.0,
#   'height': 37.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 54908.0},
#  {'element_id': '5418432879143015733641470952',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1035.03125,
#   'width': 1484.0,
#   'height': 36.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 53424.0},
#  {'element_id': '2092885961143015742186016441',
#   'is_hidden': 0,
#   'x': 82.84375,
#   'y': 7460.796875,
#   'width': 405.0,
#   'height': 126.0,
#   'predicted_label': 'textarea',
#   'predicted_probability': 1.0,
#   'sort_key': 51030.0},
#  {'element_id': '8915016926143015743169339352',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5596.671875,
#   'width': 1484.0,
#   'height': 27.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 40068.0},
#  {'element_id': '5981157151143015736219977327',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 619.78125,
#   'width': 1484.0,
#   'height': 27.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 40068.0},
#  {'element_id': '1961279346143015735989087529',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 3270.921875,
#   'width': 1484.0,
#   'height': 27.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 40068.0},
#  {'element_id': '4679102772143015732079401290',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 749.3125,
#   'width': 1484.0,
#   'height': 27.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 40068.0},
#  {'element_id': '9190256941143015740057519794',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 6039.109375,
#   'width': 1484.0,
#   'height': 27.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 40068.0},
#  {'element_id': '1081183034143015746515454678',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5834.296875,
#   'width': 1484.0,
#   'height': 27.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 40068.0},
#  {'element_id': '2149039736143015746909764185',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5715.484375,
#   'width': 1484.0,
#   'height': 27.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 40068.0},
#  {'element_id': '8593306072143015734691939667',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 3317.828125,
#   'width': 1484.0,
#   'height': 27.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 40068.0},
#  {'element_id': '4754487124143015740585684671',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 6447.921875,
#   'width': 1484.0,
#   'height': 27.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 40068.0},
#  {'element_id': '9697557245143015735907119795',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2187.71875,
#   'width': 1484.0,
#   'height': 27.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 40068.0},
#  {'element_id': '8015767635143015734838102942',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 4928.234375,
#   'width': 1484.0,
#   'height': 27.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 40068.0},
#  {'element_id': '6190955242143015743267662149',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5341.859375,
#   'width': 1484.0,
#   'height': 27.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 40068.0},
#  {'element_id': '2934950211143015742625708334',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5087.046875,
#   'width': 1484.0,
#   'height': 27.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 40068.0},
#  {'element_id': '4957786221143015741472050625',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7708.390625,
#   'width': 1452.0,
#   'height': 27.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39204.0},
#  {'element_id': '3956683657143015744299206912',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7826.390625,
#   'width': 1452.0,
#   'height': 24.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 34848.0},
#  {'element_id': '1663303185143015748347638660',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7906.390625,
#   'width': 1452.0,
#   'height': 24.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 34848.0},
#  {'element_id': '6115388206143015741580975618',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7983.390625,
#   'width': 1452.0,
#   'height': 24.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 34848.0},
#  {'element_id': '1522879134143015741163754230',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7866.390625,
#   'width': 1452.0,
#   'height': 24.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 34848.0},
#  {'element_id': '9206500038143015730327059840',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2705.0625,
#   'width': 1484.0,
#   'height': 22.328125,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 33134.9375},
#  {'element_id': '2464367071143015736618247263',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2743.390625,
#   'width': 1484.0,
#   'height': 22.1875,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 32926.25},
#  {'element_id': '5392210177143015731903077463',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 3090.296875,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '6532772657143015733423969473',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 796.21875,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '4057378420143015730629748397',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2392.34375,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '4331879700143015731735125716',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1795.65625,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '4327367503143015733080999280',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2041.09375,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '7622921719143015737308356433',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 666.6875,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '1558506059143015733702090632',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1439.34375,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '8675217371143015732723857061',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 3908.171875,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '2269512193143015734848469936',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1303.1875,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '9853596134143015731030892812',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1123.75,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '5171942457143015734527335950',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 3364.734375,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '4429093717143015735551783815',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1552.78125,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '0355414686143015739089948485',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1700.21875,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '5117388227143015732337606017',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 4391.609375,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '9173043506143015734696796433',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 707.40625,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '1042234198143015733076811200',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1343.90625,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '0329204316143015730682721805',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 994.3125,
#   'width': 1484.0,
#   'height': 22.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 32648.0},
#  {'element_id': '8296944860143015747240852865',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7788.390625,
#   'width': 1452.0,
#   'height': 22.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 31944.0},
#  {'element_id': '4428604069143015741125694349',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6534.421875,
#   'width': 1452.0,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 30492.0},
#  {'element_id': '7123481904143015749659357739',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 8161.984375,
#   'width': 1452.0,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 30492.0},
#  {'element_id': '5720198899143015744236429596',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6830.421875,
#   'width': 1452.0,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 30492.0},
#  {'element_id': '8441765135143015747470103049',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7946.390625,
#   'width': 1452.0,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 30492.0},
#  {'element_id': '8919580725143015741436842399',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6571.421875,
#   'width': 1452.0,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 30492.0},
#  {'element_id': '9848284409143015741171704832',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 8124.984375,
#   'width': 1452.0,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 30492.0},
#  {'element_id': '2063282712143015740312189268',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6793.421875,
#   'width': 1452.0,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 30492.0},
#  {'element_id': '6356222234143015749368531257',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6682.421875,
#   'width': 1452.0,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 30492.0},
#  {'element_id': '1937323138143015747934097667',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6608.421875,
#   'width': 1452.0,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 30492.0},
#  {'element_id': '8798960027143015744608429032',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6719.421875,
#   'width': 1452.0,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 30492.0},
#  {'element_id': '8799829348143015748722745226',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6645.421875,
#   'width': 1452.0,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 30492.0},
#  {'element_id': '1464427879143015745167169082',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7751.390625,
#   'width': 1452.0,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 30492.0},
#  {'element_id': '0447190963143015745986136000',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6756.421875,
#   'width': 1452.0,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 30492.0},
#  {'element_id': '7351048317143015749955710608',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6969.015625,
#   'width': 1452.0,
#   'height': 19.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 27588.0},
#  {'element_id': '4048449566143015736265481744',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2569.0625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '5072548349143015731623859114',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 4890.328125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '3652459210143015730283570150',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 3053.578125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '4987253632143015748009011760',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5558.765625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '6456008870143015747436287528',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 7209.609375,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '8015350390143015730465193472',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 839.484375,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '7661959040143015735789803080',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2883.578125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '7796982624143015732140519958',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2004.375,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '5230865639143015743487995225',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 8226.984375,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '4944080851143015736515144570',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2671.0625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '6929346206143015735727487795',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2985.578125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '5230254665143015736315434876',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2355.625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '4335672345143015730180046628',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2815.578125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '4439120426143015738775667792',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1087.03125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '5393171396143015734908999050',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2467.0625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '8064669829143015733674439357',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2603.0625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '3524700521143015733789189452',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2149.8125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '8069474224143015734147354713',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 3019.578125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '8833947098143015747273667927',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 6895.421875,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '9905407410143015746227306039',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 6410.015625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '0431888991143015741349299184',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 7032.015625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '0494527579143015740956571731',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 8051.390625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '7315435780143015748637967955',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5677.578125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '0647771752143015748484453756',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 7387.203125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '0653074171143015732346853713',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2849.578125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '9511071566143015738715497943',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2115.8125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '0961889455143015732170912970',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2951.578125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '1037799612143015735584423268',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 957.59375,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '9234708362143015733777474400',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2917.578125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '6141286717143015732193321568',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 79.875,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '6071146248143015749676496114',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 8260.984375,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '9022268030143015734055704934',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 3131.015625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '6647386497143015733162895296',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1266.46875,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '5878520612143015748299565208',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5049.140625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '1790334424143015748048658561',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 7634.796875,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '5537245965143015731712617871',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2781.578125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '3370029492143015732212231017',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2637.0625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '3367256927143015731337190958',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 3165.015625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '3356694011143015745239232607',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 6001.203125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '3312894441143015730418194281',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2081.8125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '6693897183143015736907513316',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 3233.015625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '2602838639143015731466307888',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1758.9375,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '2465672470143015741756593145',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5796.390625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '6695139820143015739595825671',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1663.5,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '7651950028143015736887720980',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2535.0625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '2130842764143015737422299604',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2501.0625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '1840441519143015745616808536',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5303.953125,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '5152644974143015736613443596',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2433.0625,
#   'width': 1484.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 26712.0},
#  {'element_id': '1307209594143015733862130002',
#   'is_hidden': 0,
#   'x': 48.0,
#   'y': 1164.46875,
#   'width': 1404.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 25272.0},
#  {'element_id': '5985991780143015739199719505',
#   'is_hidden': 0,
#   'x': 48.0,
#   'y': 1198.46875,
#   'width': 1404.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 25272.0},
#  {'element_id': '8540424241143015735835508425',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 879.65625,
#   'width': 1484.0,
#   'height': 16.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 23744.0},
#  {'element_id': '7126982182143015734202481845',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 920.625,
#   'width': 1484.0,
#   'height': 12.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 17808.0},
#  {'element_id': '3271391052143015745777977613',
#   'is_hidden': 0,
#   'x': 159.953125,
#   'y': 7983.390625,
#   'width': 213.0,
#   'height': 24.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 5112.0},
#  {'element_id': '8543507001143015741540511857',
#   'is_hidden': 0,
#   'x': 107.5625,
#   'y': 7866.390625,
#   'width': 183.0,
#   'height': 24.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 4392.0},
#  {'element_id': '9821231032143015749750248071',
#   'is_hidden': 0,
#   'x': 100.921875,
#   'y': 7906.390625,
#   'width': 175.0,
#   'height': 24.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 4200.0},
#  {'element_id': '2961621868143015749640720894',
#   'is_hidden': 0,
#   'x': 95.09375,
#   'y': 7826.390625,
#   'width': 153.0,
#   'height': 24.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 3672.0},
#  {'element_id': '8936892083143015749268864214',
#   'is_hidden': 0,
#   'x': 121.765625,
#   'y': 6645.421875,
#   'width': 153.0,
#   'height': 21.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 3213.0},
#  {'element_id': '4569153517143015742757628712',
#   'is_hidden': 0,
#   'x': 61.765625,
#   'y': 6793.421875,
#   'width': 153.0,
#   'height': 21.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 3213.0},
#  {'element_id': '6940233484143015747403364865',
#   'is_hidden': 0,
#   'x': 61.78125,
#   'y': 6830.421875,
#   'width': 153.0,
#   'height': 21.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 3213.0},
#  {'element_id': '6533196955143015748892935071',
#   'is_hidden': 0,
#   'x': 124.4375,
#   'y': 6682.421875,
#   'width': 153.0,
#   'height': 21.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 3213.0},
#  {'element_id': '1326665016143015747974716477',
#   'is_hidden': 0,
#   'x': 123.53125,
#   'y': 7946.390625,
#   'width': 153.0,
#   'height': 21.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 3213.0},
#  {'element_id': '2475001732143015744953094353',
#   'is_hidden': 0,
#   'x': 89.34375,
#   'y': 6571.421875,
#   'width': 153.0,
#   'height': 21.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 3213.0},
#  {'element_id': '7046266148143015742781919438',
#   'is_hidden': 0,
#   'x': 71.53125,
#   'y': 6719.421875,
#   'width': 153.0,
#   'height': 21.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 3213.0},
#  {'element_id': '6027026273143015743527324631',
#   'is_hidden': 0,
#   'x': 112.484375,
#   'y': 6608.421875,
#   'width': 153.0,
#   'height': 21.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 3213.0},
#  {'element_id': '4710273055143015740131006181',
#   'is_hidden': 0,
#   'x': 93.984375,
#   'y': 6534.421875,
#   'width': 153.0,
#   'height': 21.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 3213.0},
#  {'element_id': '6786909627143015743976285194',
#   'is_hidden': 0,
#   'x': 118.203125,
#   'y': 6756.421875,
#   'width': 153.0,
#   'height': 21.0,
#   'predicted_label': 'numberselector',
#   'predicted_probability': 1.0,
#   'sort_key': 3213.0},
#  {'element_id': '7758643066143015744610715246',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 8161.984375,
#   'width': 144.578125,
#   'height': 21.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 3036.140625},
#  {'element_id': '7670739240143015744947281838',
#   'is_hidden': 0,
#   'x': 172.578125,
#   'y': 8161.984375,
#   'width': 142.375,
#   'height': 21.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2989.875},
#  {'element_id': '1356427387143015740877877665',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 8124.984375,
#   'width': 136.421875,
#   'height': 21.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2864.859375},
#  {'element_id': '2425531767143015743058186839',
#   'is_hidden': 0,
#   'x': 318.953125,
#   'y': 8161.984375,
#   'width': 134.953125,
#   'height': 21.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2834.015625},
#  {'element_id': '8535193122143015741276162771',
#   'is_hidden': 0,
#   'x': 164.421875,
#   'y': 8124.984375,
#   'width': 134.234375,
#   'height': 21.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2818.921875},
#  {'element_id': '1294584102143015748453446449',
#   'is_hidden': 0,
#   'x': 302.65625,
#   'y': 8124.984375,
#   'width': 126.796875,
#   'height': 21.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2662.734375},
#  {'element_id': '0506406410143015746706989896',
#   'is_hidden': 0,
#   'x': 457.90625,
#   'y': 8161.984375,
#   'width': 122.0,
#   'height': 21.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2562.0},
#  {'element_id': '7595466651143015748068437374',
#   'is_hidden': 0,
#   'x': 433.453125,
#   'y': 8124.984375,
#   'width': 113.84375,
#   'height': 21.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2390.71875},
#  {'element_id': '7835826261143015741721347332',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7984.890625,
#   'width': 131.953125,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 2243.203125},
#  {'element_id': '6108537021143015741655921589',
#   'is_hidden': 0,
#   'x': 67.09375,
#   'y': 6969.015625,
#   'width': 115.0,
#   'height': 19.0,
#   'predicted_label': 'dropdown',
#   'predicted_probability': 1.0,
#   'sort_key': 2185.0},
#  {'element_id': '6011522011143015741764938867',
#   'is_hidden': 0,
#   'x': 107.765625,
#   'y': 7790.390625,
#   'width': 129.0,
#   'height': 16.0,
#   'predicted_label': 'range',
#   'predicted_probability': 1.0,
#   'sort_key': 2064.0},
#  {'element_id': '9122155623143015739073595547',
#   'is_hidden': 0,
#   'x': 48.0,
#   'y': 293.875,
#   'width': 119.515625,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2031.765625},
#  {'element_id': '1531573505143015735303947529',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 275.875,
#   'width': 118.078125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2007.328125},
#  {'element_id': '6821937192143015733021760586',
#   'is_hidden': 0,
#   'x': 48.0,
#   'y': 1232.46875,
#   'width': 113.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1926.3125},
#  {'element_id': '6922024020143015731611702671',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2433.0625,
#   'width': 111.109375,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1888.859375},
#  {'element_id': '4324878628143015736303320417',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 203.875,
#   'width': 103.53125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1760.03125},
#  {'element_id': '5471371934143015735459728382',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 257.875,
#   'width': 98.1875,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1669.1875},
#  {'element_id': '5317484561143015731915576595',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 563.875,
#   'width': 96.453125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1639.703125},
#  {'element_id': '5635015802143015748921199571',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6683.421875,
#   'width': 96.4375,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1639.4375},
#  {'element_id': '1799362448143015737349366021',
#   'is_hidden': 0,
#   'x': 48.0,
#   'y': 455.875,
#   'width': 95.546875,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1624.296875},
#  {'element_id': '5061486841143015749005763345',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7947.390625,
#   'width': 95.53125,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1624.03125},
#  {'element_id': '9976763186143015735526690155',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 581.875,
#   'width': 94.671875,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1609.421875},
#  {'element_id': '2722740749143015748130344501',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6646.421875,
#   'width': 93.765625,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1594.015625},
#  {'element_id': '8233381810143015740622148830',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6757.421875,
#   'width': 90.203125,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1533.453125},
#  {'element_id': '1397078605143015733476065864',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 527.875,
#   'width': 89.34375,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1518.84375},
#  {'element_id': '7684717650143015746828644192',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7752.390625,
#   'width': 89.328125,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1518.578125},
#  {'element_id': '5204463504143015734614786974',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 491.875,
#   'width': 84.875,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1442.875},
#  {'element_id': '0711762796143015746119122828',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6609.421875,
#   'width': 84.484375,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1436.234375},
#  {'element_id': '2039880662143015746162022438',
#   'is_hidden': 0,
#   'x': 64.0,
#   'y': 7107.609375,
#   'width': 84.0,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1428.0},
#  {'element_id': '6260143829143015743224757838',
#   'is_hidden': 0,
#   'x': 64.0,
#   'y': 7127.609375,
#   'width': 84.0,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1428.0},
#  {'element_id': '5801019791143015747499717409',
#   'is_hidden': 0,
#   'x': 64.0,
#   'y': 7147.609375,
#   'width': 84.0,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1428.0},
#  {'element_id': '0853146764143015740476328393',
#   'is_hidden': 0,
#   'x': 64.0,
#   'y': 7305.203125,
#   'width': 81.453125,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1384.703125},
#  {'element_id': '1461008330143015744197714604',
#   'is_hidden': 0,
#   'x': 64.0,
#   'y': 7285.203125,
#   'width': 81.453125,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1384.703125},
#  {'element_id': '1113556031143015746833591893',
#   'is_hidden': 0,
#   'x': 64.0,
#   'y': 7325.203125,
#   'width': 81.453125,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1384.703125},
#  {'element_id': '4150026283143015730050207311',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 167.875,
#   'width': 80.0,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1360.0},
#  {'element_id': '2306423188143015749980562744',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7867.890625,
#   'width': 79.5625,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1352.5625},
#  {'element_id': '2153401571143015742116087149',
#   'is_hidden': 0,
#   'x': 101.34375,
#   'y': 7708.390625,
#   'width': 50.0,
#   'height': 27.0,
#   'predicted_label': 'colorpicker',
#   'predicted_probability': 1.0,
#   'sort_key': 1350.0},
#  {'element_id': '7204330255143015731770374647',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 221.875,
#   'width': 79.28125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1347.78125},
#  {'element_id': '8399840597143015737463426502',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 509.875,
#   'width': 78.203125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1329.453125},
#  {'element_id': '0037892375143015746996940424',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7792.390625,
#   'width': 77.765625,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1322.015625},
#  {'element_id': '8191832522143015744861871854',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5644.765625,
#   'width': 80.0,
#   'height': 16.0,
#   'predicted_label': 'progressbar',
#   'predicted_probability': 1.0,
#   'sort_key': 1280.0},
#  {'element_id': '5759632327143015745549499060',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7715.390625,
#   'width': 73.34375,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1246.84375},
#  {'element_id': '1667660428143015736816473239',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 419.875,
#   'width': 73.328125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1246.578125},
#  {'element_id': '1367628601143015733048162298',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 473.875,
#   'width': 73.328125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1246.578125},
#  {'element_id': '6427563855143015749033419594',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7907.890625,
#   'width': 72.921875,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1239.671875},
#  {'element_id': '0433478617143015731195807697',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 149.875,
#   'width': 71.09375,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1208.59375},
#  {'element_id': '3602427651143015744168417865',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7827.890625,
#   'width': 67.09375,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1140.59375},
#  {'element_id': '6110122138143015745335305967',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6535.421875,
#   'width': 65.984375,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1121.734375},
#  {'element_id': '3410673418143015742565868949',
#   'is_hidden': 0,
#   'x': 68.4375,
#   'y': 8260.984375,
#   'width': 64.46875,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1095.96875},
#  {'element_id': '1297720529143015749394775579',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6572.421875,
#   'width': 61.34375,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1042.84375},
#  {'element_id': '9135081677143015731140339168',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 545.875,
#   'width': 61.0625,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1038.0625},
#  {'element_id': '9818497409143015733540675540',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 131.875,
#   'width': 60.4375,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1027.4375},
#  {'element_id': '1661739150143015730091202595',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 401.875,
#   'width': 55.109375,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 936.859375},
#  {'element_id': '2909264098143015745085475937',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 7572.796875,
#   'width': 54.84375,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 932.34375},
#  {'element_id': '3248290353143015733661075206',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 437.875,
#   'width': 52.4375,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 891.4375},
#  {'element_id': '8298468282143015748028792995',
#   'is_hidden': 0,
#   'x': 117.328125,
#   'y': 7751.390625,
#   'width': 42.0,
#   'height': 21.0,
#   'predicted_label': 'numberselector',
#   'predicted_probability': 1.0,
#   'sort_key': 882.0},
#  {'element_id': '5007059084143015743630370634',
#   'is_hidden': 0,
#   'x': 198.6875,
#   'y': 8260.984375,
#   'width': 48.0,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 816.0},
#  {'element_id': '0798356673143015731553949433',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 365.875,
#   'width': 47.109375,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 800.859375},
#  {'element_id': '7867488632143015731252268527',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 311.875,
#   'width': 46.203125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 785.453125},
#  {'element_id': '0940514265143015748483727820',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6720.421875,
#   'width': 43.53125,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 740.03125},
#  {'element_id': '0368372543143015735606535971',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 329.875,
#   'width': 40.0,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 680.0},
#  {'element_id': '8736019867143015740135835567',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6969.015625,
#   'width': 39.09375,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 664.59375},
#  {'element_id': '6988642470143015730786128379',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 383.875,
#   'width': 38.203125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 649.453125},
#  {'element_id': '9300619378143015739469431955',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 347.875,
#   'width': 38.140625,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 648.390625},
#  {'element_id': '8874398786143015744203833376',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5303.953125,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '9326158391143015737621468119',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1663.5,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '8944389405143015747753080087',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5049.140625,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '1452927223143015732728421604',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 957.59375,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '9074690428143015732154778910',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1266.46875,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '1775708466143015741840893151',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 8051.390625,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '1657729755143015730372031975',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 4890.328125,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '6905482320143015743925249045',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 8226.984375,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '8608090301143015747663037340',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 6895.421875,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '4726851782143015744118047461',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 6001.203125,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '6519480664143015747827591830',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 6410.015625,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '6976965465143015748527211798',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5677.578125,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '7012422245143015732638133841',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1087.03125,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '6310068458143015749144164950',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5558.765625,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '6259679473143015741662646778',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 7209.609375,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '7377984111143015732577238445',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 3233.015625,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '5169534550143015734024488659',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 1758.9375,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '2233018952143015747892828964',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 7032.015625,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '3120581799143015735791621121',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2004.375,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '4376183021143015740368822019',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 5796.390625,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '4235398246143015745259915761',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 7634.796875,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '4118885161143015735558393330',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 2355.625,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '3518913988143015731519574502',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 3053.578125,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '8089498312143015740014392242',
#   'is_hidden': 0,
#   'x': 8.0,
#   'y': 7387.203125,
#   'width': 35.3125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 600.3125},
#  {'element_id': '7458940523143015736525145077',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 239.875,
#   'width': 33.78125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 574.28125},
#  {'element_id': '9975812442143015746201664273',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6831.421875,
#   'width': 33.78125,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 574.28125},
#  {'element_id': '1283229682143015745727588783',
#   'is_hidden': 0,
#   'x': 24.0,
#   'y': 6794.421875,
#   'width': 33.765625,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 574.015625},
#  {'element_id': '5033731168143015738194642501',
#   'is_hidden': 0,
#   'x': 88.0,
#   'y': 185.875,
#   'width': 31.125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 529.125},
#  {'element_id': '0747534095143015731592343995',
#   'is_hidden': 0,
#   'x': 48.0,
#   'y': 113.875,
#   'width': 28.203125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 479.453125},
#  {'element_id': '4231079172143015744368192030',
#   'is_hidden': 0,
#   'x': 69.0,
#   'y': 7306.203125,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '3775949831143015740075615489',
#   'is_hidden': 0,
#   'x': 68.0,
#   'y': 7148.609375,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '6307412775143015748854888758',
#   'is_hidden': 0,
#   'x': 68.0,
#   'y': 7128.609375,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '1531241635143015743872151276',
#   'is_hidden': 0,
#   'x': 69.0,
#   'y': 7326.203125,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '6828072105143015744661040623',
#   'is_hidden': 0,
#   'x': 68.0,
#   'y': 7108.609375,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '1154059561143015749787769971',
#   'is_hidden': 0,
#   'x': 69.0,
#   'y': 7286.203125,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0}]
# CPU times: user 79 ms, sys: 11.4 ms, total: 90.4 ms
# Wall time: 1.28 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id  is_hidden     x            y      width  \
# 0  3060354668143015738114027681          0   8.0  3405.453125  1484.0000
# 1  4388473115143015746326695219          0  24.0  7460.796875  1452.0000
# 2  7748549603143015739922589157          0   8.0  1836.375000   579.1875
# 3  9548816000143015738482479146          0   8.0    21.437500  1484.0000
# 4  5418432879143015733641470952          0   8.0  1035.031250  1484.0000
#
#    height predicted_label  predicted_probability  sort_key tag_name
# 0   484.0            text                    1.0  718256.0        P
# 1   130.0            text                    1.0  188760.0        P
# 2   152.0           table                    1.0   88036.5    TABLE
# 3    37.0           title                    1.0   54908.0       H1
# 4    36.0            text                    1.0   53424.0        P

# %%
predictions_df.predicted_label.unique()
# Out:
# array(['text', 'table', 'title', 'textarea', 'datetimeselector',
#        'textfield', 'numberselector', 'button', 'label', 'dropdown',
#        'range', 'link', 'colorpicker', 'progressbar', 'radiobutton',
#        'checkbox'], dtype=object)

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
        if r.is_hidden==0:
                patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
                axes.add_patch(patch)
                axes.text(r.x*2, r.y*2, 
                        str(r.predicted_label) + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                        backgroundcolor='black', 
                        color='white',
                        bbox=dict(alpha=0.5))
