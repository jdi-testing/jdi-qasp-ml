# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-11-24 13:23:08,230 -INFO - config.py:31 - Module utils.config was loaded
# 2021-11-24 13:23:08,254 -INFO - common.py:127 - Module utils.common is loaded...
# 2021-11-24 13:23:08,255 -INFO - dataset_builder.py:244 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'material-ui-Buttons'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click()
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click()
        driver.find_element_by_xpath("/html/body/div/div/div/div[1]/div/div[2]/div/div").click()
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-11-24 13:23:13,744 -INFO - dataset_builder.py:100 - Dataset name: material-ui-Buttons
# 2021-11-24 13:23:13,745 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-11-24 13:23:13,747 -INFO - dataset_builder.py:150 - Creating driver
# 2021-11-24 13:23:14,931 -INFO - dataset_builder.py:162 - Chrome web driver is created
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   # This is added back by InteractiveShellApp.init_path()
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if sys.path[0] == '':
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   del sys.path[0]
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   app.launch_new_instance()
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2021-11-24 13:23:27,197 -INFO - common.py:30 - Window maximized
# 2021-11-24 13:23:34,202 -INFO - dataset_builder.py:165 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/material-ui-Buttons.png
# 2021-11-24 13:23:40,344 -INFO - dataset_builder.py:209 - Collect features using JS script
# 2021-11-24 13:23:40,895 -INFO - dataset_builder.py:217 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/material-ui-Buttons.html
# 2021-11-24 13:23:40,911 -INFO - dataset_builder.py:229 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/material-ui-Buttons.pkl
# 2021-11-24 13:23:40,914 -INFO - dataset_builder.py:232 - No attributes: (15, 13)
# 2021-11-24 13:23:45,044 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '4950743516494203498955953049',
#   'x': 0.0,
#   'y': 1152.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7064686331494203499727951832',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6946850226494203493013177660',
#   'x': 0.0,
#   'y': 384.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6857174090494203499809819600',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6544092305494203492507151242',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6488524525494203491856589856',
#   'x': 0.0,
#   'y': 960.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5963300459494203498498488494',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5859953420494203490450784169',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5629861040494203495526256296',
#   'x': 0.0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5553254347494203495189695051',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5516848794494203496050332417',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5360320883494203490489402835',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5298443405494203498064680551',
#   'x': 0.0,
#   'y': 1536.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5239956731494203495195853816',
#   'x': 0.0,
#   'y': 2064.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5030930139494203491633205092',
#   'x': 0.0,
#   'y': 2160.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0103405292494203494745638739',
#   'x': 0.0,
#   'y': 1248.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999995232,
#   'sort_key': 12000.0},
#  {'element_id': '4941739204494203494907132119',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '
0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4041945719494203497125951225',
#   'x': 0.0,
#   'y': 432.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4166645808494203496653055502',
#   'x': 0.0,
#   'y': 1920.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4195936087494203496627166229',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0165295591494203497886848375',
#   'x': 0.0,
#   'y': 480.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '1606656353494203491476416399',
#   'x': 0.0,
#   'y': 2352.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4760734648494203508814830909',
#   'x': 420.46875,
#   'y': 751.71875,
#   'width': 153.640625,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999960661,
#   'sort_key': 5607.8828125},
#  {'element_id': '8776263789494203508653493807',
#   'x': 282.0,
#   'y': 751.71875,
#   'width': 122.46875,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4470.109375},
#  {'element_id': '7738315352494203502085486672',
#   'x': 500.328125,
#   'y': 146.21875,
#   'width': 115.984375,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.8965185285,
#   'sort_key': 4233.4296875},
#  {'element_id': '4639361507494203507523968404',
#   'x': 282.0,
#   'y': 439.84375,
#   'width': 107.515625,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 3924.3203125},
#  {'element_id': '9353735557494203505532709681',
#   'x': 389.25,
#   'y': 146.21875,
#   'width': 95.078125,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999526739,
#   'sort_key': 3470.3515625},
#  {'element_id': '0017981832494203503996072380',
#   'x': 282.0,
#   'y': 146.21875,
#   'width': 91.25,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 3330.625},
#  {'element_id': '8245514894494203508186492427',
#   'x': 282.0,
#   'y': 291.59375,
#   'width': 75.25,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999493361,
#   'sort_key': 2746.625},
#  {'element_id': '1778468588494203503388464363',
#   'x': 474.0,
#   'y': 594.09375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9933838248,
#   'sort_key': 2304.0},
#  {'element_id': '7484215177494203500854148003',
#   'x': 410.0,
#   'y': 594.09375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999090433,
#   'sort_key': 2304.0},
#  {'element_id': '6112252527494203506501564794',
#   'x': 346.0,
#   'y': 594.09375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2304.0},
#  {'element_id': '0252238532494203504774910718',
#   'x': 282.0,
#   'y': 594.09375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999983311,
#   'sort_key': 2304.0}]
# CPU times: user 59.7 ms, sys: 17.9 ms, total: 77.6 ms
# Wall time: 2.84 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id    x       y  width  height predicted_label  \
# 0  4950743516494203498955953049  0.0  1152.0  250.0    48.0          button
# 1  7064686331494203499727951832  0.0   864.0  250.0    48.0          button
# 2  6946850226494203493013177660  0.0   384.0  250.0    48.0          button
# 3  6857174090494203499809819600  0.0   864.0  250.0    48.0          button
# 4  6544092305494203492507151242  0.0  1056.0  250.0    48.0          button
#
#    predicted_probability  sort_key tag_name
# 0                    1.0   12000.0      DIV
# 1                    1.0   12000.0      DIV
# 2                    1.0   12000.0      DIV
# 3                    1.0   12000.0      DIV
# 4                    1.0   12000.0      DIV

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
