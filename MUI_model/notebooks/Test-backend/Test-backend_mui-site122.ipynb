# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
WORKING_DIR = re.sub('jdi-qasp-ml.*$','',os.path.normpath(os.getcwd())) + 'jdi-qasp-ml'
os.chdir(WORKING_DIR)

# %%
WORKING_DIR
# Out:
# 'C:\\WORK\\jdi-qasp-ml'

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-09-07 09:40:46,516 -INFO - config.py:25 - Module utils.config was loaded
# 2021-09-07 09:40:46,518 -INFO - common.py:618 - Module utils.common is loaded...
# 2021-09-07 09:40:46,520 -INFO - hidden.py:121 - hidden module is loaded
# 2021-09-07 09:40:46,522 -INFO - features_builder.py:305 - feature_bilder module is loaded...
# 2021-09-07 09:40:46,526 -INFO - dataset_builder.py:213 - dataset package is loaded...
# 2021-09-07 09:40:46,529 -INFO - dataset.py:277 - dataset module is loaded...

# %%
UTILS_LOGGER = 'utils.dataset'
LOG_FILE_PATH = 'tmp/log.txt'

os.makedirs(name='tmp', exist_ok=True)

logger = logging.getLogger(UTILS_LOGGER)
logger.setLevel(logging.DEBUG)


formatter = logging.Formatter('%(asctime)s -%(levelname)s - %(module)s:%(filename)s:%(lineno)d - %(message)s')

console_handler = logging.StreamHandler(sys.stdout)
console_handler.setFormatter(formatter)

file_handler = logging.FileHandler(filename=LOG_FILE_PATH, mode='w')
file_handler.setFormatter(formatter)

logger.addHandler(console_handler)
logger.addHandler(file_handler)

logger.info('Module utils.config was loaded')
# Out:
# 2021-09-07 09:40:46,550 -INFO - 632196539.py:21 - Module utils.config was loaded
# 2021-09-07 09:40:46,550 -INFO - 632196539:632196539.py:21 - Module utils.config was loaded

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# 'C:\\WORK\\jdi-qasp-ml'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'mui-site122'

# %%
SITE_URL = 'C:/WORK/jdi-qasp-ml/MUI_model/dataset/build/site122/index.html'

# %%
PREDICT_URL = 'http://localhost:5000/mui-predict'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path='./MUI_model/dataset/') as builder:
    plt.imshow(plt.imread(f'MUI_model/dataset/images/{DATASET_NAME}.png'))
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2021-09-07 09:40:46,656 -INFO - dataset_builder.py:78 - Dataset name: mui-site122
# 2021-09-07 09:40:46,656 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site122
# 2021-09-07 09:40:46,659 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-09-07 09:40:46,659 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-09-07 09:40:46,664 -INFO - dataset_builder.py:126 - Creating driver
# 2021-09-07 09:40:46,664 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-09-07 09:40:47,800 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-09-07 09:40:47,800 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-09-07 09:40:47,934 -INFO - 3258695736.py:10 - getting url: C:/WORK/jdi-qasp-ml/MUI_model/dataset/build/site122/index.html
# 2021-09-07 09:40:47,934 -INFO - 3258695736:3258695736.py:10 - getting url: C:/WORK/jdi-qasp-ml/MUI_model/dataset/build/site122/index.html
# 2021-09-07 09:40:51,514 -INFO - common.py:75 - Window maximized
# 2021-09-07 09:40:51,514 -INFO - common:common.py:75 - Window maximized
# 2021-09-07 09:40:58,518 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site122.png
# 2021-09-07 09:40:58,518 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site122.png
# 2021-09-07 09:41:00,082 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-09-07 09:41:00,082 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-09-07 09:41:01,493 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site122.html
# 2021-09-07 09:41:01,493 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site122.html
# 2021-09-07 09:41:01,536 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site122.pkl
# 2021-09-07 09:41:01,536 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site122.pkl
# 2021-09-07 09:41:01,540 -INFO - dataset_builder.py:204 - No attributes: (26, 13)
# 2021-09-07 09:41:01,540 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (26, 13)
# 2021-09-07 09:41:02,462 -INFO - dataset_builder.py:103 - Close web driver
# 2021-09-07 09:41:02,462 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '9612996082968601064966851098',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 1500.0,
#   'height': 15000.0,
#   'predicted_label': 'popover',
#   'predicted_probability': 0.9931508303,
#   'sort_key': 22500000.0},
#  {'element_id': '8759831815968601060564925749',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 1500.0,
#   'height': 15000.0,
#   'predicted_label': 'popover',
#   'predicted_probability': 0.9931553006,
#   'sort_key': 22500000.0},
#  {'element_id': '6068802060968601069533630197',
#   'x': 110.0,
#   'y': 6250.234375,
#   'width': 1280.0,
#   'height': 4800.0,
#   'predicted_label': 'container',
#   'predicted_probability': 0.9998525381,
#   'sort_key': 6144000.0},
#  {'element_id': '6254791986968601061587839707',
#   'x': 134.0,
#   'y': 6250.234375,
#   'width': 1232.0,
#   'height': 4800.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 5913600.0},
#  {'element_id': '3718713335968601043463543300',
#   'x': 0.0,
#   'y': 1606.96875,
#   'width': 1500.0,
#   'height': 422.78125,
#   'predicted_label': 'dialog',
#   'predicted_probability': 0.8450890183,
#   'sort_key': 634171.875},
#  {'element_id': '3530644066968601054596053568',
#   'x': 0.0,
#   'y': 2342.75,
#   'width': 1500.0,
#   'height': 342.0,
#   'predicted_label': 'dialog',
#   'predicted_probability': 0.5154204965,
#   'sort_key': 513000.0},
#  {'element_id': '9311264527968601043070560858',
#   'x': 0.0,
#   'y': 1264.96875,
#   'width': 1500.0,
#   'height': 342.0,
#   'predicted_label': 'dialog',
#   'predicted_probability': 0.5704889894,
#   'sort_key': 513000.0},
#  {'element_id': '9600967588968601040371810087',
#   'x': 0.0,
#   'y': 942.96875,
#   'width': 1500.0,
#   'height': 322.0,
#   'predicted_label': 'table',
#   'predicted_probability': 0.9976317883,
#   'sort_key': 483000.0},
#  {'element_id': '1440925373968601054091943758',
#   'x': 0.0,
#   'y': 2029.75,
#   'width': 1500.0,
#   'height': 313.0,
#   'predicted_label': 'dialog',
#   'predicted_probability': 0.9938767552,
#   'sort_key': 469500.0},
#  {'element_id': '4708602194968601060485079796',
#   'x': 0.0,
#   'y': 11150.234375,
#   'width': 1500.0,
#   'height': 305.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 0.9999980927,
#   'sort_key': 457500.0},
#  {'element_id': '2293919188968601067856126917',
#   'x': 1190.4000244141,
#   'y': 6178.2001953125,
#   'width': 1467.9998779297,
#   'height': 108.0,
#   'predicted_label': 'menu',
#   'predicted_probability': 0.9985489249,
#   'sort_key': 158543.9868164062},
#  {'element_id': '5982721613968601061531107681',
#   'x': 1190.4000244141,
#   'y': 6178.2001953125,
#   'width': 1467.9998779297,
#   'height': 108.0,
#   'predicted_label': 'menu',
#   'predicted_probability': 0.9985489249,
#   'sort_key': 158543.9868164062},
#  {'element_id': '8167618775968601068201151121',
#   'x': 0.0,
#   'y': 11856.234375,
#   'width': 240.0,
#   'height': 434.0,
#   'predicted_label': 'drawer',
#   'predicted_probability': 1.0,
#   'sort_key': 104160.0},
#  {'element_id': '5995276610968601058454171223',
#   'x': 0.0,
#   'y': 2812.75,
#   'width': 240.0,
#   'height': 433.0,
#   'predicted_label': 'drawer',
#   'predicted_probability': 1.0,
#   'sort_key': 103920.0},
#  {'element_id': '1097913152968601057262280260',
#   'x': 0.0,
#   'y': 4810.75,
#   'width': 360.0,
#   'height': 282.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 101520.0},
#  {'element_id': '5942163655968601057855427480',
#   'x': 0.0,
#   'y': 4462.75,
#   'width': 360.0,
#   'height': 282.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 101520.0},
#  {'element_id': '9059922746968601041344113293',
#   'x': 0.0,
#   'y': 654.96875,
#   'width': 345.0,
#   'height': 288.0,
#   'predicted_label': 'card',
#   'predicted_probability': 1.0,
#   'sort_key': 99360.0},
#  {'element_id': '7108342296968601051315878196',
#   'x': 0.0,
#   'y': 5928.234375,
#   'width': 360.0,
#   'height': 234.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 84240.0},
#  {'element_id': '7676268763968601056343665349',
#   'x': 0.0,
#   'y': 4040.75,
#   'width': 360.0,
#   'height': 211.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999383688,
#   'sort_key': 75960.0},
#  {'element_id': '2138652365968601058892544935',
#   'x': 0.0,
#   'y': 3649.75,
#   'width': 360.0,
#   'height': 211.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.999071002,
#   'sort_key': 75960.0},
#  {'element_id': '9932842141968601054518212618',
#   'x': 0.0,
#   'y': 4251.75,
#   'width': 360.0,
#   'height': 211.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999200106,
#   'sort_key': 75960.0},
#  {'element_id': '9539521733968601060873840426',
#   'x': 0.0,
#   'y': 11557.234375,
#   'width': 360.0,
#   'height': 211.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9995520711,
#   'sort_key': 75960.0},
#  {'element_id': '8516150101968601054342557465',
#   'x': 0.0,
#   'y': 3992.75,
#   'width': 1500.0,
#   'height': 48.0,
#   'predicted_label': 'alert',
#   'predicted_probability': 1.0,
#   'sort_key': 72000.0},
#  {'element_id': '0263562442968601068493867970',
#   'x': 0.0,
#   'y': 6202.234375,
#   'width': 1500.0,
#   'height': 48.0,
#   'predicted_label': 'alert',
#   'predicted_probability': 1.0,
#   'sort_key': 72000.0},
#  {'element_id': '7163076698968601063936388470',
#   'x': 0.0,
#   'y': 11050.234375,
#   'width': 1500.0,
#   'height': 48.0,
#   'predicted_label': 'app-bar',
#   'predicted_probability': 0.9090031385,
#   'sort_key': 72000.0},
#  {'element_id': '8399887889968601054053105644',
#   'x': 0.0,
#   'y': 2876.75,
#   'width': 239.0,
#   'height': 208.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 49712.0},
#  {'element_id': '4043067417968601063951107745',
#   'x': 0.0,
#   'y': 11921.234375,
#   'width': 239.0,
#   'height': 208.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 49712.0},
#  {'element_id': '0395393850968601046796025349',
#   'x': 466.0,
#   'y': 1851.15625,
#   'width': 568.0,
#   'height': 72.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 40896.0},
#  {'element_id': '6459902158968601044053629226',
#   'x': 466.0,
#   'y': 1719.96875,
#   'width': 568.0,
#   'height': 72.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 40896.0},
#  {'element_id': '0056810203968601051025394131',
#   'x': 147.0,
#   'y': 36.0,
#   'width': 364.0,
#   'height': 108.0,
#   'predicted_label': 'backdrop',
#   'predicted_probability': 1.0,
#   'sort_key': 39312.0},
#  {'element_id': '5111765030968601052472698510',
#   'x': 0.0,
#   'y': 3085.75,
#   'width': 239.0,
#   'height': 160.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 38240.0},
#  {'element_id': '1425670029968601068877611561',
#   'x': 0.0,
#   'y': 12130.234375,
#   'width': 239.0,
#   'height': 160.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 38240.0},
#  {'element_id': '7831511075968601051311695752',
#   'x': 0.0,
#   'y': 3261.75,
#   'width': 112.25,
#   'height': 336.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 37716.0},
#  {'element_id': '6781683755968601040936345495',
#   'x': 17.0,
#   'y': 759.96875,
#   'width': 311.0,
#   'height': 120.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.9998127818,
#   'sort_key': 37320.0},
#  {'element_id': '0704161260968601051715924739',
#   'x': 0.0,
#   'y': 2708.75,
#   'width': 1500.0,
#   'height': 24.0,
#   'predicted_label': 'breadcrumbs',
#   'predicted_probability': 0.9999760389,
#   'sort_key': 36000.0},
#  {'element_id': '7604256723968601055219292640',
#   'x': 0.0,
#   'y': 2684.75,
#   'width': 1500.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 36000.0},
#  {'element_id': '1724649496968601055223149125',
#   'x': 0.0,
#   'y': 2788.75,
#   'width': 1500.0,
#   'height': 24.0,
#   'predicted_label': 'breadcrumbs',
#   'predicted_probability': 0.9999841452,
#   'sort_key': 36000.0},
#  {'element_id': '6604715448968601054356519810',
#   'x': 0.0,
#   'y': 3968.75,
#   'width': 1500.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.999658227,
#   'sort_key': 36000.0},
#  {'element_id': '6728246151968601058912909072',
#   'x': 0.0,
#   'y': 2748.75,
#   'width': 1500.0,
#   'height': 24.0,
#   'predicted_label': 'breadcrumbs',
#   'predicted_probability': 1.0,
#   'sort_key': 36000.0},
#  {'element_id': '4491747303968601058256578475',
#   'x': 0.0,
#   'y': 5124.75,
#   'width': 500.0,
#   'height': 56.0,
#   'predicted_label': 'bottom-navigation',
#   'predicted_probability': 1.0,
#   'sort_key': 28000.0},
#  {'element_id': '5319110502968601048941156915',
#   'x': 466.0,
#   'y': 1797.5625,
#   'width': 568.0,
#   'height': 48.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 27264.0},
#  {'element_id': '2974654185968601051985385437',
#   'x': 474.0,
#   'y': 2201.75,
#   'width': 552.0,
#   'height': 45.0,
#   'predicted_label': 'text-field',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 24840.0},
#  {'element_id': '7013920874968601064430966474',
#   'x': 0.0,
#   'y': 11768.234375,
#   'width': 500.0,
#   'height': 48.0,
#   'predicted_label': 'paper',
#   'predicted_probability': 1.0,
#   'sort_key': 24000.0},
#  {'element_id': '7962385458968601065039030584',
#   'x': 0.0,
#   'y': 11768.234375,
#   'width': 500.0,
#   'height': 48.0,
#   'predicted_label': 'tabs',
#   'predicted_probability': 1.0,
#   'sort_key': 24000.0},
#  {'element_id': '9381463062968601045155655166',
#   'x': 466.0,
#   'y': 1654.96875,
#   'width': 568.0,
#   'height': 32.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 18176.0},
#  {'element_id': '1284970276968601045340720146',
#   'x': 16.0,
#   'y': 311.484375,
#   'width': 328.0,
#   'height': 52.890625,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 17348.125},
#  {'element_id': '0495544089968601058776680537',
#   'x': 16.0,
#   'y': 5656.75,
#   'width': 328.0,
#   'height': 52.890625,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 17348.125},
#  {'element_id': '9045250334968601043953028635',
#   'x': 16.0,
#   'y': 24.0,
#   'width': 328.0,
#   'height': 52.890625,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 17348.125},
#  {'element_id': '9469704769968601051486397035',
#   'x': 16.0,
#   'y': 5656.75,
#   'width': 277.1875,
#   'height': 52.890625,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 14660.6201171875},
#  {'element_id': '6660900129968601041214258955',
#   'x': 16.0,
#   'y': 311.484375,
#   'width': 277.1875,
#   'height': 52.890625,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 14660.6201171875},
#  {'element_id': '9644084518968601040916971585',
#   'x': 16.0,
#   'y': 24.0,
#   'width': 277.1875,
#   'height': 52.890625,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 14660.6201171875},
#  {'element_id': '9313856866968601048387045738',
#   'x': 16.0,
#   'y': 76.890625,
#   'width': 328.0,
#   'height': 40.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 13120.0},
#  {'element_id': '2372995226968601047963436382',
#   'x': 16.0,
#   'y': 364.375,
#   'width': 328.0,
#   'height': 40.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 13120.0},
#  {'element_id': '3625341032968601055848581697',
#   'x': 16.0,
#   'y': 5709.640625,
#   'width': 328.0,
#   'height': 40.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 13120.0},
#  {'element_id': '0296683190968601040991544767',
#   'x': 16.0,
#   'y': 24.0,
#   'width': 277.1875,
#   'height': 41.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 11364.6875},
#  {'element_id': '3779005654968601053790440744',
#   'x': 16.0,
#   'y': 5656.75,
#   'width': 277.1875,
#   'height': 41.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 11364.6875},
#  {'element_id': '1627658140968601041765709051',
#   'x': 16.0,
#   'y': 311.484375,
#   'width': 277.1875,
#   'height': 41.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 11364.6875},
#  {'element_id': '1255340949968601054366033196',
#   'x': 8.0,
#   'y': 3904.75,
#   'width': 194.640625,
#   'height': 56.0,
#   'predicted_label': 'text-field',
#   'predicted_probability': 1.0,
#   'sort_key': 10899.875},
#  {'element_id': '7394165077968601052617860231',
#   'x': -11.7921733856,
#   'y': 5544.9580078125,
#   'width': 95.5843505859,
#   'height': 95.583984375,
#   'predicted_label': 'progress',
#   'predicted_probability': 0.999999404,
#   'sort_key': 9136.3330729008},
#  {'element_id': '3105465864968601052549543735',
#   'x': 16.0,
#   'y': 5790.640625,
#   'width': 328.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 7872.0},
#  {'element_id': '7716298851968601043275879582',
#   'x': 16.0,
#   'y': 445.375,
#   'width': 328.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 7872.0},
#  {'element_id': '1998021924968601044421892830',
#   'x': 16.0,
#   'y': 157.890625,
#   'width': 328.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 7872.0},
#  {'element_id': '9695985936968601068046863911',
#   'x': 645.5625,
#   'y': 11106.234375,
#   'width': 208.859375,
#   'height': 36.0,
#   'predicted_label': 'button-group',
#   'predicted_probability': 1.0,
#   'sort_key': 7518.9375},
#  {'element_id': '8867501461968601055004569681',
#   'x': 645.5625,
#   'y': 3605.75,
#   'width': 208.859375,
#   'height': 36.0,
#   'predicted_label': 'button-group',
#   'predicted_probability': 1.0,
#   'sort_key': 7518.9375},
#  {'element_id': '2755752099968601052630171353',
#   'x': 0.0,
#   'y': 5200.75,
#   'width': 179.984375,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 6479.4375},
#  {'element_id': '1965358713968601055703992747',
#   'x': 10.0,
#   'y': 5246.75,
#   'width': 200.0,
#   'height': 28.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 5600.0},
#  {'element_id': '6562917712968601061050970838',
#   'x': 353.078125,
#   'y': 11455.234375,
#   'width': 166.9375,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 5342.0},
#  {'element_id': '2383210404968601069585201985',
#   'x': 218.984375,
#   'y': 11487.234375,
#   'width': 166.515625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 5328.5},
#  {'element_id': '0383625414968601059252671322',
#   'x': 1157.84375,
#   'y': 5092.75,
#   'width': 164.625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 5268.0},
#  {'element_id': '5922212772968601054016933425',
#   'x': 0.0,
#   'y': 3860.75,
#   'width': 132.875,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4783.5},
#  {'element_id': '4788365979968601049824304786',
#   'x': 911.75,
#   'y': 1953.75,
#   'width': 130.25,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4689.0},
#  {'element_id': '0910817424968601065688038643',
#   'x': 754.1875,
#   'y': 11455.234375,
#   'width': 142.9375,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 4574.0},
#  {'element_id': '3917730486968601059736881190',
#   'x': 683.953125,
#   'y': 2514.75,
#   'width': 132.09375,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 1.0,
#   'sort_key': 4227.0},
#  {'element_id': '9183709976968601049897801782',
#   'x': 683.953125,
#   'y': 1436.96875,
#   'width': 132.09375,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 1.0,
#   'sort_key': 4227.0},
#  {'element_id': '5726946928968601062704002968',
#   'x': 897.125,
#   'y': 11455.234375,
#   'width': 130.484375,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 4175.5},
#  {'element_id': '7465571090968601045046536403',
#   'x': 8.0,
#   'y': 538.96875,
#   'width': 114.53125,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4123.125},
#  {'element_id': '0161611765968601047040760773',
#   'x': 8.0,
#   'y': 251.484375,
#   'width': 114.53125,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4123.125},
#  {'element_id': '3627517485968601055372703061',
#   'x': 8.0,
#   'y': 5884.234375,
#   'width': 114.53125,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4123.125},
#  {'element_id': '3407493488968601059094124786',
#   'x': 1030.96875,
#   'y': 5092.75,
#   'width': 126.875,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 4060.0},
#  {'element_id': '9488007711968601060745001968',
#   'x': 121.390625,
#   'y': 11459.234375,
#   'width': 166.90625,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 4005.75},
#  {'element_id': '2729081159968601056093524280',
#   'x': 807.09375,
#   'y': 5092.75,
#   'width': 125.0,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 4000.0},
#  {'element_id': '2670613707968601067315053403',
#   'x': 1124.65625,
#   'y': 11455.234375,
#   'width': 121.640625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3892.5},
#  {'element_id': '8505657170968601064163977878',
#   'x': 0.0,
#   'y': 11455.234375,
#   'width': 121.390625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3884.5},
#  {'element_id': '5713411850968601064666249418',
#   'x': 0.0,
#   'y': 11487.234375,
#   'width': 113.421875,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3629.5},
#  {'element_id': '8890540920968601056437833487',
#   'x': 941.484375,
#   'y': 2266.75,
#   'width': 100.515625,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 3618.5625},
#  {'element_id': '8791591450968601052412835136',
#   'x': 0.0,
#   'y': 5092.75,
#   'width': 110.671875,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3541.5},
#  {'element_id': '1255599597968601057531827705',
#   'x': 659.875,
#   'y': 5096.75,
#   'width': 147.21875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3533.25},
#  {'element_id': '5297044390968601059632269092',
#   'x': 297.0625,
#   'y': 5096.75,
#   'width': 139.390625,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3345.375},
#  {'element_id': '4709735839968601059040976175',
#   'x': 557.484375,
#   'y': 5092.75,
#   'width': 102.390625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3276.5},
#  {'element_id': '1498469103968601065040081523',
#   'x': 1346.0,
#   'y': 11459.234375,
#   'width': 136.359375,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3272.625},
#  {'element_id': '5126069215968601066105598053',
#   'x': 520.015625,
#   'y': 11459.234375,
#   'width': 135.140625,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3243.375},
#  {'element_id': '7055123082968601060192811297',
#   'x': 655.15625,
#   'y': 11455.234375,
#   'width': 99.03125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3169.0},
#  {'element_id': '1638731765968601069942016787',
#   'x': -8.1130428314,
#   'y': 6154.12109375,
#   'width': 56.2260894775,
#   'height': 56.2265625,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 3161.3997341394},
#  {'element_id': '4913400891968601058192237271',
#   'x': 300.8869628906,
#   'y': 61.8869552612,
#   'width': 56.2260742188,
#   'height': 56.2260894775,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 3161.3722799942},
#  {'element_id': '3808651733968601066319290221',
#   'x': 772.96875,
#   'y': 11106.234375,
#   'width': 81.453125,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2932.3125},
#  {'element_id': '8675213187968601059056733184',
#   'x': 772.96875,
#   'y': 3605.75,
#   'width': 81.453125,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2932.3125},
#  {'element_id': '3825750047968601050376023662',
#   'x': 436.453125,
#   'y': 5096.75,
#   'width': 121.03125,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2904.75},
#  {'element_id': '5969866062968601050609463408',
#   'x': 858.28125,
#   'y': 2266.75,
#   'width': 75.203125,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2707.3125},
#  {'element_id': '4061378766968601040287818711',
#   'x': 20.0,
#   'y': 191.484375,
#   'width': 82.578125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2642.5},
#  {'element_id': '7994188855968601043160430513',
#   'x': 20.0,
#   'y': 478.96875,
#   'width': 82.578125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2642.5},
#  {'element_id': '5911754990968601059381123736',
#   'x': 20.0,
#   'y': 5824.234375,
#   'width': 82.578125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2642.5},
#  {'element_id': '6787768070968601061146183093',
#   'x': 113.421875,
#   'y': 11491.234375,
#   'width': 105.5625,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2533.5},
#  {'element_id': '6390827211968601059795750956',
#   'x': 0.0,
#   'y': 4786.75,
#   'width': 104.46875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2507.25},
#  {'element_id': '3186743649968601069094896423',
#   'x': 1246.296875,
#   'y': 11459.234375,
#   'width': 99.703125,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2392.875},
#  {'element_id': '3900416417968601057291860896',
#   'x': 932.09375,
#   'y': 5096.75,
#   'width': 98.875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2373.0},
#  {'element_id': '4671537699968601060839234004',
#   'x': 708.109375,
#   'y': 11106.234375,
#   'width': 65.859375,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2370.9375},
#  {'element_id': '0209376658968601055290031909',
#   'x': 708.109375,
#   'y': 3605.75,
#   'width': 65.859375,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2370.9375},
#  {'element_id': '3491084633968601059729739877',
#   'x': 976.53125,
#   'y': 2608.75,
#   'width': 65.46875,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2356.875},
#  {'element_id': '4816734082968601046782539365',
#   'x': 976.53125,
#   'y': 1530.96875,
#   'width': 65.46875,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2356.875},
#  {'element_id': '9910176555968601067327287889',
#   'x': 1027.609375,
#   'y': 11459.234375,
#   'width': 97.046875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2329.125},
#  {'element_id': '2814573784968601051016891280',
#   'x': 110.671875,
#   'y': 5096.75,
#   'width': 97.03125,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2328.75},
#  {'element_id': '7733151568968601041317359691',
#   'x': 994.0,
#   'y': 1646.96875,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 2304.0},
#  {'element_id': '1924695638968601068454928276',
#   'x': 12.0,
#   'y': 11050.234375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2304.0},
#  {'element_id': '3591082609968601062976800027',
#   'x': 645.5625,
#   'y': 11106.234375,
#   'width': 63.546875,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2287.6875},
#  {'element_id': '1199460614968601053413661465',
#   'x': 645.5625,
#   'y': 3605.75,
#   'width': 63.546875,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2287.6875},
#  {'element_id': '1765016863968601041957235211',
#   'x': 166.3125,
#   'y': 191.484375,
#   'width': 71.140625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2276.5},
#  {'element_id': '6181644785968601055856109308',
#   'x': 166.3125,
#   'y': 5824.234375,
#   'width': 71.140625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2276.5},
#  {'element_id': '9788836036968601041064025584',
#   'x': 166.3125,
#   'y': 478.96875,
#   'width': 71.140625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2276.5},
#  {'element_id': '0625341628968601069399454293',
#   'x': 385.5,
#   'y': 11491.234375,
#   'width': 93.859375,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2252.625},
#  {'element_id': '0421915870968601052593326375',
#   'x': 207.703125,
#   'y': 5096.75,
#   'width': 89.359375,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2144.625},
#  {'element_id': '1245994850968601052529773238',
#   'x': 158.140625,
#   'y': 2708.75,
#   'width': 88.65625,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 2127.75},
#  {'element_id': '2749766227968601056738653311',
#   'x': 158.140625,
#   'y': 2748.75,
#   'width': 88.65625,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 2127.75},
#  {'element_id': '3936987146968601057149019582',
#   'x': 187.171875,
#   'y': 2788.75,
#   'width': 88.65625,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 2127.75},
#  {'element_id': '4206807281968601066718849907',
#   'x': 288.296875,
#   'y': 11455.234375,
#   'width': 64.78125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2073.0},
#  {'element_id': '9317427734968601049860787508',
#   'x': 293.1875,
#   'y': 30.9375,
#   'width': 50.8125,
#   'height': 39.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 1981.6875},
#  {'element_id': '3230466037968601059634151184',
#   'x': 293.1875,
#   'y': 5663.6875,
#   'width': 50.8125,
#   'height': 39.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 1981.6875},
#  {'element_id': '4983184910968601044173916841',
#   'x': 293.1875,
#   'y': 318.421875,
#   'width': 50.8125,
#   'height': 39.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 1981.6875},
#  {'element_id': '4927629402968601049022369479',
#   'x': 9.0,
#   'y': 903.96875,
#   'width': 64.0,
#   'height': 30.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 1920.0},
#  {'element_id': '0704846201968601055301025557',
#   'x': -11.0,
#   'y': 3513.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '6713728087968601057836519012',
#   'x': -11.0,
#   'y': 3387.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '2731238288968601053492784900',
#   'x': -11.0,
#   'y': 3261.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '0327164861968601053269411804',
#   'x': -11.0,
#   'y': 3471.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9551750422,
#   'sort_key': 1764.0},
#  {'element_id': '3158127117968601054698385676',
#   'x': -11.0,
#   'y': 3345.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '9818003742968601059234158445',
#   'x': -11.0,
#   'y': 3303.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '8073681785968601054689361812',
#   'x': -11.0,
#   'y': 3555.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '5196232312968601056231160669',
#   'x': -11.0,
#   'y': 4744.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '9846991376968601059588189987',
#   'x': -11.0,
#   'y': 3429.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '3496743955968601044804776798',
#   'x': 245.453125,
#   'y': 191.484375,
#   'width': 52.78125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 1689.0},
#  {'element_id': '9256922245968601049789456122',
#   'x': 245.453125,
#   'y': 478.96875,
#   'width': 52.78125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 1689.0},
#  {'element_id': '2777007109968601058699437171',
#   'x': 245.453125,
#   'y': 5824.234375,
#   'width': 52.78125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 1689.0},
#  {'element_id': '9771864336968601044142477489',
#   'x': 293.1875,
#   'y': 318.421875,
#   'width': 50.8125,
#   'height': 32.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 1626.0},
#  {'element_id': '3459283459968601048636812539',
#   'x': 293.1875,
#   'y': 30.9375,
#   'width': 50.8125,
#   'height': 32.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 1626.0},
#  {'element_id': '0194930587968601051351120252',
#   'x': 293.1875,
#   'y': 5663.6875,
#   'width': 50.8125,
#   'height': 32.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 1626.0},
#  {'element_id': '0460735323968601051366713376',
#   'x': 0.0,
#   'y': 3972.75,
#   'width': 100.53125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1608.5},
#  {'element_id': '7930516468968601065151028694',
#   'x': 0.0,
#   'y': 12290.234375,
#   'width': 40.0,
#   'height': 40.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0},
#  {'element_id': '5498095781968601069746440118',
#   'x': 0.0,
#   'y': 11816.234375,
#   'width': 40.0,
#   'height': 40.0,
#   'predicted_label': 'avatar',
#   'predicted_probability': 0.9999957085,
#   'sort_key': 1600.0},
#  {'element_id': '7981320042968601048320000249',
#   'x': 110.578125,
#   'y': 191.484375,
#   'width': 47.734375,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 1527.5},
#  {'element_id': '8391539494968601049275790967',
#   'x': 110.578125,
#   'y': 478.96875,
#   'width': 47.734375,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 1527.5},
#  {'element_id': '4560750824968601055481297385',
#   'x': 110.578125,
#   'y': 5824.234375,
#   'width': 47.734375,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 1527.5},
#  {'element_id': '7735986166968601056209574815',
#   'x': 692.953125,
#   'y': 2554.75,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '3179501753968601047070178632',
#   'x': 692.953125,
#   'y': 1476.96875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '3080414018968601065315769550',
#   'x': -11.0,
#   'y': 11519.234375,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '0403114057968601050195263223',
#   'x': 8.0,
#   'y': 5182.75,
#   'width': 87.703125,
#   'height': 16.0,
#   'predicted_label': 'box',
#   'predicted_probability': 1.0,
#   'sort_key': 1403.25},
#  {'element_id': '6703024739968601051117184407',
#   'x': 0.0,
#   'y': 2711.75,
#   'width': 79.890625,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1358.140625},
#  {'element_id': '2968232525968601054895344567',
#   'x': 0.0,
#   'y': 2751.75,
#   'width': 79.890625,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1358.140625},
#  {'element_id': '1309490061968601050006214496',
#   'x': 0.0,
#   'y': 2791.75,
#   'width': 79.890625,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1358.140625},
#  {'element_id': '7041859379968601056232512366',
#   'x': 101.375,
#   'y': 2711.75,
#   'width': 35.28125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 599.78125},
#  {'element_id': '3914869471968601054871692893',
#   'x': 101.375,
#   'y': 2751.75,
#   'width': 35.28125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 599.78125},
#  {'element_id': '0972220817968601051674487615',
#   'x': 115.890625,
#   'y': 2791.75,
#   'width': 35.28125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 599.78125},
#  {'element_id': '5757729558968601065169008591',
#   'x': 8.0,
#   'y': 12338.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'badge',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '6056929869968601050741436666',
#   'x': 24.0,
#   'y': 5960.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '7757668613968601062581418901',
#   'x': 16.0,
#   'y': 12085.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999456406,
#   'sort_key': 576.0},
#  {'element_id': '5771523031968601069231836386',
#   'x': 16.0,
#   'y': 12198.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999456406,
#   'sort_key': 576.0},
#  {'element_id': '6524347534968601052410184234',
#   'x': 404.671875,
#   'y': 5132.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '3003710684968601054382437743',
#   'x': 24.0,
#   'y': 6106.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '0054888532968601063039375858',
#   'x': 16.0,
#   'y': 11941.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '2601681570968601052873656680',
#   'x': 16.0,
#   'y': 3153.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999456406,
#   'sort_key': 576.0},
#  {'element_id': '8347266481968601050894607854',
#   'x': 71.328125,
#   'y': 5131.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '4026149223968601060569537714',
#   'x': 16.0,
#   'y': 12150.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '8395887269968601057226887725',
#   'x': 16.0,
#   'y': 3040.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999456406,
#   'sort_key': 576.0},
#  {'element_id': '2835161974968601068267843257',
#   'x': 16.0,
#   'y': 11989.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999456406,
#   'sort_key': 576.0},
#  {'element_id': '5404546663968601057640077416',
#   'x': 5.0,
#   'y': 5096.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '6721416228968601051584084546',
#   'x': 24.0,
#   'y': 5036.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '6545826717968601067482944640',
#   'x': 223.984375,
#   'y': 11491.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '4333190559968601068360478287',
#   'x': 16.0,
#   'y': 12246.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '3214392235968601055882413567',
#   'x': 16.0,
#   'y': 2896.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '4018205799968601053021751506',
#   'x': 16.0,
#   'y': 3105.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '9639054904968601047214311334',
#   'x': 1006.0,
#   'y': 1658.96875,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.8485919237,
#   'sort_key': 576.0},
#  {'element_id': '3895242025968601052040469421',
#   'x': 16.0,
#   'y': 2944.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999456406,
#   'sort_key': 576.0},
#  {'element_id': '7077743534968601054619299331',
#   'x': 24.0,
#   'y': 6033.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '2294326921968601066365365152',
#   'x': 228.0,
#   'y': 11780.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 576.0},
#  {'element_id': '4038742753968601050598940290',
#   'x': 16.0,
#   'y': 2992.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '1214574681968601058243472253',
#   'x': 16.0,
#   'y': 3201.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '6623980744968601058909159672',
#   'x': 238.0,
#   'y': 5132.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '7528085559968601052932329703',
#   'x': 24.0,
#   'y': 5580.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 576.0},
#  {'element_id': '7578276925968601064599581167',
#   'x': 68.0,
#   'y': 11780.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 576.0},
#  {'element_id': '9787854774968601063958072351',
#   'x': 16.0,
#   'y': 12037.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '1198864791968601061615493732',
#   'x': 5.0,
#   'y': 11459.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '2478153849968601053404485184',
#   'x': 24.0,
#   'y': 4688.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '6296306891968601065978889611',
#   'x': 76.0,
#   'y': 11058.234375,
#   'width': 16.984375,
#   'height': 32.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 543.5},
#  {'element_id': '2641798279968601051912338690',
#   'x': 0.0,
#   'y': 2687.75,
#   'width': 29.953125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 509.203125},
#  {'element_id': '9156215208968601069708641850',
#   'x': 358.5,
#   'y': 11492.234375,
#   'width': 22.0,
#   'height': 22.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 484.0},
#  {'element_id': '9875101533968601067085166114',
#   'x': 86.421875,
#   'y': 11492.234375,
#   'width': 22.0,
#   'height': 22.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 484.0},
#  {'element_id': '9062509281968601064616768011',
#   'x': 94.390625,
#   'y': 11460.234375,
#   'width': 22.0,
#   'height': 22.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 484.0},
#  {'element_id': '1634547054968601060793873642',
#   'x': 493.015625,
#   'y': 11460.234375,
#   'width': 22.0,
#   'height': 22.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 484.0},
#  {'element_id': '0019445892968601059624877801',
#   'x': 1129.84375,
#   'y': 5097.75,
#   'width': 22.0,
#   'height': 22.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 484.0},
#  {'element_id': '3174633043968601053516403381',
#   'x': 82.671875,
#   'y': 5097.75,
#   'width': 22.0,
#   'height': 22.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 484.0},
#  {'element_id': '1936666786968601057609684600',
#   'x': 159.171875,
#   'y': 2790.75,
#   'width': 20.0,
#   'height': 20.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 400.0},
#  {'element_id': '7922584759968601051911757745',
#   'x': 87.890625,
#   'y': 2790.75,
#   'width': 20.0,
#   'height': 20.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 400.0},
#  {'element_id': '0439489692968601051017544607',
#   'x': 0.0,
#   'y': 4405.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 360.0},
#  {'element_id': '3947033853968601064026732652',
#   'x': 0.0,
#   'y': 11613.234375,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999997616,
#   'sort_key': 360.0},
#  {'element_id': '5250295661968601053186091892',
#   'x': 0.0,
#   'y': 3803.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 360.0},
#  {'element_id': '5137496230968601058398557555',
#   'x': 0.0,
#   'y': 4194.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 360.0},
#  {'element_id': '7937975519968601067168873062',
#   'x': 0.0,
#   'y': 11711.234375,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 360.0},
#  {'element_id': '4902794434968601051435304890',
#   'x': 0.0,
#   'y': 4542.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 360.0},
#  {'element_id': '9712400151968601052232198538',
#   'x': 0.0,
#   'y': 4096.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999997616,
#   'sort_key': 360.0},
#  {'element_id': '3814655669968601055769589527',
#   'x': 0.0,
#   'y': 4307.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999997616,
#   'sort_key': 360.0},
#  {'element_id': '2153809090968601058661936343',
#   'x': 0.0,
#   'y': 4890.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 360.0},
#  {'element_id': '0424580903968601051035884861',
#   'x': 0.0,
#   'y': 3705.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999997616,
#   'sort_key': 360.0},
#  {'element_id': '5642387724968601059166309294',
#   'x': 301.0625,
#   'y': 5099.75,
#   'width': 18.0,
#   'height': 18.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '4197770624968601053778910719',
#   'x': 113.671875,
#   'y': 5099.75,
#   'width': 18.0,
#   'height': 18.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '6767185091968601067963474346',
#   'x': 124.390625,
#   'y': 11462.234375,
#   'width': 18.0,
#   'height': 18.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '5790007097968601052516296943',
#   'x': 440.453125,
#   'y': 5099.75,
#   'width': 18.0,
#   'height': 18.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '7396565355968601056227733150',
#   'x': 72.0,
#   'y': 6081.234375,
#   'width': 288.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 288.0},
#  {'element_id': '6621703119968601053944633744',
#   'x': 72.0,
#   'y': 6008.234375,
#   'width': 288.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 288.0},
#  {'element_id': '2893133072968601052450501043',
#   'x': 72.0,
#   'y': 4987.75,
#   'width': 288.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 288.0},
#  {'element_id': '8929405769968601052470468192',
#   'x': 72.0,
#   'y': 4639.75,
#   'width': 288.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 288.0},
#  {'element_id': '7156792749968601052588506320',
#   'x': 187.703125,
#   'y': 5100.75,
#   'width': 16.0,
#   'height': 16.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 256.0},
#  {'element_id': '3167459841968601061301124452',
#   'x': 635.15625,
#   'y': 11463.234375,
#   'width': 16.0,
#   'height': 16.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 256.0},
#  {'element_id': '1902676464968601065769040531',
#   'x': 1462.359375,
#   'y': 11463.234375,
#   'width': 16.0,
#   'height': 16.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 256.0},
#  {'element_id': '2979008287968601066228631462',
#   'x': 198.984375,
#   'y': 11495.234375,
#   'width': 16.0,
#   'height': 16.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 256.0},
#  {'element_id': '6701626986968601053913091270',
#   'x': 0.0,
#   'y': 3084.75,
#   'width': 239.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999992847,
#   'sort_key': 239.0},
#  {'element_id': '0270617014968601065664639444',
#   'x': 0.0,
#   'y': 12129.234375,
#   'width': 239.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 239.0},
#  {'element_id': '7751198414968601063952450491',
#   'x': 0.0,
#   'y': 11920.234375,
#   'width': 239.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 239.0}]
# Wall time: 6.55 s

# %%
from utils import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'MUI_model/dataset/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')

# %%
# set(df.element_id.values).intersection(set(preds.element_id.values))

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'MUI_model/dataset/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df[predictions_df['predicted_probability'] >0.995].iterrows():
    patch = Rectangle((r.x, r.y), r.width, r.height, alpha=.2, color='red')
    axes.add_patch(patch)
    
    axes.text(r.x, r.y, 
              r.predicted_label + ':' +str(round(r.predicted_probability, 3)) + ':' + r.tag_name, 
              backgroundcolor='black', 
              color='white')
