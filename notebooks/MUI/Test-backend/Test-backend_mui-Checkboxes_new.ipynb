# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-11-29 18:38:55,565 -INFO - config.py:31 - Module utils.config was loaded
# 2021-11-29 18:38:55,601 -INFO - common.py:119 - Module utils.common is loaded...
# 2021-11-29 18:38:55,602 -INFO - dataset_builder.py:245 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'material-ui-Checkbox'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click() #path to elements packs
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click() #path to mui
        driver.find_element_by_xpath("//*[@id='__next']/div/div/div[1]/div/div[4]/div").click() #path to checkboxes
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-11-29 18:38:55,765 -INFO - dataset_builder.py:100 - Dataset name: material-ui-Checkbox
# 2021-11-29 18:38:55,767 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-11-29 18:38:55,769 -INFO - dataset_builder.py:151 - Creating driver
# 2021-11-29 18:38:56,805 -INFO - dataset_builder.py:163 - Chrome web driver is created
# ipykernel_launcher:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2021-11-29 18:39:09,356 -INFO - common.py:22 - Window maximized
# 2021-11-29 18:39:16,362 -INFO - dataset_builder.py:166 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/material-ui-Checkbox.png
# 2021-11-29 18:39:21,905 -INFO - dataset_builder.py:210 - Collect features using JS script
# 2021-11-29 18:39:22,512 -INFO - dataset_builder.py:218 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/material-ui-Checkbox.html
# 2021-11-29 18:39:22,527 -INFO - dataset_builder.py:230 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/material-ui-Checkbox.pkl
# 2021-11-29 18:39:22,529 -INFO - dataset_builder.py:233 - No attributes: (12, 13)
# 2021-11-29 18:39:27,768 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '0368914267003619115437998111',
#   'x': 274.0,
#   'y': 645.703125,
#   'width': 316.0625,
#   'height': 66.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 0.9999995232,
#   'sort_key': 20860.125},
#  {'element_id': '1509389387003619111737992524',
#   'x': 298.0,
#   'y': 391.9375,
#   'width': 151.671875,
#   'height': 126.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 0.6677073836,
#   'sort_key': 19110.65625},
#  {'element_id': '7445633705003619119732602770',
#   'x': 497.671875,
#   'y': 391.9375,
#   'width': 151.671875,
#   'height': 126.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 0.6677073836,
#   'sort_key': 19110.65625},
#  {'element_id': '6249722122003619118374188038',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6211320589003619110975810929',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6097926220003619116040063927',
#   'x': 0.0,
#   'y': 336.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6055571919003619115599258132',
#   'x': 0.0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5941738543003619119278126930',
#   'x': 0.0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8894012311003619116589751710',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '9161896112003619111247247682',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6419026262003619112997826197',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5779520801003619116272551404',
#   'x': 0.0,
#   'y': 2112.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '9058350650003619113209534776',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5557786063003619115189545347',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5527738515003619114760122646',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5317493581003619117503215646',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5063246942003619116916473828',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5023056918003619118540773958',
#   'x': 0.0,
#   'y': 1104.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '9999031932003619111377650066',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '6563392232003619111147756751',
#   'x': 0.0,
#   'y': 240.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4638029769003619119020988141',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4293253175003619117618966971',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4345109798003619113596197713',
#   'x': 0.0,
#   'y': 1536.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4401843226003619111402563658',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4405133616003619115960813489',
#   'x': 0.0,
#   'y': 480.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4519754589003619111338743662',
#   'x': 0.0,
#   'y': 1872.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4598978510003619119083676041',
#   'x': 0.0,
#   'y': 2400.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4677984565003619116982771112',
#   'x': 0.0,
#   'y': 1824.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5014121527003619112185697780',
#   'x': 0.0,
#   'y': 96.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9187014268003619117316138218',
#   'x': 0.0,
#   'y': 960.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4806328805003619119745711441',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0060904100003619110888328126',
#   'x': 0.0,
#   'y': 1440.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4924030786003619113020051666',
#   'x': 0.0,
#   'y': 1248.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999946356,
#   'sort_key': 12000.0},
#  {'element_id': '4952099388003619119717442718',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4966229921003619113285257507',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '6447059646003619112847981567',
#   'x': 0.0,
#   'y': 2160.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '6591274145003619116022160837',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6581777205003619117461430658',
#   'x': 0.0,
#   'y': 2448.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8329071486003619119290605961',
#   'x': 0.0,
#   'y': 2592.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '8251168516003619117751170820',
#   'x': 0.0,
#   'y': 576.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8198432333003619119631798994',
#   'x': 0.0,
#   'y': 960.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '

#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2001213595003619112652815892',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '2120257894003619111008600879',
#   'x': 0.0,
#   'y': 1152.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4124452487003619118328264513',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '9297716818003619117672717362',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '3996409580003619113123213199',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '9334362570003619114833743355',
#   'x': 0.0,
#   'y': 672.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999946356,
#   'sort_key': 12000.0},
#  {'element_id': '3804696927003619111879464520',
#   'x': 0.0,
#   'y': 2496.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '3791137404003619117877220293',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '3773931069003619119436631856',
#   'x': 0.0,
#   'y': 240.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3668105274003619111563222143',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3639592445003619110920232432',
#   'x': 0.0,
#   'y': 2112.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3603759086003619115160207546',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3417356708003619110449732917',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3397186179003619114466057100',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '3380699156003619116991038382',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '3115715890003619115791787056',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '3056270783003619113112347177',
#   'x': 0.0,
#   'y': 576.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '3016402947003619114769134707',
#   'x': 0.0,
#   'y': 2208.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '2929364597003619111696321736',
#   'x': 0.0,
#   'y': 384.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '2828925219003619112291960399',
#   'x': 0.0,
#   'y': 192.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2816322943003619111043871419',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '9347366106003619110436845629',
#   'x': 0.0,
#   'y': 2160.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2541588534003619115902526845',
#   'x': 0.0,
#   'y': 48.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '9501141772003619117422361312',
#   'x': 0.0,
#   'y': 2544.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2493041541003619115345589730',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999946356,
#   'sort_key': 12000.0},
#  {'element_id': '2471594683003619110298893063',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2434301740003619115144434631',
#   'x': 0.0,
#   'y': 1920.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '2347105061003619115377325527',
#   'x': 0.0,
#   'y': 1872.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2339461535003619118368405411',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8261896987003619111464244206',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9345172097003619113611047504',
#   'x': 504.65625,
#   'y': 657.703125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.8863347769,
#   'sort_key': 1764.0},
#  {'element_id': '9121348989003619116164791646',
#   'x': 996.6875,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '8842450284003619110524403427',
#   'x': 526.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '0010162297003619111535312871',
#   'x': 451.9375,
#   'y': 645.703125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.8863347769,
#   'sort_key': 1764.0},
#  {'element_id': '8082690551003619110269006052',
#   'x': 489.796875,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 1764.0},
#  {'element_id': '8054394786003619110439257099',
#   'x': 1141.078125,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 1764.0},
#  {'element_id': '0477590366003619116254342804',
#   'x': 738.90625,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '0774697847003619113582305215',
#   'x': 486.671875,
#   'y': 475.9375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 1764.0},
#  {'element_id': '1309286760003619114650207417',
#   'x': 486.671875,
#   'y': 433.9375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 1764.0},
#  {'element_id': '1418547822003619115906596145',
#   'x': 287.0,
#   'y': 475.9375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 1764.0},
#  {'element_id': '2504454097003619116280297812',
#   'x': 263.0,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '2612794235003619113625668013',
#   'x': 287.0,
#   'y': 433.9375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 1764.0},
#  {'element_id': '3145289042003619112375637589',
#   'x': 358.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9996817112,
#   'sort_key': 1764.0},
#  {'element_id': '3878583976003619110243620803',
#   'x': 316.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9998086095,
#   'sort_key': 1764.0},
#  {'element_id': '4209200183003619113164897255',
#   'x': 274.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '4289314919003619110120488257',
#   'x': 442.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '4776246064003619111643137028',
#   'x': 399.21875,
#   'y': 657.703125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.8863347769,
#   'sort_key': 1764.0},
#  {'element_id': '5016823355003619113506449793',
#   'x': 629.015625,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '5310428942003619115634386320',
#   'x': 486.671875,
#   'y': 391.9375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '5715990389003619119698588166',
#   'x': 484.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '5930169567003619118787100195',
#   'x': 287.0,
#   'y': 391.9375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '6193349432003619112491925469',
#   'x': 400.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '6774236037003619113722655087',
#   'x': 290.0,
#   'y': 669.703125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.8863347769,
#   'sort_key': 1764.0},
#  {'element_id': '7492541145003619118052760556',
#   'x': 386.5,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 1764.0},
#  {'element_id': '4837728313003619119286920641',
#   'x': 848.796875,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '9245173893003619110157962350',
#   'x': 1279.609375,
#   'y': 247.078125,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999997616,
#   'sort_key': 1444.0},
#  {'element_id': '4116150758003619112090232718',
#   'x': 568.0,
#   'y': 140.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0}]
# CPU times: user 73.3 ms, sys: 18.4 ms, total: 91.7 ms
# Wall time: 2.07 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id           x            y       width  height  \
# 0  0368914267003619115437998111  274.000000   645.703125  316.062500    66.0
# 1  1509389387003619111737992524  298.000000   391.937500  151.671875   126.0
# 2  7445633705003619119732602770  497.671875   391.937500  151.671875   126.0
# 3  6249722122003619118374188038    0.000000   720.000000  250.000000    48.0
# 4  6211320589003619110975810929    0.000000  1392.000000  250.000000    48.0
#
#   predicted_label  predicted_probability     sort_key tag_name
# 0      radiogroup               1.000000  20860.12500      DIV
# 1      radiogroup               0.667707  19110.65625      DIV
# 2      radiogroup               0.667707  19110.65625      DIV
# 3          button               1.000000  12000.00000      DIV
# 4          button               1.000000  12000.00000      DIV

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
