# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-12-20 10:43:55,181 -INFO - config.py:31 - Module utils.config was loaded
# 2021-12-20 10:43:55,211 -INFO - common.py:119 - Module utils.common is loaded...
# 2021-12-20 10:43:55,213 -INFO - dataset_builder.py:245 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'mui-switch'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/basic_switches'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-12-20 10:43:55,322 -INFO - dataset_builder.py:100 - Dataset name: mui-switch
# 2021-12-20 10:43:55,323 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-12-20 10:43:55,325 -INFO - dataset_builder.py:151 - Creating driver
# 2021-12-20 10:43:56,323 -INFO - dataset_builder.py:163 - Chrome web driver is created
# 2021-12-20 10:44:00,365 -INFO - common.py:22 - Window maximized
# 2021-12-20 10:44:07,371 -INFO - dataset_builder.py:166 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/mui-switch.png
# 2021-12-20 10:44:13,451 -INFO - dataset_builder.py:210 - Collect features using JS script
# 2021-12-20 10:44:14,004 -INFO - dataset_builder.py:218 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/mui-switch.html
# 2021-12-20 10:44:14,019 -INFO - dataset_builder.py:230 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/mui-switch.pkl
# 2021-12-20 10:44:14,023 -INFO - dataset_builder.py:233 - No attributes: (9, 13)
# 2021-12-20 10:44:19,950 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '0010389625862534582477415246',
#   'x': 0,
#   'y': 1920.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '

#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '8039573072862534588307642767',
#   'x': 283,
#   'y': 333.078125,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0}]
# CPU times: user 62.4 ms, sys: 15.5 ms, total: 77.9 ms
# Wall time: 2.03 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id  x       y  width  height predicted_label  \
# 0  0010389625862534582477415246  0  1920.0  250.0    48.0          button
# 1  7067817054862534582628566393  0  2208.0  250.0    48.0            list
# 2  8192543722862534581529572780  0  2304.0  250.0    48.0            list
# 3  8077191654862534587868646845  0   768.0  250.0    48.0          button
# 4  8045090432862534586028017022  0  1344.0  250.0    48.0          button
#
#    predicted_probability  sort_key tag_name
# 0                    1.0   12000.0      DIV
# 1                    1.0   12000.0      DIV
# 2                    1.0   12000.0      DIV
# 3                    1.0   12000.0      DIV
# 4                    1.0   12000.0      DIV

# %%
preds
# Out:
#                        element_id    x            y  width  height  \
# 0    0010389625862534582477415246    0  1920.000000  250.0    48.0
# 1    7067817054862534582628566393    0  2208.000000  250.0    48.0
# 2    8192543722862534581529572780    0  2304.000000  250.0    48.0
# 3    8077191654862534587868646845    0   768.000000  250.0    48.0
# 4    8045090432862534586028017022    0  1344.000000  250.0    48.0
# ..                            ...  ...          ...    ...     ...
# 116  9811520221862534587406349303  263   295.078125   38.0    38.0
# 117  9813852374862534581784142273  283   257.078125   38.0    38.0
# 118  2034324341862534586132080241  584   138.218750   38.0    38.0
# 119  7958352651862534582902185808  390   138.218750   38.0    38.0
# 120  8039573072862534588307642767  283   333.078125   38.0    38.0
#
#     predicted_label  predicted_probability  sort_key
# 0            button                    1.0   12000.0
# 1              list                    1.0   12000.0
# 2              list                    1.0   12000.0
# 3            button                    1.0   12000.0
# 4            button                    1.0   12000.0
# ..              ...                    ...       ...
# 116          switch                    1.0    1444.0
# 117          switch                    1.0    1444.0
# 118          switch                    1.0    1444.0
# 119          switch                    1.0    1444.0
# 120          switch                    1.0    1444.0
#
# [121 rows x 8 columns]

# %%
from_pkl = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')
from_pkl[from_pkl.element_id == '1049561488694071642269580342']
# Out:
# Empty DataFrame
# Columns: [attributes, displayed, element_id, height, onmouseenter, onmouseover, parent_id, style, tag_name, text, width, x, y]
# Index: []

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))

# %%
PREDICT_URL = 'http://localhost:5050/get_tasks_statuses'
response = requests.post(
    PREDICT_URL, data=dataset_json[10]
)

# %%
response.json()
# Out:
# {'exc': 'Expecting value: line 1 column 1 (char 0)'}
