# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, "jdi-qasp-ml", "data/mui_dataset")

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-12-01 15:43:32,891 -INFO - config.py:31 - Module utils.config was loaded
# 2021-12-01 15:43:32,916 -INFO - common.py:119 - Module utils.common is loaded...
# 2021-12-01 15:43:32,917 -INFO - dataset_builder.py:245 - dataset package is loaded...

# %%
from utils.config import logger

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'material-ui-Radio'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click() #path to elements packs
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click() #path to mui
        driver.find_element_by_xpath("//*[@id='__next']/div/div/div[1]/div/div[7]/div").click() #path to elements
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=False, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-12-01 15:43:33,024 -INFO - dataset_builder.py:100 - Dataset name: material-ui-Radio
# 2021-12-01 15:43:33,025 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-12-01 15:43:33,027 -INFO - dataset_builder.py:151 - Creating driver
# 2021-12-01 15:43:34,909 -INFO - dataset_builder.py:163 - Chrome web driver is created
# 2021-12-01 15:43:35,023 -INFO - 1390990284.py:10 - getting url: https://jdi-testing.github.io/jdi-light/
# ipykernel_launcher:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2021-12-01 15:43:47,167 -INFO - common.py:22 - Window maximized
# 2021-12-01 15:43:54,170 -INFO - dataset_builder.py:166 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/material-ui-Radio.png
# 2021-12-01 15:43:54,432 -INFO - dataset_builder.py:210 - Collect features using JS script
# 2021-12-01 15:43:54,889 -INFO - dataset_builder.py:218 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/material-ui-Radio.html
# 2021-12-01 15:43:54,904 -INFO - dataset_builder.py:230 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/material-ui-Radio.pkl
# 2021-12-01 15:43:54,906 -INFO - dataset_builder.py:233 - No attributes: (11, 13)
# 2021-12-01 15:43:55,140 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '6129592666626344388871443035',
#   'x': 269.0,
#   'y': 293.09375,
#   'width': 316.0625,
#   'height': 66.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 20860.125},
#  {'element_id': '7823417517626344386992360154',
#   'x': 269.0,
#   'y': 138.21875,
#   'width': 374.796875,
#   'height': 42.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 15741.46875},
#  {'element_id': '1980270273626344383805340590',
#   'x': 293.0,
#   'y': 463.953125,
#   'width': 179.796875,
#   'height': 84.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 15102.9375},
#  {'element_id': '0026833165626344370606276072',
#   'x': 0.0,
#   'y': 1440.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999990463,
#   'sort_key': 11760.0},
#  {'element_id': '6965973010626344379620469128',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6526564590626344370344169781',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999990463,
#   'sort_key': 11760.0},
#  {'element_id': '6604501082626344373812380652',
#   'x': 0.0,
#   'y': 336.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6703810968626344372223403313',
#   'x': 0.0,
#   'y': 1104.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6707591500626344376023223758',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6829355930626344384645491927',
#   'x': 0.0,
#   'y': 2400.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7003033762626344385241614094',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6430045872626344376645716431',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999990463,
#   'sort_key': 11760.0},
#  {'element_id': '7057965077626344379774251997',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7101358704626344372152258073',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999990463,
#   'sort_key': 11760.0},
#  {'element_id': '7191735082626344379919995162',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7228063681626344375366396850',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999990463,
#   'sort_key': 11760.0},
#  {'element_id': '7293517499626344386520475068',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999990463,
#   'sort_key': 11760.0},
#  {'element_id': '6445445431626344384798931967',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6427435638626344376451747694',
#   'x': 0.0,
#   'y': 480.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7523026542626344374935483353',
#   'x': 0.0,
#   'y': 384.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5589421840626344379532432841',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5113380544626344383423893933',
#   'x': 0.0,
#   'y': 2448.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5168283634626344378196236314',
#   'x': 0.0,
#   'y': 1440.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5347547044626344380477687841',
#   'x': 0.0,
#   'y': 1824.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999990463,
#   'sort_key': 11760.0},
#  {'element_id':

#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9871747494,
#   'sort_key': 1764.0},
#  {'element_id': '0323380527626344383414417869',
#   'x': 499.65625,
#   'y': 305.09375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9090377688,
#   'sort_key': 1764.0},
#  {'element_id': '1016826572626344383168202138',
#   'x': 446.9375,
#   'y': 293.09375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9090377688,
#   'sort_key': 1764.0},
#  {'element_id': '0708320639626344384994462822',
#   'x': 438.609375,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9090377688,
#   'sort_key': 1764.0},
#  {'element_id': '9419228203626344387913806359',
#   'x': 394.21875,
#   'y': 305.09375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9090377688,
#   'sort_key': 1764.0},
#  {'element_id': '0784380346626344389520878160',
#   'x': 282.0,
#   'y': 463.953125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9871747494,
#   'sort_key': 1764.0},
#  {'element_id': '8968238520626344387189841278',
#   'x': 337.375,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9090377688,
#   'sort_key': 1764.0},
#  {'element_id': '8577815484626344385593363018',
#   'x': 258.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9090377688,
#   'sort_key': 1764.0},
#  {'element_id': '2828670189626344387329994168',
#   'x': 522.90625,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999974966,
#   'sort_key': 1764.0},
#  {'element_id': '4792466561626344385748617863',
#   'x': 285.0,
#   'y': 317.09375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.6846932173,
#   'sort_key': 1764.0}]
# CPU times: user 58.4 ms, sys: 8.97 ms, total: 67.3 ms
# Wall time: 1.39 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id      x            y       width  height  \
# 0  6129592666626344388871443035  269.0   293.093750  316.062500    66.0
# 1  7823417517626344386992360154  269.0   138.218750  374.796875    42.0
# 2  1980270273626344383805340590  293.0   463.953125  179.796875    84.0
# 3  0026833165626344370606276072    0.0  1440.000000  245.000000    48.0
# 4  6965973010626344379620469128    0.0   624.000000  245.000000    48.0
#
#   predicted_label  predicted_probability     sort_key tag_name
# 0      radiogroup               1.000000  20860.12500      DIV
# 1      radiogroup               1.000000  15741.46875      DIV
# 2      radiogroup               1.000000  15102.93750      DIV
# 3            list               0.999999  11760.00000      DIV
# 4          button               1.000000  11760.00000      DIV

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
