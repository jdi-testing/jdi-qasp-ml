# %%
import sys
import re
import os
from datetime import datetime
from time import sleep
from IPython.display import display, clear_output, HTML

# set working dir
WORKING_DIR = re.sub('jdi-qasp-ml.*$','',os.path.normpath(os.getcwd())) + 'jdi-qasp-ml'
os.chdir(WORKING_DIR)

import utils
from utils import *
import torch
import pandas as pd
import numpy as np
import torch
from glob import glob
import selenium

START_TS = datetime.now()
display(HTML(f'{START_TS} - Current working directory: <b>{WORKING_DIR}</b>'))

import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

import numba
# Out:
# 2021-06-01 21:49:38,712 -INFO - config:config.py:16 - Module utils.config was loaded
# 2021-06-01 21:49:38,728 -INFO - common:common.py:616 - Module utils.common is loaded...
# 2021-06-01 21:49:38,728 -INFO - hidden:hidden.py:121 - hidden module is loaded
# 2021-06-01 21:49:38,732 -INFO - dataset_builder:dataset_builder.py:200 - dataset package is loaded...
# 2021-06-01 21:49:39,366 -INFO - dataset:dataset.py:652 - dataset module is loaded...
# 2021-06-01 21:49:39.366306 - Current working directory: <b>D:\DataScience\!WORK\jdi-qasp-ml</b>

# %%
from utils import get_all_elements, iou_xywh, screenshot, maximize_window, get_parents_list, build_tree_dict, DatasetBuilder

# %%
selenium.__version__
# Out:
# '3.141.0'

# %% [markdown]
# # Parameters

# %%
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
HEADLESS = True #False

# %%
with open('dataset/classes.txt', 'r') as f:
    decoder_dict = { i:s.strip() for i, s in  enumerate(f.readlines())}
decoder_dict
# Out:
# {0: 'button',
#  1: 'link',
#  2: 'iframe',
#  3: 'textfield',
#  4: 'dropdown',
#  5: 'checkbox_btn',
#  6: 'checkbox_label',
#  7: 'radiobutton_btn',
#  8: 'radiobutton_label',
#  9: 'textarea',
#  10: 'text',
#  11: 'fileinput',
#  12: 'image',
#  13: 'colorpicker',
#  14: 'range',
#  15: 'progressbar',
#  16: 'datetimeselector',
#  17: 'numberselector',
#  18: 'dropdownselector',
#  19: 'checklist',
#  20: 'table',
#  21: 'n/a'}

# %% [markdown]
# # Generate dataset

# %%
DATASET_NAME = 'dummy'
class JDIDatasetBuilder(DatasetBuilder):

    def setUp(self, driver):
        self.logger.info(f'getting page')
        driver.get(SITE_URL)
        
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        
        driver.find_element_by_link_text("Service").click()
        driver.find_element_by_link_text("Complex Table").click()
        maximize_window(driver=driver)
        

with JDIDatasetBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True) as builder:
    elements_df = builder.dataset
    plt.imshow(plt.imread(f'dataset/images/{DATASET_NAME}.png'))
# Out:
# 2021-06-01 21:49:39,483 -WARNING - dataset_builder:dataset_builder.py:75 - The default dataset name "dummy" will be used
# 2021-06-01 21:49:39,483 -INFO - dataset_builder:dataset_builder.py:86 - Create directories to save the dataset
# 2021-06-01 21:49:39,490 -INFO - dataset_builder:dataset_builder.py:121 - Creating driver
# 2021-06-01 21:49:40,579 -INFO - dataset_builder:dataset_builder.py:129 - Chrome web driver is created
# 2021-06-01 21:49:40,579 -INFO - <ipython-input-6-539263dfd9ac>:<ipython-input-6-539263dfd9ac>:5 - getting page
# 2021-06-01 21:49:51,708 -INFO - common:common.py:75 - Window maximized
# 2021-06-01 21:49:51,708 -INFO - dataset_builder:dataset_builder.py:132 - save scrinshot: dataset/images/dummy.png
# 2021-06-01 21:49:51,774 -INFO - dataset_builder:dataset_builder.py:176 - Collect features using JS script
# 2021-06-01 21:49:52,090 -INFO - dataset_builder:dataset_builder.py:184 - Save html to dataset/html/dummy.html
# 2021-06-01 21:49:52,101 -INFO - dataset_builder:dataset_builder.py:194 - Save parquet to dataset/df/dummy.parquet
# 2021-06-01 21:49:52,206 -INFO - dataset_builder:dataset_builder.py:99 - Close web driver

# %%
df = pd.read_parquet(f'dataset/df/{DATASET_NAME}.parquet')

# %%
df = build_features(df)
# Out:
# 2021-06-01 21:49:52,567 -INFO - hidden:hidden.py:107 - build field "is_hidden"

# %%
elements_dict = build_elements_dict(df)

# %%
df[['tag_name', 'element_id', 'parent_id', 'upper_sibling', 'lower_sibling', 'displayed', 'is_hidden', 'x', 'y', 'width', 'height']]
# Out:
#     tag_name                    element_id                     parent_id  \
# 0       HTML  8674692755733917795451322398                          None
# 1       HEAD  2189455542733917795649683639  8674692755733917795451322398
# 2       META  3760874014733917792073631016  2189455542733917795649683639
# 3      TITLE  5855568352733917790279548949  2189455542733917795649683639
# 4       META  5911878373733917791786951710  2189455542733917795649683639
# ..       ...                           ...                           ...
# 421       LI  0535419331733917792660213552  6509586806733917793144624967
# 422        A  8349800838733917796667955198  0535419331733917792660213552
# 423   SCRIPT  0988642453733917799784049138  2287105514733917799219606918
# 424   SCRIPT  3315556905733917797214077814  2287105514733917799219606918
# 425   SCRIPT  9379382265733917792374820059  2287105514733917799219606918
#
#                     upper_sibling                 lower_sibling  displayed  \
# 0                            None                          None       True
# 1                            None  2287105514733917799219606918      False
# 2                            None  5855568352733917790279548949      False
# 3    3760874014733917792073631016  5911878373733917791786951710      False
# 4    5855568352733917790279548949  1011406942733917799142453513      False
# ..                            ...                           ...        ...
# 421  8262693464733917795931622702                          None       True
# 422                          None                          None       True
# 423  4632292828733917798357672905  3315556905733917797214077814      False
# 424  0988642453733917799784049138  9379382265733917792374820059      False
# 425  3315556905733917797214077814                          None      False
#
#      is_hidden            x      y        width  height
# 0            0     0.000000    0.0  1183.000000   850.0
# 1            0     0.000000    0.0     0.000000     0.0
# 2            0     0.000000    0.0     0.000000     0.0
# 3            0     0.000000    0.0     0.000000     0.0
# 4            0     0.000000    0.0     0.000000     0.0
# ..         ...          ...    ...          ...     ...
# 421          0  1115.890625  828.0    64.109375    15.0
# 422          0  1115.890625  828.0    64.109375    15.0
# 423          1     0.000000    0.0     0.000000     0.0
# 424          1     0.000000    0.0     0.000000     0.0
# 425          1     0.000000    0.0     0.000000     0.0
#
# [426 rows x 11 columns]

# %%
img = load_gray_image('dataset/images/dummy.png')
img_height, img_width = img.shape
print(img_width, img_height)
plt.figure(figsize=(15, 100))
plt.imshow(img, cmap='gray')
# Out:
# 1200 867

# %%
predictions_df = rule_base_predict(df)
print(predictions_df.shape)
predictions_df
# Out:
# 2021-06-01 21:49:53,257 -INFO - common:common.py:489 - Num radio buttons found: 0
# 2021-06-01 21:49:53,259 -INFO - common:common.py:493 - Num radio2 buttons found: 0
# 2021-06-01 21:49:53,262 -INFO - common:common.py:500 - Num checkboxes found: 16
# 2021-06-01 21:49:53,265 -INFO - common:common.py:507 - Num comboboxes/dropdowns found: 0
# 2021-06-01 21:49:53,267 -INFO - common:common.py:518 - Num textfields found: 2
# 2021-06-01 21:49:53,269 -INFO - common:common.py:523 - Num texfields for numbers found: 0
# 2021-06-01 21:49:53,272 -INFO - common:common.py:528 - Num ranges found: 0
# 2021-06-01 21:49:53,274 -INFO - common:common.py:533 - Num ordinary text inputs found: 0
# 2021-06-01 21:49:53,276 -INFO - common:common.py:536 - Num buttons found: 5
# Button1:  ['9798141386733917790439340312']
# 2021-06-01 21:49:53,278 -INFO - common:common.py:541 - Num buttons1 found: 1
# 2021-06-01 21:49:53,280 -INFO - common:common.py:546 - Num buttons2 (Material-UI) found: 0
# 2021-06-01 21:49:53,282 -INFO - common:common.py:551 - Num links found: 71
# (55, 8)
#                        element_id            x      y       width  height  \
# 211  0908069847733917796713870770   463.000000  191.0  126.000000    21.0
# 217  1712525913733917798380739275   610.000000  191.0  193.000000    21.0
# 226  6133578200733917790093693336   463.000000  271.0  126.000000    21.0
# 232  9653816640733917796634066714   610.000000  271.0  193.000000    21.0
# 241  5040656023733917795697990774   463.000000  360.0  126.000000    21.0
# 247  1230449447733917794794084808   610.000000  351.0  193.000000    21.0
# 256  9913225784733917798079250176   463.000000  450.0  126.000000    21.0
# 262  7433287710733917796172990217   610.000000  450.0  193.000000    21.0
# 340  0296022578733917796133722184   240.000000  569.0  220.000000    34.0
# 357  0971238928733917790753184402   240.000000  613.0  110.578125    34.0
# 358  8663501545733917796844375588   363.390625  613.0   74.218750    34.0
# 94   9798141386733917790439340312  1000.468750   20.0   20.000000    20.0
# 34   7292599844733917790434676006    20.000000   21.0   86.000000    18.0
# 40   1944292515733917794570224146   222.937500    0.0   64.515625    60.0
# 42   0269708098733917790039651830   287.453125    0.0  121.859375    60.0
# 44   4725913153733917793711374429   409.312500    0.0   93.546875    60.0
# 66   6849419899733917792596751053   502.859375    0.0  140.484375    60.0
# 108       True          0      1
# 111       True          0      1
# 114       True          0      1
# 119       True          0      1
# 123       True          0      1
# 126       True          0      1
# 129       True          0      1
# 132       True          0      1
# 135       True          0      1
# 138       True          0      1
# 141       True          0      1
# 144       True          0      1
# 147       True          0      1
# 150       True          0      1
# 214       True          0      1
# 220       True          0      1
# 229       True          0      1
# 235       True          0      1
# 244       True          0      1
# 250       True          0      1
# 259       True          0      1
# 265       True          0      1
# 361       True          0      1
# 364       True          0      1
# 366       True          0      1
# 368       True          0      1
# 370       True          0      1
# 372       True          0      1
# 374       True          0      1
# 376       True          0      1
# 378       True          0      1
# 380       True          0      1
# 382       True          0      1
# 384       True          0      1
# 386       True          0      1
# 419       True          0      1
# 422       True          0      1

# %%
plt.text?

# %%
img = load_gray_image('dataset/images/dummy.png')
img_height, img_width = img.shape
print(img_width, img_height)
plt.figure(figsize=(15, 100))
plt.imshow(img, cmap='gray')
axes = plt.gca()

for _, r in predictions_df.iterrows():
    
    patch = patches.Rectangle((r.x, r.y), r.width, r.height, linewidth=2, alpha = .3, facecolor = 'red', edgecolor ='black')
    axes.add_patch(patch)
    plt.text(r.x, r.y, 
             decoder_dict[r.label] + ':',  ## + r.element_id, 
             fontsize = 14, 
             color = 'white', 
             backgroundcolor='black',
             alpha=1.)
# Out:
# 1200 867

# %%
df['class'] = df.attributes.apply(lambda x: x.get('class'))

# %%
df[df.tag_name == 'SPAN'][['element_id', 'parent_id', 'tag_name', 'displayed', 'is_hidden', 'class', 'x', 'y', 'width', 'height']]
# Out:
#                        element_id                     parent_id tag_name  \
# 32   7831402894733917791820938058  2951431092733917794084603967     SPAN
# 35   6826818135733917792506642219  7292599844733917790434676006     SPAN
# 45   3355199629733917793422735172  4725913153733917793711374429     SPAN
# 72   4064629121733917791233125101  4692389850733917797783242783     SPAN
# 73   1820006785733917792578311502  3933076982733917799839237565     SPAN
# 85   9514605054733917791295597925  1546083170733917790445687850     SPAN
# 88   6282926501733917799305443966  8707910833733917792888204707     SPAN
# 92   2370839973733917790214451840  3900433008733917795435503424     SPAN
# 94   9798141386733917790439340312  9305661730733917796731272074     SPAN
# 96   3147061697733917790175596499  2713333017733917793202820752     SPAN
# 97   6080940734733917794078479966  2713333017733917793202820752     SPAN
# 109  7890066585733917794825692285  9908242877733917796453004054     SPAN
# 112  9051690391733917791173223958  7135422117733917794345003524     SPAN
# 115  0001353333733917797261191309  2341897309733917794764045514     SPAN
# 121  4029979097733917792092948825  9419999136733917799191967139     SPAN
# 124  3681226038733917799193130276  3021527410733917791690675200     SPAN
# 127  0343076627733917797659110320  1934894838733917796937732987     SPAN
# 130  6162766448733917794865438452  8530315386733917794647253113     SPAN
# 133  0056210972733917793931920598  2729994949733917794179605620     SPAN
# 136  0517819484733917791325270861  5633222858733917799173538278     SPAN
# 139  3130480347733917793184817701  8421153811733917797187525663     SPAN
# 142  0775112278733917796269113669  3564604884733917790272570657     SPAN
# 174      False          1                     None     0.000000    0.00000
# 177      False          1                     None     0.000000    0.00000
# 209       True          0                     None   250.000000  211.00000
# 224       True          0                     None   250.000000  291.00000
# 239       True          0                     None   250.000000  380.00000
# 254       True          0                     None   250.000000  470.00000
# 269       True          1                     None   250.000000  550.00000
# 284       True          1                     None   250.000000  658.00000
# 299       True          1                     None   250.000000  748.00000
# 314       True          1                     None   250.000000  828.00000
# 341       True          0  filter-option pull-left   253.000000  576.00000
# 342       True          0                    caret   439.000000  584.00000
# 347      False          1                     text     0.000000    0.00000
# 351      False          1                     text     0.000000    0.00000
# 355      False          1                     text     0.000000    0.00000
#
#           width  height
# 32     0.000000     0.0
# 35    76.937500    24.0
# 45     8.000000     4.0
# 72    89.531250    20.0
# 73     8.000000     4.0
# 85     0.000000     0.0
# 88     0.000000     0.0
# 92     0.000000     0.0
# 94    20.000000    20.0
# 96     0.000000     0.0
# 97     0.000000     0.0
# 109   41.062500    19.0
# 112   92.703125    19.0
# 115   52.031250    19.0
# 121   54.734375    19.0
# 124   32.828125    18.0
# 127   86.218750    18.0
# 130   75.406250    18.0
# 133   40.000000    18.0
# 136   61.250000    18.0
# 139   97.546875    18.0
# 142  107.921875    18.0
# 145   75.140625    18.0
# 148  109.015625    19.0
# 151  109.937500    19.0
# 156    0.000000     0.0
# 159    0.000000     0.0
# 162    0.000000     0.0
# 165    0.000000     0.0
# 168    0.000000     0.0
# 171    0.000000     0.0
# 174    0.000000     0.0
# 177    0.000000     0.0
# 209  134.125000    18.0
# 224   39.468750    18.0
# 239   24.687500    18.0
# 254  141.312500    18.0
# 269  164.875000    37.0
# 284  130.515625    18.0
# 299   74.750000    18.0
# 314  128.031250    18.0
# 341  181.000000    20.0
# 342    8.000000     4.0
# 347    0.000000     0.0
# 351    0.000000     0.0
# 355    0.000000     0.0

# %%
df[df.attributes.apply(lambda x: x.get('onclick') is not None )][['element_id', 'parent_id', 'tag_name', 'displayed', 'is_hidden', 'x', 'y', 'width', 'height']]
# Out:
#                       element_id                     parent_id tag_name  \
# 97  6080940734733917794078479966  2713333017733917793202820752     SPAN
#
#     displayed  is_hidden    x    y  width  height
# 97      False          1  0.0  0.0    0.0     0.0

# %%
describe_node(df, '0142805936656719316729959211')
# Out:
# Describe node: <b>0142805936656719316729959211<b>
# <b>Parents:</b>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-3db6711ed1dd> in <module>
# ----> 1 describe_node(df, '0142805936656719316729959211')
#
# D:\DataScience\!WORK\jdi-qasp-ml\utils\describe.py in describe_node(df, element_id, tree_dict, elements_dict, siblings_dict)
#      32     parents_list = []
#      33     while p is not None:
# ---> 34         n = elements_dict[p]
#      35         n['element_id'] = p
#      36         parents_list.append(n)
#
# KeyError: '0142805936656719316729959211'

# %%
COLS = ['element_id', 'parent_id', 'tag_name', 'displayed', 'is_hidden']

# %%
for el in df[df.tag_name == 'A'][COLS].element_id.values:
    describe_node(df=df, element_id=el)
