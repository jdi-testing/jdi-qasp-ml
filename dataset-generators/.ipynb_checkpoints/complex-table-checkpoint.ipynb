# %%
import sys
import re
import os
from datetime import datetime
from time import sleep
from IPython.display import display, clear_output, HTML

# set working dir
WORKING_DIR = re.sub('jdi-qasp-ml.*$','',os.path.normpath(os.getcwd())) + 'jdi-qasp-ml'
os.chdir(WORKING_DIR)

import utils
from utils import *
import torch
import pandas as pd
import numpy as np
import torch
from glob import glob
import selenium

START_TS = datetime.now()
display(HTML(f'{START_TS} - Current working directory: <b>{WORKING_DIR}</b>'))

import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

import numba
# Out:
# 2021-06-01 14:38:55,436 -INFO - config:config.py:16 - Module utils.config was loaded
# 2021-06-01 14:38:55,436 -INFO - common:common.py:609 - Module utils.common is loaded...
# 2021-06-01 14:38:55,452 -INFO - hidden:hidden.py:121 - hidden module is loaded
# 2021-06-01 14:38:55,454 -INFO - dataset_builder:dataset_builder.py:200 - dataset package is loaded...
# 2021-06-01 14:38:56,053 -INFO - dataset:dataset.py:652 - dataset module is loaded...
# 2021-06-01 14:38:56.053579 - Current working directory: <b>D:\DataScience\!WORK\jdi-qasp-ml</b>

# %%
from utils import get_all_elements, iou_xywh, screenshot, maximize_window, get_parents_list, build_tree_dict, DatasetBuilder

# %%
selenium.__version__
# Out:
# '3.141.0'

# %% [markdown]
# # Parameters

# %%
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
HEADLESS = True #False

# %%
with open('dataset/classes.txt', 'r') as f:
    decoder_dict = { i:s.strip() for i, s in  enumerate(f.readlines())}
decoder_dict
# Out:
# {0: 'button',
#  1: 'link',
#  2: 'iframe',
#  3: 'textfield',
#  4: 'dropdown',
#  5: 'checkbox_btn',
#  6: 'checkbox_label',
#  7: 'radiobutton_btn',
#  8: 'radiobutton_label',
#  9: 'textarea',
#  10: 'text',
#  11: 'fileinput',
#  12: 'image',
#  13: 'colorpicker',
#  14: 'range',
#  15: 'progressbar',
#  16: 'datetimeselector',
#  17: 'numberselector',
#  18: 'dropdownselector',
#  19: 'checklist',
#  20: 'table',
#  21: 'n/a'}

# %% [markdown]
# # Generate dataset

# %%
DATASET_NAME = 'dummy'
class JDIDatasetBuilder(DatasetBuilder):

    def setUp(self, driver):
        self.logger.info(f'getting page')
        driver.get(SITE_URL)
        
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        
        driver.find_element_by_link_text("Service").click()
        driver.find_element_by_link_text("Complex Table").click()
        maximize_window(driver=driver)
        

with JDIDatasetBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True) as builder:
    elements_df = builder.dataset
    plt.imshow(plt.imread(f'dataset/images/{DATASET_NAME}.png'))
# Out:
# 2021-06-01 14:38:56,202 -WARNING - dataset_builder:dataset_builder.py:75 - The default dataset name "dummy" will be used
# 2021-06-01 14:38:56,203 -INFO - dataset_builder:dataset_builder.py:86 - Create directories to save the dataset
# 2021-06-01 14:38:56,204 -INFO - dataset_builder:dataset_builder.py:121 - Creating driver
# 2021-06-01 14:38:57,256 -INFO - dataset_builder:dataset_builder.py:129 - Chrome web driver is created
# 2021-06-01 14:38:57,256 -INFO - <ipython-input-6-539263dfd9ac>:<ipython-input-6-539263dfd9ac>:5 - getting page
# 2021-06-01 14:39:05,961 -INFO - common:common.py:75 - Window maximized
# 2021-06-01 14:39:05,961 -INFO - dataset_builder:dataset_builder.py:132 - save scrinshot: dataset/images/dummy.png
# 2021-06-01 14:39:06,053 -INFO - dataset_builder:dataset_builder.py:176 - Collect features using JS script
# 2021-06-01 14:39:06,368 -INFO - dataset_builder:dataset_builder.py:184 - Save html to dataset/html/dummy.html
# 2021-06-01 14:39:06,379 -INFO - dataset_builder:dataset_builder.py:194 - Save parquet to dataset/df/dummy.parquet
# 2021-06-01 14:39:06,480 -INFO - dataset_builder:dataset_builder.py:99 - Close web driver

# %%
df = pd.read_parquet(f'dataset/df/{DATASET_NAME}.parquet')

# %%
df = build_features(df)
# Out:
# 2021-06-01 14:39:06,802 -INFO - hidden:hidden.py:107 - build field "is_hidden"

# %%
elements_dict = build_elements_dict(df)

# %%
df[['tag_name', 'element_id', 'parent_id', 'upper_sibling', 'lower_sibling', 'displayed', 'is_hidden', 'x', 'y', 'width', 'height']]
# Out:
#     tag_name                    element_id                     parent_id  \
# 0       HTML  2264520177475460579170135161                          None
# 1       HEAD  3206338291475460577343204036  2264520177475460579170135161
# 2       META  8256258045475460574863408897  3206338291475460577343204036
# 3      TITLE  3561534830475460577828189059  3206338291475460577343204036
# 4       META  7278112364475460572840299878  3206338291475460577343204036
# ..       ...                           ...                           ...
# 421       LI  0964805798475460577996862041  2714024502475460579041686849
# 422        A  4969367586475460578966679973  0964805798475460577996862041
# 423   SCRIPT  9132054389475460579962698161  4880324216475460570002823735
# 424   SCRIPT  4520004268475460576735167656  4880324216475460570002823735
# 425   SCRIPT  9420296172475460575676334854  4880324216475460570002823735
#
#                     upper_sibling                 lower_sibling  displayed  \
# 0                            None                          None       True
# 1                            None  4880324216475460570002823735      False
# 2                            None  3561534830475460577828189059      False
# 3    8256258045475460574863408897  7278112364475460572840299878      False
# 4    3561534830475460577828189059  0755591251475460574091171265      False
# ..                            ...                           ...        ...
# 421  1014789823475460577610457748                          None       True
# 422                          None                          None       True
# 423  8037931019475460576170535633  4520004268475460576735167656      False
# 424  9132054389475460579962698161  9420296172475460575676334854      False
# 425  4520004268475460576735167656                          None      False
#
#      is_hidden            x      y        width  height
# 0            0     0.000000    0.0  1183.000000   850.0
# 1            0     0.000000    0.0     0.000000     0.0
# 2            0     0.000000    0.0     0.000000     0.0
# 3            0     0.000000    0.0     0.000000     0.0
# 4            0     0.000000    0.0     0.000000     0.0
# ..         ...          ...    ...          ...     ...
# 421          0  1115.890625  828.0    64.109375    15.0
# 422          0  1115.890625  828.0    64.109375    15.0
# 423          1     0.000000    0.0     0.000000     0.0
# 424          1     0.000000    0.0     0.000000     0.0
# 425          1     0.000000    0.0     0.000000     0.0
#
# [426 rows x 11 columns]

# %%
img = load_gray_image('dataset/images/dummy.png')
img_height, img_width = img.shape
print(img_width, img_height)
plt.figure(figsize=(15, 100))
plt.imshow(img, cmap='gray')
# Out:
# 1200 867

# %%
predictions_df = rule_base_predict(df)
print(predictions_df.shape)
predictions_df
# Out:
# 2021-06-01 14:39:07,490 -INFO - common:common.py:489 - Num radio buttons found: 0
# 2021-06-01 14:39:07,493 -INFO - common:common.py:493 - Num radio2 buttons found: 0
# 2021-06-01 14:39:07,495 -INFO - common:common.py:500 - Num checkboxes found: 16
# 2021-06-01 14:39:07,498 -INFO - common:common.py:507 - Num comboboxes/dropdowns found: 0
# 2021-06-01 14:39:07,501 -INFO - common:common.py:518 - Num textfields found: 2
# 2021-06-01 14:39:07,506 -INFO - common:common.py:523 - Num texfields for numbers found: 0
# 2021-06-01 14:39:07,509 -INFO - common:common.py:528 - Num ranges found: 0
# 2021-06-01 14:39:07,513 -INFO - common:common.py:533 - Num ordinary text inputs found: 0
# 2021-06-01 14:39:07,515 -INFO - common:common.py:536 - Num buttons found: 5
# 2021-06-01 14:39:07,519 -INFO - common:common.py:541 - Num buttons2 (Material-UI) found: 0
# 2021-06-01 14:39:07,522 -INFO - common:common.py:546 - Num links found: 71
# (54, 8)
#                        element_id            x      y       width  height  \
# 211  1479005873475460577112388246   463.000000  191.0  126.000000    21.0
# 217  9931301939475460576339623743   610.000000  191.0  193.000000    21.0
# 226  2241207658475460570260529200   463.000000  271.0  126.000000    21.0
# 232  9331021305475460577195102146   610.000000  271.0  193.000000    21.0
# 241  4750292727475460576346193422   463.000000  360.0  126.000000    21.0
# 247  4607723092475460574614069116   610.000000  351.0  193.000000    21.0
# 256  2671841631475460573810690020   463.000000  450.0  126.000000    21.0
# 262  6764894114475460576521832501   610.000000  450.0  193.000000    21.0
# 340  1491124398475460570467320602   240.000000  569.0  220.000000    34.0
# 357  2154811006475460575946520087   240.000000  613.0  110.578125    34.0
# 358  5967909357475460579896491755   363.390625  613.0   74.218750    34.0
# 34   0665445126475460570421553390    20.000000   21.0   86.000000    18.0
# 40   5921833003475460573956069508   222.937500    0.0   64.515625    60.0
# 42   7393551616475460572288275327   287.453125    0.0  121.859375    60.0
# 44   1411652182475460570036881471   409.312500    0.0   93.546875    60.0
# 66   4454607371475460573396496074   502.859375    0.0  140.484375    60.0
# 69   8198527495475460571033837666  1160.000000   20.0   40.000000    20.0
# 108  7748426710475460572206978106     0.000000   60.0  200.000000    39.0
# 111  9280118600475460579812298829     0.000000  101.0  200.000000    39.0
# 114  9338297236475460571857077000     0.000000  142.0  200.000000    39.0
# 119  7938788187475460570236624376     0.000000  181.0  200.000000    43.0
# 123  8299339802475460578280310141     0.000000  224.0  200.000000    38.0
# 126  9084967534475460570230096180     0.000000  262.0  200.000000    38.0
# 129  7453761003475460570514841467     0.000000  300.0  200.000000    38.0
# 132  3385379715475460572461429808     0.000000  338.0  200.000000    38.0
# 135  2642221164475460572908382742     0.000000  376.0  200.000000    38.0
# 138  6613710928475460570264789907     0.000000  414.0  200.000000    38.0
# 141  7399691073475460571686338228     0.000000  452.0  200.000000    38.0
# 144  0599664992475460577655569620     0.000000  490.0  200.000000    38.0
# 147  4684562825475460571005617154     0.000000  530.0  200.000000    39.0
# 150  3977542140475460570148950177     0.000000  571.0  200.000000    39.0
# 214  4324222081475460576929737261   499.203125  212.0   53.593750    18.0
# 220  8328531161475460576938047871   679.703125  212.0   53.593750    18.0
# 229  9913879954475460578250726592   499.203125  292.0   53.593750    18.0
# 235  7028101009475460579980848967   679.703125  292.0   53.593750    18.0
# 244  7809200322475460573878371656   499.203125  381.0   53.593750    18.0
# 250  5760027272475460578602752097   679.703125  372.0   53.593750    18.0
# 259  4453243695475460579656085944   499.203125  471.0   53.593750    18.0
# 265  2334074480475460571744135569   679.703125  471.0   53.593750    18.0
# 361  5084981792475460575810690755   301.343750  719.0   40.000000    32.0
# 364  0586720980475460578009890450   340.343750  719.0   51.484375    32.0
# 366  8200824115475460575020661805   390.828125  719.0   32.968750    32.0
# 368  5866291825475460571602009406   422.796875  719.0   32.968750    32.0
# 370  0304183369475460578483097615   454.765625  719.0   32.968750    32.0
# 372  5694639927475460573647851243   486.734375  719.0   32.968750    32.0
# 374  7234671638475460579720776143   518.703125  719.0   32.968750    32.0
# 376  4768198723475460573575503427   550.671875  719.0   32.968750    32.0
# 378  1429698950475460572541009490   582.640625  719.0   32.968750    32.0
# 380  2220938459475460573270780279   614.609375  719.0   32.968750    32.0
# 382  9207439057475460575637205368   646.578125  719.0   32.968750    32.0
# 384  7623723339475460573352580135   678.546875  719.0   50.187500    32.0
# 386  9143816225475460572352170954   727.734375  719.0   40.000000    32.0
# 419  0357761843475460574686094858  1052.718750  828.0   30.265625    15.0
# 422  4969367586475460578966679973  1115.890625  828.0   64.109375    15.0
#
#      displayed  is_hidden  label
# 211       True          0      5
# 217       True          0      5
# 226       True          0      5
# 232       True          0      5
# 241       True          0      5
# 247       True          0      5
# 256       True          0      5
# 262       True          0      5
# 340       True          0      0
# 357       True          0      0
# 358       True          0      0
# 34        True          0      1
# 40        True          0      1
# 42        True          0      1
# 44        True          0      1
# 66        True          0      1
# 69        True          0      1
# 108       True          0      1
# 111       True          0      1
# 114       True          0      1
# 119       True          0      1
# 123       True          0      1
# 126       True          0      1
# 129       True          0      1
# 132       True          0      1
# 135       True          0      1
# 138       True          0      1
# 141       True          0      1
# 144       True          0      1
# 147       True          0      1
# 150       True          0      1
# 214       True          0      1
# 220       True          0      1
# 229       True          0      1
# 235       True          0      1
# 244       True          0      1
# 250       True          0      1
# 259       True          0      1
# 265       True          0      1
# 361       True          0      1
# 364       True          0      1
# 366       True          0      1
# 368       True          0      1
# 370       True          0      1
# 372       True          0      1
# 374       True          0      1
# 376       True          0      1
# 378       True          0      1
# 380       True          0      1
# 382       True          0      1
# 384       True          0      1
# 386       True          0      1
# 419       True          0      1
# 422       True          0      1

# %%
img = load_gray_image('dataset/images/dummy.png')
img_height, img_width = img.shape
print(img_width, img_height)
plt.figure(figsize=(15, 100))
plt.imshow(img, cmap='gray')
axes = plt.gca()

for _, r in predictions_df.iterrows():
    
    patch = patches.Rectangle((r.x, r.y), r.width, r.height, linewidth=2, alpha = .7, facecolor = 'red', edgecolor ='black')
    axes.add_patch(patch)
# Out:
# 1200 867
