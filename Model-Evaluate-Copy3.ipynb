# %%
import torch
from torch.utils.data import Dataset, DataLoader

from tqdm.auto import tqdm, trange
from sklearn.metrics import confusion_matrix

import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
# %matplotlib inline

import os, sys, re, gc, glob
from tqdm.auto import tqdm, trange
from utils import JDIDataset, JDIModel, get_grey_image, assign_labels, accuracy



import seaborn as sns
# Out:
# 2021-05-18 16:32:50,094 -INFO - common:common.py:422 - Module utils.common is loaded...
# 2021-05-18 16:32:50,096 -INFO - dataset_builder:dataset_builder.py:16 - dataset package is loaded...
# 2021-05-18 16:32:50,102 -INFO - dataset:dataset.py:627 - dataset package is loaded...

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
DEVICE
# Out:
# 'cuda'

# %%
DEVICE='cpu'

# %%
model = torch.load('model/model.pth').to(DEVICE)
model.eval()
# Out:
# JDIModel(
#   (input_layer): Linear(in_features=2231, out_features=64, bias=False)
#   (batchNorm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (leaky_relu1): LeakyReLU(negative_slope=0.1, inplace=True)
#   (hidden1): Linear(in_features=64, out_features=32, bias=False)
#   (batchNorm2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   (leaky_relu2): LeakyReLU(negative_slope=0.1, inplace=True)
#   (hidden2): Linear(in_features=32, out_features=21, bias=True)
# )

# %% [markdown]
# ## Load test dataset

# %%
# dataset_name = 'angular'
# dataset_name = 'html-5'
# dataset_name = 'react-ant'
# dataset_name = 'mobile-and-html-5'
# dataset_name = 'bootstrap'
# dataset_name = 'dummy'
# dataset_name = 'google'
# dataset_name = 'cnews'
dataset_name = 'login'

# %%
dataset = JDIDataset(dataset_names=[dataset_name], rebalance=False)
# Out:
# 2021-05-18 16:32:52,728 -INFO - dataset:dataset.py:235 - List of dataset_names:['login']
# 2021-05-18 16:32:52,729 -INFO - dataset:dataset.py:241 - Dataset for login
# 2021-05-18 16:32:52,791 -INFO - dataset:dataset.py:243 - Dataset shape: (231, 13)
# 2021-05-18 16:32:52,791 -INFO - dataset:dataset.py:245 - cleaning tag_name from dummy/auxiliary words
# 2021-05-18 16:32:52,793 -INFO - dataset:dataset.py:44 - select all leafs (nodes which are not parents)
# 2021-05-18 16:32:52,794 -INFO - dataset:dataset.py:47 - Leafs set size: 100 (nodes which have no children)
# 2021-05-18 16:32:52,795 -INFO - dataset:dataset.py:50 - count number of references to leafs
# 2021-05-18 16:32:52,796 -INFO - dataset:dataset.py:54 - Nodes with leafs as children set size: 72 (nodes which have leafs as children)
# 2021-05-18 16:32:52,798 -INFO - dataset:dataset.py:57 - count num children for each node
# 2021-05-18 16:32:52,799 -INFO - dataset:dataset.py:59 - Nodes with children: 132
# 2021-05-18 16:32:52,800 -INFO - dataset:dataset.py:62 - sum of children widths, heights, counts
# 2021-05-18 16:32:52,804 -INFO - dataset:dataset.py:69 - Sum of children widths
# 2021-05-18 16:32:52,808 -INFO - dataset:dataset.py:75 - Sum of children hights
#   0%|          | 0/231 [00:00<?, ?it/s]
# 2021-05-18 16:32:53,421 -INFO - dataset:dataset.py:260 - Dataset shape after merging with parents: (231, 44)
# 2021-05-18 16:32:53,422 -WARNING - dataset:dataset.py:266 - Load LABELS from dataset/annotations/login.txt
# Assigning labels:   0%|          | 0/23 [00:00<?, ?it/s]
# 2021-05-18 16:32:53,747 -INFO - dataset:dataset.py:282 - Concatenate datasets
# 2021-05-18 16:32:53,751 -INFO - dataset:dataset.py:284 - Dataset shape after reading: (231, 46)
# 2021-05-18 16:32:53,753 -WARNING - dataset:dataset.py:607 - Loading count vectorizer for column "cv_class": model/count_vectorizer_class.pkl
# 2021-05-18 16:32:53,755 -INFO - dataset:dataset.py:624 - class_sm: (231, 779)
# 2021-05-18 16:32:53,756 -INFO - dataset:dataset.py:293 - Build OHE column for attribute role
# 2021-05-18 16:32:53,758 -INFO - dataset:dataset.py:293 - Build OHE column for attribute type
# 2021-05-18 16:32:53,759 -INFO - dataset:dataset.py:293 - Build OHE column for attribute ui
# 2021-05-18 16:32:53,761 -INFO - dataset:dataset.py:298 - Build OHE column for attribute role_parent
# 2021-05-18 16:32:53,764 -INFO - dataset:dataset.py:298 - Build OHE column for attribute type_parent
# 2021-05-18 16:32:53,765 -INFO - dataset:dataset.py:298 - Build OHE column for attribute ui_parent
# 2021-05-18 16:32:53,768 -INFO - dataset:dataset.py:302 - OHE tag_name
# 2021-05-18 16:32:53,769 -WARNING - dataset:dataset.py:467 - loading existing OHE for column "tag_name" from model/tag_name.pkl
# 2021-05-18 16:32:53,770 -INFO - dataset:dataset.py:304 - tag_name_sm.shape: (231, 298)
# 2021-05-18 16:32:53,771 -INFO - dataset:dataset.py:306 - OHE tag_name_parent
# 2021-05-18 16:32:53,771 -WARNING - dataset:dataset.py:467 - loading existing OHE for column "tag_name_parent" from model/tag_name.pkl
# 2021-05-18 16:32:53,773 -INFO - dataset:dataset.py:310 - tag_name_parent_sm.shape: (231, 298)
# 2021-05-18 16:32:53,774 -INFO - dataset:dataset.py:312 - OHE ohe_role
# 2021-05-18 16:32:53,774 -WARNING - dataset:dataset.py:467 - loading existing OHE for column "ohe_role" from model/ohe_role.pkl
# 2021-05-18 16:32:53,776 -INFO - dataset:dataset.py:314 - ohe_role_sm.shape: (231, 37)
# 2021-05-18 16:32:53,776 -INFO - dataset:dataset.py:316 - OHE ohe_role_parent
# 2021-05-18 16:32:53,777 -WARNING - dataset:dataset.py:467 - loading existing OHE for column "ohe_role_parent" from model/ohe_role.pkl
# 2021-05-18 16:32:53,778 -INFO - dataset:dataset.py:320 - ohe_role_parent_sm.shape: (231, 37)
# 2021-05-18 16:32:53,779 -INFO - dataset:dataset.py:322 - OHE ohe_type
# 2021-05-18 16:32:53,779 -WARNING - dataset:dataset.py:467 - loading existing OHE for column "ohe_type" from model/ohe_type.pkl
# 2021-05-18 16:32:53,780 -INFO - dataset:dataset.py:324 - ohe_type_sm.shape: (231, 28)
# 2021-05-18 16:32:53,781 -INFO - dataset:dataset.py:326 - OHE ohe_type_parent
# 2021-05-18 16:32:53,781 -WARNING - dataset:dataset.py:467 - loading existing OHE for column "ohe_type_parent" from model/ohe_type.pkl
# 2021-05-18 16:32:53,783 -INFO - dataset:dataset.py:330 - ohe_type_parent_sm.shape: (231, 28)
# 2021-05-18 16:32:53,784 -INFO - dataset:dataset.py:332 - OHE ohe_ui
# 2021-05-18 16:32:53,784 -WARNING - dataset:dataset.py:467 - loading existing OHE for column "ohe_ui" from model/ohe_ui.pkl
# 2021-05-18 16:32:53,786 -INFO - dataset:dataset.py:334 - ohe_ui_sm.shape: (231, 14)
# 2021-05-18 16:32:53,787 -INFO - dataset:dataset.py:336 - OHE ohe_ui_parent
# 2021-05-18 16:32:53,787 -WARNING - dataset:dataset.py:467 - loading existing OHE for column "ohe_ui_parent" from model/ohe_ui.pkl
# 2021-05-18 16:32:53,788 -INFO - dataset:dataset.py:339 - ohe_ui_parent_sm.shape: (231, 14)
# 2021-05-18 16:32:53,790 -INFO - dataset:dataset.py:344 - Fit CountVectorizer for column "attributes"
# 2021-05-18 16:32:53,790 -WARNING - dataset:dataset.py:491 - loading existing count vectorizer for column "attributes_text" from model/count_vectorizer_attributes_text.pkl
# 2021-05-18 16:32:53,792 -INFO - dataset:dataset.py:346 - attributes_sm.shape: (231, 107)
# 2021-05-18 16:32:53,794 -WARNING - dataset:dataset.py:353 - Load CountVectorizer for column "chidren_tags": model/count_vectorizer_children_tags.pkl
# 2021-05-18 16:32:53,795 -INFO - dataset:dataset.py:363 - CountVectorizer "chilren_tags" size: 232
# 2021-05-18 16:32:53,796 -INFO - dataset:dataset.py:366 - chidren_tags_sm: (231, 232)
# 2021-05-18 16:32:53,797 -WARNING - dataset:dataset.py:373 - Load CountVectorizer for column "followers_tags": model/count_vectorizer_followers_tags.pkl
# 2021-05-18 16:32:53,797 -INFO - dataset:dataset.py:383 - CountVectorizer "followers_tags" size: 232
# 2021-05-18 16:32:53,799 -INFO - dataset:dataset.py:386 - followers_tags_sm: (231, 232)
# 2021-05-18 16:32:53,800 -INFO - dataset:dataset.py:391 - Fit CountVectorizer for column "attributes_parent"
# 2021-05-18 16:32:53,801 -WARNING - dataset:dataset.py:491 - loading existing count vectorizer for column "attributes_parent_text" from model/count_vectorizer_attributes_text.pkl
# 2021-05-18 16:32:53,803 -INFO - dataset:dataset.py:396 - attributes_parent_sm.shape: (231, 107)
# 2021-05-18 16:32:53,818 -INFO - dataset:dataset.py:423 - OHE columns sparse matrix: (231, 2231)

# %%
dataset.dataset.shape
# Out:
# (231, 55)

# %%
dataset.labels
# Out:
# 0       n/a
# 1       n/a
# 2       n/a
# 3       n/a
# 4       n/a
#        ...
# 226    link
# 227     n/a
# 228    link
# 229     n/a
# 230     n/a
# Name: label, Length: 231, dtype: object

# %%
dataset.dataset.label
# Out:
# 0      20
# 1      20
# 2      20
# 3      20
# 4      20
#        ..
# 226     1
# 227    20
# 228     1
# 229    20
# 230    20
# Name: label, Length: 231, dtype: int32

# %%
dataloader=DataLoader(dataset, shuffle=False, batch_size=1, collate_fn=dataset.collate_fn, pin_memory=True)

# %%
results = []
with trange(len(dataloader)) as bar:
    with torch.no_grad():
        for x, y in dataloader:
           
            y_pred = torch.round(torch.nn.Softmax(dim=1)(model(x.to(DEVICE)).to('cpu'))).detach().numpy()
            y_pred = y_pred[0].argmax()
            y = y.item()           
            
            results.append({
                'y_true': y,
                'y_pred': y_pred,
                'y_true_label': dataset.classes_reverse_dict[y], 
                'y_pred_label': dataset.classes_reverse_dict[y_pred]
            })
            bar.update(1)

results_df = pd.DataFrame(results)
results_df
# Out:
#   0%|          | 0/231 [00:00<?, ?it/s]
#      y_true  y_pred y_true_label y_pred_label
# 0        20      20          n/a          n/a
# 1        20      20          n/a          n/a
# 2        20      20          n/a          n/a
# 3        20      20          n/a          n/a
# 4        20      20          n/a          n/a
# ..      ...     ...          ...          ...
# 226       1       1         link         link
# 227      20      20          n/a          n/a
# 228       1       1         link         link
# 229      20      20          n/a          n/a
# 230      20      20          n/a          n/a
#
# [231 rows x 4 columns]

# %%
list(dataset.classes_dict.keys())
# Out:
# ['button',
#  'link',
#  'iframe',
#  'textfield',
#  'dropdown',
#  'checkbox',
#  'textarea',
#  'label',
#  'text',
#  'fileinput',
#  'image',
#  'colorpicker',
#  'range',
#  'progressbar',
#  'datetimeselector',
#  'numberselector',
#  'dropdownselector',
#  'checklist',
#  'radiobutton',
#  'table',
#  'n/a']

# %%
confusion_matrix_df = pd.DataFrame(
    confusion_matrix(y_true=results_df.y_true_label.values,
                     y_pred=results_df.y_pred_label.values, 
                     labels=list(dataset.classes_dict.keys())
                    ), 
    columns=list(dataset.classes_dict.keys()),
    index=list(dataset.classes_dict.keys())
)

# %%
confusion_matrix_df
# Out:
#                   button  link  iframe  textfield  dropdown  checkbox  \
# button                 2     0       0          0         0         0
# link                   0    13       0          0         0         0
# iframe                 0     0       4          0         0         0
# textfield              0     0       0          0         0         0
# dropdown               0     0       0          0         1         0
# checkbox               0     0       0          0         0         0
# textarea               0     0       0          0         0         0
# label                  0     0       0          0         0         0
# text                   0     0       0          0         0         0
# fileinput              0     0       0          0         0         0
# image                  0     0       0          0         0         0
# colorpicker            0     0       0          0         0         0
# range                  0     0       0          0         0         0
# progressbar            0     0       0          0         0         0
# datetimeselector       0     0       0          0         0         0
# numberselector         0     0       0          0         0         0
# dropdownselector       0     0       0          0         0         0
# checklist              0     0       0          0         0         0
# radiobutton            0     0       0          0         0         0
# table                  0     0       0          0         0         0
# n/a                    1     5       0          0         0         0
#
#                   textarea  label  text  fileinput  ...  colorpicker  range  \
# button                   0      0     0          0  ...            0      0
# link                     0      0     0          0  ...            0      0
# iframe                   0      0     0          0  ...            0      0
# textfield                0      0     0          0  ...            0      0
# dropdown                 0      0     0          0  ...            0      0
# checkbox                 0      0     0          0  ...            0      0
# textarea                 0      0     0          0  ...            0      0
# label                    0      0     0          0  ...            0      0
# text                     0      0     0          0  ...            0      0
# fileinput                0      0     0          0  ...            0      0
# image                    0      0     0          0  ...            0      0
# colorpicker              0      0     0          0  ...            0      0
# range                    0      0     0          0  ...            0      0
# progressbar              0      0     0          0  ...            0      0
# datetimeselector         0      0     0          0  ...            0      0
# numberselector           0      0     0          0  ...            0      0
# dropdownselector         0      0     0          0  ...            0      0
# checklist                0      0     0          0  ...            0      0
# radiobutton              0      0     0          0  ...            0      0
# table                    0      0     0          0  ...            0      0
# n/a                      0      0     0          0  ...            0      0
#
#                   progressbar  datetimeselector  numberselector  \
# button                      0                 0               0
# link                        0                 0               0
# iframe                      0                 0               0
# textfield                   0                 0               0
# dropdown                    0                 0               0
# checkbox                    0                 0               0
# textarea                    0                 0               0
# label                       0                 0               0
# text                        0                 0               0
# fileinput                   0                 0               0
# image                       0                 0               0
# colorpicker                 0                 0               0
# range                       0                 0               0
# progressbar                 0                 0               0
# datetimeselector            0                 0               0
# numberselector              0                 0               0
# dropdownselector            0                 0               0
# checklist                   0                 0               0
# radiobutton                 0                 0               0
# table                       0                 0               0
# n/a                         0                 0               0
#
#                   dropdownselector  checklist  radiobutton  table  n/a
# button                           0          0            0      0    0
# link                             0          0            0      0    3
# iframe                           0          0            0      0    0
# textfield                        0          0            0      0    0
# dropdown                         0          0            0      0    0
# checkbox                         0          0            0      0    0
# textarea                         0          0            0      0    0
# label                            0          0            0      0    0
# text                             0          0            0      0    0
# fileinput                        0          0            0      0    0
# image                            0          0            0      0    0
# colorpicker                      0          0            0      0    0
# range                            0          0            0      0    0
# progressbar                      0          0            0      0    0
# datetimeselector                 0          0            0      0    0
# numberselector                   0          0            0      0    0
# dropdownselector                 0          0            0      0    0
# checklist                        0          0            0      0    0
# radiobutton                      0          0            0      0    0
# table                            0          0            0      0    0
# n/a                              0          0            0      0  202
#
# [21 rows x 21 columns]

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
sns.heatmap(confusion_matrix_df, annot=True, fmt="4d", cmap="YlGnBu");

# %%
dataset_name
# Out:
# 'login'

# %%
accuracy(results_df)
# Out:
# <H2>Accuracy: 0.6896551724137931 <H2>
# 2021-05-18 16:32:55,534 -INFO - common:common.py:457 - Accuracy:  20/29 = 0.6896551724137931, for 231 elements
# 0.6896551724137931

# %%
dataset.classes_dict
# Out:
# {'button': 0,
#  'link': 1,
#  'iframe': 2,
#  'textfield': 3,
#  'dropdown': 4,
#  'checkbox': 5,
#  'textarea': 6,
#  'label': 7,
#  'text': 8,
#  'fileinput': 9,
#  'image': 10,
#  'colorpicker': 11,
#  'range': 12,
#  'progressbar': 13,
#  'datetimeselector': 14,
#  'numberselector': 15,
#  'dropdownselector': 16,
#  'checklist': 17,
#  'radiobutton': 18,
#  'table': 19,
#  'n/a': 20}

# %%
dataset.dataset['label_text_predicted'] = results_df.y_pred_label

# %%
gray_img = get_grey_image(f'dataset/images/{dataset_name}.png')
print(gray_img.shape)

IMG_SIZE = 15
_h = gray_img.shape[0]/gray_img.shape[1]*IMG_SIZE
_w = IMG_SIZE
plt.figure(figsize=(_w, _h))

plt.imshow(gray_img, cmap='gray')
axes = plt.gca()

for i, r in dataset.dataset[dataset.dataset.label_text_predicted != 'n/a'].iterrows():
    #print(r.predicted_label, r.x, r.y, r.width, r.height)
    
    if (r.x<0) or (r.y<0): # or (r.x>r.width): #or (r.y>r.height):
        continue
        
    patch = Rectangle((r.x, r.y), r.width, r.height, linewidth=2, alpha = .2, facecolor = 'blue')
    axes.add_patch(patch)
    axes.text(r.x, r.y, r.label_text_predicted, color='white', backgroundcolor='blue')

for i, r in dataset.dataset[dataset.dataset.label != dataset.dummy_class_value].iterrows():
    #print(r.predicted_label, r.x, r.y, r.width, r.height)
    patch = Rectangle((r.x, r.y), r.width, r.height, linewidth=2, alpha = .2, facecolor = 'red')
    axes.add_patch(patch)
    axes.text(r.x+15, r.y+15, dataset.classes_reverse_dict[r.label], color='white', backgroundcolor='red')
# Out:
# (1336, 1200)

# %%
results_df
# Out:
#      y_true  y_pred y_true_label y_pred_label
# 0        20      20          n/a          n/a
# 1        20      20          n/a          n/a
# 2        20      20          n/a          n/a
# 3        20      20          n/a          n/a
# 4        20      20          n/a          n/a
# ..      ...     ...          ...          ...
# 226       1       1         link         link
# 227      20      20          n/a          n/a
# 228       1       1         link         link
# 229      20      20          n/a          n/a
# 230      20      20          n/a          n/a
#
# [231 rows x 4 columns]

# %%
dataset.dataset[:1].to_json(orient='records')
# Out:
# '[{"attributes":{"alt":null,"charset":null,"class":null,"content":null,"data-placement":null,"data-toggle":null,"dir":null,"for":null,"href":null,"http-equiv":null,"id":null,"index":null,"lang":"en","language":null,"name":null,"onclick":null,"oncontextmenu":null,"rel":null,"role":null,"scrolling":null,"src":null,"style":null,"tabindex":null,"target":null,"title":null,"type":null,"ui":null,"width":null},"displayed":false,"element_id":"7447075968320943569374131866","height":1319.0,"onmouseenter":null,"onmouseover":null,"parent_id":"7447075968320943569374131866","style":["align-content","align-items","align-self","alignment-baseline","animation-delay","animation-direction","animation-duration","animation-fill-mode","animation-iteration-count","animation-name","animation-play-state","animation-timing-function","appearance","backdrop-filter","backface-visibility","background-attachment","background-blend-mode","background-clip","background-color","background-image","background-origin","background-position","background-repeat","background-size","baseline-shift","block-size","border-block-end-color","border-block-end-style","border-block-end-width","border-block-start-color","border-block-start-style","border-block-start-width","border-bottom-color","border-bottom-left-radius","border-bottom-right-radius","border-bottom-style","border-bottom-width","border-collapse","border-end-end-radius","border-end-start-radius","border-image-outset","border-image-repeat","border-image-slice","border-image-source","border-image-width","border-inline-end-color","border-inline-end-style","border-inline-end-width","border-inline-start-color","border-inline-start-style","border-inline-start-width","border-left-color","border-left-style","border-left-width","border-right-color","border-right-style","border-right-width","border-start-end-radius","border-start-start-radius","border-top-color","border-top-left-radius","border-top-right-radius","border-top-style","border-top-width","bottom","box-shadow","box-sizing","break-after","break-before","break-inside","buffered-rendering","caption-side","caret-color","clear","clip","clip-path","clip-rule","color","color-interpolation","color-interpolation-filters","color-rendering","column-count","column-gap","column-rule-color","column-rule-style","column-rule-width","column-span","column-width","content","cursor","cx","cy","d","direction","display","dominant-baseline","empty-cells","fill","fill-opacity","fill-rule","filter","flex-basis","flex-direction","flex-grow","flex-shrink","flex-wrap","float","flood-color","flood-opacity","font-family","font-kerning","font-optical-sizing","font-size","font-stretch","font-style","font-variant","font-variant-caps","font-variant-east-asian","font-variant-ligatures","font-variant-numeric","font-weight","grid-auto-columns","grid-auto-flow","grid-auto-rows","grid-column-end","grid-column-start","grid-row-end","grid-row-start","grid-template-areas","grid-template-columns","grid-template-rows","height","hyphens","image-orientation","image-rendering","inline-size","inset-block-end","inset-block-start","inset-inline-end","inset-inline-start","isolation","justify-content","justify-items","justify-self","left","letter-spacing","lighting-color","line-break","line-height","list-style-image","list-style-position","list-style-type","margin-block-end","margin-block-start","margin-bottom","margin-inline-end","margin-inline-start","margin-left","margin-right","margin-top","marker-end","marker-mid","marker-start","mask-type","max-block-size","max-height","max-inline-size","max-width","min-block-size","min-height","min-inline-size","min-width","mix-blend-mode","object-fit","object-position","offset-distance","offset-path","offset-rotate","opacity","order","orphans","outline-color","outline-offset","outline-style","outline-width","overflow-anchor","overflow-clip-margin","overflow-wrap","overflow-x","overflow-y","overscroll-behavior-block","overscroll-behavior-inline","padding-block-end","padding ...
