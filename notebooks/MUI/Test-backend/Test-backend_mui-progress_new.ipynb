# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-12-01 16:45:00,475 -INFO - config.py:31 - Module utils.config was loaded
# 2021-12-01 16:45:00,502 -INFO - common.py:119 - Module utils.common is loaded...
# 2021-12-01 16:45:00,503 -INFO - dataset_builder.py:245 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'mui-progress'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/progress'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-12-01 16:45:00,664 -INFO - dataset_builder.py:100 - Dataset name: mui-progress
# 2021-12-01 16:45:00,666 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-12-01 16:45:00,669 -INFO - dataset_builder.py:151 - Creating driver
# 2021-12-01 16:45:01,940 -INFO - dataset_builder.py:163 - Chrome web driver is created
# 2021-12-01 16:45:05,891 -INFO - common.py:22 - Window maximized
# 2021-12-01 16:45:12,894 -INFO - dataset_builder.py:166 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/mui-progress.png
# 2021-12-01 16:45:18,928 -INFO - dataset_builder.py:210 - Collect features using JS script
# 2021-12-01 16:45:19,535 -INFO - dataset_builder.py:218 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/mui-progress.html
# 2021-12-01 16:45:19,556 -INFO - dataset_builder.py:230 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/mui-progress.pkl
# 2021-12-01 16:45:19,558 -INFO - dataset_builder.py:233 - No attributes: (17, 13)
# 2021-12-01 16:45:24,801 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '0050721000663189360957311796',
#   'x': 0.0,
#   'y': 2304.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id':
0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 3136.0},
#  {'element_id': '7363146303663189369806798039',
#   'x': 266.0726013184,
#   'y': 878.1975708008,
#   'width': 55.8547973633,
#   'height': 55.8547973633,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 3119.7583884932},
#  {'element_id': '5472210279663189366695505562',
#   'x': 546.224609375,
#   'y': 235.3027191162,
#   'width': 55.55078125,
#   'height': 55.5507965088,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 3085.890145123},
#  {'element_id': '7343892444663189369594112458',
#   'x': 266.224609375,
#   'y': 130.4433441162,
#   'width': 55.55078125,
#   'height': 55.5507965088,
#   'predicted_label': 'progress',
#   'predicted_probability': 0.9999645948,
#   'sort_key': 3085.890145123},
#  {'element_id': '7043906819663189368618895836',
#   'x': 485.328125,
#   'y': 1082.015625,
#   'width': 77.34375,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9746752977,
#   'sort_key': 2823.046875},
#  {'element_id': '8783789523663189364222752633',
#   'x': 274.0,
#   'y': 594.671875,
#   'width': 500.0,
#   'height': 4.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 2000.0},
#  {'element_id': '8738117499663189360433582246',
#   'x': 274.0,
#   'y': 732.390625,
#   'width': 500.0,
#   'height': 4.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 2000.0},
#  {'element_id': '7463895880663189368125265441',
#   'x': 274.0,
#   'y': 663.53125,
#   'width': 500.0,
#   'height': 4.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 2000.0},
#  {'element_id': '2553842287663189365445018092',
#   'x': 274.0,
#   'y': 809.25,
#   'width': 457.0,
#   'height': 4.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 1828.0},
#  {'element_id': '0505081851663189366283127829',
#   'x': 330.0,
#   'y': 243.078125,
#   'width': 40.0,
#   'height': 40.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0},
#  {'element_id': '2915391429663189369639367476',
#   'x': 274.0,
#   'y': 484.796875,
#   'width': 40.0,
#   'height': 40.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0},
#  {'element_id': '5169402774663189369559164115',
#   'x': 386.0,
#   'y': 243.078125,
#   'width': 40.0,
#   'height': 40.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0},
#  {'element_id': '0558767894663189362700876831',
#   'x': 274.0,
#   'y': 243.078125,
#   'width': 40.0,
#   'height': 40.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0},
#  {'element_id': '5528879832663189369702675247',
#   'x': 274.0,
#   'y': 886.125,
#   'width': 40.0,
#   'height': 40.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0},
#  {'element_id': '5801749035663189366163313326',
#   'x': 498.0,
#   'y': 243.078125,
#   'width': 40.0,
#   'height': 40.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0},
#  {'element_id': '3818965105663189363229664429',
#   'x': 442.0,
#   'y': 243.078125,
#   'width': 40.0,
#   'height': 40.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0}]
# CPU times: user 64.9 ms, sys: 23.4 ms, total: 88.3 ms
# Wall time: 1.68 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id    x       y  width  height predicted_label  \
# 0  0050721000663189360957311796  0.0  2304.0  250.0    48.0            list
# 1  6336956961663189363441597590  0.0   384.0  250.0    48.0          button
# 2  6021709796663189365698111118  0.0   144.0  250.0    48.0          button
# 3  6055313513663189367888063387  0.0   960.0  250.0    48.0          button
# 4  6097754969663189365290658051  0.0  1872.0  250.0    48.0          button
#
#    predicted_probability  sort_key tag_name
# 0               0.999999   12000.0      DIV
# 1               1.000000   12000.0      DIV
# 2               1.000000   12000.0      DIV
# 3               1.000000   12000.0      DIV
# 4               1.000000   12000.0      DIV

# %%
preds
# Out:
#                        element_id      x            y  width  height  \
# 0    0050721000663189360957311796    0.0  2304.000000  250.0    48.0
# 1    6336956961663189363441597590    0.0   384.000000  250.0    48.0
# 2    6021709796663189365698111118    0.0   144.000000  250.0    48.0
# 3    6055313513663189367888063387    0.0   960.000000  250.0    48.0
# 4    6097754969663189365290658051    0.0  1872.000000  250.0    48.0
# ..                            ...    ...          ...    ...     ...
# 146  5169402774663189369559164115  386.0   243.078125   40.0    40.0
# 147  0558767894663189362700876831  274.0   243.078125   40.0    40.0
# 148  5528879832663189369702675247  274.0   886.125000   40.0    40.0
# 149  5801749035663189366163313326  498.0   243.078125   40.0    40.0
# 150  3818965105663189363229664429  442.0   243.078125   40.0    40.0
#
#     predicted_label  predicted_probability  sort_key
# 0              list               0.999999   12000.0
# 1            button               1.000000   12000.0
# 2            button               1.000000   12000.0
# 3            button               1.000000   12000.0
# 4            button               1.000000   12000.0
# ..              ...                    ...       ...
# 146        progress               1.000000    1600.0
# 147        progress               1.000000    1600.0
# 148        progress               1.000000    1600.0
# 149        progress               1.000000    1600.0
# 150        progress               1.000000    1600.0
#
# [151 rows x 8 columns]

# %%
from_pkl = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')
from_pkl[from_pkl.element_id == '1049561488694071642269580342']
# Out:
# Empty DataFrame
# Columns: [attributes, displayed, element_id, height, onmouseenter, onmouseover, parent_id, style, tag_name, text, width, x, y]
# Index: []

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))

# %%
PREDICT_URL = 'http://localhost:5050/get_tasks_statuses'
response = requests.post(
    PREDICT_URL, data=dataset_json[10]
)

# %%
response.json()
# Out:
# {'exc': 'Expecting value: line 1 column 1 (char 0)'}
