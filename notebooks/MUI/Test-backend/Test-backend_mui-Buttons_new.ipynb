# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2022-01-26 15:06:11,376 -INFO - config.py:31 - Module utils.config was loaded
# 2022-01-26 15:06:11,403 -INFO - common.py:119 - Module utils.common is loaded...
# 2022-01-26 15:06:11,404 -INFO - dataset_builder.py:246 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'material-ui-Buttons'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click()
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click()
        driver.find_element_by_xpath("/html/body/div/div/div/div[1]/div/div[2]/div/div").click()
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2022-01-26 15:06:16,087 -INFO - dataset_builder.py:100 - Dataset name: material-ui-Buttons
# 2022-01-26 15:06:16,088 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2022-01-26 15:06:16,091 -INFO - dataset_builder.py:152 - Creating driver
# 2022-01-26 15:06:18,226 -INFO - dataset_builder.py:164 - Chrome web driver is created
# ipykernel_launcher:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2022-01-26 15:06:30,939 -INFO - common.py:22 - Window maximized
# 2022-01-26 15:06:37,944 -INFO - dataset_builder.py:167 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/material-ui-Buttons.png
# 2022-01-26 15:06:43,538 -INFO - dataset_builder.py:211 - Collect features using JS script
# 2022-01-26 15:06:44,115 -INFO - dataset_builder.py:219 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/material-ui-Buttons.html
# 2022-01-26 15:06:44,131 -INFO - dataset_builder.py:231 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/material-ui-Buttons.pkl
# 2022-01-26 15:06:44,133 -INFO - dataset_builder.py:234 - No attributes: (16, 14)
# 2022-01-26 15:06:48,585 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '8756582302988035458003350718',
#   'x': 274.0,
#   'y': 32.0,
#   'width': 1202.0,
#   'height': 1111.859375,
#   'predicted_label': 'dialog',
#   'predicted_probability': 0.7527531981468201,
#   'sort_key': 1336454.96875},
#  {'element_id': '1449893871988035456920011793',
#   'x': 274.0,
#   'y': 742.96875,
#   'width': 1202.0,
#   'height': 88.015625,
#   'predicted_label': 'dialog',
#   'predicted_probability': 0.8544961810112,
#   'sort_key': 105794.78125},
#  {'element_id': '0047214030988035452090854094',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '7299010522988035446790494440',
#   'x': 0.0,
#   'y': 432.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '7137462871988035445764871548',
#   'x': 0.0,
#   'y': 48.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '7061205916988035459929093521',
#   'x': 0.0,
#   'y': 2448.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '7024624391988035457520238924',
#   'x': 0.0,
#   'y': 2304.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '7001360925988035455514008426',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '6923901075988035459254294479',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '6713472586988035458705277525',
#   'x': 0.0,
#   'y': 1152.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '6573663508988035453016589702',
#   'x': 0.0,
#   'y': 2592.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '6546102846988035456466500614',
#   'x': 0.0,
#   'y': 2064.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '6540217635988035453952772864',
#   'x': 0.0,
#   'y': 1920.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '6531794621988035448462474881',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '6519559138988035455544946385',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '6402406585988035450735756527',
#   'x': 0.0,
#   'y': 2448.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '6322676547988035458250673389',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '6186980857988035450889751657',
#   'x': 0.0,
#   'y': 2544.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '6182592975988035443343719205',
#   'x': 0.0,
#   'y': 336.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '5788575584988035457497804925',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '5725248138988035451933296230',
#   'x': 0.0,
#   'y': 2640.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '5635768937988035458007064047',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '5392554847988035440200514714',
#   'x': 0.0,
#   'y': 240.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '5374055387988035455100000343',
#   'x': 0.0,
#   'y': 1872.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '5146945348988035445559612155',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '5066416550988035449042523956',
#   'x': 0.0,
#   'y': 48.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '5035219964988035451274790004',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '0240639314988035454648292353',
#   'x': 0.0,
#   'y': 2592.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '4714216680988035458664887333',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '4706924948988035447528531614',
#   'x': 0.0,
#   'y': 480.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '4587728810988035450884879185',
#   'x': 0.0,
#   'y': 2208.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '7292307000988035444089153792',
#   'x': 0.0,
#   'y': 96.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '7487696534988035459067618299',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '7352518885988035458269976941',
#   'x': 0.0,
#   'y': 2208.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '4123368254988035452571964607',
#   'x': 0.0,
#   'y': 2544.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '9924468158988035444550317999',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '9798929338988035445559922810',
#   'x': 0.0,
#   'y': 432.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '9653544028988035458313787947',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '9538280546988035454253040735',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '9498805183988035455953337374',
#   'x': 0.0,
#   'y': 2640.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '9468392480988035456150082975',
#   'x': 0.0,
#   'y': 2352.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '9431055403988035457056781765',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '9381678649988035449040641400',
#   'x': 0.0,
#   'y': 144.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '9195203117988035456218989031',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '9101069698988035459166529566',
#   'x': 0.0,
#   'y': 1824.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '9056787933988035449935332356',
#   'x': 0.0,
#   'y': 480.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '9052504135988035457515325989',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '9037710621988035459913026601',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '8990645882988035451874565219',
#   'x': 0.0,
#   'y': 1104.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '8941348519988035455803213013',
#   'x': 0.0,
#   'y': 1440.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '8766986987988035450683396427',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '8749610181988035455329984279',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '8732800423988035459072610620',
#   'x': 0.0,
#   'y': 1536.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '8657172137988035440492322727',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '8582794119988035458371381906',
#   'x': 0.0,
#   'y': 2016.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '8308653549988035453200754636',
#   'x': 0.0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '8214214352988035441805176335',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '8058455180988035448879826084',
#   'x': 0.0,
#   'y': 576.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '7971695770988035449995546473',
#   'x': 0.0,
#   'y': 288.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '7775719686988035457227513725',
#   'x': 0.0,
#   'y': 2400.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '7733698041988035443277860668',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '7503821712988035450180032463',
#   'x': 0.0,
#   'y': 2496.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '4389030933988035455459424759',
#   'x': 0.0,
#   'y': 2112.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '4903232239988035453162500639',
#   'x': 0.0,
#   'y': 1536.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '9931564521988035445926510197',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '1501120710988035456284272406',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '2406731426988035454365218480',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '2263720292988035455333670721',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '0402947976988035455683887502',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '4104394955988035453596189219',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '2168806131988035455835001572',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '2101548187988035452564786002',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '2082408535988035455218960711',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '1957983097988035457312550724',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '1855555669988035450331182051',
#   'x': 0.0,
#   'y': 1632.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '1622464234988035441287247750',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '1582760827988035456952416992',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '0421469491988035451135292162',
#   'x': 0.0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '1492838960988035441581222944',
#   'x': 0.0,
#   'y': 288.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '2454173553988035442263547522',
#   'x': 0.0,
#   'y': 960.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '1430237302988035447106334878',
#   'x': 0.0,
#   'y': 192.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '1337429299988035453164382697',
#   'x': 0.0,
#   'y': 1824.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '1290713991988035450363900146',
#   'x': 0.0,
#   'y': 2400.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '1267204559988035450684591290',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '1190966749988035459745999005',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '1134301305988035451374935759',
#   'x': 0.0,
#   'y': 2112.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '0991418599988035450884275209',
#   'x': 0.0,
#   'y': 2304.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '0861806599988035456943195913',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '0820204586988035449163290062',
#   'x': 0.0,
#   'y': 384.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '0441320134988035443374174501',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '0503294505988035451041031576',
#   'x': 0.0,
#   'y': 1872.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '0536021283988035443266513956',
#   'x': 0.0,
#   'y': 192.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '0530536975988035455565937823',
#   'x': 0.0,
#   'y': 1104.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '2425776293988035447296631259',
#   'x': 0.0,
#   'y': 144.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '3806847667988035450431017699',
#   'x': 0.0,
#   'y': 1248.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '3382218583988035459244474313',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '0269004428988035453681686211',
#   'x': 0.0,
#   'y': 1920.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '3181487711988035459120828480',
#   'x': 0.0,
#   'y': 2352.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '3936224293988035456408758154',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '2998249785988035442497095319',
#   'x': 0.0,
#   'y': 528.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '3990937489988035444665715643',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '3863760193988035447255347139',
#   'x': 0.0,
#   'y': 672.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '3415898280988035458858175217',
#   'x': 0.0,
#   'y': 2064.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '2984710232988035448001965153',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '2862756533988035457213419895',
#   'x': 0.0,
#   'y': 1152.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '2860715119988035442666739264',
#   'x': 0.0,
#   'y': 240.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '2848921515988035457155811065',
#   'x': 0.0,
#   'y': 2160.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '2805476840988035448463555327',
#   'x': 0.0,
#   'y': 336.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '2737334339988035441693546599',
#   'x': 0.0,
#   'y': 384.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '2647650990988035454725921042',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '3623362252988035445016059521',
#   'x': 0.0,
#   'y': 96.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '0275800194988035452693556494',
#   'x': 0.0,
#   'y': 2160.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '2640385670988035450724261572',
#   'x': 0.0,
#   'y': 2016.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 12000.0},
#  {'element_id': '3208691583988035450253463167',
#   'x': 0.0,
#   'y': 2496.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996423721313,
#   'sort_key': 12000.0},
#  {'element_id': '6245959376988035455613865059',
#   'x': 842.453125,
#   'y': 436.96875,
#   'width': 140.046875,
#   'height': 42.25,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999731779098511,
#   'sort_key': 5916.98046875},
#  {'element_id': '0277653515988035452900444117',
#   'x': 420.46875,
#   'y': 751.71875,
#   'width': 153.640625,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999934434890747,
#   'sort_key': 5607.8828125},
#  {'element_id': '9010309514988035450091530484',
#   'x': 282.0,
#   'y': 751.71875,
#   'width': 122.46875,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999979734420776,
#   'sort_key': 4470.109375},
#  {'element_id': '6681197980988035452517720171',
#   'x': 500.328125,
#   'y': 146.21875,
#   'width': 115.984375,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999995231628418,
#   'sort_key': 4233.4296875},
#  {'element_id': '2339951224988035459464130841',
#   'x': 514.578125,
#   'y': 439.84375,
#   'width': 111.609375,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999817609786987,
#   'sort_key': 4073.7421875},
#  {'element_id': '6259980231988035455201125794',
#   'x': 590.109375,
#   'y': 750.96875,
#   'width': 103.3125,
#   'height': 38.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999997615814209,
#   'sort_key': 3925.875},
#  {'element_id': '5518868796988035459023539365',
#   'x': 282.0,
#   'y': 439.84375,
#   'width': 107.515625,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9961448907852173,
#   'sort_key': 3924.3203125},
#  {'element_id': '9419632150988035458505372278',
#   'x': 468.328125,
#   'y': 291.59375,
#   'width': 99.984375,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 3649.4296875},
#  {'element_id': '8693197492988035455170418071',
#   'x': 632.3125,
#   'y': 146.21875,
#   'width': 99.546875,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999990463256836,
#   'sort_key': 3633.4609375},
#  {'element_id': '3876573745988035455949499764',
#   'x': 389.25,
#   'y': 146.21875,
#   'width': 95.078125,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 3470.3515625},
#  {'element_id': '6879732705988035452908983600',
#   'x': 405.515625,
#   'y': 439.84375,
#   'width': 93.0625,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 3396.78125},
#  {'element_id': '2593845317988035450863183186',
#   'x': 282.0,
#   'y': 146.21875,
#   'width': 91.25,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 3330.625},
#  {'element_id': '1549662965988035459393268517',
#   'x': 642.1875,
#   'y': 439.84375,
#   'width': 91.0,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9934086799621582,
#   'sort_key': 3321.5},
#  {'element_id': '2181295634988035453650499700',
#   'x': 584.3125,
#   'y': 291.59375,
#   'width': 83.546875,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999793767929077,
#   'sort_key': 3049.4609375},
#  {'element_id': '3722543640988035459322380894',
#   'x': 373.25,
#   'y': 291.59375,
#   'width': 79.078125,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2886.3515625},
#  {'element_id': '9178730438988035456667461687',
#   'x': 282.0,
#   'y': 291.59375,
#   'width': 75.25,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2746.625},
#  {'element_id': '2212206133988035452077739831',
#   'x': 749.1875,
#   'y': 442.71875,
#   'width': 77.265625,
#   'height': 30.75,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999994039535522,
#   'sort_key': 2375.91796875},
#  {'element_id': '8448696387988035451190553500',
#   'x': 747.859375,
#   'y': 146.21875,
#   'width': 64.0,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2336.0},
#  {'element_id': '5007300812988035450772521563',
#   'x': 683.859375,
#   'y': 291.59375,
#   'width': 64.0,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2336.0},
#  {'element_id': '9310203918988035453885710904',
#   'x': 282.0,
#   'y': 594.09375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 2304.0},
#  {'element_id': '0804730925988035453340495385',
#   'x': 474.0,
#   'y': 594.09375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998807907104,
#   'sort_key': 2304.0},
#  {'element_id': '3008503942988035454728356059',
#   'x': 410.0,
#   'y': 594.09375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.999996542930603,
#   'sort_key': 2304.0},
#  {'element_id': '4112971365988035451125002279',
#   'x': 346.0,
#   'y': 594.09375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9998262524604797,
#   'sort_key': 2304.0}]
# CPU times: user 81.2 ms, sys: 33.6 ms, total: 115 ms
# Wall time: 2.5 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id      x           y   width       height  \
# 0  8756582302988035458003350718  274.0    32.00000  1202.0  1111.859375
# 1  1449893871988035456920011793  274.0   742.96875  1202.0    88.015625
# 2  0047214030988035452090854094    0.0  1392.00000   250.0    48.000000
# 3  7299010522988035446790494440    0.0   432.00000   250.0    48.000000
# 4  7137462871988035445764871548    0.0    48.00000   250.0    48.000000
#
#   predicted_label  predicted_probability      sort_key tag_name
# 0          dialog               0.752753  1.336455e+06      DIV
# 1          dialog               0.854496  1.057948e+05      DIV
# 2          button               1.000000  1.200000e+04      DIV
# 3          button               1.000000  1.200000e+04      DIV
# 4          button               1.000000  1.200000e+04      DIV

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
