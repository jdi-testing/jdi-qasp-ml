# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'HTML5_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/html5_dataset')

# %%
DATASET_NAME = 'html-test-jdi'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/html5.html'
PREDICT_URL = 'http://localhost:5050/html5-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 2
# HEADLESS = True

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click() #path to elements packs
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[1]/a").click() #path to mui
        sleep(2.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(2.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2022-01-13 10:56:27,426 -INFO - dataset_builder.py:100 - Dataset name: html-test-jdi
# 2022-01-13 10:56:27,428 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2022-01-13 10:56:27,432 -INFO - dataset_builder.py:152 - Creating driver
# 2022-01-13 10:56:29,069 -INFO - dataset_builder.py:164 - Chrome web driver is created
# ipykernel_launcher:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2022-01-13 10:56:35,216 -INFO - common.py:22 - Window maximized
# 2022-01-13 10:56:37,221 -INFO - dataset_builder.py:167 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/images/html-test-jdi.png
# 2022-01-13 10:56:42,710 -INFO - dataset_builder.py:211 - Collect features using JS script
# 2022-01-13 10:56:43,234 -INFO - dataset_builder.py:219 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/html/html-test-jdi.html
# 2022-01-13 10:56:43,246 -INFO - dataset_builder.py:231 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/df/html-test-jdi.pkl
# 2022-01-13 10:56:43,249 -INFO - dataset_builder.py:234 - No attributes: (255, 14)
# 2022-01-13 10:56:43,305 -INFO - dataset_builder.py:125 - Close web driver

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset'

# %%
d = pd.DataFrame(dataset_json)
d[d.html.apply(lambda x: True if '<input type="button"' in x else False)].tail(3)
# Out:
#                                             attributes  displayed  \
# 206                             {'class': 'html-left'}       True
# 208  {'class': 'uui-button red', 'onclick': 'alert(...       True
# 211  {'class': 'uui-button grey', 'disabled': '', '...       True
#
#                        element_id     height  \
# 206  1146690520606027156073179214  477.59375
# 208  8341899917606027153618988666   34.00000
# 211  7709121091606027159646212413   34.00000
#
#                                                   html onmouseenter  \
# 206  <div class="html-left">\n                     ...         None
# 208  <input type="button" value="Big Red Button-Inp...         None
# 211  <input type="button" value="Disabled Button-In...         None
#
#     onmouseover                     parent_id  \
# 206        None  8467288084606027154987021027
# 208        None  1146690520606027156073179214
# 211        None  1146690520606027156073179214
#
#                                                  style tag_name  \
# 206  [accent-color, align-content, align-items, ali...      DIV
# 208  [accent-color, align-content, align-items, ali...    INPUT
# 211  [accent-color, align-content, align-items, ali...    INPUT
#
#                                                   text       width      x  \
# 206  BUTTON\n\n\n\n\nTAG BUTTON\nBIG BLUE BUTTON\n\...  283.187500  363.0
# 208                                                     163.421875  363.0
# 211                                                     171.906250  363.0
#
#               y
# 206  378.187500
# 208  417.984375
# 211  469.984375

# %%
from utils.dataset import HTML5_JDNDataset
dataset = HTML5_JDNDataset(
        datasets_list=[DATASET_NAME],
        dataset_type="html5",
        rebalance_and_shuffle=False,
    )
# Out:
# Build tree features: 100%|██████████| 668/668 [00:00<00:00, 1247.67it/s]i-qasp-ml/data/html5_dataset/df/html-test-jdi.pkl]
# 100%|██████████| 1/1 [00:01<00:00,  1.64s/it, /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/df/html-test-jdi.pkl]
# 2022-01-13 10:56:45,120 -INFO - dataset.py:210 - self.df.shape: (668, 33)
# 2022-01-13 10:56:45,122 -INFO - dataset.py:101 - Check for duplicates...
# 2022-01-13 10:56:45,124 -INFO - dataset.py:105 - Check for duplicates is OK
# 2022-01-13 10:56:45,125 -INFO - dataset.py:214 - Calculating features...
# 2022-01-13 10:56:45,228 -INFO - dataset_collector.py:177 - X: (668, 79)
# 2022-01-13 10:56:45,229 -INFO - dataset.py:218 - Features have calculated succesfully!

# %%
print(dataset.df.shape)
print(dataset.X.shape)
# Out:
# (668, 33)
# (668, 79)

# %%
pkl_filename = "DT_model.pkl"
with open(f"{model_path}/{pkl_filename}", "rb") as file:
    model = pickle.load(file)

# %%
model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 17,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
html5_classes_path = "/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/classes.txt"
with open(html5_classes_path, "r") as f:
        lines = f.readlines()
        encoder_dict = {line.strip(): i for i, line in enumerate(lines)}
        decoder_dict = {v: k for k, v in encoder_dict.items()}

# %%
# pd.Series(model.predict(dataset.X)).apply(lambda x: decoder_dict[x]).unique()

# %%
res_dataset = dataset.X.copy()
res_dataset.shape
# Out:
# (668, 79)

# %%
res_dataset["pred"] = pd.Series(model.predict(res_dataset)).apply(lambda x: decoder_dict.get(x, "n/a")).values
res_dataset.head()
# Out:
#                               tag_HTML  tag_HEAD  tag_META  tag_TITLE  \
# element_id
# 0013076904606027159878838098         0         0         0          0
# 0036161838606027150771997692         0         0         0          0
# 0048220162606027150294443180         0         0         0          0
# 0050868833606027158441640551         0         0         0          0
# 0074694623606027150608774053         0         0         0          0
#
#                               tag_STYLE  tag_BODY  tag_DIV  tag_LABEL  \
# element_id
# 0013076904606027159878838098          0         0        0          0
# 0036161838606027150771997692          0         0        0          0
# 0048220162606027150294443180          0         0        0          0
# 0050868833606027158441640551          0         0        0          0
# 0074694623606027150608774053          0         0        0          0
#
#                               tag_INPUT  tag_DATALIST  ...  type_range  \
# element_id                                             ...
# 0013076904606027159878838098          0             0  ...           0
# 0036161838606027150771997692          0             0  ...           0
# 0048220162606027150294443180          0             0  ...           0
# 0050868833606027158441640551          0             0  ...           0
# 0074694623606027150608774053          0             0  ...           0
#
#                               type_radio  type_month  type_checkbox  \
# element_id
# 0013076904606027159878838098           0           0              0
# 0036161838606027150771997692           0           0              0
# 0048220162606027150294443180           0           0              0
# 0050868833606027158441640551           0           0              0
# 0074694623606027150608774053           0           0              0
#
#                               type_reset  type_number  type_week  \
# element_id
# 0013076904606027159878838098           0            0          0
# 0036161838606027150771997692           0            0          0
# 0048220162606027150294443180           0            0          0
# 0050868833606027158441640551           0            0          0
# 0074694623606027150608774053           0            0          0
#
#                               is_checkbox_in_childs  is_radio_in_childs  pred
# element_id
# 0013076904606027159878838098                      0                   0  text
# 0036161838606027150771997692                      0                   0   n/a
# 0048220162606027150294443180                      0                   0  text
# 0050868833606027158441640551                      0                   0  link
# 0074694623606027150608774053                      0                   0   n/a
#
# [5 rows x 80 columns]

# %%
res_dataset.pred.unique()
# Out:
# array(['text', 'n/a', 'link', 'colorpicker', 'label', 'button', 'title',
#        'radiobuttongroup', 'checkbox', 'datetimeselector', 'textfield',
#        'checklist', 'radiobutton', 'range', 'fileinput', 'textarea',
#        'progressbar', 'dropdown', 'numberselector', 'multidropdown',
#        'multiselector', 'datalist'], dtype=object)

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '8464212078606027153228147771',
#   'x': 363.0,
#   'y': 3816.75,
#   'width': 283.1875,
#   'height': 130.0,
#   'predicted_label': 'checklist',
#   'predicted_probability': 1.0,
#   'sort_key': 36814.375},
#  {'element_id': '0834439285606027154610779081',
#   'x': 363.0,
#   'y': 4129.546875,
#   'width': 283.1875,
#   'height': 104.0,
#   'predicted_label': 'radiobuttongroup',
#   'predicted_probability': 1.0,
#   'sort_key': 29451.5},
#  {'element_id': '5448572401606027154367109963',
#   'x': 363.0,
#   'y': 186.0,
#   'width': 283.1875,
#   'height': 79.1875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 22424.91015625},
#  {'element_id': '6646091731606027157777266957',
#   'x': 696.203125,
#   'y': 1359.375,
#   'width': 610.796875,
#   'height': 36.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 21988.6875},
#  {'element_id': '4135912454606027155854238435',
#   'x': 696.203125,
#   'y': 1257.375,
#   'width': 610.796875,
#   'height': 36.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key':
0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8429.0625},
#  {'element_id': '1516445719606027153865257919',
#   'x': 730.34375,
#   'y': 3627.75,
#   'width': 462.5,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8325.0},
#  {'element_id': '0050868833606027158441640551',
#   'x': 730.34375,
#   'y': 3884.546875,
#   'width': 462.5,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8325.0},
#  {'element_id': '2965681946606027166944605898',
#   'x': 730.34375,
#   'y': 5953.71875,
#   'width': 453.765625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8167.78125},
#  {'element_id': '8350389052606027165452933756',
#   'x': 730.34375,
#   'y': 5262.53125,
#   'width': 446.53125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8037.5625},
#  {'element_id': '6506809850606027158919606633',
#   'x': 730.34375,
#   'y': 4654.9375,
#   'width': 440.375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7926.75},
#  {'element_id': '9330881154606027163676711519',
#   'x': 730.34375,
#   'y': 5780.921875,
#   'width': 438.15625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7886.8125},
#  {'element_id': '5166638039606027156442161025',
#   'x': 730.34375,
#   'y': 4197.34375,
#   'width': 437.609375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7876.96875},
#  {'element_id': '1706212446606027151068580935',
#   'x': 730.34375,
#   'y': 4426.140625,
#   'width': 436.59375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7858.6875},
#  {'element_id': '1375991191606027161813906492',
#   'x': 730.34375,
#   'y': 5608.125,
#   'width': 434.1875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7815.375},
#  {'element_id': '8932103425606027153896071214',
#   'x': 0.0,
#   'y': 224.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '6545411606606027152119626529',
#   'x': 0.0,
#   'y': 60.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '8461350090606027158051185960',
#   'x': 0.0,
#   'y': 142.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '3313679683606027151076868703',
#   'x': 0.0,
#   'y': 101.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '2273270713606027155398752473',
#   'x': 0.0,
#   'y': 183.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '3839055451606027158717382708',
#   'x': 730.34375,
#   'y': 1229.375,
#   'width': 429.484375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7730.71875},
#  {'element_id': '6550367516606027154341340253',
#   'x': 730.34375,
#   'y': 1974.96875,
#   'width': 425.265625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7654.78125},
#  {'element_id': '1080804616606027157541996631',
#   'x': 0.0,
#   'y': 377.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '9985727269606027156517121011',
#   'x': 0.0,
#   'y': 567.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '1162387343606027152868855541',
#   'x': 0.0,
#   'y': 415.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '6729525080606027158040662228',
#   'x': 0.0,
#   'y': 453.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '9335103627606027155878816778',
#   'x': 0.0,
#   'y': 339.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '0790558405606027153882721333',
#   'x': 0.0,
#   'y': 301.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '7004209333606027158810109660',
#   'x': 0.0,
#   'y': 529.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '5562391756606027150271886811',
#   'x': 0.0,
#   'y': 263.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '4897640864606027159834921047',
#   'x': 0.0,
#   'y': 491.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '8837650792606027160521069978',
#   'x': 730.34375,
#   'y': 4944.9375,
#   'width': 421.25,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7582.5},
#  {'element_id': '2217561705606027150695454287',
#   'x': 730.34375,
#   'y': 1634.171875,
#   'width': 418.15625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7526.8125},
#  {'element_id': '5679910152606027156459989924',
#   'x': 730.34375,
#   'y': 3398.953125,
#   'width': 413.75,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7447.5},
#  {'element_id': '5015649579606027165546962990',
#   'x': 730.34375,
#   'y': 5089.734375,
#   'width': 410.484375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7388.71875},
#  {'element_id': '4096508315606027157293565495',
#   'x': 730.34375,
#   'y': 445.984375,
#   'width': 410.3125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7385.625},
#  {'element_id': '2779571772606027153185866296',
#   'x': 363.0,
#   'y': 3559.953125,
#   'width': 283.1875,
#   'height': 26.0,
#   'predicted_label': 'checklist',
#   'predicted_probability': 1.0,
#   'sort_key': 7362.875},
#  {'element_id': '1960936679606027152528116368',
#   'x': 287.453125,
#   'y': 0.0,
#   'width': 121.859375,
#   'height': 60.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7311.5625},
#  {'element_id': '7870612388606027156346433013',
#   'x': 730.34375,
#   'y': 2773.359375,
#   'width': 405.03125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7290.5625},
#  {'element_id': '0114104714606027158913685749',
#   'x': 730.34375,
#   'y': 2460.5625,
#   'width': 405.03125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7290.5625},
#  {'element_id': '9454278765606027159061084412',
#   'x': 730.34375,
#   'y': 3114.15625,
#   'width': 405.03125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7290.5625},
#  {'element_id': '3888333133606027164199371574',
#   'x': 728.453125,
#   'y': 5407.328125,
#   'width': 404.25,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7276.5},
#  {'element_id': '6481067030606027152647468624',
#   'x': 730.34375,
#   'y': 2231.765625,
#   'width': 393.1875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7077.375},
#  {'element_id': '2618081496606027163148670657',
#   'x': 445.984375,
#   'y': 5367.53125,
#   'width': 172.796875,
#   'height': 40.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 6911.875},
#  {'element_id': '7292989818606027157621276999',
#   'x': 730.34375,
#   'y': 944.578125,
#   'width': 377.453125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6794.15625},
#  {'element_id': '2210038866606027154902378208',
#   'x': 728.453125,
#   'y': 3856.546875,
#   'width': 374.515625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6741.28125},
#  {'element_id': '0870145491606027151884344650',
#   'x': 728.453125,
#   'y': 3599.75,
#   'width': 374.515625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6741.28125},
#  {'element_id': '7174786139606027159715843597',
#   'x': 728.453125,
#   'y': 1201.375,
#   'width': 367.6875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6618.375},
#  {'element_id': '7829992208606027169031304895',
#   'x': 363.0,
#   'y': 5908.921875,
#   'width': 300.0,
#   'height': 22.0,
#   'predicted_label': 'numberselector',
#   'predicted_probability': 1.0,
#   'sort_key': 6600.0},
#  {'element_id': '9409846655606027166448643100',
#   'x': 728.453125,
#   'y': 5925.71875,
#   'width': 364.65625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6563.8125},
#  {'element_id': '9960146209606027163521730100',
#   'x': 728.453125,
#   'y': 5234.53125,
#   'width': 358.21875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6447.9375},
#  {'element_id': '9113373781606027155573528948',
#   'x': 728.453125,
#   'y': 4626.9375,
#   'width': 352.0625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6337.125},
#  {'element_id': '5826546240606027169600606117',
#   'x': 728.453125,
#   'y': 5752.921875,
#   'width': 350.015625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6300.28125},
#  {'element_id': '5102925632606027154977634516',
#   'x': 728.453125,
#   'y': 4169.34375,
#   'width': 349.265625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6286.78125},
#  {'element_id': '0365502947606027154447988207',
#   'x': 728.453125,
#   'y': 4398.140625,
#   'width': 347.921875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6262.59375},
#  {'element_id': '0478189858606027164728288307',
#   'x': 728.453125,
#   'y': 5580.125,
#   'width': 345.75,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6223.5},
#  {'element_id': '1514150404606027161839457465',
#   'x': 728.453125,
#   'y': 5061.734375,
#   'width': 345.140625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6212.53125},
#  {'element_id': '4771224979606027156305095179',
#   'x': 728.453125,
#   'y': 1946.96875,
#   'width': 344.34375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6198.1875},
#  {'element_id': '5914015192606027157226104350',
#   'x': 728.453125,
#   'y': 3086.15625,
#   'width': 338.375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6090.75},
#  {'element_id': '5525142667606027158016928622',
#   'x': 728.453125,
#   'y': 2745.359375,
#   'width': 338.375,
# ...
#   'x': 363.0,
#   'y': 1135.578125,
#   'width': 83.453125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1502.15625},
#  {'element_id': '3868532619606027158316396320',
#   'x': 378.8125,
#   'y': 3819.75,
#   'width': 80.890625,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1456.03125},
#  {'element_id': '0939619053606027151236542333',
#   'x': 363.0,
#   'y': 2733.5625,
#   'width': 80.28125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1445.0625},
#  {'element_id': '7641780405606027164396244179',
#   'x': 363.0,
#   'y': 5378.53125,
#   'width': 80.171875,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1443.09375},
#  {'element_id': '1842369212606027168522091600',
#   'x': 363.0,
#   'y': 5032.9375,
#   'width': 75.609375,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1360.96875},
#  {'element_id': '0113486224606027152262884629',
#   'x': 363.0,
#   'y': 4330.34375,
#   'width': 50.0,
#   'height': 27.0,
#   'predicted_label': 'colorpicker',
#   'predicted_probability': 1.0,
#   'sort_key': 1350.0},
#  {'element_id': '1427708857606027152481181029',
#   'x': 363.0,
#   'y': 4361.34375,
#   'width': 50.0,
#   'height': 27.0,
#   'predicted_label': 'colorpicker',
#   'predicted_probability': 1.0,
#   'sort_key': 1350.0},
#  {'element_id': '7762615023606027152249615628',
#   'x': 378.8125,
#   'y': 3871.75,
#   'width': 74.65625,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1343.8125},
#  {'element_id': '6358559485606027154301041991',
#   'x': 363.0,
#   'y': 1160.578125,
#   'width': 74.65625,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1343.8125},
#  {'element_id': '7081469297606027151886875546',
#   'x': 363.0,
#   'y': 2175.375,
#   'width': 72.1875,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1299.375},
#  {'element_id': '6891269759606027158051760377',
#   'x': 363.0,
#   'y': 4789.140625,
#   'width': 69.5,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1251.0},
#  {'element_id': '5095320089606027155330434937',
#   'x': 378.8125,
#   'y': 3923.75,
#   'width': 69.5,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1251.0},
#  {'element_id': '2959295343606027168288241347',
#   'x': 363.0,
#   'y': 5716.515625,
#   'width': 65.234375,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1174.21875},
#  {'element_id': '7460202032606027158675490367',
#   'x': 363.0,
#   'y': 4589.140625,
#   'width': 63.046875,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1134.84375},
#  {'element_id': '2845663366606027153502824673',
#   'x': 363.0,
#   'y': 876.78125,
#   'width': 61.609375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1108.96875},
#  {'element_id': '5322870099606027159710972633',
#   'x': 378.8125,
#   'y': 4210.546875,
#   'width': 56.28125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1013.0625},
#  {'element_id': '2489573144606027158384663646',
#   'x': 378.8125,
#   'y': 3897.75,
#   'width': 55.703125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1002.65625},
#  {'element_id': '0235561668606027156457559580',
#   'x': 378.8125,
#   'y': 4158.546875,
#   'width': 53.75,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 967.5},
#  {'element_id': '8225506880606027164981471852',
#   'x': 1385.890625,
#   'y': 14961.0,
#   'width': 64.109375,
#   'height': 15.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 961.640625},
#  {'element_id': '3377328610606027155171880389',
#   'x': 378.8125,
#   'y': 3845.75,
#   'width': 46.328125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 833.90625},
#  {'element_id': '3063984282606027158200793384',
#   'x': 378.8125,
#   'y': 4184.546875,
#   'width': 45.578125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 820.40625},
#  {'element_id': '8257955101606027155359442743',
#   'x': 1430.0,
#   'y': 20.0,
#   'width': 40.0,
#   'height': 20.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 800.0},
#  {'element_id': '3454826250606027152546787855',
#   'x': 378.8125,
#   'y': 4132.546875,
#   'width': 41.859375,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 753.46875},
#  {'element_id': '3382616707606027158744441745',
#   'x': 389.734375,
#   'y': 4637.140625,
#   'width': 100.0,
#   'height': 7.0,
#   'predicted_label': 'range',
#   'predicted_probability': 1.0,
#   'sort_key': 700.0},
#  {'element_id': '8303475955606027153680466721',
#   'x': 493.40625,
#   'y': 4707.140625,
#   'width': 30.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 660.0},
#  {'element_id': '4344321516606027153184223094',
#   'x': 494.90625,
#   'y': 4666.140625,
#   'width': 30.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 660.0},
#  {'element_id': '8520350134606027155280724182',
#   'x': 428.859375,
#   'y': 4587.140625,
#   'width': 30.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 660.0},
#  {'element_id': '2435774238606027151218931580',
#   'x': 550.1875,
#   'y': 4748.140625,
#   'width': 30.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 660.0},
#  {'element_id': '3689129919606027167071282332',
#   'x': 1322.71875,
#   'y': 14961.0,
#   'width': 30.265625,
#   'height': 15.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 453.984375},
#  {'element_id': '6754923633606027152082379412',
#   'x': 363.0,
#   'y': 4211.546875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '5240855477606027155266452252',
#   'x': 363.0,
#   'y': 4185.546875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '0891087239606027156356245185',
#   'x': 363.0,
#   'y': 3872.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '3048385749606027152312001041',
#   'x': 363.0,
#   'y': 4159.546875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '1707287432606027158773818378',
#   'x': 363.0,
#   'y': 3924.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '1254088164606027153065997258',
#   'x': 363.0,
#   'y': 3898.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '3481188191606027155844931701',
#   'x': 363.0,
#   'y': 3563.953125,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '6579955599606027154164994387',
#   'x': 363.0,
#   'y': 3846.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '3283126195606027154108229202',
#   'x': 363.0,
#   'y': 3820.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '4325684373606027154015646569',
#   'x': 363.0,
#   'y': 4133.546875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '7975839923606027156688738641',
#   'x': 512.984375,
#   'y': 3053.765625,
#   'width': 1.0,
#   'height': 1.0,
#   'predicted_label': 'multidropdown',
#   'predicted_probability': 1.0,
#   'sort_key': 1.0},
#  {'element_id': '1512272707606027155528196207',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5353669819606027153179944887',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3322949466606027156617504860',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7495579009606027153903604114',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1011538649606027155873427518',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0166727374606027158660539552',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2125338626606027153125786788',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3492048706606027151924528110',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9706880641606027156697707823',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7660700666606027153474667703',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9713126561606027159938872951',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4888947586606027156426679081',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2326765464606027159034235287',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9815119524606027155068403944',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2383454856606027154328890480',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7686275257606027158759406695',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7829472946606027152096777386',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4471679008606027150282492077',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4344955979606027153266971178',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8332636168606027159246922266',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2080343247606027155686603533',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3078608981606027153361247352',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2002971878606027159318182824',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6843631907606027159546516673',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8835408378606027153456210503',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7944325623606027158640611830',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6960440001606027157267818907',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7185170815606027157716779729',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8580542388606027157421945196',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7326899182606027155977661377',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6117868874606027154141222685',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6116756867606027156993669330',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5947520636606027157049297962',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5864189537606027157357317945',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1837402908606027152311355564',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1850194176606027159543712966',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9398700406606027155908257685',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0387600304606027156947413016',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1886042301606027153644828076',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3903239640606027157884771892',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6530717275606027156475228216',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0}]
# CPU times: user 103 ms, sys: 10.9 ms, total: 114 ms
# Wall time: 2.52 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id           x            y       width  \
# 0  8464212078606027153228147771  363.000000  3816.750000  283.187500
# 1  0834439285606027154610779081  363.000000  4129.546875  283.187500
# 2  5448572401606027154367109963  363.000000   186.000000  283.187500
# 3  6646091731606027157777266957  696.203125  1359.375000  610.796875
# 4  4135912454606027155854238435  696.203125  1257.375000  610.796875
#
#      height   predicted_label  predicted_probability      sort_key tag_name
# 0  130.0000         checklist                    1.0  36814.375000      DIV
# 1  104.0000  radiobuttongroup                    1.0  29451.500000      DIV
# 2   79.1875             title                    1.0  22424.910156       H1
# 3   36.0000              text                    1.0  21988.687500        P
# 4   36.0000              text                    1.0  21988.687500        P

# %%
predictions_df.predicted_label.unique()
# Out:
# array(['checklist', 'radiobuttongroup', 'title', 'text', 'textarea',
#        'link', 'datetimeselector', 'numberselector', 'button',
#        'fileinput', 'multiselector', 'label', 'textfield', 'datalist',
#        'progressbar', 'dropdown', 'range', 'colorpicker', 'radiobutton',
#        'checkbox', 'multidropdown'], dtype=object)

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                str(r.predicted_label) + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
