# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'material-ui-Buttons'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click()
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click()
        driver.find_element_by_xpath("/html/body/div/div/div/div[1]/div/div[2]/div/div").click()
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-11-30 17:16:23,624 -INFO - dataset_builder.py:100 - Dataset name: material-ui-Buttons
# 2021-11-30 17:16:23,627 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-11-30 17:16:23,630 -INFO - dataset_builder.py:151 - Creating driver
# 2021-11-30 17:16:25,165 -INFO - dataset_builder.py:163 - Chrome web driver is created
# ipykernel_launcher:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2021-11-30 17:16:37,821 -INFO - common.py:22 - Window maximized
# 2021-11-30 17:16:44,825 -INFO - dataset_builder.py:166 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/material-ui-Buttons.png
# 2021-11-30 17:16:51,115 -INFO - dataset_builder.py:210 - Collect features using JS script
# 2021-11-30 17:16:51,746 -INFO - dataset_builder.py:218 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/material-ui-Buttons.html
# 2021-11-30 17:16:51,768 -INFO - dataset_builder.py:230 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/material-ui-Buttons.pkl
# 2021-11-30 17:16:51,773 -INFO - dataset_builder.py:233 - No attributes: (15, 13)
# 2021-11-30 17:16:56,577 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '0161506570818111226337892041',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '4954157831818111217466094210',
#   'x': 0.0,
#   'y': 288.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6083115627818111228646576277',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6275524583818111226978704185',
#   'x': 0.0,
#   'y': 2160.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6296664595818111210117050442',
#   'x': 0.0,
#   'y': 288.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '6357675994818111222927104153',
#   'x': 0.0,
#   'y': 2064.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6384689333818111219303269325',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '6626174676818111218848001223',
#   'x': 0.0,
#   'y': 240.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6795330200818111229170790348',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6901949752818111211626866215',
#   'x': 0.0,
#   'y': 240.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '6925855992818111210113483987',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '6930328650818111227712078946',
#   'x': 0.0,
#   'y': 2304.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6968729197818111222959394026',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7105540914818111216488322332',
#   'x': 0.0,
#   'y': 480.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '7213719265818111221665624036',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7313623917818111219640855001',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '7390220477818111229424722677',
#   'x': 0.0,
#   'y': 1920.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '6069017800818111228748627461',
#   'x': 0.0,
#   'y': 1440.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '6029109563818111225010093730',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '6013288336818111225123536312',
#   'x': 0.0,
#   'y': 1440.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5354504802818111223344854337',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '4969913907818111225969802165',
#   'x': 0.0,
#   'y': 2112.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5057249175818111217474167872',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '0206456475818111214563773244',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5183922923818111228157903580',
#   'x': 0.0,
#   'y': 2496.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5205276737818111224978980857',
#   'x': 0.0,
#   'y': 1824.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '5339715829818111216691501986',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '5366747778818111226834570701',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5878120839818111218670976460',
#   'x': 0.0,
#   'y': 96.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '5441533887818111211169385496',
#   'x': 0.0,
#   'y': 432.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '5456785718818111228001028032',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '5610694839818111220260564249',
#   'x': 0.0,
#   'y': 2064.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '5647930361818111229519564927',
#   'x': 0.0,
#   'y': 2016.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '5669720663818111227048126159',
#   'x': 0.0,
#   'y': 2640.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5708343424818111227176115092',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7398664879818111217659670783',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7521575762818111223830942697',
#   'x': 0.0,
#   'y': 2400.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '7531060868818111210641280103',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '9290174647818111228217950516',
#   'x': 0.0,
#   'y': 2496.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '9079123242818111224189258410',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '9150089204818111222663771864',
#   'x': 0.0,
#   'y': 2400.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9159864050818111227142870753',
#   'x': 0.0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '9198340212818111226828536735',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9274739988818111214910529539',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9275971868818111215120300189',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '9318391059818111225460100498',
#   'x': 0.0,
#   'y': 2592.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id': '8970801852818111219893819562',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999704361,
#   'sort_key': 12000.0},
#  {'element_id': '9390443793818111223192789087',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9798855186,
#   'sort_key': 12000.0},
#  {'element_id':

#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 3396.78125},
#  {'element_id': '3536926659818111226569214817',
#   'x': 282.0,
#   'y': 146.21875,
#   'width': 91.25,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 3330.625},
#  {'element_id': '4384446896818111221356002902',
#   'x': 373.25,
#   'y': 291.59375,
#   'width': 79.078125,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2886.3515625},
#  {'element_id': '1865167238818111229387130637',
#   'x': 282.0,
#   'y': 291.59375,
#   'width': 75.25,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999005795,
#   'sort_key': 2746.625},
#  {'element_id': '7782854023818111228770896721',
#   'x': 749.1875,
#   'y': 442.71875,
#   'width': 77.265625,
#   'height': 30.75,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 2375.91796875},
#  {'element_id': '6380660825818111226127230195',
#   'x': 683.859375,
#   'y': 291.59375,
#   'width': 64.0,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 2336.0},
#  {'element_id': '2508362116818111222873208609',
#   'x': 747.859375,
#   'y': 146.21875,
#   'width': 64.0,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2336.0},
#  {'element_id': '9122476343818111227319363331',
#   'x': 282.0,
#   'y': 594.09375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999960661,
#   'sort_key': 2304.0},
#  {'element_id': '9112560684818111221231076854',
#   'x': 474.0,
#   'y': 594.09375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.999999404,
#   'sort_key': 2304.0},
#  {'element_id': '7067192678818111226764725642',
#   'x': 410.0,
#   'y': 594.09375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999982119,
#   'sort_key': 2304.0},
#  {'element_id': '0270705445818111221391675476',
#   'x': 346.0,
#   'y': 594.09375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2304.0}]
# CPU times: user 73.4 ms, sys: 13.6 ms, total: 87 ms
# Wall time: 2.61 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id    x       y  width  height predicted_label  \
# 0  0161506570818111226337892041  0.0  1488.0  250.0    48.0            list
# 1  4954157831818111217466094210  0.0   288.0  250.0    48.0          button
# 2  6083115627818111228646576277  0.0  1488.0  250.0    48.0          button
# 3  6275524583818111226978704185  0.0  2160.0  250.0    48.0          button
# 4  6296664595818111210117050442  0.0   288.0  250.0    48.0            list
#
#    predicted_probability  sort_key tag_name
# 0               0.979886   12000.0      DIV
# 1               1.000000   12000.0      DIV
# 2               1.000000   12000.0      DIV
# 3               1.000000   12000.0      DIV
# 4               0.979886   12000.0      DIV

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
