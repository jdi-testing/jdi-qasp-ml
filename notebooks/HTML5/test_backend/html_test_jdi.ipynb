# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'HTML5_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/html5_dataset')

# %%
DATASET_NAME = 'html-test-jdi'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/html5.html'
PREDICT_URL = 'http://localhost:5050/html5-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 2
# HEADLESS = True

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click() #path to elements packs
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[1]/a").click() #path to mui
        sleep(2.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(2.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2022-01-12 23:15:00,894 -INFO - dataset_builder.py:100 - Dataset name: html-test-jdi
# 2022-01-12 23:15:00,896 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2022-01-12 23:15:00,898 -INFO - dataset_builder.py:152 - Creating driver
# 2022-01-12 23:15:01,781 -INFO - dataset_builder.py:164 - Chrome web driver is created
# ipykernel_launcher:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2022-01-12 23:15:07,802 -INFO - common.py:22 - Window maximized
# 2022-01-12 23:15:09,808 -INFO - dataset_builder.py:167 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/images/html-test-jdi.png
# 2022-01-12 23:15:14,892 -INFO - dataset_builder.py:211 - Collect features using JS script
# 2022-01-12 23:15:15,412 -INFO - dataset_builder.py:219 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/html/html-test-jdi.html
# 2022-01-12 23:15:15,423 -INFO - dataset_builder.py:231 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/df/html-test-jdi.pkl
# 2022-01-12 23:15:15,425 -INFO - dataset_builder.py:234 - No attributes: (255, 14)
# 2022-01-12 23:15:15,472 -INFO - dataset_builder.py:125 - Close web driver

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset'

# %%
d = pd.DataFrame(dataset_json)
d[d.html.apply(lambda x: True if '<input type="button"' in x else False)].tail(3)
# Out:
#                                             attributes  displayed  \
# 206                             {'class': 'html-left'}       True
# 208  {'class': 'uui-button red', 'onclick': 'alert(...       True
# 211  {'class': 'uui-button grey', 'disabled': '', '...       True
#
#                        element_id     height  \
# 206  3460527557185148978008213568  477.59375
# 208  0795996329185148975301459196   34.00000
# 211  6561826135185148979940662626   34.00000
#
#                                                   html onmouseenter  \
# 206  <div class="html-left">\n                     ...         None
# 208  <input type="button" value="Big Red Button-Inp...         None
# 211  <input type="button" value="Disabled Button-In...         None
#
#     onmouseover                     parent_id  \
# 206        None  3427265303185148978963461876
# 208        None  3460527557185148978008213568
# 211        None  3460527557185148978008213568
#
#                                                  style tag_name  \
# 206  [accent-color, align-content, align-items, ali...      DIV
# 208  [accent-color, align-content, align-items, ali...    INPUT
# 211  [accent-color, align-content, align-items, ali...    INPUT
#
#                                                   text       width      x  \
# 206  BUTTON\n\n\n\n\nTAG BUTTON\nBIG BLUE BUTTON\n\...  283.187500  363.0
# 208                                                     163.421875  363.0
# 211                                                     171.906250  363.0
#
#               y
# 206  378.187500
# 208  417.984375
# 211  469.984375

# %%
from utils.dataset import HTML5_JDNDataset
dataset = HTML5_JDNDataset(
        datasets_list=[DATASET_NAME],
        dataset_type="html5",
        rebalance_and_shuffle=False,
    )
# Out:
# Build tree features: 100%|██████████| 668/668 [00:00<00:00, 1531.26it/s]i-qasp-ml/data/html5_dataset/df/html-test-jdi.pkl]
# 100%|██████████| 1/1 [00:01<00:00,  1.20s/it, /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/df/html-test-jdi.pkl]
# 2022-01-12 23:32:27,134 -INFO - dataset.py:210 - self.df.shape: (668, 33)
# 2022-01-12 23:32:27,135 -INFO - dataset.py:101 - Check for duplicates...
# 2022-01-12 23:32:27,137 -INFO - dataset.py:105 - Check for duplicates is OK
# 2022-01-12 23:32:27,138 -INFO - dataset.py:214 - Calculating features...
# 2022-01-12 23:32:27,228 -INFO - dataset_collector.py:177 - X: (668, 79)
# 2022-01-12 23:32:27,230 -INFO - dataset.py:218 - Features have calculated succesfully!

# %%
print(dataset.df.shape)
print(dataset.X.shape)
# Out:
# (668, 33)
# (668, 79)

# %%
dataset.df[dataset.df.element_id == "0795996329185148975301459196"].index
# Out:
# Index(['0795996329185148975301459196'], dtype='object', name='element_id')

# %%
dataset.X.loc["0795996329185148975301459196"][dataset.X.loc["0795996329185148975301459196"]==1]
# Out:
# tag_INPUT      1
# attr_value     1
# type_button    1
# Name: 0795996329185148975301459196, dtype: int64

# %%
pkl_filename = "DT_model.pkl"
with open(f"{model_path}/{pkl_filename}", "rb") as file:
    model = pickle.load(file)

# %%
html5_classes_path = "/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/classes.txt"
with open(html5_classes_path, "r") as f:
        lines = f.readlines()
        encoder_dict = {line.strip(): i for i, line in enumerate(lines)}
        decoder_dict = {v: k for k, v in encoder_dict.items()}

# %%
# pd.Series(model.predict(dataset.X)).apply(lambda x: decoder_dict[x]).unique()

# %%
res_dataset = dataset.X.copy()
res_dataset.shape
# Out:
# (668, 79)

# %%
res_dataset["pred"] = pd.Series(model.predict(res_dataset)).apply(lambda x: decoder_dict.get(x, "n/a")).values
res_dataset.head()
# Out:
#                               tag_HTML  tag_HEAD  tag_META  tag_TITLE  \
# element_id
# 0002037534185148975896194112         0         0         0          0
# 0007072414185148970880802200         0         0         0          0
# 0019757941185148975041962840         0         0         0          0
# 0020281423185148973331208162         0         0         0          0
# 0042530667185148979837533652         0         0         0          0
#
#                               tag_STYLE  tag_BODY  tag_DIV  tag_LABEL  \
# element_id
# 0002037534185148975896194112          0         0        0          0
# 0007072414185148970880802200          0         0        0          0
# 0019757941185148975041962840          0         0        0          0
# 0020281423185148973331208162          0         0        0          0
# 0042530667185148979837533652          0         0        0          0
#
#                               tag_INPUT  tag_DATALIST  ...  type_range  \
# element_id                                             ...
# 0002037534185148975896194112          0             0  ...           0
# 0007072414185148970880802200          0             0  ...           0
# 0019757941185148975041962840          0             0  ...           0
# 0020281423185148973331208162          0             0  ...           0
# 0042530667185148979837533652          0             0  ...           0
#
#                               type_radio  type_month  type_checkbox  \
# element_id
# 0002037534185148975896194112           0           0              0
# 0007072414185148970880802200           0           0              0
# 0019757941185148975041962840           0           0              0
# 0020281423185148973331208162           0           0              0
# 0042530667185148979837533652           0           0              0
#
#                               type_reset  type_number  type_week  \
# element_id
# 0002037534185148975896194112           0            0          0
# 0007072414185148970880802200           0            0          0
# 0019757941185148975041962840           0            0          0
# 0020281423185148973331208162           0            0          0
# 0042530667185148979837533652           0            0          0
#
#                               is_checkbox_in_childs  is_radio_in_childs   pred
# element_id
# 0002037534185148975896194112                      0                   0  title
# 0007072414185148970880802200                      0                   0    n/a
# 0019757941185148975041962840                      0                   0   link
# 0020281423185148973331208162                      0                   0    n/a
# 0042530667185148979837533652                      0                   0    n/a
#
# [5 rows x 80 columns]

# %%
res_dataset.pred.unique()
# Out:
# array(['title', 'n/a', 'link', 'text', 'textfield', 'fileinput', 'label',
#        'button', 'datetimeselector', 'textarea', 'checklist', 'checkbox',
#        'radiobutton', 'range', 'dropdown', 'colorpicker', 'multiselector',
#        'datalist', 'multidropdown', 'radiobuttongroup', 'numberselector',
#        'progressbar'], dtype=object)

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '1227549143185148971821458374',
#   'x': 363.0,
#   'y': 3816.75,
#   'width': 283.1875,
#   'height': 130.0,
#   'predicted_label': 'checklist',
#   'predicted_probability': 1.0,
#   'sort_key': 36814.375},
#  {'element_id': '6906657592185148972816339672',
#   'x': 363.0,
#   'y': 4129.546875,
#   'width': 283.1875,
#   'height': 104.0,
#   'predicted_label': 'radiobuttongroup',
#   'predicted_probability': 1.0,
#   'sort_key': 29451.5},
#  {'element_id': '4844355928185148971766817755',
#   'x': 363.0,
#   'y': 186.0,
#   'width': 283.1875,
#   'height': 79.1875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 22424.91015625},
#  {'element_id': '4999792534185148976501643162',
#   'x': 696.203125,
#   'y': 1359.375,
#   'width': 610.796875,
#   'height': 36.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key':
,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8856.28125},
#  {'element_id': '5311700218185148970198218535',
#   'x': 502.859375,
#   'y': 0.0,
#   'width': 140.484375,
#   'height': 60.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8429.0625},
#  {'element_id': '6830490217185148974705666675',
#   'x': 730.34375,
#   'y': 3627.75,
#   'width': 462.5,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8325.0},
#  {'element_id': '3942045954185148972868513933',
#   'x': 730.34375,
#   'y': 3884.546875,
#   'width': 462.5,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8325.0},
#  {'element_id': '9131768722185148976273394629',
#   'x': 730.34375,
#   'y': 5953.71875,
#   'width': 453.765625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8167.78125},
#  {'element_id': '2201227287185148972782390539',
#   'x': 730.34375,
#   'y': 5262.53125,
#   'width': 446.53125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8037.5625},
#  {'element_id': '6825647897185148975163195384',
#   'x': 730.34375,
#   'y': 4654.9375,
#   'width': 440.375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7926.75},
#  {'element_id': '5268779322185148978987644955',
#   'x': 730.34375,
#   'y': 5780.921875,
#   'width': 438.15625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7886.8125},
#  {'element_id': '2931925465185148977742855710',
#   'x': 730.34375,
#   'y': 4197.34375,
#   'width': 437.609375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7876.96875},
#  {'element_id': '6834509876185148973609859780',
#   'x': 730.34375,
#   'y': 4426.140625,
#   'width': 436.59375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7858.6875},
#  {'element_id': '1344659848185148975319233069',
#   'x': 730.34375,
#   'y': 5608.125,
#   'width': 434.1875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7815.375},
#  {'element_id': '6464241000185148976428599816',
#   'x': 0.0,
#   'y': 224.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '9752283551185148973066123271',
#   'x': 0.0,
#   'y': 101.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '2714933500185148976960532132',
#   'x': 0.0,
#   'y': 142.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '1120074268185148977964103694',
#   'x': 0.0,
#   'y': 183.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '3941374006185148977348317772',
#   'x': 0.0,
#   'y': 60.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7800.0},
#  {'element_id': '7352727829185148979896036882',
#   'x': 730.34375,
#   'y': 1229.375,
#   'width': 429.484375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7730.71875},
#  {'element_id': '5464730010185148971178298290',
#   'x': 730.34375,
#   'y': 1974.96875,
#   'width': 425.265625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7654.78125},
#  {'element_id': '6746921809185148976028168046',
#   'x': 0.0,
#   'y': 529.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '2163590424185148975994060935',
#   'x': 0.0,
#   'y': 339.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '9654133229185148974968199271',
#   'x': 0.0,
#   'y': 567.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '9456440297185148976889151306',
#   'x': 0.0,
#   'y': 301.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '9348526828185148976349129678',
#   'x': 0.0,
#   'y': 415.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '1405338538185148970883786601',
#   'x': 0.0,
#   'y': 491.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '7114387490185148972437804539',
#   'x': 0.0,
#   'y': 453.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '6261307251185148972150072481',
#   'x': 0.0,
#   'y': 263.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '1587861634185148976414685877',
#   'x': 0.0,
#   'y': 377.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7600.0},
#  {'element_id': '1195925373185148976131803850',
#   'x': 730.34375,
#   'y': 4944.9375,
#   'width': 421.25,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7582.5},
#  {'element_id': '4084141127185148972928355935',
#   'x': 730.34375,
#   'y': 1634.171875,
#   'width': 418.15625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7526.8125},
#  {'element_id': '4875569845185148974930447199',
#   'x': 730.34375,
#   'y': 3398.953125,
#   'width': 413.75,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7447.5},
#  {'element_id': '5652197383185148972295873957',
#   'x': 730.34375,
#   'y': 5089.734375,
#   'width': 410.484375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7388.71875},
#  {'element_id': '7541552974185148978126589276',
#   'x': 730.34375,
#   'y': 445.984375,
#   'width': 410.3125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7385.625},
#  {'element_id': '6486099247185148974992282636',
#   'x': 363.0,
#   'y': 3559.953125,
#   'width': 283.1875,
#   'height': 26.0,
#   'predicted_label': 'checklist',
#   'predicted_probability': 1.0,
#   'sort_key': 7362.875},
#  {'element_id': '7301558099185148975593315248',
#   'x': 287.453125,
#   'y': 0.0,
#   'width': 121.859375,
#   'height': 60.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7311.5625},
#  {'element_id': '4268781188185148977577473894',
#   'x': 730.34375,
#   'y': 2460.5625,
#   'width': 405.03125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7290.5625},
#  {'element_id': '7415119849185148976871512036',
#   'x': 730.34375,
#   'y': 3114.15625,
#   'width': 405.03125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7290.5625},
#  {'element_id': '2192655195185148970382842529',
#   'x': 730.34375,
#   'y': 2773.359375,
#   'width': 405.03125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7290.5625},
#  {'element_id': '3088760470185148974623401453',
#   'x': 728.453125,
#   'y': 5407.328125,
#   'width': 404.25,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7276.5},
#  {'element_id': '8984142065185148971067091178',
#   'x': 730.34375,
#   'y': 2231.765625,
#   'width': 393.1875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7077.375},
#  {'element_id': '6686659339185148971326499873',
#   'x': 445.984375,
#   'y': 5367.53125,
#   'width': 172.796875,
#   'height': 40.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 6911.875},
#  {'element_id': '5622720227185148973326463681',
#   'x': 730.34375,
#   'y': 944.578125,
#   'width': 377.453125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6794.15625},
#  {'element_id': '5871574848185148974317048994',
#   'x': 728.453125,
#   'y': 3599.75,
#   'width': 374.515625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6741.28125},
#  {'element_id': '7330465079185148971425817260',
#   'x': 728.453125,
#   'y': 3856.546875,
#   'width': 374.515625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6741.28125},
#  {'element_id': '1646508497185148978137149387',
#   'x': 728.453125,
#   'y': 1201.375,
#   'width': 367.6875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6618.375},
#  {'element_id': '7568348315185148970501186408',
#   'x': 363.0,
#   'y': 5908.921875,
#   'width': 300.0,
#   'height': 22.0,
#   'predicted_label': 'numberselector',
#   'predicted_probability': 1.0,
#   'sort_key': 6600.0},
#  {'element_id': '9029149614185148970436600883',
#   'x': 728.453125,
#   'y': 5925.71875,
#   'width': 364.65625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6563.8125},
#  {'element_id': '2844710633185148978194854148',
#   'x': 728.453125,
#   'y': 5234.53125,
#   'width': 358.21875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6447.9375},
#  {'element_id': '3255926465185148977083792411',
#   'x': 728.453125,
#   'y': 4626.9375,
#   'width': 352.0625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6337.125},
#  {'element_id': '7653891262185148974410941820',
#   'x': 728.453125,
#   'y': 5752.921875,
#   'width': 350.015625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6300.28125},
#  {'element_id': '8008856945185148975201939668',
#   'x': 728.453125,
#   'y': 4169.34375,
#   'width': 349.265625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6286.78125},
#  {'element_id': '0384839455185148975152590236',
#   'x': 728.453125,
#   'y': 4398.140625,
#   'width': 347.921875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6262.59375},
#  {'element_id': '7811189921185148976691867763',
#   'x': 728.453125,
#   'y': 5580.125,
#   'width': 345.75,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6223.5},
#  {'element_id': '9143755245185148977673383056',
#   'x': 728.453125,
#   'y': 5061.734375,
#   'width': 345.140625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6212.53125},
#  {'element_id': '3921212964185148977624208603',
#   'x': 728.453125,
#   'y': 1946.96875,
#   'width': 344.34375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6198.1875},
#  {'element_id': '7233736211185148975444408315',
#   'x': 728.453125,
#   'y': 2745.359375,
#   'width': 338.375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6090.75},
#  {'element_id': '6084091781185148977098996199',
#   'x': 728.453125,
#   'y': 3086.15625,
#   'width': 338.375,
# ...
#   'x': 363.0,
#   'y': 1135.578125,
#   'width': 83.453125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1502.15625},
#  {'element_id': '5463957387185148975340865613',
#   'x': 378.8125,
#   'y': 3819.75,
#   'width': 80.890625,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1456.03125},
#  {'element_id': '0978657801185148979888654257',
#   'x': 363.0,
#   'y': 2733.5625,
#   'width': 80.28125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1445.0625},
#  {'element_id': '9698451788185148972046790375',
#   'x': 363.0,
#   'y': 5378.53125,
#   'width': 80.171875,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1443.09375},
#  {'element_id': '8366060837185148977748527344',
#   'x': 363.0,
#   'y': 5032.9375,
#   'width': 75.609375,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1360.96875},
#  {'element_id': '4901790189185148979894434216',
#   'x': 363.0,
#   'y': 4330.34375,
#   'width': 50.0,
#   'height': 27.0,
#   'predicted_label': 'colorpicker',
#   'predicted_probability': 1.0,
#   'sort_key': 1350.0},
#  {'element_id': '4427519037185148978171715341',
#   'x': 363.0,
#   'y': 4361.34375,
#   'width': 50.0,
#   'height': 27.0,
#   'predicted_label': 'colorpicker',
#   'predicted_probability': 1.0,
#   'sort_key': 1350.0},
#  {'element_id': '2841281717185148976696411249',
#   'x': 363.0,
#   'y': 1160.578125,
#   'width': 74.65625,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1343.8125},
#  {'element_id': '4501002367185148978139867069',
#   'x': 378.8125,
#   'y': 3871.75,
#   'width': 74.65625,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1343.8125},
#  {'element_id': '8700729933185148976642298460',
#   'x': 363.0,
#   'y': 2175.375,
#   'width': 72.1875,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1299.375},
#  {'element_id': '0802838625185148972486767888',
#   'x': 378.8125,
#   'y': 3923.75,
#   'width': 69.5,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1251.0},
#  {'element_id': '3129762835185148975614170602',
#   'x': 363.0,
#   'y': 4789.140625,
#   'width': 69.5,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1251.0},
#  {'element_id': '7017904661185148973829435358',
#   'x': 363.0,
#   'y': 5716.515625,
#   'width': 65.234375,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1174.21875},
#  {'element_id': '4933183219185148978734124311',
#   'x': 363.0,
#   'y': 4589.140625,
#   'width': 63.046875,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1134.84375},
#  {'element_id': '0441871994185148976077742509',
#   'x': 363.0,
#   'y': 876.78125,
#   'width': 61.609375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1108.96875},
#  {'element_id': '1541880081185148974092490385',
#   'x': 378.8125,
#   'y': 4210.546875,
#   'width': 56.28125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1013.0625},
#  {'element_id': '3557250446185148973128135239',
#   'x': 378.8125,
#   'y': 3897.75,
#   'width': 55.703125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1002.65625},
#  {'element_id': '8092986858185148972171019835',
#   'x': 378.8125,
#   'y': 4158.546875,
#   'width': 53.75,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 967.5},
#  {'element_id': '2935299302185148970990938191',
#   'x': 1385.890625,
#   'y': 14961.0,
#   'width': 64.109375,
#   'height': 15.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 961.640625},
#  {'element_id': '1037872162185148977339360994',
#   'x': 378.8125,
#   'y': 3845.75,
#   'width': 46.328125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 833.90625},
#  {'element_id': '0234609079185148975484499821',
#   'x': 378.8125,
#   'y': 4184.546875,
#   'width': 45.578125,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 820.40625},
#  {'element_id': '2028702146185148978129368565',
#   'x': 1430.0,
#   'y': 20.0,
#   'width': 40.0,
#   'height': 20.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 800.0},
#  {'element_id': '3445562480185148977848111342',
#   'x': 378.8125,
#   'y': 4132.546875,
#   'width': 41.859375,
#   'height': 18.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 753.46875},
#  {'element_id': '9240008871185148972911851486',
#   'x': 389.734375,
#   'y': 4637.140625,
#   'width': 100.0,
#   'height': 7.0,
#   'predicted_label': 'range',
#   'predicted_probability': 1.0,
#   'sort_key': 700.0},
#  {'element_id': '0074239851185148973892728647',
#   'x': 550.1875,
#   'y': 4748.140625,
#   'width': 30.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 660.0},
#  {'element_id': '0413671337185148971634056553',
#   'x': 428.859375,
#   'y': 4587.140625,
#   'width': 30.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 660.0},
#  {'element_id': '8975847513185148970205507113',
#   'x': 494.90625,
#   'y': 4666.140625,
#   'width': 30.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 660.0},
#  {'element_id': '8717994213185148977962487023',
#   'x': 493.40625,
#   'y': 4707.140625,
#   'width': 30.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 660.0},
#  {'element_id': '8184286394185148979887145497',
#   'x': 1322.71875,
#   'y': 14961.0,
#   'width': 30.265625,
#   'height': 15.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 453.984375},
#  {'element_id': '6397791608185148970488073221',
#   'x': 363.0,
#   'y': 3898.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '9356517634185148978061382842',
#   'x': 363.0,
#   'y': 3820.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '7581708869185148976142600954',
#   'x': 363.0,
#   'y': 3846.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '2035410319185148974296073632',
#   'x': 363.0,
#   'y': 3563.953125,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '2118318630185148975904418449',
#   'x': 363.0,
#   'y': 4159.546875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '2193390660185148973828836042',
#   'x': 363.0,
#   'y': 4185.546875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '4415368483185148973956828547',
#   'x': 363.0,
#   'y': 4133.546875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '9995202267185148971975662713',
#   'x': 363.0,
#   'y': 3924.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '4087320055185148975544618166',
#   'x': 363.0,
#   'y': 4211.546875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '7691607296185148977722357006',
#   'x': 363.0,
#   'y': 3872.75,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '6285561319185148971257212704',
#   'x': 512.984375,
#   'y': 3053.765625,
#   'width': 1.0,
#   'height': 1.0,
#   'predicted_label': 'multidropdown',
#   'predicted_probability': 1.0,
#   'sort_key': 1.0},
#  {'element_id': '5734013248185148973456185382',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4854497994185148975602897971',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0019757941185148975041962840',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9514354351185148975783350651',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6915193701185148971259115374',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5365467833185148972975140268',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5421982164185148974917706208',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7808883992185148976480083379',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5566901837185148972440774039',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6275878928185148971336818056',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5993122432185148975415335398',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0888050012185148976727472424',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0267647715185148971857190928',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3508972777185148978075472109',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0203452953185148973692794833',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3955107599185148975253141155',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6417548819185148978633404283',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3699795407185148971948756617',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9460934739185148974907288717',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4188148571185148979983123607',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4605030599185148978272336133',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9050821143185148977736342383',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2421920642185148972761516893',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8932581142185148975605246196',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2886334993185148973741235639',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2909929370185148972417490219',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2091569619185148974852368755',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2058450468185148975335490721',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7747158222185148978325506951',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3240771597185148970991185610',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6585584074185148976906575863',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7586781148185148972630220636',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1568311323185148976399835994',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4425086183185148977496829532',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7532769297185148970077611871',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7515744748185148977559356627',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7752158102185148976135597204',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4464434424185148975269415207',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3340328967185148971320258176',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7425081080185148977385775603',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3457066029185148976052708494',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0}]
# CPU times: user 124 ms, sys: 15.1 ms, total: 139 ms
# Wall time: 1.93 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id           x            y       width  \
# 0  1227549143185148971821458374  363.000000  3816.750000  283.187500
# 1  6906657592185148972816339672  363.000000  4129.546875  283.187500
# 2  4844355928185148971766817755  363.000000   186.000000  283.187500
# 3  4999792534185148976501643162  696.203125  1359.375000  610.796875
# 4  6395437581185148977247508649  696.203125  1257.375000  610.796875
#
#      height   predicted_label  predicted_probability      sort_key tag_name
# 0  130.0000         checklist                    1.0  36814.375000      DIV
# 1  104.0000  radiobuttongroup                    1.0  29451.500000      DIV
# 2   79.1875             title                    1.0  22424.910156       H1
# 3   36.0000              text                    1.0  21988.687500        P
# 4   36.0000              text                    1.0  21988.687500        P

# %%
predictions_df.predicted_label.unique()
# Out:
# array(['checklist', 'radiobuttongroup', 'title', 'text', 'textarea',
#        'link', 'datetimeselector', 'numberselector', 'button',
#        'fileinput', 'multiselector', 'label', 'textfield', 'datalist',
#        'progressbar', 'dropdown', 'range', 'colorpicker', 'checkbox',
#        'radiobutton', 'multidropdown'], dtype=object)

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                str(r.predicted_label) + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
