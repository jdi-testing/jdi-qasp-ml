# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'HTML5_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/html5_dataset')

# %%
DATASET_NAME = 'cubitts'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://www.awwwards.com/sites/cubitts'
PREDICT_URL = 'http://localhost:5050/html5-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 2
# HEADLESS = True

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        maximize_window(driver=driver, extend_pix=0)
        sleep(2.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2022-01-12 23:47:44,059 -INFO - dataset_builder.py:100 - Dataset name: cubitts
# 2022-01-12 23:47:44,061 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2022-01-12 23:47:44,063 -INFO - dataset_builder.py:152 - Creating driver
# 2022-01-12 23:47:44,998 -INFO - dataset_builder.py:164 - Chrome web driver is created
# 2022-01-12 23:47:46,566 -INFO - common.py:22 - Window maximized
# 2022-01-12 23:47:48,577 -INFO - dataset_builder.py:167 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/images/cubitts.png
# 2022-01-12 23:47:55,751 -INFO - dataset_builder.py:211 - Collect features using JS script
# 2022-01-12 23:47:57,599 -INFO - dataset_builder.py:219 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/html/cubitts.html
# 2022-01-12 23:47:57,636 -INFO - dataset_builder.py:231 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/df/cubitts.pkl
# 2022-01-12 23:47:57,638 -INFO - dataset_builder.py:234 - No attributes: (271, 14)
# 2022-01-12 23:47:57,863 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '9659562945204757594402222944',
#   'x': 0.0,
#   'y': 70.0,
#   'width': 1572.0,
#   'height': 579.15625,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 910433.625},
#  {'element_id': '9468430708204757592404057175',
#   'x': 137.0,
#   'y': 2460.453125,
#   'width': 631.5,
#   'height': 451.28125,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 284984.109375},
#  {'element_id': '6872734862204757592692617413',
#   'x': 803.5,
#   'y': 2460.453125,
#   'width': 631.5,
#   'height': 451.28125,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 284984.109375},
#  {'element_id': '3591344054204757608218646738',
#   'x': 434.75,
#   'y': 5694.734375,
#   'width': 333.75,
#   'height': 238.484375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 79594.16015625},
#  {'element_id': '5256328855204757608336700908',
#   'x': 66.0,
#   'y': 5694.734375,
#   'width': 333.75,
#   'height': 238.484375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 79594.16015625},
#  {'element_id': '5827334690204757606230085155',
#   'x': 803.5,
#   'y': 5694.734375,
#   'width': 333.75,
#   'height': 238.484375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 79594.16015625},
#  {'element_id': '4781535485204757606554769574',
#   'x': 1172.25,
#   'y': 5694.734375,
#   'width': 333.75,
#   'height': 238.484375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 79594.16015625},
#  {'element_id': '6000620000204757608853586000',
#   'x': 521.0,
#   'y': 7476.40625,
#   'width': 530.0,
#   'height': 108.75,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 57637.5},
#  {'element_id': '4374018279204757596367874575',
#   'x': 66.0,
#   'y': 260.078125,
#   'width': 1440.0,
#   'height': 38.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 54720.0},
#  {'element_id': '2267980868204757602789513698',
#   'x': 521.0,
#   'y': 7384.84375,
#   'width': 530.0,
#   'height': 81.5625,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 43228.125},
#  {'element_id': '7101276939204757581609392202',
#   'x': -320.0,
#   'y': 796.0,
#   'width': 320.0,
#   'height': 114.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 36480.0},
#  {'element_id': '1056819562204757599334093077',
#   'x': 347.0,
#   'y': 699.15625,
#   'width': 878.0,
#   'height': 32.296875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 28356.65625},
#  {'element_id': '7184446651204757603216696897',
#   'x': 66.0,
#   'y': 14833.0,
#   'width': 1144.65625,
#   'height': 23.796875,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 27239.2416992188},
#  {'element_id': '1369698616204757584771933779',
#   'x': -320.0,
#   'y': 334.0,
#   'width': 320.0,
#   'height': 66.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 21120.0},
#  {'element_id': '8166034537204757584713607559',
#   'x': -320.0,
#   'y': 466.0,
#   'width': 320.0,
#   'height': 66.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 21120.0},
#  {'element_id': '3438861209204757581085439783',
#   'x': -320.0,
#   'y': 268.0,
#   'width': 320.0,
#   'height': 66.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 21120.0},
#  {'element_id': '5366477099204757588369001049',
#   'x': -320.0,
#   'y': 70.0,
#   'width': 320.0,
#   'height': 66.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 21120.0},
#  {'element_id': '2637200880204757588864961880',
#   'x': -320.0,
#   'y': 400.0,
#   'width': 320.0,
#   'height': 66.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 21120.0},
#  {'element_id': '8725241840204757583382828835',
#   'x': -320.0,
#   'y': 136.0,
#   'width': 320.0,
#   'height': 66.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 21120.0},
#  {'element_id': '2936023569204757583044394120',
#   'x': -320.0,
#   'y': 202.0,
#   'width': 320.0,
#   'height': 66.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 21120.0},
#  {'element_id': '9303877790204757584936795631',
#   'x': -320.0,
#   'y': 598.0,
#   'width': 320.0,
#   'height': 66.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 21120.0},
#  {'element_id': '9412393862204757589014309617',
#   'x': -320.0,
#   'y': 664.0,
#   'width': 320.0,
#   'height': 66.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 21120.0},
#  {'element_id': '6945111899204757589535694177',
#   'x': -320.0,
#   'y': 532.0,
#   'width': 320.0,
#   'height': 66.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 21120.0},
#  {'element_id': '9483516653204757582763584129',
#   'x': -320.0,
#   'y': 730.0,
#   'width': 320.0,
#   'height': 66.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 21120.0},
#  {'element_id': '3123013281204757602325174565',
#   'x': 66.0,
#   'y': 14723.0,
#   'width': 520.0,
#   'height': 35.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 18200.0},
#  {'element_id': '9502426211204757596286263812',
#   'x': 823.5,
#   'y': 2931.734375,
#   'width': 591.5,
#   'height': 25.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 14787.5},
#  {'element_id': '4555968305204757590870765896',
#   'x': 157.0,
#   'y': 2931.734375,
#   'width': 591.5,
#   'height': 25.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 14787.5},
#  {'element_id': '1317777476204757597419891764',
#   'x': 1382.0,
#   'y': 0.0,
#   'width': 190.0,
#   'height': 70.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 13300.0},
#  {'element_id': '9713605653204757606853731849',
#   'x': 521.0,
#   'y': 7335.84375,
#   'width': 530.0,
#   'height': 24.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 12720.0},
#  {'element_id': '6084573242204757595751739744',
#   'x': 892.5,
#   'y': 353.078125,
#   'width': 84.0,
#   'height': 106.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8904.0},
#  {'element_id': '0984422288204757595779133667',
#   'x': 991.5,
#   'y': 353.078125,
#   'width': 84.0,
#   'height': 106.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8904.0},
#  {'element_id': '6480430817204757601737092581',
#   'x': 86.0,
#   'y': 5953.21875,
#   'width': 293.75,
#   'height': 25.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 7343.75},
#  {'element_id': '5837679148204757600776946144',
#   'x': 1192.25,
#   'y': 5953.21875,
#   'width': 293.75,
#   'height': 25.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 7343.75},
#  {'element_id': '0721935690204757602890878720',
#   'x': 454.75,
#   'y': 5953.21875,
#   'width': 293.75,
#   'height': 25.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 7343.75},
#  {'element_id': '4851276427204757608017259627',
#   'x': 823.5,
#   'y': 5953.21875,
#   'width': 293.75,
#   'height': 25.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 7343.75},
#  {'element_id': '2147877188204757596116374774',
#   'x': 720.421875,
#   'y': 260.078125,
#   'width': 131.140625,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4983.34375},
#  {'element_id': '4333662450204757591696815867',
#   'x': 364.0,
#   'y': 760.453125,
#   'width': 123.953125,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4214.40625},
#  {'element_id': '9412072721204757599439215969',
#   'x': 689.03125,
#   'y': 760.453125,
#   'width': 111.078125,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3776.65625},
#  {'element_id': '9042010936204757601034753425',
#   'x': 1359.234375,
#   'y': 14952.796875,
#   'width': 146.765625,
#   'height': 23.796875,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 3492.5632324219},
#  {'element_id': '2041799198204757590350572714',
#   'x': 808.640625,
#   'y': 760.453125,
#   'width': 96.625,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3285.25},
#  {'element_id': '4139817057204757592070994602',
#   'x': 66.0,
#   'y': 565.15625,
#   'width': 93.453125,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3177.40625},
#  {'element_id': '6513167260204757594657032354',
#   'x': 496.484375,
#   'y': 760.453125,
#   'width': 87.828125,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2986.15625},
#  {'element_id': '2403430970204757591226316434',
#   'x': 592.84375,
#   'y': 760.453125,
#   'width': 87.65625,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2980.3125},
#  {'element_id': '9764178145204757594672240815',
#   'x': 1079.953125,
#   'y': 760.453125,
#   'width': 86.515625,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2941.53125},
#  {'element_id': '1639218785204757592746173411',
#   'x': 987.953125,
#   'y': 760.453125,
#   'width': 83.46875,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2837.9375},
#  {'element_id': '0646837509204757609473302584',
#   'x': 823.5,
#   'y': 5958.21875,
#   'width': 200.203125,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2802.84375},
#  {'element_id': '5792794955204757597101393334',
#   'x': 622.609375,
#   'y': 890.453125,
#   'width': 95.03125,
#   'height': 29.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2755.90625},
#  {'element_id': '8499618952204757599871657112',
#   'x': 867.78125,
#   'y': 890.453125,
#   'width': 81.59375,
#   'height': 29.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2366.21875},
#  {'element_id': '7793550619204757603888741736',
#   'x': 66.0,
#   'y': 5619.734375,
#   'width': 129.28125,
#   'height': 18.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 2327.0625},
#  {'element_id': '7188777218204757592428983718',
#   'x': 606.25,
#   'y': 313.078125,
#   'width': 152.171875,
#   'height': 15.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2282.578125},
#  {'element_id': '2344883196204757602207546713',
#   'x': 66.0,
#   'y': 5619.734375,
#   'width': 124.28125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2237.0625},
#  {'element_id': '7070487317204757596063412650',
#   'x': 913.796875,
#   'y': 760.453125,
#   'width': 65.625,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2231.25},
#  {'element_id': '1961599756204757591567795072',
#   'x': 754.28125,
#   'y': 890.453125,
#   'width': 76.796875,
#   'height': 29.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2227.109375},
#  {'element_id': '5715432296204757601601706255',
#   'x': 86.0,
#   'y': 5958.21875,
#   'width': 158.46875,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2218.5625},
#  {'element_id': '7677535548204757599681166465',
#   'x': 237.0,
#   'y': 3622.734375,
#   'width': 148.328125,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2076.59375},
#  {'element_id': '5213288629204757609457099945',
#   'x': 1359.234375,
#   'y': 14956.796875,
#   'width': 146.765625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2054.71875},
#  {'element_id': '2034307293204757608059246825',
#   'x': 237.0,
#   'y': 5343.734375,
#   'width': 141.890625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1986.46875},
#  {'element_id': '0931341162204757604344668276',
#   'x': 1399.21875,
#   'y': 14731.0,
#   'width': 106.78125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1922.0625},
#  {'element_id': '5168428275204757593006372998',
#   'x': 66.0,
#   'y': 128.5,
#   'width': 109.828125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1867.078125},
#  {'element_id': '8084549829204757603217743762',
#   'x': 237.0,
#   'y': 4857.234375,
#   'width': 132.5625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1855.875},
#  {'element_id': '4002910399204757597770341915',
#   'x': 715.5,
#   'y': 33.296875,
#   'width': 141.0,
#   'height': 13.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1833.0},
#  {'element_id': '4140183982204757604150027826',
#   'x': 66.0,
#   'y': 14788.0,
#   'width': 128.984375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1805.78125},
#  {'element_id': '5377486729204757609349885196',
#   'x': 454.75,
#   'y': 5958.21875,
#   'width': 116.9375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1637.125},
#  {'element_id': '9181167715204757595541154829',
#   'x': 237.0,
#   'y': 3294.734375,
#   'width': 113.25,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1585.5},
#  {'element_id': '2340037755204757591382024371',
#   'x': 237.0,
#   'y': 4032.734375,
#   'width': 111.0625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1554.875},
#  {'element_id': '8613301046204757593386958504',
#   'x': 237.0,
#   'y': 3950.734375,
#   'width': 107.4375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1504.125},
#  {'element_id': '7522875944204757602257261406',
#   'x': 676.78125,
#   'y': 7562.96875,
#   'width': 92.53125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1480.5},
#  {'element_id': '3172808850204757590472953592',
#   'x': 237.0,
#   'y': 3868.734375,
#   'width': 105.34375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1474.8125},
#  {'element_id': '8187485768204757598289443415',
#   'x': 1246.265625,
#   'y': 30.0,
#   'width': 112.734375,
#   'height': 13.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1465.546875},
#  {'element_id': '4817095530204757598710044626',
#   'x': 237.0,
#   'y': 3376.734375,
#   'width': 104.640625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1464.96875},
#  {'element_id': '6517650680204757599205978503',
#   'x': 237.0,
#   'y': 3212.734375,
#   'width': 104.46875,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1462.5625},
#  {'element_id': '5351664190204757593467562090',
#   'x': 171.625,
#   'y': 2971.734375,
#   'width': 104.46875,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1462.5625},
#  {'element_id': '7762531925204757591818626052',
#   'x': 207.78125,
#   'y': 3027.234375,
#   'width': 121.734375,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1460.8125},
#  {'element_id': '2504841994204757591211598417',
#   'x': 874.28125,
#   'y': 3027.234375,
#   'width': 121.734375,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1460.8125},
#  {'element_id': '6610066193204757606837795508',
#   'x': 237.0,
#   'y': 4442.734375,
#   'width': 101.84375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1425.8125},
#  {'element_id': '2966436079204757604389806570',
#   'x': 237.0,
#   'y': 4196.734375,
#   'width': 101.5625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1421.875},
#  {'element_id': '8608350493204757602099691038',
#   'x': 237.0,
#   'y': 4114.734375,
#   'width': 98.390625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1377.46875},
#  {'element_id': '1150106394204757605769295026',
#   'x': 237.0,
#   'y': 4706.734375,
#   'width': 95.171875,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1332.40625},
#  {'element_id': '4288976263204757594913171558',
#   'x': 157.0,
#   'y': 2936.734375,
#   'width': 93.90625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1314.6875},
#  {'element_id': '5963271427204757609929161850',
#   'x': 214.984375,
#   'y': 14788.0,
#   'width': 93.09375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1303.3125},
#  {'element_id': '8863405067204757598044659852',
#   'x': 237.0,
#   'y': 3458.734375,
#   'width': 92.234375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1291.28125},
#  {'element_id': '6796884525204757599629533255',
#   'x': 823.5,
#   'y': 2936.734375,
#   'width': 91.1875,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1276.625},
#  {'element_id': '3374575402204757604249269858',
#   'x': 237.0,
#   'y': 4524.734375,
#   'width': 90.875,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1272.25},
#  {'element_id': '2753060053204757601194001829',
#   'x': 237.0,
#   'y': 5027.234375,
#   'width': 90.203125,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1262.84375},
#  {'element_id': '4867240794204757596584415248',
#   'x': 237.0,
#   'y': 3786.734375,
#   'width': 89.25,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1249.5},
#  {'element_id': '3996719939204757601899530165',
#   'x': 204.53125,
#   'y': 14957.796875,
#   'width': 86.8125,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1215.375},
#  {'element_id': '2754551429204757607634756027',
#   'x': 237.0,
#   'y': 4606.734375,
#   'width': 86.09375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1205.3125},
#  {'element_id': '8419336869204757604249224389',
#   'x': 237.0,
#   'y': 4278.734375,
#   'width': 85.3125,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1194.375},
#  {'element_id': '3822208960204757595857260058',
#   'x': 838.125,
#   'y': 2971.734375,
#   'width': 84.890625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1188.46875},
#  {'element_id': '7674851869204757607304244303',
#   'x': 237.0,
#   'y': 4360.734375,
#   'width': 83.734375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1172.28125},
#  {'element_id': '5159123964204757606767350040',
#   'x': 237.0,
#   'y': 4772.234375,
#   'width': 83.265625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1165.71875},
#  {'element_id': '7825212824204757603927364245',
#   'x': 345.75,
#   'y': 5879.21875,
#   'width': 34.0,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1156.0},
#  {'element_id': '8436549336204757596714191133',
#   'x': 1381.0,
#   'y': 2857.734375,
#   'width': 34.0,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1156.0},
#  {'element_id': '5076406776204757602752680485',
#   'x': 714.5,
#   'y': 5879.21875,
#   'width': 34.0,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1156.0},
#  {'element_id': '6716593867204757599970146714',
#   'x': 1432.0,
#   'y': 562.15625,
#   'width': 34.0,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1156.0},
#  {'element_id': '9949822975204757605968806384',
#   'x': 1452.0,
#   'y': 5879.21875,
#   'width': 34.0,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1156.0},
#  {'element_id': '4151988255204757596738838414',
#   'x': 1472.0,
#   'y': 562.15625,
#   'width': 34.0,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1156.0},
#  {'element_id': '0515577278204757608240103499',
#   'x': 1083.25,
#   'y': 5879.21875,
#   'width': 34.0,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1156.0},
#  {'element_id': '0809214855204757595099123566',
#   'x': 714.5,
#   'y': 2857.734375,
#   'width': 34.0,
#   'height': 34.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1156.0},
#  {'element_id': '3801155681204757588824363847',
#   'x': -71.0,
#   'y': 14945.0,
#   'width': 46.0,
#   'height': 25.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1150.0},
#  {'element_id': '6292109128204757582684198732',
#   'x': -71.0,
#   'y': 14945.0,
#   'width': 46.0,
#   'height': 25.0,
#   'predicted_label': 'checklist',
#   'predicted_probability': 1.0,
#   'sort_key': 1150.0},
#  {'element_id': '8593636468204757605223096123',
#   'x': 402.53125,
#   'y': 14957.796875,
#   'width': 81.015625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1134.21875},
#  {'element_id': '8406837872204757598329167073',
#   'x': 237.0,
#   'y': 3540.734375,
#   'width': 80.8125,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1131.375},
#  {'element_id': '0299902755204757604439242115',
#   'x': 136.78125,
#   'y': 6048.71875,
#   'width': 85.625,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1027.5},
#  {'element_id': '8932331177204757605291913588',
#   'x': 1373.0,
#   'y': 5325.734375,
#   'width': 32.0,
#   'height': 32.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1024.0},
#  {'element_id': '9070548851204757599124633314',
#   'x': 1373.0,
#   'y': 3130.734375,
#   'width': 32.0,
#   'height': 32.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1024.0},
#  {'element_id': '0736180097204757604200603921',
#   'x': 1373.0,
#   'y': 5407.734375,
#   'width': 32.0,
#   'height': 32.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1024.0},
#  {'element_id': '0963033374204757602825936550',
#   'x': 874.28125,
#   'y': 6048.71875,
#   'width': 85.25,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1023.0},
#  {'element_id': '7474231527204757609665050347',
#   'x': 311.34375,
#   'y': 14957.796875,
#   'width': 71.1875,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 996.625},
#  {'element_id': '7709969708204757605380429154',
#   'x': 237.0,
#   'y': 5112.234375,
#   'width': 67.71875,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 948.0625},
#  {'element_id': '1663011739204757600312751810',
#   'x': 66.0,
#   'y': 14957.796875,
#   'width': 67.046875,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 938.65625},
#  {'element_id': '2246789519204757609555132786',
#   'x': 560.3125,
#   'y': 14788.0,
#   'width': 63.3125,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 886.375},
#  {'element_id': '1305854010204757605924258740',
#   'x': 328.078125,
#   'y': 14788.0,
#   'width': 62.625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 876.75},
#  {'element_id': '1942120015204757603056102764',
#   'x': 237.0,
#   'y': 4942.234375,
#   'width': 60.703125,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 849.84375},
#  {'element_id': '8783788126204757608502130785',
#   'x': 183.71875,
#   'y': 14837.0,
#   'width': 58.6875,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 821.625},
#  {'element_id': '2779745525204757604471811169',
#   'x': 309.015625,
#   'y': 14837.0,
#   'width': 58.484375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 818.78125},
#  {'element_id': '4979169593204757600388018633',
#   'x': 410.703125,
#   'y': 14788.0,
#   'width': 57.59375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 806.3125},
#  {'element_id': '2912731447204757591359697336',
#   'x': 237.0,
#   'y': 3704.734375,
#   'width': 56.375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 789.25},
#  {'element_id': '1529961734204757598974229970',
#   'x': 1175.0,
#   'y': 761.453125,
#   'width': 28.0,
#   'height': 28.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 784.0},
#  {'element_id': '8536728422204757604635573799',
#   'x': 488.296875,
#   'y': 14788.0,
#   'width': 52.015625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 728.21875},
#  {'element_id': '6484925240204757608320274355',
#   'x': 376.03125,
#   'y': 14837.0,
#   'width': 50.328125,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 704.59375},
#  {'element_id': '8906965095204757601774864275',
#   'x': 250.9375,
#   'y': 14837.0,
#   'width': 49.546875,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 693.65625},
#  {'element_id': '4173822657204757600114402591',
#   'x': 133.84375,
#   'y': 14837.0,
#   'width': 41.34375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 578.8125},
#  {'element_id': '8548809700204757607474727183',
#   'x': 505.53125,
#   'y': 6048.71875,
#   'width': 43.609375,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 523.3125},
#  {'element_id': '8252346531204757605329636963',
#   'x': 153.046875,
#   'y': 14957.796875,
#   'width': 31.484375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 440.78125},
#  {'element_id': '0895327366204757600445254661',
#   'x': 643.625,
#   'y': 14788.0,
#   'width': 27.65625,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 387.1875},
#  {'element_id': '3063326817204757600494755884',
#   'x': 1192.25,
#   'y': 5958.21875,
#   'width': 27.09375,
#   'height': 14.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 379.3125},
#  {'element_id': '7350550102204757606171467984',
#   'x': 823.5,
#   'y': 6048.75,
#   'width': 27.0,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '7212773883204757599818136528',
#   'x': 157.0,
#   'y': 3027.265625,
#   'width': 27.0,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '9910675783204757603820779355',
#   'x': 1192.25,
#   'y': 6048.75,
#   'width': 27.0,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '2632274470204757604035710518',
#   'x': 86.0,
#   'y': 6048.75,
#   'width': 27.0,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '4450590295204757605447398758',
#   'x': 454.75,
#   'y': 6048.75,
#   'width': 27.0,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '1572979644204757593164862226',
#   'x': 823.5,
#   'y': 3027.265625,
#   'width': 27.0,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '5591650833204757608331867629',
#   'x': 1243.03125,
#   'y': 6048.71875,
#   'width': 17.015625,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 204.1875},
#  {'element_id': '1556130096204757592759301687',
#   'x': 217.0,
#   'y': 3941.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9187166460204757618686613305',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2093557797204757614431130630',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9505867851204757597624612262',
#   'x': 217.0,
#   'y': 3613.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1038562855204757593730238521',
#   'x': 217.0,
#   'y': 3367.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1994759694204757614647576211',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8432759891204757607623376950',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9649623969204757593369868698',
#   'x': 1198.328125,
#   'y': 120.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9921416656204757596265375748',
#   'x': 1431.0,
#   'y': 969.453125,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1065201098204757599441634093',
#   'x': 0.0,
#   'y': 70.0,
#   'width': 1572.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1158221812204757613360232515',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8671755312204757617209906004',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8493468439204757618378263488',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9085518911204757609554426392',
#   'x': 217.0,
#   'y': 5018.234375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0323392890204757614723296012',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9810807206204757598760005295',
#   'x': 217.0,
#   'y': 3531.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2164355360204757602463719111',
#   'x': 217.0,
#   'y': 4515.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8787266911204757597569887385',
#   'x': 217.0,
#   'y': 4023.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1554113783204757610359665616',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5009818186204757590523943100',
#   'x': 217.0,
#   'y': 3695.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2758445681204757615114706030',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8014370900204757599887678590',
#   'x': 217.0,
#   'y': 3777.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7878402930204757611025385410',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3886628960204757608749717495',
#   'x': 217.0,
#   'y': 4933.234375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4005093547204757608143513768',
#   'x': 217.0,
#   'y': 4187.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6353461201204757605469825819',
#   'x': 217.0,
#   'y': 4679.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6314228333204757618110248347',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6279162154204757608920211679',
#   'x': 217.0,
#   'y': 5103.234375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4103932000204757606254509116',
#   'x': 217.0,
#   'y': 4848.234375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4149187369204757608121954209',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4237545579204757596945929739',
#   'x': 1278.328125,
#   'y': 120.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5804932972204757602297860187',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4285723552204757591670289477',
#   'x': 217.0,
#   'y': 3449.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4336784011204757590921679592',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5703308490204757619614200088',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5644498734204757593261294236',
#   'x': 1238.328125,
#   'y': 120.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4413549900204757608475473271',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4593148902204757584146337933',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5337513855204757604548033468',
#   'x': 217.0,
#   'y': 4269.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4855953178204757608290448567',
#   'x': 217.0,
#   'y': 4763.234375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6526964865204757599767675248',
#   'x': 217.0,
#   'y': 3203.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6565138246204757596993455804',
#   'x': 1431.0,
#   'y': 1707.453125,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3756526695204757600100282734',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7095830367204757615828503772',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7849350834204757619856676218',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2247411448204757616858500689',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checklist',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2386956586204757602631773025',
#   'x': 217.0,
#   'y': 5398.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0184951805204757610180231620',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7491122461204757612276527830',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checklist',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2964197217204757613043328266',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3081747905204757605851960965',
#   'x': 217.0,
#   'y': 4433.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7091840236204757608845781002',
#   'x': 217.0,
#   'y': 4351.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3599471120204757618075254159',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'checklist',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3183678951204757594166856959',
#   'x': 217.0,
#   'y': 3859.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6982815971204757604743334024',
#   'x': 217.0,
#   'y': 5316.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3459758745204757604827655464',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6891835773204757604472509388',
#   'x': 217.0,
#   'y': 4597.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3555933602204757607101024527',
#   'x': 217.0,
#   'y': 4105.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3561110674204757598281371419',
#   'x': 217.0,
#   'y': 3285.734375,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6752233524204757610783689132',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0155381775204757591334877399',
#   'x': 1318.328125,
#   'y': 120.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0}]
# CPU times: user 161 ms, sys: 42.3 ms, total: 204 ms
# Wall time: 5.97 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id       x            y    width      height  \
# 0  9659562945204757594402222944    0.00    70.000000  1572.00  579.156250
# 1  9468430708204757592404057175  137.00  2460.453125   631.50  451.281250
# 2  6872734862204757592692617413  803.50  2460.453125   631.50  451.281250
# 3  3591344054204757608218646738  434.75  5694.734375   333.75  238.484375
# 4  5256328855204757608336700908   66.00  5694.734375   333.75  238.484375
#
#   predicted_label  predicted_probability       sort_key tag_name
# 0            link                    1.0  910433.625000        A
# 1            link                    1.0  284984.109375        A
# 2            link                    1.0  284984.109375        A
# 3            link                    1.0   79594.160156        A
# 4            link                    1.0   79594.160156        A

# %%
predictions_df.predicted_label.unique()
# Out:
# array(['link', 'text', 'title', 'label', 'checklist', 'checkbox'],
#       dtype=object)

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                str(r.predicted_label) + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
