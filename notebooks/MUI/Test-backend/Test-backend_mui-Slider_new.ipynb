# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-11-24 13:46:49,477 -INFO - config.py:31 - Module utils.config was loaded
# 2021-11-24 13:46:49,502 -INFO - common.py:127 - Module utils.common is loaded...
# 2021-11-24 13:46:49,504 -INFO - dataset_builder.py:244 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'slider'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click() #path to elements packs
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click() #path to mui
        driver.find_element_by_xpath("//*[@id='__next']/div/div/div[1]/div/div[9]").click() #path to checkboxes
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-11-24 13:47:52,186 -INFO - dataset_builder.py:100 - Dataset name: slider
# 2021-11-24 13:47:52,187 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-11-24 13:47:52,190 -INFO - dataset_builder.py:150 - Creating driver
# 2021-11-24 13:47:53,171 -INFO - dataset_builder.py:162 - Chrome web driver is created
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   # This is added back by InteractiveShellApp.init_path()
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if sys.path[0] == '':
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   del sys.path[0]
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   app.launch_new_instance()
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2021-11-24 13:48:05,829 -INFO - common.py:30 - Window maximized
# 2021-11-24 13:48:12,833 -INFO - dataset_builder.py:165 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/slider.png
# 2021-11-24 13:48:18,371 -INFO - dataset_builder.py:209 - Collect features using JS script
# 2021-11-24 13:48:18,932 -INFO - dataset_builder.py:217 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/slider.html
# 2021-11-24 13:48:18,947 -INFO - dataset_builder.py:229 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/slider.pkl
# 2021-11-24 13:48:18,949 -INFO - dataset_builder.py:232 - No attributes: (14, 13)
# 2021-11-24 13:48:23,715 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '0007298009508983776973430857',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999934435,
#   'sort_key': 12000.0},
#  {'element_id': '4360116549508983773404703197',
#   'x': 0.0,
#   'y': 960.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6155197458508983770363422365',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5910946150508983777282063641',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5814732757508983773563288955',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5680640730508983778775831783',
#   'x': 0.0,
#   'y': 2592.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5669262049508983775323439902',
#   'x': 0.0,
#   'y': 144.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5634047180508983775279754448',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5583653374508983779165320031',
#   'x': 0.0,
#   'y': 2448.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5413870423508983775962834050',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5334782514508983772517683340',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4987562994508983779268751540',
#   'x': 0.0,
#   'y': 2304.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4826872002508983779228094982',
#   'x': 0.0,
#   'y': 240.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4613481221508983778977124484',
#   'x': 0.0,
#   'y': 2112.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4596166227508983779454033370',
#   'x': 0.0,
#   'y': 1536.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4582731176508983774193645880',
#   'x': 0.0,
#   'y': 1872.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0048281062508983772513592451',
#   'x': 0.0,
#   'y': 1632.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999934435,
#   'sort_key': 12000.0},
#  {'element_id': '6532253465508983777819019183',
#   'x': 0.0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6806951485508983776997288011',
#   'x': 0.0,
#   'y': 288.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6930840913508983774676909031',
#   'x': 0.0,
#   'y': 2640.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8108619554508983772838598137',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9877381629508983771449933302',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9540023766508983778554732637',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9492666637508983772327064167',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9211732390508983772945608004',
#   'x': 0.0,
#   'y': 192.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '
0,
#   'height': 28.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999997616,
#   'sort_key': 11200.0},
#  {'element_id': '8412303520508983779166095264',
#   'x': 274.0,
#   'y': 1097.84375,
#   'width': 28.0,
#   'height': 300.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999985695,
#   'sort_key': 8400.0},
#  {'element_id': '7083630139508983770108029883',
#   'x': 274.0,
#   'y': 167.8125,
#   'width': 268.5625,
#   'height': 28.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 7519.75},
#  {'element_id': '3186594651508983774322002059',
#   'x': 314.0,
#   'y': 970.375,
#   'width': 152.0,
#   'height': 28.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 4256.0}]
# CPU times: user 52 ms, sys: 8.86 ms, total: 60.8 ms
# Wall time: 1.86 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id    x       y  width  height predicted_label  \
# 0  0007298009508983776973430857  0.0   816.0  250.0    48.0          button
# 1  4360116549508983773404703197  0.0   960.0  250.0    48.0          button
# 2  6155197458508983770363422365  0.0   864.0  250.0    48.0          button
# 3  5910946150508983777282063641  0.0  1008.0  250.0    48.0          button
# 4  5814732757508983773563288955  0.0  1728.0  250.0    48.0          button
#
#    predicted_probability  sort_key tag_name
# 0               0.999993   12000.0      DIV
# 1               1.000000   12000.0      DIV
# 2               1.000000   12000.0      DIV
# 3               1.000000   12000.0      DIV
# 4               1.000000   12000.0      DIV

# %%
preds
# Out:
#                       element_id      x           y     width  height  \
# 0   0007298009508983776973430857    0.0   816.00000  250.0000    48.0
# 1   4360116549508983773404703197    0.0   960.00000  250.0000    48.0
# 2   6155197458508983770363422365    0.0   864.00000  250.0000    48.0
# 3   5910946150508983777282063641    0.0  1008.00000  250.0000    48.0
# 4   5814732757508983773563288955    0.0  1728.00000  250.0000    48.0
# ..                           ...    ...         ...       ...     ...
# 73  5392140204508983770841967968  274.0   547.96875  400.0000    28.0
# 74  6828650893508983772174553548  274.0   842.90625  400.0000    28.0
# 75  8412303520508983779166095264  274.0  1097.84375   28.0000   300.0
# 76  7083630139508983770108029883  274.0   167.81250  268.5625    28.0
# 77  3186594651508983774322002059  314.0   970.37500  152.0000    28.0
#
#    predicted_label  predicted_probability  sort_key
# 0           button               0.999993  12000.00
# 1           button               1.000000  12000.00
# 2           button               1.000000  12000.00
# 3           button               1.000000  12000.00
# 4           button               1.000000  12000.00
# ..             ...                    ...       ...
# 73          slider               1.000000  11200.00
# 74          slider               1.000000  11200.00
# 75          slider               0.999999   8400.00
# 76          slider               1.000000   7519.75
# 77          slider               1.000000   4256.00
#
# [78 rows x 8 columns]

# %%
from_pkl = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')
from_pkl[from_pkl.element_id == '1049561488694071642269580342']
# Out:
# Empty DataFrame
# Columns: [attributes, displayed, element_id, height, onmouseenter, onmouseover, parent_id, style, tag_name, text, width, x, y]
# Index: []

# %%
# set(df.element_id.values).intersection(set(preds.element_id.values))

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
