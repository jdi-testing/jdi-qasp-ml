# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
WORKING_DIR = re.sub('jdi-qasp-ml.*$','',os.path.normpath(os.getcwd())) + 'jdi-qasp-ml'
os.chdir(WORKING_DIR)

# %%
WORKING_DIR
# Out:
# 'C:\\WORK\\jdi-qasp-ml'

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-09-06 15:17:50,672 -INFO - config.py:25 - Module utils.config was loaded
# 2021-09-06 15:17:50,677 -INFO - common.py:618 - Module utils.common is loaded...
# 2021-09-06 15:17:50,682 -INFO - hidden.py:121 - hidden module is loaded
# 2021-09-06 15:17:50,687 -INFO - features_builder.py:305 - feature_bilder module is loaded...
# 2021-09-06 15:17:50,693 -INFO - dataset_builder.py:213 - dataset package is loaded...
# 2021-09-06 15:17:50,699 -INFO - dataset.py:277 - dataset module is loaded...

# %%
UTILS_LOGGER = 'utils.dataset'
LOG_FILE_PATH = 'tmp/log.txt'

os.makedirs(name='tmp', exist_ok=True)

logger = logging.getLogger(UTILS_LOGGER)
logger.setLevel(logging.DEBUG)


formatter = logging.Formatter('%(asctime)s -%(levelname)s - %(module)s:%(filename)s:%(lineno)d - %(message)s')

console_handler = logging.StreamHandler(sys.stdout)
console_handler.setFormatter(formatter)

file_handler = logging.FileHandler(filename=LOG_FILE_PATH, mode='w')
file_handler.setFormatter(formatter)

logger.addHandler(console_handler)
logger.addHandler(file_handler)

logger.info('Module utils.config was loaded')
# Out:
# 2021-09-06 15:18:00,820 -INFO - 632196539.py:21 - Module utils.config was loaded
# 2021-09-06 15:18:00,820 -INFO - 632196539:632196539.py:21 - Module utils.config was loaded

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# 'C:\\WORK\\jdi-qasp-ml'

# %% [markdown]
# Below we regenerate datasets we used, after applying changes to DatasetBuilder (.pkl storage and dataset_root_path parameter)

# %%
SITE_URLS = [ p.replace("\\", "/") +"/index.html" for p in glob(f'{os.getcwd()}/MUI_model/dataset/build/*')]
DATASET_NAMES = [ re.search('site[0-9]+', nm)[0] for nm in SITE_URLS]
DATASET_NAMES = ['mui-' + name for name in DATASET_NAMES]

# %%
class JDIDatasetBuilder(DatasetBuilder):

    def setUp(self, driver):
        self.logger.info(f'getting page')
        driver.get(self.url)
        #driver.set_window_size(width=1500, height=8000)
        maximize_window(driver)
        sleep(WAIT_TIME_SECONDS)
        
        
with JDIDatasetBuilder(url=SITE_URLS[0], 
                       dataset_name=DATASET_NAMES[0], 
                       headless=True, 
                       dataset_root_path='./MUI_model/dataset/') as builder:
    
    elements_df = builder.dataset
    dataset_json = builder.dataset_json
    plt.imshow(plt.imread(f'./MUI_model/dataset/images/{DATASET_NAMES[0]}.png'))
    
    
# builder = JDIDatasetBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True)
# elements_df = builder.dataset
# plt.imshow(plt.imread(f'dataset/images/{DATASET_NAME}.png'))
# Out:
# 2021-09-06 13:07:30,295 -INFO - dataset_builder.py:78 - Dataset name: mui-site1
# 2021-09-06 13:07:30,295 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site1
# 2021-09-06 13:07:30,298 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-09-06 13:07:30,298 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-09-06 13:07:30,301 -INFO - dataset_builder.py:126 - Creating driver
# 2021-09-06 13:07:30,301 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# C:\Users\NINA_P~1\AppData\Local\Temp/ipykernel_13748/3704720344.py in <module>
#      12                        dataset_name=DATASET_NAMES[0],
#      13                        headless=True,
# ---> 14                        dataset_root_path='./MUI_model/dataset/') as builder:
#      15
#      16     elements_df = builder.dataset
#
# C:\WORK\jdi-qasp-ml\utils\dataset_builder.py in __init__(self, url, dataset_name, headless, dataset_root_path)
#      98         os.makedirs(f'{self.root_path}/cache-labels', exist_ok=True)
#      99
# --> 100         self.__enter__()
#     101
#     102     def __exit__(self, exc_type, exc_val, exc_tb):
#
# C:\WORK\jdi-qasp-ml\utils\dataset_builder.py in __enter__(self)
#     131         if os.path.exists(chrome_driver_path):
#     132             self.driver = selenium.webdriver.Chrome(
# --> 133                 executable_path=chrome_driver_path, options=self.options)
#     134         else:
#     135             raise FileNotFoundError(f"chromedriver.exe  {os.getcwd()}")
#
# ~\Miniconda3\envs\py37-torch\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# ~\Miniconda3\envs\py37-torch\lib\site-packages\selenium\webdriver\remote\webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     155             warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                           DeprecationWarning, stacklevel=2)
# --> 157         self.start_session(capabilities, browser_profile)
#     158         self._switch_to = SwitchTo(self)
#     159         self._mobile = Mobile(self)
#
# ~\Miniconda3\envs\py37-torch\lib\site-packages\selenium\webdriver\remote\webdriver.py in start_session(self, capabilities, browser_profile)
#     250         parameters = {"capabilities": w3c_caps,
#     251                       "desiredCapabilities": capabilities}
# --> 252         response = self.execute(Command.NEW_SESSION, parameters)
#     253         if 'sessionId' not in response:
#     254             response = response['value']
#
# ~\Miniconda3\envs\py37-torch\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Miniconda3\envs\py37-torch\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 91
# Current browser version is 93.0.4577.63 with binary path C:\Program Files\Google\Chrome\Application\chrome.exe

# %%
def collect_many_ds(site_urls, dataset_names):
    
    all_dfs = []
    
    with trange(len(site_urls)) as bar:

        for site, ds_name in zip(site_urls, dataset_names):
            
            class JDIDatasetBuilder(DatasetBuilder):
                def setUp(self, driver):
                    self.logger.info(f'getting page')
                    driver.get(self.url)
                    maximize_window(driver=driver)
                    sleep(WAIT_TIME_SECONDS)

            with JDIDatasetBuilder(url=site, 
                                   dataset_name=ds_name, 
                                   headless=True,
                                   dataset_root_path='./MUI_model/dataset/'
                                  ) as builder:
                elements_df = builder.dataset
                dataset_json = builder.dataset_json
                elements_df['idx'] = elements_df.index
                elements_df['ds_name'] = ds_name
                # plt.imshow(plt.imread(f'dataset/images/{ds_name}.png'))
                all_dfs.append(elements_df)
                
            bar.update(1)
            
    df_sites = pd.concat(all_dfs, axis=0)      
    return df_sites

# %%
elements_df = collect_many_ds(SITE_URLS, DATASET_NAMES)
elements_df.to_pickle('MUI_model/dataset/elements_df.pkl')
# Out:
#   0%|          | 0/122 [00:00<?, ?it/s]
# 2021-08-30 14:03:44,333 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site1
# 2021-08-30 14:03:44,333 -INFO - dataset_builder.py:78 - Dataset name: mui-site1
# 2021-08-30 14:03:44,339 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:03:44,339 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:03:44,345 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:03:44,345 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:03:45,466 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:03:45,466 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:03:45,469 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:03:45,469 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:03:46,009 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:03:46,009 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:03:49,025 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site1.png
# 2021-08-30 14:03:49,025 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site1.png
# 2021-08-30 14:03:49,587 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:03:49,587 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:03:51,188 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site1.html
# 2021-08-30 14:03:51,188 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site1.html
# 2021-08-30 14:03:51,226 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site1.pkl
# 2021-08-30 14:03:51,226 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site1.pkl
# 2021-08-30 14:03:51,231 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (21, 13)
# 2021-08-30 14:03:51,231 -INFO - dataset_builder.py:204 - No attributes: (21, 13)
# 2021-08-30 14:03:51,502 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:03:51,502 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:03:51,587 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site10
# 2021-08-30 14:03:51,587 -INFO - dataset_builder.py:78 - Dataset name: mui-site10
# 2021-08-30 14:03:51,590 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:03:51,590 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:03:51,596 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:03:51,596 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:03:52,687 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:03:52,687 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:03:52,692 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:03:52,692 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:03:53,264 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:03:53,264 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:03:56,272 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site10.png
# 2021-08-30 14:03:56,272 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site10.png
# 2021-08-30 14:03:56,723 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:03:56,723 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:03:58,418 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site10.html
# 2021-08-30 14:03:58,418 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site10.html
# 2021-08-30 14:03:58,455 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site10.pkl
# 2021-08-30 14:03:58,455 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site10.pkl
# 2021-08-30 14:03:58,461 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (24, 13)
# 2021-08-30 14:03:58,461 -INFO - dataset_builder.py:204 - No attributes: (24, 13)
# 2021-08-30 14:03:58,677 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:03:58,677 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:03:58,764 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site100
# 2021-08-30 14:03:58,764 -INFO - dataset_builder.py:78 - Dataset name: mui-site100
# 2021-08-30 14:03:58,768 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:03:58,768 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:03:58,772 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:03:58,772 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:03:59,907 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:03:59,907 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:03:59,910 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:03:59,910 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:04:00,470 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:04:00,470 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:04:03,487 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site100.png
# 2021-08-30 14:04:03,487 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site100.png
# 2021-08-30 14:04:03,878 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:03,878 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:05,556 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site100.html
# 2021-08-30 14:04:05,556 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site100.html
# 2021-08-30 14:04:05,593 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site100.pkl
# 2021-08-30 14:04:05,593 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site100.pkl
# 2021-08-30 14:04:05,598 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (23, 13)
# 2021-08-30 14:04:05,598 -INFO - dataset_builder.py:204 - No attributes: (23, 13)
# 2021-08-30 14:04:05,813 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:05,813 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:05,897 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site101
# 2021-08-30 14:04:05,897 -INFO - dataset_builder.py:78 - Dataset name: mui-site101
# 2021-08-30 14:04:05,900 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:05,900 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:05,907 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:05,907 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:06,994 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:06,994 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:06,996 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:04:06,996 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:04:07,549 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:04:07,549 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:04:10,555 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site101.png
# 2021-08-30 14:04:10,555 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site101.png
# 2021-08-30 14:04:10,868 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:10,868 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:12,878 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site101.html
# 2021-08-30 14:04:12,878 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site101.html
# 2021-08-30 14:04:12,921 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site101.pkl
# 2021-08-30 14:04:12,921 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site101.pkl
# 2021-08-30 14:04:12,928 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (20, 13)
# 2021-08-30 14:04:12,928 -INFO - dataset_builder.py:204 - No attributes: (20, 13)
# 2021-08-30 14:04:13,163 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:13,163 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:13,247 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site102
# 2021-08-30 14:04:13,247 -INFO - dataset_builder.py:78 - Dataset name: mui-site102
# 2021-08-30 14:04:13,251 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:13,251 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:13,256 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:13,256 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:14,375 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:14,375 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:14,378 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:04:14,378 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:04:15,007 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:04:15,007 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:04:18,017 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site102.png
# 2021-08-30 14:04:18,017 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site102.png
# 2021-08-30 14:04:18,663 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:18,663 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:20,891 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site102.html
# 2021-08-30 14:04:20,891 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site102.html
# 2021-08-30 14:04:20,935 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site102.pkl
# 2021-08-30 14:04:20,935 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site102.pkl
# 2021-08-30 14:04:20,940 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (26, 13)
# 2021-08-30 14:04:20,940 -INFO - dataset_builder.py:204 - No attributes: (26, 13)
# 2021-08-30 14:04:21,233 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:21,233 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:21,326 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site103
# 2021-08-30 14:04:21,326 -INFO - dataset_builder.py:78 - Dataset name: mui-site103
# 2021-08-30 14:04:21,331 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:21,331 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:21,336 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:21,336 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:22,460 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:22,460 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:22,463 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:04:22,463 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:04:23,000 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:04:23,000 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:04:26,017 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site103.png
# 2021-08-30 14:04:26,017 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site103.png
# 2021-08-30 14:04:26,543 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:26,543 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:27,904 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site103.html
# 2021-08-30 14:04:27,904 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site103.html
# 2021-08-30 14:04:27,938 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site103.pkl
# 2021-08-30 14:04:27,938 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site103.pkl
# 2021-08-30 14:04:27,944 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (31, 13)
# 2021-08-30 14:04:27,944 -INFO - dataset_builder.py:204 - No attributes: (31, 13)
# 2021-08-30 14:04:28,127 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:28,127 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:28,204 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site104
# 2021-08-30 14:04:28,204 -INFO - dataset_builder.py:78 - Dataset name: mui-site104
# 2021-08-30 14:04:28,207 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:28,207 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:28,211 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:28,211 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:29,317 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:29,317 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:29,321 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:04:29,321 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:04:29,842 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:04:29,842 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:04:32,856 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site104.png
# 2021-08-30 14:04:32,856 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site104.png
# 2021-08-30 14:04:33,261 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:33,261 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:34,677 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site104.html
# 2021-08-30 14:04:34,677 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site104.html
# 2021-08-30 14:04:34,711 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site104.pkl
# 2021-08-30 14:04:34,711 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site104.pkl
# 2021-08-30 14:04:34,716 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (26, 13)
# 2021-08-30 14:04:34,716 -INFO - dataset_builder.py:204 - No attributes: (26, 13)
# 2021-08-30 14:04:34,899 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:34,899 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:34,983 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site105
# 2021-08-30 14:04:34,983 -INFO - dataset_builder.py:78 - Dataset name: mui-site105
# 2021-08-30 14:04:34,986 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:34,986 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:34,992 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:34,992 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:36,113 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:36,113 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:36,116 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:04:36,116 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:04:36,602 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:04:36,602 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:04:39,615 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site105.png
# 2021-08-30 14:04:39,615 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site105.png
# 2021-08-30 14:04:40,241 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:40,241 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:41,491 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site105.html
# 2021-08-30 14:04:41,491 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site105.html
# 2021-08-30 14:04:41,523 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site105.pkl
# 2021-08-30 14:04:41,523 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site105.pkl
# 2021-08-30 14:04:41,529 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (18, 13)
# 2021-08-30 14:04:41,529 -INFO - dataset_builder.py:204 - No attributes: (18, 13)
# 2021-08-30 14:04:41,711 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:41,711 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:41,797 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site106
# 2021-08-30 14:04:41,797 -INFO - dataset_builder.py:78 - Dataset name: mui-site106
# 2021-08-30 14:04:41,800 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:41,800 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:41,805 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:41,805 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:42,923 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:42,923 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:42,926 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:04:42,926 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:04:43,449 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:04:43,449 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:04:46,460 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site106.png
# 2021-08-30 14:04:46,460 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site106.png
# 2021-08-30 14:04:46,752 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:46,752 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:48,114 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site106.html
# 2021-08-30 14:04:48,114 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site106.html
# 2021-08-30 14:04:48,150 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site106.pkl
# 2021-08-30 14:04:48,150 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site106.pkl
# 2021-08-30 14:04:48,156 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (20, 13)
# 2021-08-30 14:04:48,156 -INFO - dataset_builder.py:204 - No attributes: (20, 13)
# 2021-08-30 14:04:48,335 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:48,335 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:48,422 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site107
# 2021-08-30 14:04:48,422 -INFO - dataset_builder.py:78 - Dataset name: mui-site107
# 2021-08-30 14:04:48,425 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:48,425 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:48,430 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:48,430 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:49,549 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:49,549 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:49,552 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:04:49,552 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:04:50,090 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:04:50,090 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:04:53,095 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site107.png
# 2021-08-30 14:04:53,095 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site107.png
# 2021-08-30 14:04:53,438 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:53,438 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:04:54,795 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site107.html
# 2021-08-30 14:04:54,795 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site107.html
# 2021-08-30 14:04:54,834 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site107.pkl
# 2021-08-30 14:04:54,834 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site107.pkl
# 2021-08-30 14:04:54,840 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (23, 13)
# 2021-08-30 14:04:54,840 -INFO - dataset_builder.py:204 - No attributes: (23, 13)
# 2021-08-30 14:04:55,031 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:55,031 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:04:55,128 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site108
# 2021-08-30 14:04:55,128 -INFO - dataset_builder.py:78 - Dataset name: mui-site108
# 2021-08-30 14:04:55,132 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:55,132 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:04:55,139 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:55,139 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:04:56,273 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:56,273 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:04:56,277 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:04:56,277 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:04:56,795 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:04:56,795 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:04:59,810 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site108.png
# 2021-08-30 14:04:59,810 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site108.png
# 2021-08-30 14:05:00,289 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:05:00,289 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:05:03,885 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site108.html
# 2021-08-30 14:05:03,885 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site108.html
# 2021-08-30 14:05:03,934 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site108.pkl
# 2021-08-30 14:05:03,934 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site108.pkl
# 2021-08-30 14:05:03,941 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (21, 13)
# 2021-08-30 14:05:03,941 -INFO - dataset_builder.py:204 - No attributes: (21, 13)
# 2021-08-30 14:05:04,162 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:05:04,162 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:05:04,258 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site109
# 2021-08-30 14:05:04,258 -INFO - dataset_builder.py:78 - Dataset name: mui-site109
# 2021-08-30 14:05:04,262 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:05:04,262 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:05:04,267 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:05:04,267 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:05:05,387 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:05:05,387 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:05:05,390 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:05:05,390 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:05:05,881 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:05:05,881 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:05:08,899 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site109.png
# 2021-08-30 14:05:08,899 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site109.png
# 2021-08-30 14:05:09,295 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:05:09,295 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:05:10,728 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site109.html
# 2021-08-30 14:05:10,728 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site109.html
# 2021-08-30 14:05:10,764 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site109.pkl
# 2021-08-30 14:05:10,764 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site109.pkl
# 2021-08-30 14:05:10,769 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (28, 13)
# 2021-08-30 14:05:10,769 -INFO - dataset_builder.py:204 - No attributes: (28, 13)
# 2021-08-30 14:05:10,982 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:05:10,982 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:05:11,070 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site11
# 2021-08-30 14:05:11,070 -INFO - dataset_builder.py:78 - Dataset name: mui-site11
# 2021-08-30 14:05:11,073 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:05:11,073 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:05:11,082 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:05:11,082 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:05:12,220 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:05:12,220 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:05:12,224 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:05:12,224 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:05:12,875 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:05:12,875 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:05:15,894 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site11.png
# 2021-08-30 14:05:15,894 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site11.png
# 2021-08-30 14:05:16,284 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:05:16,284 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:05:39,397 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site11.html
# 2021-08-30 14:05:39,397 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site11.html
# 2021-08-30 14:05:39,493 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site11.pkl
# 2021-08-30 14:05:39,493 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site11.pkl
# 2021-08-30 14:05:39,499 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (33, 13)
# 2021-08-30 14:05:39,499 -INFO - dataset_builder.py:204 - No attributes: (33, 13)
# 2021-08-30 14:05:39,964 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:05:39,964 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:05:40,058 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site110
# 2021-08-30 14:05:40,058 -INFO - dataset_builder.py:78 - Dataset name: mui-site110
# 2021-08-30 14:05:40,063 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:05:40,063 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:05:40,068 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:05:40,068 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:05:41,135 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:05:41,135 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:05:41,138 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:05:41,138 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:05:41,684 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:05:41,684 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:05:44,691 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site110.png
# 2021-08-30 14:05:44,691 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site110.png
# 2021-08-30 14:05:45,067 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:05:45,067 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:05:46,716 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site110.html
# 2021-08-30 14:05:46,716 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site110.html
# 2021-08-30 14:05:46,751 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site110.pkl
# 2021-08-30 14:05:46,751 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site110.pkl
# 2021-08-30 14:05:46,757 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (16, 13)
# 2021-08-30 14:05:46,757 -INFO - dataset_builder.py:204 - No attributes: (16, 13)
# 2021-08-30 14:05:46,972 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:05:46,972 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:05:47,053 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site111
# 2021-08-30 14:05:47,053 -INFO - dataset_builder.py:78 - Dataset name: mui-site111
# 2021-08-30 14:05:47,058 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:05:47,058 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:05:47,062 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:05:47,062 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:05:48,172 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:05:48,172 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:05:48,175 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:05:48,175 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:05:48,742 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:05:48,742 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:05:51,755 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site111.png
# 2021-08-30 14:05:51,755 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site111.png
# 2021-08-30 14:05:52,238 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:05:52,238 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:05:54,198 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site111.html
# 2021-08-30 14:05:54,198 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site111.html
# 2021-08-30 14:05:54,241 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site111.pkl
# 2021-08-30 14:05:54,241 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site111.pkl
# 2021-08-30 14:05:54,247 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (17, 13)
# 2021-08-30 14:05:54,247 -INFO - dataset_builder.py:204 - No attributes: (17, 13)
# 2021-08-30 14:05:54,517 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:05:54,517 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:05:54,609 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site112
# 2021-08-30 14:05:54,609 -INFO - dataset_builder.py:78 - Dataset name: mui-site112
# 2021-08-30 14:05:54,612 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:05:54,612 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:05:54,617 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:05:54,617 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:05:55,746 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:05:55,746 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:05:55,750 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:05:55,750 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:05:56,285 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:05:56,285 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:05:59,303 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site112.png
# 2021-08-30 14:05:59,303 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site112.png
# 2021-08-30 14:05:59,696 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:05:59,696 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:06:01,440 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site112.html
# 2021-08-30 14:06:01,440 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site112.html
# 2021-08-30 14:06:01,481 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site112.pkl
# 2021-08-30 14:06:01,481 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site112.pkl
# 2021-08-30 14:06:01,488 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (22, 13)
# 2021-08-30 14:06:01,488 -INFO - dataset_builder.py:204 - No attributes: (22, 13)
# 2021-08-30 14:06:01,731 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:06:01,731 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:06:01,825 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site113
# 2021-08-30 14:06:01,825 -INFO - dataset_builder.py:78 - Dataset name: mui-site113
# 2021-08-30 14:06:01,829 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:06:01,829 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:06:01,833 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:06:01,833 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:06:02,954 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:06:02,954 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:06:02,957 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:06:02,957 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:06:03,429 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:06:03,429 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:06:06,437 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site113.png
# 2021-08-30 14:06:06,437 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site113.png
# 2021-08-30 14:06:06,790 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:06:06,790 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:06:07,916 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site113.html
# 2021-08-30 14:06:07,916 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site113.html
# 2021-08-30 14:06:07,948 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site113.pkl
# 2021-08-30 14:06:07,948 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site113.pkl
# 2021-08-30 14:06:07,952 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (21, 13)
# 2021-08-30 14:06:07,952 -INFO - dataset_builder.py:204 - No attributes: (21, 13)
# 2021-08-30 14:06:08,075 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:06:08,075 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:06:08,167 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site114
# 2021-08-30 14:06:08,167 -INFO - dataset_builder.py:78 - Dataset name: mui-site114
# 2021-08-30 14:06:08,168 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:06:08,168 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:06:08,175 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:06:08,175 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:06:09,171 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:06:09,171 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:06:09,174 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:06:09,174 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:06:09,691 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:06:09,691 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:06:12,701 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site114.png
# 2021-08-30 14:06:12,701 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site114.png
# 2021-08-30 14:06:13,125 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:06:13,125 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:06:14,622 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site114.html
# 2021-08-30 14:06:14,622 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site114.html
# 2021-08-30 14:06:14,654 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site114.pkl
# 2021-08-30 14:06:14,654 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site114.pkl
# 2021-08-30 14:06:14,660 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (27, 13)
# 2021-08-30 14:06:14,660 -INFO - dataset_builder.py:204 - No attributes: (27, 13)
# 2021-08-30 14:06:14,855 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:06:14,855 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:06:14,935 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site115
# 2021-08-30 14:06:14,935 -INFO - dataset_builder.py:78 - Dataset name: mui-site115
# 2021-08-30 14:06:14,939 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:06:14,939 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:06:14,945 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:06:14,945 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:06:15,972 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:06:15,972 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:06:15,975 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:06:15,975 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:06:16,623 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:06:16,623 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:06:19,635 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site115.png
# 2021-08-30 14:06:19,635 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site115.png
# 2021-08-30 14:06:20,174 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:06:20,174 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:06:24,612 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site115.html
# 2021-08-30 14:06:24,612 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site115.html
# 2021-08-30 14:06:24,698 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site115.pkl
# 2021-08-30 14:06:24,698 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site115.pkl
# 2021-08-30 14:06:24,706 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (21, 13)
# 2021-08-30 14:06:24,706 -INFO - dataset_builder.py:204 - No attributes: (21, 13)
# 2021-08-30 14:06:25,062 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:06:25,062 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:06:25,152 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site116
# 2021-08-30 14:06:25,152 -INFO - dataset_builder.py:78 - Dataset name: mui-site116
# 2021-08-30 14:06:25,155 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:06:25,155 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:06:25,162 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:06:25,162 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:06:26,293 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:06:26,293 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:06:26,298 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:06:26,298 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:06:26,956 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:06:26,956 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:06:29,968 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site116.png
# 2021-08-30 14:06:29,968 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site116.png
# 2021-08-30 14:06:30,510 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:06:30,510 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:06:32,790 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site116.html
# 2021-08-30 14:06:32,790 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site116.html
# 2021-08-30 14:06:32,835 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site116.pkl
# 2021-08-30 14:06:32,835 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site116.pkl
# 2021-08-30 14:06:32,841 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (25, 13)
# 2021-08-30 14:06:32,841 -INFO - dataset_builder.py:204 - No attributes: (25, 13)
# 2021-08-30 14:06:33,125 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:06:33,125 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:06:33,210 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site117
# 2021-08-30 14:06:33,210 -INFO - dataset_builder.py:78 - Dataset name: mui-site117
# 2021-08-30 14:06:33,214 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:06:33,214 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:06:33,221 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:06:33,221 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:06:34,322 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:06:34,322 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:06:34,325 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:06:34,325 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:06:34,925 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:06:34,925 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:06:37,944 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site117.png
# 2021-08-30 14:06:37,944 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site117.png
# 2021-08-30 14:06:38,343 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:06:38,343 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:06:40,656 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site117.html
# 2021-08-30 14:06:40,656 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site117.html
# 2021-08-30 14:06:40,701 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site117.pkl
# 2021-08-30 14:06:40,701 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site117.pkl
# 2021-08-30 14:06:40,706 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (26, 13)
# 2021-08-30 14:06:40,706 -INFO - dataset_builder.py:204 - No attributes: (26, 13)
# 2021-08-30 14:06:40,988 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:06:40,988 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:06:41,080 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site118
# 2021-08-30 14:06:41,080 -INFO - dataset_builder.py:78 - Dataset name: mui-site118
# ...
# 2021-08-30 14:21:24,622 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:21:24,718 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site93
# 2021-08-30 14:21:24,718 -INFO - dataset_builder.py:78 - Dataset name: mui-site93
# 2021-08-30 14:21:24,722 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:21:24,722 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:21:24,729 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:21:24,729 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:21:25,842 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:21:25,842 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:21:25,845 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:21:25,845 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:21:26,408 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:21:26,408 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:21:29,413 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site93.png
# 2021-08-30 14:21:29,413 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site93.png
# 2021-08-30 14:21:30,060 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:21:30,060 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:21:31,872 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site93.html
# 2021-08-30 14:21:31,872 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site93.html
# 2021-08-30 14:21:31,915 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site93.pkl
# 2021-08-30 14:21:31,915 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site93.pkl
# 2021-08-30 14:21:31,921 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (32, 13)
# 2021-08-30 14:21:31,921 -INFO - dataset_builder.py:204 - No attributes: (32, 13)
# 2021-08-30 14:21:32,167 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:21:32,167 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:21:32,246 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site94
# 2021-08-30 14:21:32,246 -INFO - dataset_builder.py:78 - Dataset name: mui-site94
# 2021-08-30 14:21:32,249 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:21:32,249 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:21:32,254 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:21:32,254 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:21:33,321 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:21:33,321 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:21:33,323 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:21:33,323 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:21:33,969 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:21:33,969 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:21:36,985 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site94.png
# 2021-08-30 14:21:36,985 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site94.png
# 2021-08-30 14:21:37,416 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:21:37,416 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:21:39,791 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site94.html
# 2021-08-30 14:21:39,791 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site94.html
# 2021-08-30 14:21:39,836 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site94.pkl
# 2021-08-30 14:21:39,836 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site94.pkl
# 2021-08-30 14:21:39,842 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (24, 13)
# 2021-08-30 14:21:39,842 -INFO - dataset_builder.py:204 - No attributes: (24, 13)
# 2021-08-30 14:21:40,158 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:21:40,158 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:21:40,255 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site95
# 2021-08-30 14:21:40,255 -INFO - dataset_builder.py:78 - Dataset name: mui-site95
# 2021-08-30 14:21:40,259 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:21:40,259 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:21:40,265 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:21:40,265 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:21:41,399 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:21:41,399 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:21:41,403 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:21:41,403 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:21:42,046 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:21:42,046 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:21:45,063 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site95.png
# 2021-08-30 14:21:45,063 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site95.png
# 2021-08-30 14:21:45,749 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:21:45,749 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:21:47,924 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site95.html
# 2021-08-30 14:21:47,924 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site95.html
# 2021-08-30 14:21:47,967 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site95.pkl
# 2021-08-30 14:21:47,967 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site95.pkl
# 2021-08-30 14:21:47,972 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (30, 13)
# 2021-08-30 14:21:47,972 -INFO - dataset_builder.py:204 - No attributes: (30, 13)
# 2021-08-30 14:21:48,251 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:21:48,251 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:21:48,334 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site96
# 2021-08-30 14:21:48,334 -INFO - dataset_builder.py:78 - Dataset name: mui-site96
# 2021-08-30 14:21:48,338 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:21:48,338 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:21:48,345 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:21:48,345 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:21:49,443 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:21:49,443 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:21:49,446 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:21:49,446 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:21:50,020 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:21:50,020 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:21:53,029 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site96.png
# 2021-08-30 14:21:53,029 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site96.png
# 2021-08-30 14:21:53,478 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:21:53,478 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:21:55,553 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site96.html
# 2021-08-30 14:21:55,553 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site96.html
# 2021-08-30 14:21:55,609 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site96.pkl
# 2021-08-30 14:21:55,609 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site96.pkl
# 2021-08-30 14:21:55,613 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (27, 13)
# 2021-08-30 14:21:55,613 -INFO - dataset_builder.py:204 - No attributes: (27, 13)
# 2021-08-30 14:21:55,882 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:21:55,882 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:21:55,966 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site97
# 2021-08-30 14:21:55,966 -INFO - dataset_builder.py:78 - Dataset name: mui-site97
# 2021-08-30 14:21:55,969 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:21:55,969 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:21:55,973 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:21:55,973 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:21:57,083 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:21:57,083 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:21:57,086 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:21:57,086 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:21:57,575 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:21:57,575 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:22:00,581 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site97.png
# 2021-08-30 14:22:00,581 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site97.png
# 2021-08-30 14:22:00,957 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:22:00,957 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:22:02,162 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site97.html
# 2021-08-30 14:22:02,162 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site97.html
# 2021-08-30 14:22:02,196 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site97.pkl
# 2021-08-30 14:22:02,196 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site97.pkl
# 2021-08-30 14:22:02,201 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (28, 13)
# 2021-08-30 14:22:02,201 -INFO - dataset_builder.py:204 - No attributes: (28, 13)
# 2021-08-30 14:22:02,363 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:22:02,363 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:22:02,455 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site98
# 2021-08-30 14:22:02,455 -INFO - dataset_builder.py:78 - Dataset name: mui-site98
# 2021-08-30 14:22:02,458 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:22:02,458 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:22:02,465 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:22:02,465 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:22:03,596 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:22:03,596 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:22:03,599 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:22:03,599 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:22:04,139 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:22:04,139 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:22:07,146 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site98.png
# 2021-08-30 14:22:07,146 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site98.png
# 2021-08-30 14:22:07,454 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:22:07,454 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:22:09,148 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site98.html
# 2021-08-30 14:22:09,148 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site98.html
# 2021-08-30 14:22:09,182 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site98.pkl
# 2021-08-30 14:22:09,182 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site98.pkl
# 2021-08-30 14:22:09,187 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (21, 13)
# 2021-08-30 14:22:09,187 -INFO - dataset_builder.py:204 - No attributes: (21, 13)
# 2021-08-30 14:22:09,424 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:22:09,424 -INFO - dataset_builder.py:103 - Close web driver
# 2021-08-30 14:22:09,508 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site99
# 2021-08-30 14:22:09,508 -INFO - dataset_builder.py:78 - Dataset name: mui-site99
# 2021-08-30 14:22:09,512 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:22:09,512 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-08-30 14:22:09,517 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-08-30 14:22:09,517 -INFO - dataset_builder.py:126 - Creating driver
# 2021-08-30 14:22:10,616 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:22:10,616 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-08-30 14:22:10,618 -INFO - 2387718061:2387718061.py:11 - getting page
# 2021-08-30 14:22:10,618 -INFO - 2387718061.py:11 - getting page
# 2021-08-30 14:22:11,173 -INFO - common:common.py:75 - Window maximized
# 2021-08-30 14:22:11,173 -INFO - common.py:75 - Window maximized
# 2021-08-30 14:22:14,190 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site99.png
# 2021-08-30 14:22:14,190 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site99.png
# 2021-08-30 14:22:14,637 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:22:14,637 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-08-30 14:22:16,364 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site99.html
# 2021-08-30 14:22:16,364 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site99.html
# 2021-08-30 14:22:16,406 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site99.pkl
# 2021-08-30 14:22:16,406 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site99.pkl
# 2021-08-30 14:22:16,412 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (25, 13)
# 2021-08-30 14:22:16,412 -INFO - dataset_builder.py:204 - No attributes: (25, 13)
# 2021-08-30 14:22:16,655 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver
# 2021-08-30 14:22:16,655 -INFO - dataset_builder.py:103 - Close web driver

# %%
display(elements_df.shape)
# Out:
# (182727, 15)

# %% [markdown]
# #### Changing functions: using TfIdfTransformer instead of TfIdfVectorizer

# %%
def build_class_feature(df: pd.DataFrame, colname='attributes') -> csr_matrix:
    """
        Extract TfIdf features for "class" attribute from a column
        containing attributes ("attributes", "attributes_parent", "attributes_up_sibling"...)
        default columns: "attributes"
    """
    model_count_file_path = 'MUI_model/model/count_attr_class.pkl'
    model_tf_file_path = 'MUI_model/model/tfidf_attr_class.pkl'
    logger.info(f'used column: {colname}')

    if os.path.exists(model_count_file_path) and os.path.exists(model_tf_file_path):
        logger.info("CountVectorizer and TfidfTransformer for class attribute exist. Loading...")
        with open(model_count_file_path, 'rb') as c:
            model_cv = pickle.load(file=c)
        with open(model_tf_file_path, 'rb') as f:
            model_tf = pickle.load(file=f)
#             print(f'{model_tf!r}')
#         attr_class_series = df[colname].apply(lambda x: x.get('class') if x is not None else '').fillna('')
        attr_class_series = df[colname].apply(lambda x: x.get('class') if x is not None else '').fillna('')
        attr_class_series = attr_class_series.apply(lambda x: x.replace("-", " ").lower())
        class_sm = model_cv.transform(attr_class_series.values)
        class_sm = model_tf.transform(class_sm)
    else:
        logger.info("TfIdfVectorizer for class attribute does not exist. Build the one.")
#         if len(set(df.columns).intersection(set(['label', 'label_text']))) != 2:
#             raise Exception('Cannot prepare CountVectorizer for attribute "class": need labels')

        logger.info("Extract useful attr_class features, 'attributes' column will be used")
        attr_class_series = df[df.label_text != 'n/a']\
            .attributes.apply(lambda x: x.get('class') if x is not None else '')\
            .fillna('')
        attr_class_series = attr_class_series.apply(lambda x: x.replace("-", " ").lower())
        class_vocab = list(itertools.chain.from_iterable(attr_class_series.apply(lambda x: x.split(sep=' '))))
        class_vocab = list(set(class_vocab))
        class_vocab = sorted([v for v in class_vocab if re.match(r'^[a-z][a-z]+$', v)])
        class_cv = CountVectorizer(vocabulary = class_vocab)
        class_sm = class_cv.fit_transform(attr_class_series.values)
        model = TfidfTransformer()
        class_sm = model.fit_transform(class_sm)
        # filter out class names:  length is at least 2 characters and only letters
#         vocabulary = sorted([v for v in class_cv.vocabulary_.keys() if re.match(r'^[a-z][a-z]+$', v)])

        logger.info(f'Column ["{colname}"] used for tfidf')
#         attr_class_series = df[colname].apply(lambda x: None if type(x) is not dict else x.get('class')).fillna('')
#         model = TfidfVectorizer(vocabulary=vocabulary)  # CountVectorizer?
#         model.fit(attr_class_series.values)
        logger.info(f'Saving {model_count_file_path}, vocabulary length: {len(class_cv.vocabulary_)}')
        with open(model_count_file_path, 'wb') as c:
            pickle.dump(class_cv, c)
            c.flush()
        logger.info(f'Saving {model_tf_file_path}')
        with open(model_tf_file_path, 'wb') as f:
            pickle.dump(model, f)
            f.flush()

    return class_sm

# %%
def build_tree_dict(df: pd.DataFrame) -> dict:
    """
        Builds tree dict for
        get_parents_list
        df:pd.DataFrame must have columns: 'parent_id', 'element_id'

    """
    # tree_dict = dict(zip(df.element_id.values, df.parent_id.values))  # old implementation
    tree_dict = {
        r.element_id: None if r.element_id == r.parent_id else r.parent_id
        for _, r in df[['element_id', 'parent_id']].iterrows()
    }

    return tree_dict

# %%
@numba.jit(forceobj=True)
def get_parents_list(tree_dict: dict, element_id: str, paternts_list: list = None) -> list:
    """
        returns ordered list of parent for a element
        starting from root which is the <html/> tag
    """
    if paternts_list is None:
        paternts_list = []

    parent_id = tree_dict.get(element_id)
    if parent_id is None:
        return paternts_list
    else:
        paternts_list.append(parent_id)
        return get_parents_list(tree_dict, element_id=parent_id, paternts_list=paternts_list)

# %%
def build_tree_features(elements_df: pd.DataFrame) -> pd.DataFrame:
    """
        Walk on elements tree and build tree-features:
           - chilren_tags
           - folloer_counters
    """

    def empty_string():
        return ''

    tree_dict = build_tree_dict(elements_df)

    # Build paths
    followers_counter = Counter()
    # level_dict = defaultdict(int)
    children_tags_dict = defaultdict(empty_string)

    with trange(elements_df.shape[0]) as tbar:
        tbar.set_description('Build tree features')
        for i, r in elements_df.iterrows():
            list_of_parents = get_parents_list(
                tree_dict=tree_dict, element_id=r.element_id)
            children_tags_dict[r.parent_id] += r.tag_name.lower() + ' '
            # print(list_of_parents)
            # calculate number of followers
            followers_counter.update(list_of_parents)
            tbar.update(1)

    elements_df['children_tags'] = elements_df.element_id.map(
        children_tags_dict).fillna('')
    elements_df['num_followers'] = elements_df.element_id.map(
        followers_counter)
    return elements_df

# %%
def followers_features(df: pd.DataFrame, followers_set: set = None, level=0) -> pd.DataFrame:
    """
        Build feature: "children_tags" and max reverse depth ( depth from leafs) # noqa
        Concatenate all children tag_names into a string filed 'children_tags'
    """
    # get leafs (nodes without children)
    if followers_set is None:
        level = 0
        followers_set = set(df.element_id.values) - set(df.parent_id.values)
        followers_tags_df = \
            df[df.element_id.isin(followers_set)][['parent_id', 'tag_name']]\
            .groupby('parent_id')['tag_name']\
            .apply(lambda x: ','.join(x))\
            .reset_index()
        followers_tags_dict = dict(followers_tags_df.values)
        df['followers_tags'] = df.element_id.map(
            followers_tags_dict).fillna('')

        # create max_depth field
        df['max_depth'] = 0
        df.max_depth = df.max_depth + \
            df.element_id.isin(set(followers_tags_dict.keys())).astype(int)

        # recursive call
        followers_features(df=df, followers_set=set(
            followers_tags_dict.keys()), level=level + 1)

    elif len(followers_set) > 0:
        # print(f'level: {level}')
        followers_tags_df = \
            df[df.element_id.isin(followers_set)][['parent_id', 'tag_name']]\
            .groupby('parent_id')['tag_name']\
            .apply(lambda x: ','.join(x))\
            .reset_index()
        followers_tags_dict = dict(followers_tags_df.values)
        df['followers_tags'] = df.followers_tags + ',' + \
            df.element_id.map(followers_tags_dict).fillna('')

        # increase max_depth
        df.max_depth = df.max_depth + \
            df.element_id.isin(set(followers_tags_dict.keys())).astype(int)

        # recursive call
        followers_features(df=df, followers_set=set(
            followers_tags_dict.keys()), level=level + 1)

    df['followers_tags'] = df['followers_tags'].apply(
        lambda x: re.sub('\\s+', ' ', x.replace(',', ' ')).lower().strip())
    return df

# %%
def build_children_tags(df: pd.DataFrame, colname='children_tags') -> csr_matrix:
    model_count_path = 'MUI_model/model/count_children_tags.pkl'
    model_tf_path = 'MUI_model/model/tfidf_children_tags.pkl'
    logger.info(f'used column: {colname}')

    if os.path.exists(model_count_path) and os.path.exists(model_tf_path):
        logger.info("CountVectorizer and TfidfTransformer for children tags exist. Loading...")
        with open(model_count_path, 'rb') as c:
            model_cv = pickle.load(file=c)
        with open(model_tf_path, 'rb') as f:
            model_tf = pickle.load(file=f)
        
        child_tags_series = df[colname].fillna('')
        child_tags_series = child_tags_series.apply(lambda x: x.strip() if x != '' else x)
        child_sm = model_cv.transform(child_tags_series.values)
        child_sm = model_tf.transform(child_sm)

    else:
        logger.info("TfIdfVectorizer for children tags does not exist. Build the one.")
#         if len(set(df.columns).intersection(set(['label', 'label_text']))) != 2:
#             raise Exception('Cannot prepare CountVectorizer for attribute "class": need labels')

        logger.info("Extract useful child_tags features, 'children_tags' column will be used")
        child_tags_series =  df[colname].fillna('')
        child_vocab = list(itertools.chain.from_iterable(child_tags_series.apply(lambda x: x.split(sep=' '))))
        child_vocab = list(set(child_vocab))
        child_vocab = sorted([v for v in child_vocab if re.match(r'^[a-z][a-z]+$', v)])
        
        child_cv = CountVectorizer(vocabulary=child_vocab)
        child_sm = child_cv.fit_transform(child_tags_series.values)

        logger.info(f'Column ["{colname}"] used for tfidf')
        
        model = TfidfTransformer()
        child_sm = model.fit_transform(child_sm)
        
        logger.info(f'Saving {model_count_path}, vocabulary length: {len(child_cv.vocabulary_)}')
        logger.info(f'Saving {model_tf_path}')
        with open(model_count_path, 'wb') as c:
            pickle.dump(child_cv, c)
            c.flush()
        with open(model_tf_path, 'wb') as f:
            pickle.dump(model, f)
            f.flush()

    return child_sm

# %%
def build_followers_tags(df: pd.DataFrame, colname='followers_tags') -> csr_matrix:
    model_count_path = 'MUI_model/model/count_followers_tags.pkl'
    model_tf_path = 'MUI_model/model/tfidf_followers_tags.pkl'
    logger.info(f'used column: {colname}')

    if os.path.exists(model_count_path) and os.path.exists(model_tf_path):
        logger.info("CountVectorizer and TfidfTransformer for followers tags exist. Loading...")
        with open(model_count_path, 'rb') as c:
            model_cv = pickle.load(file=c)
        with open(model_tf_path, 'rb') as f:
            model_tf = pickle.load(file=f)
        
        followers_tags_series = df[colname].fillna('')
        followers_tags_series = followers_tags_series.apply(lambda x: x.strip() if x != '' else x)
        followers_sm = model_cv.transform(followers_tags_series.values)
        followers_sm = model_tf.transform(followers_sm)

    else:
        logger.info("CountVectorizer and TfIdfTransformer for followers tags do not exist. Build them.")
#         if len(set(df.columns).intersection(set(['label', 'label_text']))) != 2:
#             raise Exception('Cannot prepare CountVectorizer for attribute "class": need labels')

        logger.info("Extract useful child_tags features, 'followers_tags' column will be used")
        followers_tags_series =  df[colname].fillna('')
        followers_vocab = list(itertools.chain.from_iterable(followers_tags_series.apply(lambda x: x.split(sep=' '))))
        followers_vocab = list(set(followers_vocab))
        followers_vocab = sorted([v for v in followers_vocab if re.match(r'^[a-z][a-z]+$', v)])
        
        followers_cv = CountVectorizer(vocabulary=followers_vocab)
        followers_sm = followers_cv.fit_transform(followers_tags_series.values)

        logger.info(f'Column ["{colname}"] used for tfidf')
        
        model = TfidfTransformer()
        followers_sm = model.fit_transform(followers_sm)
        
        logger.info(f'Saving {model_count_path}, vocabulary length: {len(followers_cv.vocabulary_)}')
        logger.info(f'Saving {model_tf_path}')
        with open(model_count_path, 'wb') as c:
            pickle.dump(followers_cv, c)
            c.flush()
        with open(model_tf_path, 'wb') as f:
            pickle.dump(model, f)
            f.flush()

    return followers_sm

# %%
elements_df['label_text'] =  elements_df.attributes.apply(lambda x: x.get('data-label') if x is not None else None).fillna('n/a')

# %%
followers_features(elements_df)
# Out:
#                                                attributes  displayed  \
# 0                                          {'lang': 'en'}      False
# 1                                                    None      False
# 2                                    {'charset': 'utf-8'}      False
# 3                {'href': './favicon.ico', 'rel': 'icon'}      False
# 4       {'content': 'width=device-width,initial-scale=...      False
# ...                                                   ...        ...
# 182722      {'data-test': 'sentinelEnd', 'tabindex': '0'}      False
# 182723  {'data-label': 'popper', 'role': 'tooltip', 's...       True
# 182724                                 {'class': 'jss11'}       True
# 182725                                               None       True
# 182726                                               None       True
#
#                           element_id       height onmouseenter onmouseover  \
# 0       5313751051214295958780828823  24307.71875         None        None
# 1       9972128381214295958976818296      0.00000         None        None
# 2       1422379309214295952079575008      0.00000         None        None
# 3       3794611023214295951238901967      0.00000         None        None
# 4       7491848177214295950995160010      0.00000         None        None
# ...                              ...          ...          ...         ...
# 182722  9643588738225346508842760690      0.00000         None        None
# 182723  6253881103225346501377423261     38.00000         None        None
# 182724  3681047993225346505640883357     38.00000         None        None
# 182725  0082313773225346501113264030     16.00000         None        None
# 182726  5206660754225346504351626589     16.00000         None        None
#
#                            parent_id  \
# 0                               None
# 1       5313751051214295958780828823
# 2       9972128381214295958976818296
# 3       9972128381214295958976818296
# 4       9972128381214295958976818296
# ...                              ...
# 182722  7741191648225346505783329108
# 182723  0201343053225346488931122608
# 182724  6253881103225346501377423261
# 182725  0201343053225346488931122608
# 182726  0201343053225346488931122608
#
#                                                     style tag_name  \
# 0       [align-content, align-items, align-self, align...     HTML
# 1       [align-content, align-items, align-self, align...     HEAD
# 2       [align-content, align-items, align-self, align...     META
# 3       [align-content, align-items, align-self, align...     LINK
# 4       [align-content, align-items, align-self, align...     META
# ...                                                   ...      ...
# 182722  [align-content, align-items, align-self, align...      DIV
# 182723  [align-content, align-items, align-self, align...      DIV
# 182724  [align-content, align-items, align-self, align...      DIV
# 182725  [align-content, align-items, align-self, align...     SPAN
# 182726  [align-content, align-items, align-self, align...     SPAN
#
#                                                      text       width  \
# 0       Recents\nFavorites\nNearby\nInbox\nStarred\nSe...  877.000000
# 1       React App\n.MuiSvgIcon-root {\n  fill: current...    0.000000
# 2                                                            0.000000
# 3                                                            0.000000
# 4                                                            0.000000
# ...                                                   ...         ...
# 182722                                                     774.000000
# 182723                         The content of the Popper.  186.906250
# 182724                         The content of the Popper.  186.906250
# 182725                        But I actually render here!  164.359375
# 182726                        But I actually render here!  164.359375
#
#                  x         y   idx     ds_name label_text  \
# 0         0.000000 -15615.00     0   mui-site1        n/a
# 1         0.000000      0.00     1   mui-site1        n/a
# 2         0.000000      0.00     2   mui-site1        n/a
# 3         0.000000      0.00     3   mui-site1        n/a
# 4         0.000000      0.00     4   mui-site1        n/a
# ...            ...       ...   ...         ...        ...
# 182722    0.000000      0.00  1484  mui-site99        n/a
# 182723    0.000000      0.00  1485  mui-site99     popper
# 182724    0.000000      0.00  1486  mui-site99        n/a
# 182725    0.000000   7329.75  1487  mui-site99        n/a
# 182726  164.359375   7329.75  1488  mui-site99        n/a
#
#                                             children_tags  num_followers  \
# 0                                              head body            1435
# 1       meta link meta meta meta link link title style...            118
# 2                                                                      0
# 3                                                                      0
# 4                                                                      0
# ...                                                   ...            ...
# 182722                                                                 0
# 182723                                               div               1
# 182724                                                                 0
# 182725                                                                 0
# 182726                                                                 0
#
#                                            followers_tags  max_depth
# 0       head body body body body body body body body b...         13
# 1       meta link meta meta meta link link title style...          1
# 2                                                                  0
# 3                                                                  0
# 4                                                                  0
# ...                                                   ...        ...
# 182722                                                             0
# 182723                                                div          1
# 182724                                                             0
# 182725                                                             0
# 182726                                                             0
#
# [182727 rows x 20 columns]

# %%
attr_class_series = elements_df['attributes'].apply(lambda x: x.get('class') if x is not None else '').fillna('')
attr_class_series = attr_class_series.apply(lambda x: x.replace("-", " ").lower())

# %%
attr_class_series[100:130]
# Out:
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124                        muibottomnavigation root jss1
# 125    muibuttonbase root muibottomnavigationaction r...
# 126                    muibottomnavigationaction wrapper
# 127                                      muisvgicon root
# 128
# 129         muibottomnavigationaction label mui selected
# Name: attributes, dtype: object

# %%
child_tags_series = elements_df['children_tags'].fillna('')

# %%
child_tags_series
# Out:
# 0                                                head body
# 1         meta link meta meta meta link link title style...
# 2
# 3
# 4
#                                 ...
# 182722
# 182723                                                 div
# 182724
# 182725
# 182726
# Name: children_tags, Length: 182727, dtype: object

# %%
child_vocab = list(itertools.chain.from_iterable(child_tags_series.apply(lambda x: x.split(sep=' '))))
child_vocab = list(set(child_vocab))
child_vocab = sorted([v for v in child_vocab if re.match(r'^[a-z][a-z]+$', v)])

# %%
child_vocab
# Out:
# ['body',
#  'button',
#  'circle',
#  'div',
#  'em',
#  'fieldset',
#  'form',
#  'head',
#  'header',
#  'hr',
#  'input',
#  'label',
#  'legend',
#  'li',
#  'link',
#  'meta',
#  'nav',
#  'noscript',
#  'ol',
#  'option',
#  'path',
#  'script',
#  'select',
#  'span',
#  'style',
#  'svg',
#  'table',
#  'tbody',
#  'td',
#  'text',
#  'textarea',
#  'th',
#  'thead',
#  'title',
#  'tr',
#  'ul']

# %%
child_cv = CountVectorizer(vocabulary = child_vocab)

# %%
child_cv.fit_transform(child_tags_series.values)
# Out:
# <182727x36 sparse matrix of type '<class 'numpy.int64'>'
# 	with 96019 stored elements in Compressed Sparse Row format>

# %%
child_cv.transform(child_tags_series.values)
# Out:
# <182727x36 sparse matrix of type '<class 'numpy.int64'>'
# 	with 96019 stored elements in Compressed Sparse Row format>

# %%
vocabulary = sorted([v for v in child_cv.vocabulary_.keys() if re.match(r'^[a-z][a-z]+$', v)])

# %%
attr_class_series = elements_df['attributes'].apply(lambda x: x.get('class') if x is not None else '').fillna('')

# %%
attr_class_series = attr_class_series.apply(lambda x: x.replace("-", " ").lower())

# %%
attr_class_series
# Out:
# 0
# 1
# 2
# 3
# 4
#           ...
# 182722
# 182723
# 182724    jss11
# 182725
# 182726
# Name: attributes, Length: 182727, dtype: object

# %%
elements_df.reset_index(drop=True, inplace=True)

# %%
elements_df.loc[0,:'attributes'].values
# Out:
# array([{'lang': 'en'}], dtype=object)

# %%
type(elements_df.loc[0,:'attributes'].values)
# Out:
# numpy.ndarray

# %%
elements_df[elements_df.label_text != 'n/a'].attributes.apply(lambda x: x.get('class') if x is not None else '')\
            .fillna('')
# Out:
# 124                      MuiBottomNavigation-root jss1
# 127                                    MuiSvgIcon-root
# 133                                    MuiSvgIcon-root
# 139                                    MuiSvgIcon-root
# 145               MuiDrawer-root MuiDrawer-docked jss4
#                               ...
# 182707       MuiList-root MuiMenu-list MuiList-padding
# 182715
# 182717                                 MuiPopover-root
# 182721    MuiTypography-root jss58 MuiTypography-body1
# 182723
# Name: attributes, Length: 24137, dtype: object

# %%
attr_class_series = elements_df[elements_df.label_text != 'n/a']\
            .attributes.apply(lambda x: x.get('class') if x is not None else '')\
            .fillna('')
attr_class_series = attr_class_series.apply(lambda x: x.replace("-", " ").lower())
class_vocab = list(itertools.chain.from_iterable(attr_class_series.apply(lambda x: x.split(sep=' '))))
class_vocab = list(set(class_vocab))
class_vocab = sorted([v for v in class_vocab if re.match(r'^[a-z][a-z]+$', v)])

# %%
attr_class_series = attr_class_series.apply(lambda x: x.replace("-", " ").lower())

# %%
class_vocab = list(itertools.chain.from_iterable(attr_class_series.apply(lambda x: x.split(sep=' '))))

# %%
class_vocab = list(set(class_vocab))

# %%
class_vocab = sorted([v for v in class_vocab if re.match(r'^[a-z][a-z]+$', v)])

# %%
class_vocab
# Out:
# ['action',
#  'actions',
#  'active',
#  'align',
#  'aligncenter',
#  'alignleft',
#  'alignright',
#  'alternativelabel',
#  'ampmlabel',
#  'ampmselection',
#  'anchororiginbottomcenter',
#  'anchororigintoprightrectangle',
#  'animated',
#  'animatetransform',
#  'around',
#  'asterisk',
#  'avatar',
#  'avatarcolorprimary',
#  'avatarcolorsecondary',
#  'avatarsmall',
#  'badge',
#  'bar',
#  'barcolorprimary',
#  'barcolorsecondary',
#  'body',
#  'button',
#  'caption',
#  'cell',
#  'cellcheckbox',
#  'center',
#  'checkboxinput',
#  'checked',
#  'child',
#  'childpulsate',
#  'circle',
#  'circledeterminate',
#  'circleindeterminate',
#  'circular',
#  'clickable',
#  'clickablecolorprimary',
#  'clickablecolorsecondary',
#  'clock',
#  'clocknumber',
#  'clocknumberselected',
#  'colordefault',
#  'colorerror',
#  'colorinherit',
#  'colorprimary',
#  'colorsecondary',
#  'colortextprimary',
#  'colortextsecondary',
#  'columnheader',
#  'columnheadercheckbox',
#  'columnheaderdraggablecontainer',
#  'columnheadertitle',
#  'columnheadertitlecontainer',
#  'columnheaderwrapper',
#  'columnscontainer',
#  'columnseparator',
#  'completed',
#  'contained',
#  'containedprimary',
#  'container',
#  'content',
#  'contract',
#  'datacontainer',
#  'day',
#  'daylabel',
#  'dayselected',
#  'daysheader',
#  'deletable',
#  'deletablecolorprimary',
#  'deletablecolorsecondary',
#  'deleteicon',
#  'deleteiconcolorprimary',
#  'deleteiconcolorsecondary',
#  'deleteiconoutlinedcolorprimary',
#  'deleteiconoutlinedcolorsecondary',
#  'deleteiconsmall',
#  'dense',
#  'determinate',
#  'disabled',
#  'disableelevation',
#  'displayblock',
#  'divider',
#  'dividers',
#  'docked',
#  'dot',
#  'edgeend',
#  'edgestart',
#  'entered',
#  'error',
#  'even',
#  'expand',
#  'expanded',
#  'expandicon',
#  'filled',
#  'fillederror',
#  'filledinfo',
#  'filledsuccess',
#  'filledwarning',
#  'fixed',
#  'flexcontainer',
#  'flexcontainervertical',
#  'flexitem',
#  'focused',
#  'focusvisible',
#  'fontsizeinherit',
#  'fontsizesmall',
#  'footercontainer',
#  'formcontrol',
#  'fullwidth',
#  'grid',
#  'grouped',
#  'groupedcontained',
#  'groupedcontainedhorizontal',
#  'groupedcontainedprimary',
#  'groupedcontainedvertical',
#  'groupedhorizontal',
#  'groupedoutlined',
#  'groupedoutlinedhorizontal',
#  'groupedoutlinedprimary',
#  'groupedoutlinedsecondary',
#  'groupedtext',
#  'groupedtextprimary',
#  'groupedtextvertical',
#  'groupedvertical',
#  'gutterbottom',
#  'gutters',
#  'head',
#  'hidden',
#  'horizontal',
#  'hourminutelabel',
#  'hover',
#  'icon',
#  'iconbutton',
#  'iconbuttoncontainer',
#  'iconcolorprimary',
#  'iconcolorsecondary',
#  'iconcontainer',
#  'icondirectionasc',
#  'iconfilled',
#  'icononly',
#  'iconseparator',
#  'iconsmall',
#  'indeterminate',
#  'indicator',
#  'input',
#  'inputmargindense',
#  'inset',
#  'item',
#  'items',
#  'justify',
#  'label',
#  'labelcontainer',
#  'labelplacementbottom',
#  'labelplacementstart',
#  'labelplacementtop',
#  'labelsmall',
#  'li',
#  'light',
#  'line',
#  'linehorizontal',
#  'linevertical',
#  'list',
#  'main',
#  'margindense',
#  'mark',
#  'markactive',
#  'marked',
#  'marklabel',
#  'marklabelactive',
#  'maxwidthlg',
#  'menuicon',
#  'menuiconbutton',
#  'message',
#  'middle',
#  'mui',
#  'muiaccordion',
#  'muiaccordiondetails',
#  'muiaccordionsummary',
#  'muialert',
#  'muiappbar',
#  'muiavatar',
#  'muiavatargroup',
#  'muibackdrop',
#  'muibadge',
#  'muibottomnavigation',
#  'muibottomnavigationaction',
#  'muibox',
#  'muibreadcrumbs',
#  'muibutton',
#  'muibuttonbase',
#  'muibuttongroup',
#  'muicard',
#  'muicardactions',
#  'muicardcontent',
#  'muicardheader',
#  'muicheckbox',
#  'muichip',
#  'muicircularprogress',
#  'muicollapse',
#  'muicontainer',
#  'muidatagrid',
#  'muidialog',
#  'muidialogactions',
#  'muidialogcontent',
#  'muidialogcontenttext',
#  'muidialogtitle',
#  'muidivider',
#  'muidrawer',
#  'muifab',
#  'muifilledinput',
#  'muiformcontrol',
#  'muiformcontrollabel',
#  'muiformgroup',
#  'muiformhelpertext',
#  'muiformlabel',
#  'muigrid',
#  'muiiconbutton',
#  'muiinput',
#  'muiinputbase',
#  'muiinputlabel',
#  'muilinearprogress',
#  'muilink',
#  'muilist',
#  'muilistitem',
#  'muilistitemavatar',
#  'muilistitemicon',
#  'muilistitemtext',
#  'muimenu',
#  'muimenuitem',
#  'muinativeselect',
#  'muipaper',
#  'muipickersbasepicker',
#  'muipickerscalendar',
#  'muipickerscalendarheader',
#  'muipickersclock',
#  'muipickersclocknumber',
#  'muipickersclockpointer',
#  'muipickersdatepickerroot',
#  'muipickersday',
#  'muipickersslidetransition',
#  'muipickersstaticwrapper',
#  'muipickerstimepickertoolbar',
#  'muipickerstoolbar',
#  'muipickerstoolbarbutton',
#  'muipickerstoolbartext',
#  'muipopover',
#  'muiradio',
#  'muiselect',
#  'muislider',
#  'muisnackbar',
#  'muisnackbarcontent',
#  'muistep',
#  'muistepconnector',
#  'muistepicon',
#  'muisteplabel',
#  'muistepper',
#  'muisvgicon',
#  'muiswitch',
#  'muitab',
#  'muitable',
#  'muitablebody',
#  'muitablecell',
#  'muitablecontainer',
#  'muitablehead',
#  'muitablepagination',
#  'muitablerow',
#  'muitablesortlabel',
#  'muitabs',
#  'muitabscrollbutton',
#  'muitextfield',
#  'muitoolbar',
#  'muitouchripple',
#  'muitypography',
#  'multiline',
#  'nativeinput',
#  'nopoint',
#  'nowrap',
#  'numeric',
#  'odd',
#  'ol',
#  'outlined',
#  'outlinedprimary',
#  'outlinedsecondary',
#  'outlinedsizelarge',
#  'padding',
#  'paddingcheckbox',
#  'paddingnone',
#  'paper',
#  'paperanchordockedleft',
#  'paperanchordockedright',
#  'paperanchorleft',
#  'paperanchorright',
#  'paperfullwidth',
#  'paperscrollpaper',
#  'paperwidthsm',
#  'paperwidthxs',
#  'pickerview',
#  'pin',
#  'pointer',
#  'positionstatic',
#  'primary',
#  'rail',
#  'regular',
#  'renderingzone',
#  'required',
#  'resizetriggers',
#  'ripple',
#  'ripplepulsate',
#  'ripplevisible',
#  'root',
#  'rounded',
#  'row',
#  'scrollable',
#  'scrollbuttons',
#  'scrollbuttonsdesktop',
#  'scroller',
#  'scrollpaper',
#  'secondary',
#  'select',
#  'selected',
#  'selecticon',
#  'selectmenu',
#  'selectroot',
#  'separator',
#  'shrink',
#  'sizelarge',
#  'sizesmall',
#  'sortable',
#  'sorticon',
#  'space',
#  'spacer',
#  'spacing',
#  'square',
#  'squaremask',
#  'staticwrapperroot',
#  'subheader',
#  'svg',
#  'switchbase',
#  'switchheader',
#  'text',
#  'textcenter',
#  'textcolorprimary',
#  'textleft',
#  'textprimary',
#  'textright',
#  'textsizesmall',
#  'thumb',
#  'thumbcolorprimary',
#  'title',
#  'toolbar',
#  'toolbarampmleftpadding',
#  'toolbarbtn',
#  'toolbarbtnselected',
#  'toolbartxt',
#  'track',
#  'transitioncontainer',
#  'trigger',
#  'true',
#  'underline',
#  'underlinehover',
#  'valuelabel',
#  'vertical',
#  'viewport',
#  'week',
#  'window',
#  'windowcontainer',
#  'withrenderer',
#  'wrapper',
#  'wrapperinner',
#  'xs']

# %%
class_cv = CountVectorizer(vocabulary = class_vocab)

# %%
class_sm = class_cv.fit_transform(attr_class_series)

# %%
model = TfidfTransformer()

# %%
class_sm = model.fit_transform(class_sm.reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\NINA_P~1\AppData\Local\Temp/ipykernel_9612/1927798175.py in <module>
# ----> 1 class_sm = model.fit_transform(class_sm.reshape(-1, 1))
#
# AttributeError: 'CountVectorizer' object has no attribute 'reshape'

# %%
m = build_class_feature(elements_df)
# Out:
# 2021-08-30 17:46:43,805 -INFO - 143991698:143991698.py:9 - used column: attributes
# 2021-08-30 17:46:43,805 -INFO - 143991698.py:9 - used column: attributes
# 2021-08-30 17:46:43,809 -INFO - 143991698:143991698.py:12 - CountVectorizer and TfidfTransformer for class attribute exist. Loading...
# 2021-08-30 17:46:43,809 -INFO - 143991698.py:12 - CountVectorizer and TfidfTransformer for class attribute exist. Loading...

# %%
with open('MUI_model/model/count_children_tags.pkl', 'rb') as c:
            model_cv = pickle.load(file=c)

# %%
model_cv.transform(child_tags_series)
# Out:
# <182727x36 sparse matrix of type '<class 'numpy.int64'>'
# 	with 96019 stored elements in Compressed Sparse Row format>

# %%
build_followers_tags(elements_df)
# Out:
# 2021-08-30 19:15:44,569 -INFO - 2004508130:2004508130.py:4 - used column: followers_tags
# 2021-08-30 19:15:44,569 -INFO - 2004508130.py:4 - used column: followers_tags
# 2021-08-30 19:15:44,574 -INFO - 2004508130:2004508130.py:7 - CountVectorizer and TfidfTransformer for followers tags exist. Loading...
# 2021-08-30 19:15:44,574 -INFO - 2004508130.py:7 - CountVectorizer and TfidfTransformer for followers tags exist. Loading...
# <182727x36 sparse matrix of type '<class 'numpy.float64'>'
# 	with 96019 stored elements in Compressed Sparse Row format>
