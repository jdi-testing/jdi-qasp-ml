# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'HTML5_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/html5_dataset')

# %%
DATASET_NAME = 'uda'
WAIT_TIME_SECONDS = 7
SITE_URL = 'http://www.u-d-a.com/html-markup-test-page/'
PREDICT_URL = 'http://localhost:5050/html5-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 2
# HEADLESS = True

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2022-01-25 15:30:53,522 -INFO - config.py:31 - Module utils.config was loaded
# 2022-01-25 15:30:53,729 -INFO - common.py:119 - Module utils.common is loaded...
# 2022-01-25 15:30:53,730 -INFO - dataset_builder.py:246 - dataset package is loaded...

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2022-01-25 15:30:56,480 -INFO - dataset_builder.py:100 - Dataset name: uda
# 2022-01-25 15:30:56,481 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2022-01-25 15:30:56,482 -INFO - dataset_builder.py:152 - Creating driver
# 2022-01-25 15:30:57,900 -INFO - dataset_builder.py:164 - Chrome web driver is created
# 2022-01-25 15:31:01,207 -INFO - common.py:22 - Window maximized
# 2022-01-25 15:31:08,213 -INFO - dataset_builder.py:167 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/images/uda.png
# 2022-01-25 15:31:13,499 -INFO - dataset_builder.py:211 - Collect features using JS script
# 2022-01-25 15:31:13,859 -INFO - dataset_builder.py:219 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/html/uda.html
# 2022-01-25 15:31:13,878 -INFO - dataset_builder.py:231 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/df/uda.pkl
# 2022-01-25 15:31:13,883 -INFO - dataset_builder.py:234 - No attributes: (211, 14)
# 2022-01-25 15:31:13,911 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '4367217518138735063862535444',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4156.328125,
#   'width': 1405.0,
#   'height': 259.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 363895.0},
#  {'element_id': '5926936251138735066172946253',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 1481.328125,
#   'width': 1405.0,
#   'height': 246.0,
#   'predicted_label': 'table',
#   'predicted_probability': 1.0,
#   'sort_key': 345630.0},
#  {'element_id': '9726261673138735067600993973',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5037.328125,
#   'width': 1405.0,
#   'height': 140.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 196700.0},
#  {'element_id': '7290505610138735063450146503',
#   'is_hidden': 0,
#   'x': 70.0,
#   'y': 1216.328125,
#   'width': 1345.0,
#   'height': 86.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 115670.0},
#  {'element_id': '1895294807138735067405644575',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 6201.328125,
#   'width': 1405.0,
#   'height': 56.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 78680.0},
#  {'element_id': '6299044061138735063673355016',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 6657.328125,
#   'width': 1405.0,
#   'height': 56.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 78680.0},
#  {'element_id': '9239775555138735063192839913',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 6049.328125,
#   'width': 1405.0,
#   'height': 56.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 78680.0},
#  {'element_id': '1497016653138735064251210070',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 6353.328125,
#   'width': 1405.0,
#   'height': 56.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 78680.0},
#  {'element_id': '5333654582138735069660781947',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 6505.328125,
#   'width': 1405.0,
#   'height': 56.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 78680.0},
#  {'element_id': '5193663270138735060981597394',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 223.1875,
#   'width': 1405.0,
#   'height': 48.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 67440.0},
#  {'element_id': '2454413884138735063539736815',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 365.5625,
#   'width': 1405.0,
#   'height': 48.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 67440.0},
#  {'element_id': '5336121130138735062374979479',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 3439.328125,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '2645553777138735066576950033',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 1425.328125,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '5236297192138735068476043405',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4981.328125,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '6161006867138735063306006454',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 1757.328125,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '4477658533138735062274946143',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 6439.328125,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '5869897262138735061517347303',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 2139.328125,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '5059366284138735061938550536',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 6287.328125,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '0909330201138735061177867787',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 763.328125,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '8429763815138735063905976887',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 6135.328125,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '9797174358138735064704716754',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 6591.328125,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '9705621731138735060876340514',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 446.75,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '9245676641138735065141758602',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5983.328125,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '1283242473138735062456820049',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 512.75,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '4382788176138735067997193783',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 2789.328125,
#   'width': 1405.0,
#   'height': 36.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 50580.0},
#  {'element_id': '3084254614138735061387871816',
#   'is_hidden': 0,
#   'x': 90.0,
#   'y': 6868.328125,
#   'width': 637.5,
#   'height': 72.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 45900.0},
#  {'element_id': '1414707593138735068261932811',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 3982.328125,
#   'width': 1405.0,
#   'height': 30.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 42150.0},
#  {'element_id': '9895225050138735066373235068',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5407.328125,
#   'width': 1405.0,
#   'height': 29.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 40745.0},
#  {'element_id': '4802370627138735060999597513',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4663.328125,
#   'width': 1405.0,
#   'height': 29.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 40745.0},
#  {'element_id': '0869543205138735062428322035',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5752.328125,
#   'width': 1405.0,
#   'height': 29.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 40745.0},
#  {'element_id': '1834078680138735064532963096',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4836.328125,
#   'width': 1405.0,
#   'height': 29.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 40745.0},
#  {'element_id': '2064673715138735066255058915',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4473.328125,
#   'width': 1405.0,
#   'height': 29.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 40745.0},
#  {'element_id': '6531374374138735068977326574',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5709.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '6528685825138735060465959824',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 3681.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '7740706627138735065773922286',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 1367.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '4631585444138735060790027696',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 698.0625,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '7181640405138735065654959926',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5666.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '4843641289138735065036940992',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4880.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '0032125000138735065487573524',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4603.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '8060087393138735069076706687',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5580.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '9729783123138735065769890345',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4707.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '7891835562138735062287261245',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 3495.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '9447251210138735060613691375',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4517.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '5437191298138735069475168186',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5839.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '5742421284138735066752677751',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4750.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '8257841599138735061890541090',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5796.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '5903764508138735067184441382',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 819.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '7386253643138735067308784117',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 3767.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '7089770747138735064617335794',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5192.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '6033356958138735060481537917',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 304.375,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '6760037048138735067905095107',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5235.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '7799063126138735062758906060',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 632.796875,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '8641196445138735067244347583',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4027.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '8095605765138735061031116391',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 3724.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '0010219776138735067057250622',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5537.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '2430251689138735066367539060',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5882.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '3342215769138735069109656411',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 3810.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '0147728548138735062317672655',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 1064.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '0164936556138735065543100584',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 3538.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '0761213872138735063193222348',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4560.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '1324742494138735064695369096',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4113.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '1488055664138735068266912553',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4923.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '1500851237138735068496604004',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5321.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '1663173943138735066017203758',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4430.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '1854445929138735061553462258',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5623.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '2048885107138735069314544450',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 3853.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '2561181633138735066444227759',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5494.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '2688271383138735065685652283',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5925.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '3168052902138735067077171188',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 3896.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '3327207674138735065477828540',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 3939.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '9904355003138735063782030878',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5364.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '3964602456138735064019999411',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5278.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '4003190681138735066848805365',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4793.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '3532959478138735062957312376',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 4070.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '3985114531138735068395954286',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 5451.328125,
#   'width': 1405.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 39340.0},
#  {'element_id': '2185583866138735065175518402',
#   'is_hidden': 0,
#   'x': 70.0,
#   'y': 971.328125,
#   'width': 1345.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 37660.0},
#  {'element_id': '2144086551138735066408085432',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 578.75,
#   'width': 1405.0,
#   'height': 24.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 33720.0},
#  {'element_id': '9333345328138735061680828627',
#   'is_hidden': 0,
#   'x': 1069.96875,
#   'y': 7169.328125,
#   'width': 375.0,
#   'height': 56.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 21000.0},
#  {'element_id': '5746680165138735069794393090',
#   'is_hidden': 0,
#   'x': 1069.96875,
#   'y': 7169.328125,
#   'width': 375.0,
#   'height': 56.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 21000.0},
#  {'element_id': '7054397497138735066361802176',
#   'is_hidden': 0,
#   'x': 757.5,
#   'y': 6881.828125,
#   'width': 458.0,
#   'height': 45.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 20610.0},
#  {'element_id': '4702052733138735066328836939',
#   'is_hidden': 0,
#   'x': 1019.15625,
#   'y': 35.0,
#   'width': 241.140625,
#   'height': 70.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 16879.84375},
#  {'element_id': '2026921271138735065295864167',
#   'is_hidden': 0,
#   'x': 699.203125,
#   'y': 7242.328125,
#   'width': 295.0,
#   'height': 56.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 16520.0},
#  {'element_id': '5873373907138735063294873971',
#   'is_hidden': 0,
#   'x': 699.203125,
#   'y': 7170.328125,
#   'width': 295.0,
#   'height': 56.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 16520.0},
#  {'element_id': '0624854870138735062672274721',
#   'is_hidden': 0,
#   'x': 699.203125,
#   'y': 7246.328125,
#   'width': 287.3125,
#   'height': 47.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 13503.6875},
#  {'element_id': '5673544794138735064312243065',
#   'is_hidden': 0,
#   'x': 699.203125,
#   'y': 7174.328125,
#   'width': 265.09375,
#   'height': 47.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 12459.40625},
#  {'element_id': '5731643776138735060851113522',
#   'is_hidden': 0,
#   'x': 668.796875,
#   'y': 35.0,
#   'width': 174.65625,
#   'height': 70.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 12225.9375},
#  {'element_id': '9794646481138735061884788952',
#   'is_hidden': 0,
#   'x': 1275.34375,
#   'y': 35.0,
#   'width': 154.609375,
#   'height': 70.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10822.65625},
#  {'element_id': '7256513606138735061347074294',
#   'is_hidden': 0,
#   'x': 1069.96875,
#   'y': 7283.328125,
#   'width': 375.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10500.0},
#  {'element_id': '2263230841138735065979580295',
#   'is_hidden': 0,
#   'x': 1069.96875,
#   'y': 7283.328125,
#   'width': 375.0,
#   'height': 28.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10500.0},
#  {'element_id': '4864012127138735069972031558',
#   'is_hidden': 0,
#   'x': 1069.96875,
#   'y': 7240.328125,
#   'width': 375.0,
#   'height': 28.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 10500.0},
#  {'element_id': '3575283009138735062787113419',
#   'is_hidden': 0,
#   'x': 858.5,
#   'y': 35.0,
#   'width': 145.609375,
#   'height': 70.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10192.65625},
#  {'element_id': '6321397602138735066647771476',
#   'is_hidden': 0,
#   'x': 1069.96875,
#   'y': 7125.328125,
#   'width': 375.0,
#   'height': 24.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 9000.0},
#  {'element_id': '6374464515138735065920352130',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 49.109375,
#   'width': 200.0,
#   'height': 41.78125,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8356.25},
#  {'element_id': '1203717101138735062901503575',
#   'is_hidden': 0,
#   'x': 1215.5,
#   'y': 6881.828125,
#   'width': 179.5,
#   'height': 45.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 8077.5},
#  {'element_id': '2396878362138735061761191407',
#   'is_hidden': 0,
#   'x': 316.765625,
#   'y': 7125.328125,
#   'width': 306.671875,
#   'height': 24.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 7360.125},
#  {'element_id': '5286691427138735067860949979',
#   'is_hidden': 0,
#   'x': 699.203125,
#   'y': 7246.328125,
#   'width': 227.171875,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4316.265625},
#  {'element_id': '9237809456138735068086615669',
#   'is_hidden': 0,
#   'x': 1098.46875,
#   'y': 7240.328125,
#   'width': 146.984375,
#   'height': 28.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4115.5625},
#  {'element_id': '2478059660138735062879688412',
#   'is_hidden': 0,
#   'x': 1260.453125,
#   'y': 7240.328125,
#   'width': 146.984375,
#   'height': 28.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4115.5625},
#  {'element_id': '6775638575138735060438423373',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 7157.328125,
#   'width': 201.0,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3819.0},
#  {'element_id': '2435795711138735068080177695',
#   'is_hidden': 0,
#   'x': 119.984375,
#   'y': 1692.328125,
#   'width': 94.703125,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1799.359375},
#  {'element_id': '4252108941138735068693615506',
#   'is_hidden': 0,
#   'x': 121.046875,
#   'y': 1643.328125,
#   'width': 92.578125,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1758.984375},
#  {'element_id': '9532023045138735067434392529',
#   'is_hidden': 0,
#   'x': 130.9375,
#   'y': 1545.328125,
#   'width': 72.796875,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1383.140625},
#  {'element_id': '4924304067138735060140805927',
#   'is_hidden': 0,
#   'x': 550.796875,
#   'y': 7173.328125,
#   'width': 72.640625,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1380.171875},
#  {'element_id': '8664020682138735061418394400',
#   'is_hidden': 0,
#   'x': 131.5625,
#   'y': 1594.328125,
#   'width': 71.546875,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1359.390625},
#  {'element_id': '5152316306138735063854837995',
#   'is_hidden': 0,
#   'x': 70.0,
#   'y': 1277.328125,
#   'width': 57.609375,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1094.578125},
#  {'element_id': '7347012973138735066124530544',
#   'is_hidden': 0,
#   'x': 216.609375,
#   'y': 2085.328125,
#   'width': 54.484375,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1035.203125},
#  {'element_id': '3333723332138735060919541871',
#   'is_hidden': 0,
#   'x': 389.359375,
#   'y': 7173.328125,
#   'width': 51.78125,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 983.84375},
#  {'element_id': '5665397888138735060637748436',
#   'is_hidden': 0,
#   'x': 471.140625,
#   'y': 7173.328125,
#   'width': 49.65625,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 943.46875},
#  {'element_id': '6293179171138735060240692862',
#   'is_hidden': 0,
#   'x': 107.4375,
#   'y': 1249.328125,
#   'width': 44.53125,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 846.09375},
#  {'element_id': '2613205825138735060416615820',
#   'is_hidden': 0,
#   'x': 316.765625,
#   'y': 7173.328125,
#   'width': 42.59375,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 809.28125},
#  {'element_id': '5327230062138735062645515135',
#   'is_hidden': 0,
#   'x': 467.875,
#   'y': 3499.328125,
#   'width': 32.53125,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 618.09375},
#  {'element_id': '3953482734138735064834307453',
#   'is_hidden': 0,
#   'x': 208.21875,
#   'y': 3728.328125,
#   'width': 27.171875,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 516.265625},
#  {'element_id': '4797387841138735063094103147',
#   'is_hidden': 0,
#   'x': 72.5,
#   'y': 7211.328125,
#   'width': 20.0,
#   'height': 24.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 480.0},
#  {'element_id': '0496589177138735065999500370',
#   'is_hidden': 0,
#   'x': 40.0,
#   'y': 7211.328125,
#   'width': 17.5,
#   'height': 24.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 420.0},
#  {'element_id': '5586813403138735064457976020',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 1.0,
#   'height': 1.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1.0},
#  {'element_id': '6071948922138735062065928600',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3686534953138735061685225802',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6891574726138735065738594390',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7036363922138735068765200354',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0448079121138735065472786696',
#   'is_hidden': 1,
#   'x': 1445.0,
#   'y': 70.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0258352834138735061070583756',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3052660372138735067035108093',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1853039864138735062974660805',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7972300762138735066151470770',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7704040587138735066853208720',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0}]
# CPU times: user 58.8 ms, sys: 9.94 ms, total: 68.8 ms
# Wall time: 2.2 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id  is_hidden     x            y   width  height  \
# 0  4367217518138735063862535444          0  40.0  4156.328125  1405.0   259.0
# 1  5926936251138735066172946253          0  40.0  1481.328125  1405.0   246.0
# 2  9726261673138735067600993973          0  40.0  5037.328125  1405.0   140.0
# 3  7290505610138735063450146503          0  70.0  1216.328125  1345.0    86.0
# 4  1895294807138735067405644575          0  40.0  6201.328125  1405.0    56.0
#
#   predicted_label  predicted_probability  sort_key tag_name
# 0            text                    1.0  363895.0        P
# 1           table                    1.0  345630.0    TABLE
# 2            text                    1.0  196700.0        P
# 3            text                    1.0  115670.0        P
# 4            text                    1.0   78680.0        P

# %%
predictions_df.predicted_label.unique()
# Out:
# array(['text', 'table', 'title', 'link', 'datetimeselector', 'button',
#        'label'], dtype=object)

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
        if r.is_hidden==0:
                patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
                axes.add_patch(patch)
                axes.text(r.x*2, r.y*2, 
                        str(r.predicted_label) + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                        backgroundcolor='black', 
                        color='white',
                        bbox=dict(alpha=0.5))
