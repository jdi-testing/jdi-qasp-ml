# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'mui-com'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://mui.com'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-11-30 17:19:15,344 -INFO - dataset_builder.py:100 - Dataset name: mui-com
# 2021-11-30 17:19:15,351 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-11-30 17:19:15,360 -INFO - dataset_builder.py:151 - Creating driver
# 2021-11-30 17:19:16,289 -INFO - dataset_builder.py:163 - Chrome web driver is created
# 2021-11-30 17:19:21,300 -INFO - common.py:22 - Window maximized
# 2021-11-30 17:19:28,306 -INFO - dataset_builder.py:166 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/mui-com.png
# 2021-11-30 17:19:34,901 -INFO - dataset_builder.py:210 - Collect features using JS script
# 2021-11-30 17:19:36,098 -INFO - dataset_builder.py:218 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/mui-com.html
# 2021-11-30 17:19:36,175 -INFO - dataset_builder.py:230 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/mui-com.pkl
# 2021-11-30 17:19:36,179 -INFO - dataset_builder.py:233 - No attributes: (42, 13)
# 2021-11-30 17:19:42,749 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '0341900627819749075984273779',
#   'x': 781.0,
#   'y': 1462.0,
#   'width': 443.1875,
#   'height': 434.375,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 0.9266265035,
#   'sort_key': 192509.5703125},
#  {'element_id': '2173738591819749073491263502',
#   'x': 170.0,
#   'y': 1178.0,
#   'width': 500.0,
#   'height': 221.0,
#   'predicted_label': 'dialog',
#   'predicted_probability': 0.5325105786,
#   'sort_key': 110500.0},
#  {'element_id': '7197964663819749078377978250',
#   'x': 833.796875,
#   'y': 1226.484375,
#   'width': 422.390625,
#   'height': 143.015625,
#   'predicted_label': 'tabs',
#   'predicted_probability': 0.9999947548,
#   'sort_key': 60408.4592285156},
#  {'element_id': '8118156281819749083835378446',
#   'x': 577.65625,
#   'y': 3173.984375,
#   'width': 343.65625,
#   'height': 162.03125,
#   'predicted_label': 'table',
#   'predicted_probability': 1.0,
#   'sort_key': 55683.0517578125},
#  {'element_id': '5187649034819749076806570160',
#   'x': 1180.0,
#   'y': 736.0,
#   'width': 360.0,
#   'height': 86.015625,
#   'predicted_label': 'accordion',
#   'predicted_probability': 1.0,
#   'sort_key': 30965.625},
#  {'element_id': '2812962315819749070718078394',
#   'x': 833.796875,
#   'y': 1299.5,
#   'width': 422.390625,
#   'height': 62.0,
#   'predicted_label': 'tabs',
#   'predicted_probability': 0.8274841905,
#   'sort_key': 26188.21875},
#  {'element_id': '8676753609819749074217327721',
#   'x': 780.0,
#   'y': 600.0,
#   'width': 360.0,
#   'height': 48.5,
#   'predicted_label': 'button-group',
#   'predicted_probability': 0.999994874,
#   'sort_key': 17460.0},
#  {'element_id': '3896139964819749076903399398',
#   'x': 1180.0,
#   'y': 394.0,
#   'width': 360.0,
#   'height': 48.0,
#   'predicted_label': 'tabs',
#   'predicted_probability': 1.0,
#   'sort_key': 17280.0},
#  {'element_id': '5626997045819749084053948681',
#   'x': 336.890625,
#   'y': 5230.0,
#   'width': 291.15625,
#   'height': 56.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9456569552,
#   'sort_key': 16304.75},
#  {'element_id': '6249042814819749077355239311',
#   'x': 336.890625,
#   'y': 563.96875,
#   'width': 291.15625,
#   'height': 56.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9456569552,
#   'sort_key': 16304.75},
#  {'element_id': '4981357244819749084542631301',
#   'x': 953.3125,
#   'y': 2856.0,
#   'width': 355.65625,
#   'height': 34.5,
#   'predicted_label': 'tabs',
#   'predicted_probability': 1.0,
#   'sort_key': 12270.140625},
#  {'element_id': '0113166400819749085075457014',
#   'x': 566.65625,
#   'y': 2856.0,
#   'width': 355.65625,
#   'height': 34.5,
#   'predicted_label': 'tabs',
#   'predicted_probability': 1.0,
#   'sort_key': 12270.140625},
#  {'element_id': '7043179683819749086825211184',
#   'x': 181.0,
#   'y': 2856.0,
#   'width': 354.65625,
#   'height': 34.5,
#   'predicted_label': 'tabs',
#   'predicted_probability': 1.0,
#   'sort_key': 12235.640625},
#  {'element_id': '4490906496819749078324374634',
#   'x': 224.0,
#   'y': 11.5,
#   'width': 275.453125,
#   'height': 41.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11293.578125},
#  {'element_id': '6882447416819749081430366816',
#   'x': 1038.640625,
#   'y': 2962.0,
#   'width': 195.0,
#   'height': 56.0,
#   'predicted_label': 'text-field',
#   'predicted_probability': 0.9999997616,
#   'sort_key': 10920.0},
#  {'element_id': '5821445500819749085374393780',
#   'x': 652.9375,
#   'y': 2965.984375,
#   'width': 193.078125,
#   'height': 48.015625,
#   'predicted_label': 'alert',
#   'predicted_probability': 1.0,
#   'sort_key': 9270.7668457031},
#  {'element_id': '2895626824819749086730682561',
#   'x': 170.0,
#   'y': 5230.0,
#   'width': 150.890625,
#   'height': 56.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.8677999377,
#   'sort_key': 8449.875},
#  {'element_id': '9441009677819749076898406081',
#   'x': 170.0,
#   'y': 563.96875,
#   'width': 150.890625,
#   'height': 56.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.8677999377,
#   'sort_key': 8449.875},
#  {'element_id': '0235096812819749076241761476',
#   'x': 899.671875,
#   'y': 600.0,
#   'width': 120.671875,
#   'height': 48.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999921322,
#   'sort_key': 5852.5859375},
#  {'element_id': '3885969043819749074063128402',
#   'x': 1019.34375,
#   'y': 600.0,
#   'width': 120.671875,
#   'height': 48.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999921322,
#   'sort_key': 5852.5859375},
#  {'element_id': '1712972662819749073121297433',
#   'x': 780.0,
#   'y': 600.0,
#   'width': 120.671875,
#   'height': 48.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999902248,
#   'sort_key': 5852.5859375},
#  {'element_id': '2528355208819749080649328243',
#   'x': 289.375,
#   'y': 2971.75,
#   'width': 147.90625,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 5398.578125},
#  {'element_id': '5219071651819749078984981862',
#   'x': 825.546875,
#   'y': 1789.1875,
#   'width': 361.421875,
#   'height': 14.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9998326302,
#   'sort_key': 5059.90625},
#  {'element_id': '9219130161819749084555636985',
#   'x': 424.0625,
#   'y': 5629.0,
#   'width': 105.9375,
#   'height': 44.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4714.21875},
#  {'element_id': '4111563052819749074138507114',
#   'x': 1227.0,
#   'y': 511.0,
#   'width': 30.0,
#   'height': 156.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999992847,
#   'sort_key': 4680.0},
#  {'element_id': '9815949565819749087523757993',
#   'x': 302.90625,
#   'y': 3236.75,
#   'width': 120.84375,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4410.796875},
#  {'element_id': '7116986123819749083735219486',
#   'x': 1079.0,
#   'y': 3283.75,
#   'width': 114.28125,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.5822057724,
#   'sort_key': 4171.265625},
#  {'element_id': '0499837587819749071088527449',
#   'x': 1026.21875,
#   'y': 688.5,
#   'width': 113.78125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3641.0},
#  {'element_id': '0867120737819749079450868745',
#   'x': 421.03125,
#   'y': 11.5,
#   'width': 78.421875,
#   'height': 41.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3215.296875},
#  {'element_id': '3020222325819749076376353869',
#   'x': 847.25,
#   'y': 1483.1875,
#   'width': 202.421875,
#   'height': 14.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999086857,
#   'sort_key': 2833.90625},
#  {'element_id': '3169273823819749085950016587',
#   'x': 1099.671875,
#   'y': 2801.0,
#   'width': 113.140625,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2715.375},
#  {'element_id': '1394635874819749078307672199',
#   'x': 355.0,
#   'y': 11.5,
#   'width': 66.03125,
#   'height': 41.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2707.28125},
#  {'element_id': '1155116893819749074743478850',
#   'x': 849.796875,
#   'y': 1318.5,
#   'width': 111.0,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2664.0},
#  {'element_id': '1287165239819749079341570982',
#   'x': 927.546875,
#   'y': 688.5,
#   'width': 82.671875,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2645.5},
#  {'element_id': '5039668485819749075963235075',
#   'x': 771.0,
#   'y': 1428.0,
#   'width': 109.828125,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2635.875},
#  {'element_id': '4129366009819749086878159114',
#   'x': 1060.0,
#   'y': 5559.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '1429886880819749089574561719',
#   'x': 1060.0,
#   'y': 5621.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '9713636951819749088406987313',
#   'x': 1060.0,
#   'y': 5528.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '8963453778819749089569101597',
#   'x': 915.0,
#   'y': 5559.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '7187360480819749085972694239',
#   'x': 915.0,
#   'y': 5621.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '5403992707819749083421765887',
#   'x': 915.0,
#   'y': 5652.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '4378442141819749081211346631',
#   'x': 770.0,
#   'y': 5590.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '5956980589819749083808468682',
#   'x': 770.0,
#   'y': 5528.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '8911108426819749082067529931',
#   'x': 770.0,
#   'y': 5621.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '3172406741819749083572422765',
#   'x': 770.0,
#   'y': 5559.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '8779779902819749089306194763',
#   'x': 1060.0,
#   'y': 5652.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '4969473400819749082433076750',
#   'x': 915.0,
#   'y': 5590.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '8033967201819749081609874436',
#   'x': 915.0,
#   'y': 5528.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '3473668482819749081103261368',
#   'x': 1205.0,
#   'y': 5559.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '4712718731819749083177200940',
#   'x': 1060.0,
#   'y': 5590.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '0651038795819749086948666845',
#   'x': 1205.0,
#   'y': 5652.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '4051299710819749086088267691',
#   'x': 1205.0,
#   'y': 5621.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '9714914965819749089460506848',
#   'x': 1205.0,
#   'y': 5528.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2625.0},
#  {'element_id': '6807260706819749086157972393',
#   'x': 1222.8125,
#   'y': 2801.0,
#   'width': 107.1875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2572.5},
#  {'element_id': '2857807101819749074710200916',
#   'x': 247.0,
#   'y': 1896.0,
#   'width': 96.296875,
#   'height': 24.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.5817679763,
#   'sort_key': 2311.125},
#  {'element_id': '8378526893819749071691292968',
#   'x': 247.0,
#   'y': 1640.0,
#   'width': 96.296875,
#   'height': 24.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.5817679763,
#   'sort_key': 2311.125},
#  {'element_id': '6261492631819749074412637367',
#   'x': 247.0,
#   'y': 1512.0,
#   'width': 96.296875,
#   'height': 24.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.5817679763,
#   'sort_key': 2311.125},
#  {'element_id': '6492102432819749073004333767',
#   'x': 247.0,
#   'y': 1768.0,
#   'width': 96.296875,
#   'height': 24.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.5817679763,
#   'sort_key': 2311.125},
#  {'element_id': '2326081084819749074437063414',
#   'x': 890.828125,
#   'y': 1429.0,
#   'width': 104.171875,
#   'height': 22.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2291.78125},
#  {'element_id': '0076350194819749073498113608',
#   'x': 303.046875,
#   'y': 11.5,
#   'width': 51.953125,
#   'height': 41.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2130.078125},
#  {'element_id': '1773913864819749078537029577',
#   'x': 926.71875,
#   'y': 1573.1875,
#   'width': 151.8125,
#   'height': 14.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9995500445,
#   'sort_key': 2125.375},
#  {'element_id': '1610506501819749074107321801',
#   'x': 883.375,
#   'y': 1645.1875,
#   'width': 137.359375,
#   'height': 14.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.987898767,
#   'sort_key': 1923.03125},
#  {'element_id': '4813963935819749082431912696',
#   'x': 619.171875,
#   'y': 4834.0,
#   'width': 77.484375,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1627.171875},
#  {'element_id': '8530624345819749071745921730',
#   'x': 1254.0,
#   'y': 15.5,
#   'width': 33.0,
#   'height': 33.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.4523199797,
#   'sort_key': 1089.0},
#  {'element_id': '9973726781819749071735681517',
#   'x': 1297.0,
#   'y': 15.5,
#   'width': 33.0,
#   'height': 33.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9983496666,
#   'sort_key': 1089.0},
#  {'element_id': '7447344822819749074468838750',
#   'x': 170.0,
#   'y': 16.0,
#   'width': 34.0,
#   'height': 32.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1088.0},
#  {'element_id': '3213906919819749073029808379',
#   'x': 805.0,
#   'y': 341.984375,
#   'width': 259.5625,
#   'height': 4.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 1038.25},
#  {'element_id': '7518427578819749085887918702',
#   'x': 222.0,
#   'y': 3566.0,
#   'width': 32.0,
#   'height': 32.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9971615076,
#   'sort_key': 1024.0},
#  {'element_id': '2890745334819749072736036799',
#   'x': 987.0,
#   'y': 502.953125,
#   'width': 32.0,
#   'height': 32.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9971615076,
#   'sort_key': 1024.0},
#  {'element_id': '3351507229819749084073559897',
#   'x': 1205.0,
#   'y': 5590.25,
#   'width': 48.578125,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1020.140625},
#  {'element_id': '4915171409819749077150897354',
#   'x': 1210.1875,
#   'y': 1234.484375,
#   'width': 30.0,
#   'height': 30.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9989134073,
#   'sort_key': 900.0},
#  {'element_id': '8094621526819749077556709669',
#   'x': 1245.703125,
#   'y': 204.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '0990039811819749077648086358',
#   'x': 1296.84375,
#   'y': 232.625,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '5507725588819749073955605941',
#   'x': 1296.84375,
#   'y': 260.5,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '5327252787819749079838981080',
#   'x': 1245.703125,
#   'y': 232.625,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '1934356804819749079381777012',
#   'x': 1245.703125,
#   'y': 260.5,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '2160852013819749072643963530',
#   'x': 1245.703125,
#   'y': 176.875,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '7785703754819749079382367372',
#   'x': 1296.84375,
#   'y': 288.375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '7922534316819749075518574241',
#   'x': 1194.5625,
#   'y': 204.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '8767785839819749074105463852',
#   'x': 1194.5625,
#   'y': 232.625,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '7602464007819749074142697582',
#   'x': 1194.5625,
#   'y': 260.5,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '8544367721819749073263360372',
#   'x': 1296.84375,
#   'y': 176.875,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '5556665962819749070946741254',
#   'x': 1194.5625,
#   'y': 288.375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '4492953170819749073688024048',
#   'x': 1296.84375,
#   'y': 204.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '5873821341819749079824499593',
#   'x': 1245.703125,
#   'y': 288.375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '8539073066819749071084316950',
#   'x': 855.546875,
#   'y': 694.5,
#   'width': 20.0,
#   'height': 20.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 0.9990667701,
#   'sort_key': 400.0},
#  {'element_id': '1848131428819749071902822396',
#   'x': 792.0,
#   'y': 694.5,
#   'width': 20.0,
#   'height': 20.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 400.0},
#  {'element_id': '9145381629819749076060241099',
#   'x': 1238.0,
#   'y': 585.0,
#   'width': 8.0,
#   'height': 8.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 64.0},
#  {'element_id': '8251134407819749073829862822',
#   'x': 1238.0,
#   'y': 624.0,
#   'width': 8.0,
#   'height': 8.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 64.0}]
# CPU times: user 113 ms, sys: 16.6 ms, total: 130 ms
# Wall time: 3.79 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id            x            y       width  \
# 0  0341900627819749075984273779   781.000000  1462.000000  443.187500
# 1  2173738591819749073491263502   170.000000  1178.000000  500.000000
# 2  7197964663819749078377978250   833.796875  1226.484375  422.390625
# 3  8118156281819749083835378446   577.656250  3173.984375  343.656250
# 4  5187649034819749076806570160  1180.000000   736.000000  360.000000
#
#        height predicted_label  predicted_probability       sort_key tag_name
# 0  434.375000      radiogroup               0.926627  192509.570312     CODE
# 1  221.000000          dialog               0.532511  110500.000000      DIV
# 2  143.015625            tabs               0.999995   60408.459229      DIV
# 3  162.031250           table               1.000000   55683.051758    TABLE
# 4   86.015625       accordion               1.000000   30965.625000      DIV

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))

# %%
PREDICT_URL = 'http://localhost:5050/get_tasks_statuses'
response = requests.post(
    PREDICT_URL, data=dataset_json[10]
)

# %%
response.json()
# Out:
# {'exc': 'Expecting value: line 1 column 1 (char 0)'}
