# %%
import pandas as pd

# %%
df_499 = pd.read_pickle("/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/site-499.pkl")

# %%
df_499[~df_499.parent_id.isna()]
# Out:
#                                              attributes  displayed  \
# 1                                                  None      False
# 2                                  {'charset': 'utf-8'}      False
# 3              {'href': './favicon.ico', 'rel': 'icon'}      False
# 4     {'content': 'width=device-width,initial-scale=...      False
# 5         {'content': '#000000', 'name': 'theme-color'}      False
# ...                                                 ...        ...
# 1861    {'data-test': 'sentinelStart', 'tabindex': '0'}      False
# 1862  {'class': 'MuiPaper-root MuiPopover-paper jss5...       True
# 1863  {'class': 'MuiTypography-root MuiTypography-bo...       True
# 1864      {'data-test': 'sentinelEnd', 'tabindex': '0'}      False
# 1865                                               None       True
#
#                         element_id  height onmouseenter onmouseover  \
# 1     5110628664739463020550042836     0.0         None        None
# ...

# %%
n=0
df = df_499["element_id", "parent_id", "attributes", "tag_name"]
df[f"descendant_{n}_id"] = df["element_id"]
df.columns = [f"descendant_{n}_attr", f"descendant_{n}_attr", f"descendant_{n}_tag"]

# while df[f"descendant_{n}_id"].isna().sum() > 0:
#     column_list = [f"descendant_{n}_attr", f"descendant_{n}_attr", f"descendant_{n}_tag"]
#     df = pd.merge([df, df[]])
# Out:
#                                              attributes  displayed  \
# 0                                        {'lang': 'en'}       True
# 1                                                  None      False
# 2                                  {'charset': 'utf-8'}      False
# 3              {'href': './favicon.ico', 'rel': 'icon'}      False
# 4     {'content': 'width=device-width,initial-scale=...      False
# ...                                                 ...        ...
# 1861    {'data-test': 'sentinelStart', 'tabindex': '0'}      False
# 1862  {'class': 'MuiPaper-root MuiPopover-paper jss5...       True
# 1863  {'class': 'MuiTypography-root MuiTypography-bo...       True
# 1864      {'data-test': 'sentinelEnd', 'tabindex': '0'}      False
# 1865                                               None       True
#
#                         element_id     height onmouseenter onmouseover  \
# 0     3636369781739463028244590606  7073.5625         None        None
# ...

# %%
followers_tags_df
# Out:
#                         parent_id   tag_name
# 0    0022020089739463045447433196       path
# 1    0024963688739463034202941628       path
# 2    0025323278739463044973569995  SPAN,SPAN
# 3    0032509572739463046664450777       SPAN
# 4    0064220727739463038384927398       SPAN
# ..                            ...        ...
# 649  9891374568739463045906622857  SPAN,SPAN
# 650  9894143842739463044352434981       path
# 651  9922057877739463041748560065       path
# 652  9991288799739463033013916941       path
# 653  9997487682739463032675858288       SPAN
#
# [654 rows x 2 columns]
