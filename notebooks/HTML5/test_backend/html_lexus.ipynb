# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'HTML5_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/html5_dataset')

# %%
DATASET_NAME = 'lexus'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://discoverlexus.com/experiences/select'
PREDICT_URL = 'http://localhost:5050/html5-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 2
# HEADLESS = True

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2022-01-25 15:48:30,753 -INFO - config.py:31 - Module utils.config was loaded
# 2022-01-25 15:48:30,776 -INFO - common.py:119 - Module utils.common is loaded...
# 2022-01-25 15:48:30,777 -INFO - dataset_builder.py:246 - dataset package is loaded...

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=False, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2022-01-25 15:49:57,365 -INFO - dataset_builder.py:100 - Dataset name: lexus
# 2022-01-25 15:49:57,367 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2022-01-25 15:49:57,370 -INFO - dataset_builder.py:152 - Creating driver
# 2022-01-25 15:50:00,061 -INFO - dataset_builder.py:164 - Chrome web driver is created
# 2022-01-25 15:50:13,657 -INFO - common.py:22 - Window maximized
# 2022-01-25 15:50:20,664 -INFO - dataset_builder.py:167 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/images/lexus.png
# 2022-01-25 15:50:22,041 -INFO - dataset_builder.py:211 - Collect features using JS script
# 2022-01-25 15:50:22,788 -INFO - dataset_builder.py:219 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/html/lexus.html
# 2022-01-25 15:50:22,890 -INFO - dataset_builder.py:231 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/df/lexus.pkl
# 2022-01-25 15:50:22,897 -INFO - dataset_builder.py:234 - No attributes: (60, 14)
# 2022-01-25 15:50:23,057 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '9231858077150220886715604419',
#   'is_hidden': 1,
#   'x': 239.0,
#   'y': 204.0,
#   'width': 972.0,
#   'height': 40.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 38880.0},
#  {'element_id': '1309536007150220882094363895',
#   'is_hidden': 0,
#   'x': 1209.96875,
#   'y': 43.0,
#   'width': 123.40625,
#   'height': 53.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6540.53125},
#  {'element_id': '9958383651150220881023127776',
#   'is_hidden': 0,
#   'x': 1108.4375,
#   'y': 43.0,
#   'width': 107.53125,
#   'height': 53.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 5699.15625},
#  {'element_id': '3289486255150220882207795446',
#   'is_hidden': 0,
#   'x': 928.28125,
#   'y': 43.0,
#   'width': 104.46875,
#   'height': 53.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 5536.84375},
#  {'element_id': '0883254268150220887874250793',
#   'is_hidden': 0,
#   'x': 843.359375,
#   'y': 43.0,
#   'width': 90.921875,
#   'height': 53.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4818.859375},
#  {'element_id': '1451660948150220881224409863',
#   'is_hidden': 0,
#   'x': 1026.75,
#   'y': 43.0,
#   'width': 87.6875,
#   'height': 53.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4647.4375},
#  {'element_id': '5711635564150220885055373054',
#   'is_hidden': 0,
#   'x': 112.0,
#   'y': 47.0,
#   'width': 150.0,
#   'height': 27.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4050.0},
#  {'element_id': '8554245694150220884086467104',
#   'is_hidden': 0,
#   'x': 234.0,
#   'y': 109.0,
#   'width': 135.0,
#   'height': 20.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 2700.0},
#  {'element_id': '7546484592150220889860215874',
#   'is_hidden': 0,
#   'x': 1252.34375,
#   'y': 113.0,
#   'width': 135.65625,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1627.875},
#  {'element_id': '6124922168150220884667518826',
#   'is_hidden': 0,
#   'x': 1252.34375,
#   'y': 113.0,
#   'width': 135.65625,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1627.875},
#  {'element_id': '2200128606150220885801059858',
#   'is_hidden': 0,
#   'x': 383.265625,
#   'y': 63.0,
#   'width': 135.65625,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1627.875},
#  {'element_id': '9083342908150220881057109043',
#   'is_hidden': 0,
#   'x': 1252.34375,
#   'y': 113.5,
#   'width': 135.65625,
#   'height': 12.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1627.875},
#  {'element_id': '4694193897150220880794179176',
#   'is_hidden': 1,
#   'x': 1221.0,
#   'y': 204.0,
#   'width': 40.0,
#   'height': 40.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0},
#  {'element_id': '4394608373150220885168227400',
#   'is_hidden': 0,
#   'x': 450.0,
#   'y': 109.0,
#   'width': 75.0,
#   'height': 20.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 1500.0},
#  {'element_id': '7350986316150220889542164370',
#   'is_hidden': 0,
#   'x': 1006.984375,
#   'y': 65.0,
#   'width': 93.4375,
#   'height': 9.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 840.9375},
#  {'element_id': '8264314662150220888029248613',
#   'is_hidden': 0,
#   'x': 1137.421875,
#   'y': 65.0,
#   'width': 56.890625,
#   'height': 9.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 512.015625},
#  {'element_id': '2839429153150220884534444874',
#   'is_hidden': 0,
#   'x': -19.71875,
#   'y': -5.828125,
#   'width': 40.4375,
#   'height': 12.640625,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 511.1552734375},
#  {'element_id': '8669461924150220885753819361',
#   'is_hidden': 0,
#   'x': 1231.3125,
#   'y': 65.0,
#   'width': 56.6875,
#   'height': 9.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 510.1875},
#  {'element_id': '0133471055150220882441507572',
#   'is_hidden': 0,
#   'x': -19.21875,
#   'y': -6.328125,
#   'width': 38.4375,
#   'height': 12.640625,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 485.8740234375},
#  {'element_id': '7547186984150220880424335910',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 32.1875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '6934681725150220888757526571',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '1815856572150220881920614342',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 48.28125,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '5293728894150220880352520854',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 16.09375,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '5469345592150220887858960357',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8532119193150220881216485880',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9679826945150220889347954451',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 1.0,
#   'height': 0.0,
#   'predicted_label': 'checklist',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9334262321150220885296468785',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1715669862150220888815655967',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1716983719150220888967536179',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9038992419150220889917615797',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8882543521150220884591991699',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4935512627150220887905914338',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '1929683853150220882596290929',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2133960248150220884294711650',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3740688613150220883267343382',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7885668811150220888614525198',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4901936413150220884272799934',
#   'is_hidden': 1,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2362702293150220886494548131',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7483966398150220888411936815',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2433810269150220883594608808',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7317532961150220884265390849',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3972898784150220884300516042',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3443872590150220882109583499',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4795866828150220886795402004',
#   'is_hidden': 0,
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0}]
# CPU times: user 54.2 ms, sys: 12.6 ms, total: 66.9 ms
# Wall time: 1.79 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id  is_hidden            x      y       width  \
# 0  9231858077150220886715604419          1   239.000000  204.0  972.000000
# 1  1309536007150220882094363895          0  1209.968750   43.0  123.406250
# 2  9958383651150220881023127776          0  1108.437500   43.0  107.531250
# 3  3289486255150220882207795446          0   928.281250   43.0  104.468750
# 4  0883254268150220887874250793          0   843.359375   43.0   90.921875
#
#    height predicted_label  predicted_probability      sort_key tag_name
# 0    40.0       textfield                    1.0  38880.000000    INPUT
# 1    53.0            link                    1.0   6540.531250        A
# 2    53.0            link                    1.0   5699.156250        A
# 3    53.0            link                    1.0   5536.843750        A
# 4    53.0            link                    1.0   4818.859375        A

# %%
predictions_df.predicted_label.unique()
# Out:
# array(['textfield', 'link', 'text', 'label', 'title', 'checkbox',
#        'checklist', 'button'], dtype=object)

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
        if r.is_hidden==0:
                patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
                axes.add_patch(patch)
                axes.text(r.x*2, r.y*2, 
                        str(r.predicted_label) + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                        backgroundcolor='black', 
                        color='white',
                        bbox=dict(alpha=0.5))
