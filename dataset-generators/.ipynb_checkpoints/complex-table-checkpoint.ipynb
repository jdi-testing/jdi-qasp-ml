# %%
import sys
import re
import os
from datetime import datetime
from time import sleep
from IPython.display import display, clear_output, HTML

# set working dir
WORKING_DIR = re.sub('jdi-qasp-ml.*$','',os.path.normpath(os.getcwd())) + 'jdi-qasp-ml'
os.chdir(WORKING_DIR)

import utils
from utils import *
import torch
import pandas as pd
import numpy as np
import torch
from glob import glob
import selenium

START_TS = datetime.now()
display(HTML(f'{START_TS} - Current working directory: <b>{WORKING_DIR}</b>'))

import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

import numba
# Out:
# 2021-06-01 22:39:02,612 -INFO - config:config.py:16 - Module utils.config was loaded
# 2021-06-01 22:39:02,612 -INFO - common:common.py:616 - Module utils.common is loaded...
# 2021-06-01 22:39:02,612 -INFO - hidden:hidden.py:121 - hidden module is loaded
# 2021-06-01 22:39:02,622 -INFO - dataset_builder:dataset_builder.py:200 - dataset package is loaded...
# 2021-06-01 22:39:03,260 -INFO - dataset:dataset.py:652 - dataset module is loaded...
# 2021-06-01 22:39:03.260723 - Current working directory: <b>D:\DataScience\!WORK\jdi-qasp-ml</b>

# %%
from utils import get_all_elements, iou_xywh, screenshot, maximize_window, get_parents_list, build_tree_dict, DatasetBuilder

# %%
selenium.__version__
# Out:
# '3.141.0'

# %% [markdown]
# # Parameters

# %%
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
HEADLESS = True #False

# %%
with open('dataset/classes.txt', 'r') as f:
    decoder_dict = { i:s.strip() for i, s in  enumerate(f.readlines())}
decoder_dict
# Out:
# {0: 'button',
#  1: 'link',
#  2: 'iframe',
#  3: 'textfield',
#  4: 'dropdown',
#  5: 'checkbox_btn',
#  6: 'checkbox_label',
#  7: 'radiobutton_btn',
#  8: 'radiobutton_label',
#  9: 'textarea',
#  10: 'text',
#  11: 'fileinput',
#  12: 'image',
#  13: 'colorpicker',
#  14: 'range',
#  15: 'progressbar',
#  16: 'datetimeselector',
#  17: 'numberselector',
#  18: 'dropdownselector',
#  19: 'checklist',
#  20: 'table',
#  21: 'n/a'}

# %% [markdown]
# # Generate dataset

# %%
DATASET_NAME = 'dummy'
class JDIDatasetBuilder(DatasetBuilder):

    def setUp(self, driver):
        self.logger.info(f'getting page')
        driver.get(SITE_URL)
        
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        
        driver.find_element_by_link_text("Service").click()
        driver.find_element_by_link_text("Complex Table").click()
        maximize_window(driver=driver)
        

with JDIDatasetBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True) as builder:
    elements_df = builder.dataset
    plt.imshow(plt.imread(f'dataset/images/{DATASET_NAME}.png'))
# Out:
# 2021-06-01 22:39:03,383 -WARNING - dataset_builder:dataset_builder.py:75 - The default dataset name "dummy" will be used
# 2021-06-01 22:39:03,383 -INFO - dataset_builder:dataset_builder.py:86 - Create directories to save the dataset
# 2021-06-01 22:39:03,383 -INFO - dataset_builder:dataset_builder.py:121 - Creating driver
# 2021-06-01 22:39:04,469 -INFO - dataset_builder:dataset_builder.py:129 - Chrome web driver is created
# 2021-06-01 22:39:04,469 -INFO - <ipython-input-6-539263dfd9ac>:<ipython-input-6-539263dfd9ac>:5 - getting page
# 2021-06-01 22:39:12,327 -INFO - common:common.py:75 - Window maximized
# 2021-06-01 22:39:12,327 -INFO - dataset_builder:dataset_builder.py:132 - save scrinshot: dataset/images/dummy.png
# 2021-06-01 22:39:12,389 -INFO - dataset_builder:dataset_builder.py:176 - Collect features using JS script
# 2021-06-01 22:39:12,699 -INFO - dataset_builder:dataset_builder.py:184 - Save html to dataset/html/dummy.html
# 2021-06-01 22:39:12,711 -INFO - dataset_builder:dataset_builder.py:194 - Save parquet to dataset/df/dummy.parquet
# 2021-06-01 22:39:12,815 -INFO - dataset_builder:dataset_builder.py:99 - Close web driver

# %%
df = pd.read_parquet(f'dataset/df/{DATASET_NAME}.parquet')

# %%
df = build_features(df)
# Out:
# 2021-06-01 22:39:13,154 -INFO - hidden:hidden.py:107 - build field "is_hidden"

# %%
elements_dict = build_elements_dict(df)

# %%
df[['tag_name', 'element_id', 'parent_id', 'upper_sibling', 'lower_sibling', 'displayed', 'is_hidden', 'x', 'y', 'width', 'height']]
# Out:
#     tag_name                    element_id                     parent_id  \
# 0       HTML  2570685367763524031792107125                          None
# 1       HEAD  2391326805763524032419164391  2570685367763524031792107125
# 2       META  8073948390763524039523767235  2391326805763524032419164391
# 3      TITLE  6413402079763524037308716685  2391326805763524032419164391
# 4       META  7330371907763524031985668178  2391326805763524032419164391
# ..       ...                           ...                           ...
# 421       LI  4463669206763524046340303865  7589452435763524042008878960
# 422        A  9068651460763524044349397594  4463669206763524046340303865
# 423   SCRIPT  7223418055763524040981783636  9455592694763524045401704525
# 424   SCRIPT  6221472316763524042504600018  9455592694763524045401704525
# 425   SCRIPT  1665347767763524047113346888  9455592694763524045401704525
#
#                     upper_sibling                 lower_sibling  displayed  \
# 0                            None                          None       True
# 1                            None  9455592694763524045401704525      False
# 2                            None  6413402079763524037308716685      False
# 3    8073948390763524039523767235  7330371907763524031985668178      False
# 4    6413402079763524037308716685  5901188992763524041956644765      False
# ..                            ...                           ...        ...
# 421  8830220249763524045604542798                          None       True
# 422                          None                          None       True
# 423  3716403338763524048903670965  6221472316763524042504600018      False
# 424  7223418055763524040981783636  1665347767763524047113346888      False
# 425  6221472316763524042504600018                          None      False
#
#      is_hidden            x      y        width  height
# 0            0     0.000000    0.0  1183.000000   850.0
# 1            0     0.000000    0.0     0.000000     0.0
# 2            0     0.000000    0.0     0.000000     0.0
# 3            0     0.000000    0.0     0.000000     0.0
# 4            0     0.000000    0.0     0.000000     0.0
# ..         ...          ...    ...          ...     ...
# 421          0  1115.890625  828.0    64.109375    15.0
# 422          0  1115.890625  828.0    64.109375    15.0
# 423          1     0.000000    0.0     0.000000     0.0
# 424          1     0.000000    0.0     0.000000     0.0
# 425          1     0.000000    0.0     0.000000     0.0
#
# [426 rows x 11 columns]

# %%
img = load_gray_image('dataset/images/dummy.png')
img_height, img_width = img.shape
print(img_width, img_height)
plt.figure(figsize=(15, 100))
plt.imshow(img, cmap='gray')
# Out:
# 1200 867

# %%
predictions_df = rule_base_predict(df)
print(predictions_df.shape)
predictions_df
# Out:
# 2021-06-01 22:39:13,854 -INFO - common:common.py:489 - Num radio buttons found: 0
# 2021-06-01 22:39:13,857 -INFO - common:common.py:493 - Num radio2 buttons found: 0
# 2021-06-01 22:39:13,860 -INFO - common:common.py:500 - Num checkboxes found: 16
# 2021-06-01 22:39:13,864 -INFO - common:common.py:507 - Num comboboxes/dropdowns found: 0
# 2021-06-01 22:39:13,867 -INFO - common:common.py:518 - Num textfields found: 2
# 2021-06-01 22:39:13,870 -INFO - common:common.py:523 - Num texfields for numbers found: 0
# 2021-06-01 22:39:13,873 -INFO - common:common.py:528 - Num ranges found: 0
# 2021-06-01 22:39:13,875 -INFO - common:common.py:533 - Num ordinary text inputs found: 0
# 2021-06-01 22:39:13,878 -INFO - common:common.py:536 - Num buttons found: 5
# Button1:  ['9732621066763524043941598578']
# 2021-06-01 22:39:13,881 -INFO - common:common.py:541 - Num buttons1 found: 1
# 2021-06-01 22:39:13,883 -INFO - common:common.py:546 - Num buttons2 (Material-UI) found: 0
# 2021-06-01 22:39:13,885 -INFO - common:common.py:551 - Num links found: 71
# (55, 8)
#                        element_id            x      y       width  height  \
# 211  0721650082763524045592206313   463.000000  191.0  126.000000    21.0
# 217  2721615871763524041444718619   610.000000  191.0  193.000000    21.0
# 226  8040585584763524047513600241   463.000000  271.0  126.000000    21.0
# 232  0060048662763524048108485585   610.000000  271.0  193.000000    21.0
# 241  3949380490763524049608376958   463.000000  360.0  126.000000    21.0
# 247  0478661416763524047483639464   610.000000  351.0  193.000000    21.0
# 256  2233706780763524046067929204   463.000000  450.0  126.000000    21.0
# 262  4582543479763524040352222835   610.000000  450.0  193.000000    21.0
# 340  4596146017763524047746158902   240.000000  569.0  220.000000    34.0
# 357  3309542806763524044634917738   240.000000  613.0  110.578125    34.0
# 358  6488154549763524046343267498   363.390625  613.0   74.218750    34.0
# 94   9732621066763524043941598578  1000.468750   20.0   20.000000    20.0
# 34   0669924157763524043878513654    20.000000   21.0   86.000000    18.0
# 241       True          0      5
# 247       True          0      5
# 256       True          0      5
# 262       True          0      5
# 340       True          0      0
# 357       True          0      0
# 358       True          0      0
# 94        True          0      0
# 34        True          0      1
# 40        True          0      1
# 42        True          0      1
# 44        True          0      1
# 66        True          0      1
# 69        True          0      1
# 108       True          0      1
# 111       True          0      1
# 114       True          0      1
# 119       True          0      1
# 123       True          0      1
# 126       True          0      1
# 129       True          0      1
# 132       True          0      1
# 135       True          0      1
# 138       True          0      1
# 141       True          0      1
# 144       True          0      1
# 147       True          0      1
# 150       True          0      1
# 214       True          0      1
# 220       True          0      1
# 229       True          0      1
# 235       True          0      1
# 244       True          0      1
# 250       True          0      1
# 259       True          0      1
# 265       True          0      1
# 361       True          0      1
# 364       True          0      1
# 366       True          0      1
# 368       True          0      1
# 370       True          0      1
# 372       True          0      1
# 374       True          0      1
# 376       True          0      1
# 378       True          0      1
# 380       True          0      1
# 382       True          0      1
# 384       True          0      1
# 386       True          0      1
# 419       True          0      1
# 422       True          0      1

# %%
img = load_gray_image('dataset/images/dummy.png')
img_height, img_width = img.shape
print(img_width, img_height)
plt.figure(figsize=(15, 100))
plt.imshow(img, cmap='gray')
axes = plt.gca()

for _, r in predictions_df.iterrows():
    
    patch = patches.Rectangle((r.x, r.y), r.width, r.height, linewidth=2, alpha = .3, facecolor = 'red', edgecolor ='black')
    axes.add_patch(patch)
    plt.text(r.x, r.y, 
             decoder_dict[r.label] + ':',  ## + r.element_id, 
             fontsize = 10, 
             color = 'white', 
             backgroundcolor='black',
             alpha=1.)
# Out:
# 1200 867

# %%
labels = build_to_yolo(df = predictions_df, img_width=img_width, img_heght=img_height)
labels
# Out:
# array([[5.      , 0.438333, 0.232411, 0.105   , 0.024221],
#        [5.      , 0.58875 , 0.232411, 0.160833, 0.024221],
#        [5.      , 0.438333, 0.324683, 0.105   , 0.024221],
#        [5.      , 0.58875 , 0.324683, 0.160833, 0.024221],
#        [5.      , 0.438333, 0.427336, 0.105   , 0.024221],
#        [5.      , 0.58875 , 0.416955, 0.160833, 0.024221],
#        [5.      , 0.438333, 0.531142, 0.105   , 0.024221],
#        [5.      , 0.58875 , 0.531142, 0.160833, 0.024221],
#        [0.      , 0.291667, 0.675894, 0.183333, 0.039216],
#        [0.      , 0.246074, 0.726644, 0.092148, 0.039216],
#        [0.      , 0.33375 , 0.726644, 0.061849, 0.039216],
#        [0.      , 0.842057, 0.034602, 0.016667, 0.023068],
#        [1.      , 0.0525  , 0.034602, 0.071667, 0.020761],
#        [1.      , 0.212663, 0.034602, 0.053763, 0.069204],
#        [1.      , 0.290319, 0.034602, 0.101549, 0.069204],
#        [1.      , 0.380072, 0.034602, 0.077956, 0.069204],
#        [1.      , 0.477585, 0.034602, 0.11707 , 0.069204],
#        [1.      , 0.983333, 0.034602, 0.033333, 0.023068],
#        [1.      , 0.083333, 0.091696, 0.166667, 0.044983],
#        [1.      , 0.083333, 0.138985, 0.166667, 0.044983],
#        [1.      , 0.083333, 0.186275, 0.166667, 0.044983],
#        [1.      , 0.083333, 0.233564, 0.166667, 0.049596],
#        [1.      , 0.083333, 0.280277, 0.166667, 0.043829],
#        [1.      , 0.083333, 0.324106, 0.166667, 0.043829],
#        [1.      , 0.083333, 0.367935, 0.166667, 0.043829],
#        [1.      , 0.083333, 0.411765, 0.166667, 0.043829],
#        [1.      , 0.083333, 0.455594, 0.166667, 0.043829],
#        [1.      , 0.083333, 0.499423, 0.166667, 0.043829],
#        [1.      , 0.083333, 0.543253, 0.166667, 0.043829],
#        [1.      , 0.083333, 0.587082, 0.166667, 0.043829],
#        [1.      , 0.083333, 0.633795, 0.166667, 0.044983],
#        [1.      , 0.083333, 0.681084, 0.166667, 0.044983],
#        [1.      , 0.438333, 0.254902, 0.044661, 0.020761],
#        [1.      , 0.58875 , 0.254902, 0.044661, 0.020761],
#        [1.      , 0.438333, 0.347174, 0.044661, 0.020761],
#        [1.      , 0.58875 , 0.347174, 0.044661, 0.020761],
#        [1.      , 0.438333, 0.449827, 0.044661, 0.020761],
#        [1.      , 0.58875 , 0.439446, 0.044661, 0.020761],
#        [1.      , 0.438333, 0.553633, 0.044661, 0.020761],
#        [1.      , 0.58875 , 0.553633, 0.044661, 0.020761],
#        [1.      , 0.267786, 0.847751, 0.033333, 0.036909],
#        [1.      , 0.305072, 0.847751, 0.042904, 0.036909],
#        [1.      , 0.339427, 0.847751, 0.027474, 0.036909],
#        [1.      , 0.366068, 0.847751, 0.027474, 0.036909],
#        [1.      , 0.392708, 0.847751, 0.027474, 0.036909],
#        [1.      , 0.419349, 0.847751, 0.027474, 0.036909],
#        [1.      , 0.44599 , 0.847751, 0.027474, 0.036909],
#        [1.      , 0.47263 , 0.847751, 0.027474, 0.036909],
#        [1.      , 0.499271, 0.847751, 0.027474, 0.036909],
#        [1.      , 0.525911, 0.847751, 0.027474, 0.036909],
#        [1.      , 0.552552, 0.847751, 0.027474, 0.036909],
#        [1.      , 0.586367, 0.847751, 0.041823, 0.036909],
#        [1.      , 0.623112, 0.847751, 0.033333, 0.036909],
#        [1.      , 0.889876, 0.963668, 0.025221, 0.017301],
#        [1.      , 0.956621, 0.963668, 0.053424, 0.017301]])

# %% [markdown]
# # Save labels

# %%
labeled_df = pd.DataFrame(labels, columns=['label', 'x', 'y', 'width', 'height'])
display(labeled_df)
labeled_df.to_csv(f'dataset/annotations/{DATASET_NAME}.txt', header=False, sep=' ', index=False)
# Out:
#     label         x         y     width    height
# 0     5.0  0.438333  0.232411  0.105000  0.024221
# 1     5.0  0.588750  0.232411  0.160833  0.024221
# 2     5.0  0.438333  0.324683  0.105000  0.024221
# 3     5.0  0.588750  0.324683  0.160833  0.024221
