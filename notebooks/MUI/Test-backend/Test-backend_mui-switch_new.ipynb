# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-11-25 08:55:07,586 -INFO - config.py:31 - Module utils.config was loaded
# 2021-11-25 08:55:07,632 -INFO - common.py:127 - Module utils.common is loaded...
# 2021-11-25 08:55:07,639 -INFO - dataset_builder.py:244 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'mui-switch'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/basic_switches'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-11-25 08:55:29,165 -INFO - dataset_builder.py:100 - Dataset name: mui-switch
# 2021-11-25 08:55:29,166 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-11-25 08:55:29,168 -INFO - dataset_builder.py:150 - Creating driver
# 2021-11-25 08:55:30,069 -INFO - dataset_builder.py:162 - Chrome web driver is created
# 2021-11-25 08:55:33,989 -INFO - common.py:30 - Window maximized
# 2021-11-25 08:55:40,993 -INFO - dataset_builder.py:165 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/mui-switch.png
# 2021-11-25 08:55:46,282 -INFO - dataset_builder.py:209 - Collect features using JS script
# 2021-11-25 08:55:46,768 -INFO - dataset_builder.py:217 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/mui-switch.html
# 2021-11-25 08:55:46,781 -INFO - dataset_builder.py:229 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/mui-switch.pkl
# 2021-11-25 08:55:46,784 -INFO - dataset_builder.py:232 - No attributes: (9, 13)
# 2021-11-25 08:55:51,037 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '5271785514197462880690304627',
#   'x': 274,
#   'y': 257.078125,
#   'width': 167.671875,
#   'height': 114.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 0.999997139,
#   'sort_key': 19114.59375},
#  {'element_id': '0005908593197462885069366848',
#   'x': 0,
#   'y': 1152.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6061145067197462881404074041',
#   'x': 0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6397880851197462881999460682',
#   'x': 0,
#   'y': 2016.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6343958418197462880167705580',
#   'x': 0,
#   'y': 1632.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999934435,
#   'sort_key': 12000.0},
#  {'element_id': '6170405977197462879392004450',
#   'x': 0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6158648352197462881427619685',
#   'x': 0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6093062612197462875749336393',
#   'x': 0,
#   'y': 288.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6082537773197462889164898392',
#   'x': 0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6048361173197462874201050130',
#   'x': 0,
#   'y': 336.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6606787204197462873555255888',
#   'x': 0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5933683934197462875376464050',
#   'x': 0,
#   'y': 816.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5789636450197462879314926849',
#   'x': 0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5580739053197462883119686467',
#   'x': 0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5241185465197462884103554695',
#   'x': 0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5201126195197462887807808259',
#   'x': 0,
#   'y': 2112.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5051710752197462874707779468',
#   'x': 0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999982119,
#   'sort_key': 12000.0},
#  {'element_id': '6559295422197462873258490594',
#   'x': 0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6772896384197462870876478449',
#   'x': 0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4792843797197462870831325592',
#   'x': 0,
#   'y': 432.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6847675479197462880910613956',
#   'x': 0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9402977745197462883907621807',
#   'x': 0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8968657100197462882199522414',
#   'x': 0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8672876180197462883196856442',
#   'x': 0,
#   'y': 2592.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8539580558197462879853313255',
#   'x': 0,
#   'y': 672.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999934435,
#   'sort_key': 12000.0},
#  {'element_id': '8442424350197462880713110672',
#   'x': 0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8206187468197462882057719558',
#   'x': 0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '

#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '6921011756197462888793588732',
#   'x': 294,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '4547765405197462885986082416',
#   'x': 283,
#   'y': 333.078125,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '0247914332197462883198044094',
#   'x': 584,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '8793582366197462886078061044',
#   'x': 263,
#   'y': 295.078125,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0}]
# CPU times: user 56.8 ms, sys: 17.2 ms, total: 74 ms
# Wall time: 1.88 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id    x            y       width  height  \
# 0  5271785514197462880690304627  274   257.078125  167.671875   114.0
# 1  0005908593197462885069366848    0  1152.000000  250.000000    48.0
# 2  6061145067197462881404074041    0  1488.000000  250.000000    48.0
# 3  6397880851197462881999460682    0  2016.000000  250.000000    48.0
# 4  6343958418197462880167705580    0  1632.000000  250.000000    48.0
#
#   predicted_label  predicted_probability     sort_key tag_name
# 0      radiogroup               0.999997  19114.59375      DIV
# 1          button               1.000000  12000.00000      DIV
# 2          button               1.000000  12000.00000      DIV
# 3          button               1.000000  12000.00000      DIV
# 4          button               0.999993  12000.00000      DIV

# %%
preds
# Out:
#                       element_id    x            y       width  height  \
# 0   5271785514197462880690304627  274   257.078125  167.671875   114.0
# 1   0005908593197462885069366848    0  1152.000000  250.000000    48.0
# 2   6061145067197462881404074041    0  1488.000000  250.000000    48.0
# 3   6397880851197462881999460682    0  2016.000000  250.000000    48.0
# 4   6343958418197462880167705580    0  1632.000000  250.000000    48.0
# ..                           ...  ...          ...         ...     ...
# 74  8187447105197462887654605763  352   138.218750   38.000000    38.0
# 75  6921011756197462888793588732  294   138.218750   38.000000    38.0
# 76  4547765405197462885986082416  283   333.078125   38.000000    38.0
# 77  0247914332197462883198044094  584   138.218750   38.000000    38.0
# 78  8793582366197462886078061044  263   295.078125   38.000000    38.0
#
#    predicted_label  predicted_probability     sort_key
# 0       radiogroup               0.999997  19114.59375
# 1           button               1.000000  12000.00000
# 2           button               1.000000  12000.00000
# 3           button               1.000000  12000.00000
# 4           button               0.999993  12000.00000
# ..             ...                    ...          ...
# 74          switch               1.000000   1444.00000
# 75          switch               1.000000   1444.00000
# 76          switch               1.000000   1444.00000
# 77          switch               1.000000   1444.00000
# 78          switch               1.000000   1444.00000
#
# [79 rows x 8 columns]

# %%
from_pkl = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')
from_pkl[from_pkl.element_id == '1049561488694071642269580342']
# Out:
# Empty DataFrame
# Columns: [attributes, displayed, element_id, height, onmouseenter, onmouseover, parent_id, style, tag_name, text, width, x, y]
# Index: []

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))

# %%
PREDICT_URL = 'http://localhost:5050/get_tasks_statuses'
response = requests.post(
    PREDICT_URL, data=dataset_json[10]
)

# %%
response.json()
# Out:
# {'exc': 'Expecting value: line 1 column 1 (char 0)'}
