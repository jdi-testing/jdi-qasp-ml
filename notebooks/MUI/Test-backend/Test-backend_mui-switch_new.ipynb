# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-11-29 18:59:00,073 -INFO - config.py:31 - Module utils.config was loaded
# 2021-11-29 18:59:00,108 -INFO - common.py:119 - Module utils.common is loaded...
# 2021-11-29 18:59:00,110 -INFO - dataset_builder.py:245 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'mui-switch'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/basic_switches'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-11-29 18:59:00,325 -INFO - dataset_builder.py:100 - Dataset name: mui-switch
# 2021-11-29 18:59:00,328 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-11-29 18:59:00,330 -INFO - dataset_builder.py:151 - Creating driver
# 2021-11-29 18:59:01,918 -INFO - dataset_builder.py:163 - Chrome web driver is created
# 2021-11-29 18:59:08,852 -INFO - common.py:22 - Window maximized
# 2021-11-29 18:59:15,857 -INFO - dataset_builder.py:166 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/mui-switch.png
# 2021-11-29 18:59:22,178 -INFO - dataset_builder.py:210 - Collect features using JS script
# 2021-11-29 18:59:22,750 -INFO - dataset_builder.py:218 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/mui-switch.html
# 2021-11-29 18:59:22,769 -INFO - dataset_builder.py:230 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/mui-switch.pkl
# 2021-11-29 18:59:22,773 -INFO - dataset_builder.py:233 - No attributes: (9, 13)
# 2021-11-29 18:59:29,420 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '7589077348015621850930835237',
#   'x': 274,
#   'y': 257.078125,
#   'width': 167.671875,
#   'height': 114.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 0.6762567163,
#   'sort_key': 19114.59375},
#  {'element_id': '7581144268015621843967712292',
#   'x': 0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7162259416015621842836420623',
#   'x': 0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '7277039004015621843660186312',
#   'x': 0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7356950650015621844888944998',
#   'x': 0,
#   'y': 2496.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '7401216948015621841321253984',
#   'x': 0,
#   'y': 288.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '7528379146015621849484819373',
#   'x': 0,
#   'y': 1872.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7566089188015621846851043270',
#   'x': 0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999946356,
#   'sort_key': 12000.0},
#  {'element_id': '0033076928015621843843805849',
#   'x': 0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5675295104015621841674594674',
#   'x': 0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '7603837062015621848687379936',
#   'x': 0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7637830022015621846553367363',
#   'x': 0,
#   'y': 144.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '7676280774015621846108415570',
#   'x': 0,
#   'y': 528.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999946356,
#   'sort_key': 12000.0},
#  {'element_id': '7707651448015621847813330573',
#   'x': 0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7713603882015621840750590854',
#   'x': 0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '7758576284015621849697196905',
#   'x': 0,
#   'y': 2208.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6957257496015621849594116320',
#   'x': 0,
#   'y': 2352.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6909551870015621844126856242',
#   'x': 0,
#   'y': 672.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999946356,
#   'sort_key': 12000.0},
#  {'element_id': '6902550758015621849006041450',
#   'x': 0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6764523185015621848284450776',
#   'x': 0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '6708642394015621846818489614',
#   'x': 0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '6704688608015621841668258106',
#   'x': 0,
#   'y': 2400.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '6654356483015621846779510616',
#   'x': 0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6518546918015621849385724399',
#   'x': 0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '6494291023015621848813592537',
#   'x': 0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '6491897629015621840716930215',
#   'x': 0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6490698998015621847654126085',
#   'x': 0,
#   'y': 1536.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '6331153551015621848047241134',
#   'x': 0,
#   'y': 432.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5974051897015621842753683142',
#   'x': 0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5924046243015621840490979822',
#   'x': 0,
#   'y': 1824.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5880712581015621840384702690',
#   'x': 0,
#   'y': 2448.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5849472641015621849111907813',
#   'x': 0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '0114771600015621843912996041',
#   'x': 0,
#   'y': 576.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '7765818318015621843463270816',
#   'x': 0,
#   'y': 1104.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8026217401015621844934080629',
#   'x': 0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8105127380015621842416892334',
#   'x': 0,
#   'y': 432.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9114401850015621847448465460',
#   'x': 0,
#   'y': 1104.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '9959193366015621849158910402',
#   'x': 0,
#   'y': 2064.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9958354990015621846765242818',
#   'x': 0,
#   'y': 2304.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '9766113216015621848051278593',
#   'x': 0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '9649374948015621844232400034',
#   'x': 0,
#   'y': 336.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9524405668015621841095751515',
#   'x': 0,
#   'y': 2544.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9495350076015621843142267530',
#   'x': 0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '
0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0389833537015621847229117502',
#   'x': 0,
#   'y': 192.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0345270997015621848354018181',
#   'x': 0,
#   'y': 816.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999946356,
#   'sort_key': 12000.0},
#  {'element_id': '0140771579015621843381417789',
#   'x': 0,
#   'y': 2160.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '2883546952015621848413545452',
#   'x': 0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '9974379293015621840957973361',
#   'x': 0,
#   'y': 1872.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '2940195915015621847833936799',
#   'x': 0,
#   'y': 2592.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5032784291015621844428386863',
#   'x': 0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4572882471015621842294083818',
#   'x': 0,
#   'y': 1920.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4587777068015621848827521591',
#   'x': 0,
#   'y': 336.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4896359768015621848862608280',
#   'x': 0,
#   'y': 1632.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999946356,
#   'sort_key': 12000.0},
#  {'element_id': '4912415665015621845584458317',
#   'x': 0,
#   'y': 384.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4915630675015621840751554142',
#   'x': 0,
#   'y': 288.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4957456721015621844057260415',
#   'x': 0,
#   'y': 480.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5101962095015621843830944486',
#   'x': 0,
#   'y': 2592.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2966222166015621849059564332',
#   'x': 0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5113901230015621844552737151',
#   'x': 0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5154469284015621844299936321',
#   'x': 0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5165179211015621844567165041',
#   'x': 0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5275755678015621844376026076',
#   'x': 0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5336108853015621848701601715',
#   'x': 0,
#   'y': 1152.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5341554777015621841776360010',
#   'x': 0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4567338541015621843125546728',
#   'x': 0,
#   'y': 2352.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4487151036015621844027894970',
#   'x': 0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '3622659428015621848598597978',
#   'x': 0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3081612131015621842126086466',
#   'x': 0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4249574668015621840699155765',
#   'x': 0,
#   'y': 2544.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '3302867446015621848289145443',
#   'x': 0,
#   'y': 2304.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3384348924015621847249654283',
#   'x': 0,
#   'y': 96.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4249176862015621842938286611',
#   'x': 0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '3935642476015621841992467229',
#   'x': 0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3811016416015621841829857354',
#   'x': 0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4392287240015621845703600867',
#   'x': 0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3713248049015621843556343056',
#   'x': 0,
#   'y': 1536.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3646368571015621843733608574',
#   'x': 0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3473055507015621847714616638',
#   'x': 0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6931327198015621856157278787',
#   'x': 584,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '9759367304015621854537451508',
#   'x': 263,
#   'y': 295.078125,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '8566666141015621858121644931',
#   'x': 283,
#   'y': 333.078125,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '8358907073015621851757999059',
#   'x': 448,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '2022875822015621846434884392',
#   'x': 294,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '7237829555015621844329378592',
#   'x': 352,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '1280994086015621853380547532',
#   'x': 283,
#   'y': 257.078125,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '1639553923015621850259247084',
#   'x': 390,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '2626638747015621853586930938',
#   'x': 526,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0}]
# CPU times: user 68.2 ms, sys: 19.8 ms, total: 87.9 ms
# Wall time: 3.54 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id    x            y       width  height  \
# 0  7589077348015621850930835237  274   257.078125  167.671875   114.0
# 1  7581144268015621843967712292    0   864.000000  250.000000    48.0
# 2  7162259416015621842836420623    0  1680.000000  250.000000    48.0
# 3  7277039004015621843660186312    0  1584.000000  250.000000    48.0
# 4  7356950650015621844888944998    0  2496.000000  250.000000    48.0
#
#   predicted_label  predicted_probability     sort_key tag_name
# 0      radiogroup               0.676257  19114.59375      DIV
# 1          button               1.000000  12000.00000      DIV
# 2            list               1.000000  12000.00000      DIV
# 3          button               1.000000  12000.00000      DIV
# 4            list               1.000000  12000.00000      DIV

# %%
preds
# Out:
#                        element_id    x            y       width  height  \
# 0    7589077348015621850930835237  274   257.078125  167.671875   114.0
# 1    7581144268015621843967712292    0   864.000000  250.000000    48.0
# 2    7162259416015621842836420623    0  1680.000000  250.000000    48.0
# 3    7277039004015621843660186312    0  1584.000000  250.000000    48.0
# 4    7356950650015621844888944998    0  2496.000000  250.000000    48.0
# ..                            ...  ...          ...         ...     ...
# 137  2022875822015621846434884392  294   138.218750   38.000000    38.0
# 138  7237829555015621844329378592  352   138.218750   38.000000    38.0
# 139  1280994086015621853380547532  283   257.078125   38.000000    38.0
# 140  1639553923015621850259247084  390   138.218750   38.000000    38.0
# 141  2626638747015621853586930938  526   138.218750   38.000000    38.0
#
#     predicted_label  predicted_probability     sort_key
# 0        radiogroup               0.676257  19114.59375
# 1            button               1.000000  12000.00000
# 2              list               1.000000  12000.00000
# 3            button               1.000000  12000.00000
# 4              list               1.000000  12000.00000
# ..              ...                    ...          ...
# 137          switch               1.000000   1444.00000
# 138          switch               1.000000   1444.00000
# 139          switch               1.000000   1444.00000
# 140          switch               1.000000   1444.00000
# 141          switch               1.000000   1444.00000
#
# [142 rows x 8 columns]

# %%
from_pkl = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')
from_pkl[from_pkl.element_id == '1049561488694071642269580342']
# Out:
# Empty DataFrame
# Columns: [attributes, displayed, element_id, height, onmouseenter, onmouseover, parent_id, style, tag_name, text, width, x, y]
# Index: []

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))

# %%
PREDICT_URL = 'http://localhost:5050/get_tasks_statuses'
response = requests.post(
    PREDICT_URL, data=dataset_json[10]
)

# %%
response.json()
# Out:
# {'exc': 'Expecting value: line 1 column 1 (char 0)'}
