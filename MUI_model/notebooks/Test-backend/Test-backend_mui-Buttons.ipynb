# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
WORKING_DIR = re.sub('jdi-qasp-ml.*$','',os.path.normpath(os.getcwd())) + 'jdi-qasp-ml'
os.chdir(WORKING_DIR)

# %%
WORKING_DIR
# Out:
# 'C:\\WORK\\jdi-qasp-ml'

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-09-06 15:56:47,470 -INFO - config.py:25 - Module utils.config was loaded
# 2021-09-06 15:56:47,470 -INFO - common.py:618 - Module utils.common is loaded...
# 2021-09-06 15:56:47,481 -INFO - hidden.py:121 - hidden module is loaded
# 2021-09-06 15:56:47,483 -INFO - features_builder.py:305 - feature_bilder module is loaded...
# 2021-09-06 15:56:47,483 -INFO - dataset_builder.py:213 - dataset package is loaded...
# 2021-09-06 15:56:47,492 -INFO - dataset.py:277 - dataset module is loaded...

# %%
UTILS_LOGGER = 'utils.dataset'
LOG_FILE_PATH = 'tmp/log.txt'

os.makedirs(name='tmp', exist_ok=True)

logger = logging.getLogger(UTILS_LOGGER)
logger.setLevel(logging.DEBUG)


formatter = logging.Formatter('%(asctime)s -%(levelname)s - %(module)s:%(filename)s:%(lineno)d - %(message)s')

console_handler = logging.StreamHandler(sys.stdout)
console_handler.setFormatter(formatter)

file_handler = logging.FileHandler(filename=LOG_FILE_PATH, mode='w')
file_handler.setFormatter(formatter)

logger.addHandler(console_handler)
logger.addHandler(file_handler)

logger.info('Module utils.config was loaded')
# Out:
# 2021-09-06 15:56:47,525 -INFO - 632196539.py:21 - Module utils.config was loaded
# 2021-09-06 15:56:47,525 -INFO - 632196539:632196539.py:21 - Module utils.config was loaded

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# 'C:\\WORK\\jdi-qasp-ml'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'material-ui-Buttons'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5000/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
# DATASET_NAME = 'mui-site122'

# %%
# SITE_URL = 'C:/WORK/jdi-qasp-ml/MUI_model/dataset/build/site122/index.html'

# %%
# PREDICT_URL = 'http://localhost:5000/mui-predict'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click()
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click()
        driver.find_element_by_xpath("/html/body/div/div/div/div[1]/div/div[2]/div/div").click()
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path='./MUI_model/dataset/') as builder:
    plt.imshow(plt.imread(f'MUI_model/dataset/images/{DATASET_NAME}.png'))
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2021-09-06 15:59:41,097 -INFO - dataset_builder.py:78 - Dataset name: material-ui-Buttons
# 2021-09-06 15:59:41,097 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: material-ui-Buttons
# 2021-09-06 15:59:41,102 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-09-06 15:59:41,102 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-09-06 15:59:41,108 -INFO - dataset_builder.py:126 - Creating driver
# 2021-09-06 15:59:41,108 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-09-06 15:59:42,342 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-09-06 15:59:42,342 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-09-06 15:59:42,460 -INFO - 3512600575.py:10 - getting url: https://jdi-testing.github.io/jdi-light/
# 2021-09-06 15:59:42,460 -INFO - 3512600575:3512600575.py:10 - getting url: https://jdi-testing.github.io/jdi-light/
# 2021-09-06 15:59:58,563 -INFO - common.py:75 - Window maximized
# 2021-09-06 15:59:58,563 -INFO - common:common.py:75 - Window maximized
# 2021-09-06 16:00:05,563 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/material-ui-Buttons.png
# 2021-09-06 16:00:05,563 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/material-ui-Buttons.png
# 2021-09-06 16:00:09,784 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-09-06 16:00:09,784 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-09-06 16:00:11,930 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/material-ui-Buttons.html
# 2021-09-06 16:00:11,930 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/material-ui-Buttons.html
# 2021-09-06 16:00:11,967 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/material-ui-Buttons.pkl
# 2021-09-06 16:00:11,967 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/material-ui-Buttons.pkl
# 2021-09-06 16:00:11,973 -INFO - dataset_builder.py:204 - No attributes: (15, 13)
# 2021-09-06 16:00:11,973 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (15, 13)
# 2021-09-06 16:00:13,347 -INFO - dataset_builder.py:103 - Close web driver
# 2021-09-06 16:00:13,347 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '2556920214332097927471784466',
#   'x': 282.0,
#   'y': 750.546875,
#   'width': 122.46875,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4408.875},
#  {'element_id': '9444271200332097920336424082',
#   'x': 282.0,
#   'y': 438.859375,
#   'width': 107.515625,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999972582,
#   'sort_key': 3870.5625},
#  {'element_id': '1977155283332097924394946321',
#   'x': 282.0,
#   'y': 146.171875,
#   'width': 91.25,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 3285.0},
#  {'element_id': '0183374284332097924437568043',
#   'x': 294.0,
#   'y': 604.703125,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9997305274,
#   'sort_key': 576.0},
#  {'element_id': '4010718347332097921826444545',
#   'x': 486.0,
#   'y': 604.703125,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9856587052,
#   'sort_key': 576.0},
#  {'element_id': '5657968728332097920980899222',
#   'x': 422.0,
#   'y': 604.703125,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9964058995,
#   'sort_key': 576.0},
#  {'element_id': '6177202472332097929512876070',
#   'x': 358.0,
#   'y': 604.703125,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9997305274,
#   'sort_key': 576.0},
#  {'element_id': '2831005422332097925477639504',
#   'x': 860.453125,
#   'y': 445.859375,
#   'width': 22.0,
#   'height': 22.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.6120329499,
#   'sort_key': 484.0},
#  {'element_id': '4830038162332097928173252397',
#   'x': 526.578125,
#   'y': 446.859375,
#   'width': 20.0,
#   'height': 20.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.6748146415,
#   'sort_key': 400.0}]
# Wall time: 4.23 s

# %%
from utils import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'MUI_model/dataset/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')

# %%
# set(df.element_id.values).intersection(set(preds.element_id.values))
# Out:
# {'0054746281310279177122739520',
#  '0056653958310279189038698656',
#  '0138574620310279162305777942',
#  '0161493274310279185243519724',
#  '0236061596310279172158172581',
#  '0311024309310279183162690748',
#  '0400935551310279160030543706',
#  '0463577500310279152884064393',
#  '0532482995310279178245807542',
#  '0603587882310279170703778873',
#  '0623392467310279160198413626',
#  '0639370217310279170793001006',
#  '0644066980310279163174787885',
#  '0707446897310279150565023610',
#  '0715425304310279171018032689',
