# %%
import sys
import re
import os
from datetime import datetime
from time import sleep
from IPython.display import display, clear_output, HTML

# set working dir
WORKING_DIR = re.sub('jdi-qasp-ml.*$','',os.path.normpath(os.getcwd())) + 'jdi-qasp-ml'
os.chdir(WORKING_DIR)

import utils
from utils import *
import torch
import pandas as pd
import numpy as np
import torch
from glob import glob
import selenium
from tqdm.auto import tqdm

START_TS = datetime.now()
display(HTML(f'{START_TS} - Current working directory: <b>{WORKING_DIR}</b>'))

import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

import numba
# Out:
# 2021-06-07 13:59:58,558 -INFO - config:config.py:16 - Module utils.config was loaded
# 2021-06-07 13:59:58,558 -INFO - common:common.py:616 - Module utils.common is loaded...
# 2021-06-07 13:59:58,574 -INFO - hidden:hidden.py:121 - hidden module is loaded
# 2021-06-07 13:59:58,575 -INFO - dataset_builder:dataset_builder.py:202 - dataset package is loaded...
# 2021-06-07 13:59:59,170 -INFO - dataset:dataset.py:653 - dataset module is loaded...
# 2021-06-07 13:59:59.170000 - Current working directory: <b>D:\DataScience\!WORK\jdi-qasp-ml</b>

# %%
from utils import get_all_elements, iou_xywh, screenshot, maximize_window, get_parents_list, build_tree_dict, DatasetBuilder

# %%
selenium.__version__
# Out:
# '3.141.0'

# %% [markdown]
# # Parameters

# %%
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
HEADLESS = True #False

# %%
with open('dataset/classes.txt', 'r') as f:
    decoder_dict = { i:s.strip() for i, s in  enumerate(f.readlines())}
    encoder_dict = { v: k for k, v in decoder_dict.items()}
decoder_dict, encoder_dict
# Out:
# ({0: 'button',
#   1: 'link',
#   2: 'textfield',
#   3: 'dropdown',
#   4: 'checkbox',
#   5: 'radiobutton',
#   6: 'textarea',
#   7: 'fileinput',
#   8: 'iframe',
#   9: 'range',
#   10: 'progressbar',
#   11: 'datetimeselector',
#   12: 'colorpicker',
#   13: 'numberselector',
#   14: 'selector',
#   15: 'table',
#   16: 'slider-toggle',
#   17: 'slider',
#   18: 'tree-node',
#   19: 'steper',
#   20: 'tab',
#   21: 'n/a'},
#  {'button': 0,
#   'link': 1,
#   'textfield': 2,
#   'dropdown': 3,
#   'checkbox': 4,
#   'radiobutton': 5,
#   'textarea': 6,
#   'fileinput': 7,
#   'iframe': 8,
#   'range': 9,
#   'progressbar': 10,
#   'datetimeselector': 11,
#   'colorpicker': 12,
#   'numberselector': 13,
#   'selector': 14,
#   'table': 15,
#   'slider-toggle': 16,
#   'slider': 17,
#   'tree-node': 18,
#   'steper': 19,
#   'tab': 20,
#   'n/a': 21})

# %% [markdown]
# # Generate dataset

# %%
DATASET_NAME = 'bootstrap-form'
class JDIDatasetBuilder(DatasetBuilder):

    def setUp(self, driver):
        self.logger.info(f'getting page')
        driver.get(SITE_URL)
        
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        
        driver.find_element_by_link_text("Elements packs").click()
        driver.find_element_by_link_text("Bootstrap form").click()
        sleep(WAIT_TIME_SECONDS)
        
#         driver.find_element_by_link_text("Service").click()
#         driver.find_element_by_link_text("Complex Table").click()
        maximize_window(driver=driver)
        sleep(WAIT_TIME_SECONDS)
        

with JDIDatasetBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True) as builder:
    elements_df = builder.dataset
    plt.imshow(plt.imread(f'dataset/images/{DATASET_NAME}.png'))
# Out:
# 2021-06-07 13:59:59,292 -INFO - dataset_builder:dataset_builder.py:77 - Dataset name: bootstrap-form
# 2021-06-07 13:59:59,293 -INFO - dataset_builder:dataset_builder.py:86 - Create directories to save the dataset
# 2021-06-07 13:59:59,294 -INFO - dataset_builder:dataset_builder.py:123 - Creating driver
# 2021-06-07 14:00:00,364 -INFO - dataset_builder:dataset_builder.py:131 - Chrome web driver is created
# 2021-06-07 14:00:00,365 -INFO - <ipython-input-6-ae6584b99ea5>:<ipython-input-6-ae6584b99ea5>:5 - getting page
# 2021-06-07 14:00:18,407 -INFO - common:common.py:75 - Window maximized
# 2021-06-07 14:00:25,422 -INFO - dataset_builder:dataset_builder.py:134 - save scrinshot: dataset/images/bootstrap-form.png
# 2021-06-07 14:00:25,840 -INFO - dataset_builder:dataset_builder.py:178 - Collect features using JS script
# 2021-06-07 14:00:26,389 -INFO - dataset_builder:dataset_builder.py:186 - Save html to dataset/html/bootstrap-form.html
# 2021-06-07 14:00:26,408 -INFO - dataset_builder:dataset_builder.py:196 - Save parquet to dataset/df/bootstrap-form.parquet
# 2021-06-07 14:00:26,722 -INFO - dataset_builder:dataset_builder.py:101 - Close web driver

# %%
df = pd.read_parquet(f'dataset/df/{DATASET_NAME}.parquet')

# %%
df = build_features(df)
# Out:
# 2021-06-07 14:00:27,329 -INFO - hidden:hidden.py:107 - build field "is_hidden"

# %%
elements_dict = build_elements_dict(df)

# %%
df[['tag_name', 'element_id', 'parent_id', 'upper_sibling', 'lower_sibling', 'displayed', 'is_hidden', 'x', 'y', 'width', 'height']]
# Out:
#     tag_name                    element_id                     parent_id  \
# 0       HTML  7192393615636258444340301138                          None
# 1       HEAD  6762289377636258445981237120  7192393615636258444340301138
# 2       META  5929771232636258441571237030  6762289377636258445981237120
# 3      TITLE  2638108713636258446749220823  6762289377636258445981237120
# 4       META  2305121218636258446113368325  6762289377636258445981237120
# ..       ...                           ...                           ...
# 809        A  3815285976636258455937070411  9281592806636258453319591490
# 810   SCRIPT  2667334909636258453792276022  0042738690636258443555665783
# 811   SCRIPT  4870483102636258454218172385  0042738690636258443555665783
# 812   SCRIPT  9516943567636258458976017821  0042738690636258443555665783
# 813   SCRIPT  5854555980636258458844230856  0042738690636258443555665783
#
#                     upper_sibling                 lower_sibling  displayed  \
# 0                            None                          None       True
# 1                            None  0042738690636258443555665783      False
# 2                            None  2638108713636258446749220823      False
# 3    5929771232636258441571237030  2305121218636258446113368325      False
# 4    2638108713636258446749220823  4170937301636258444090076233      False
# ..                            ...                           ...        ...
# 809                          None                          None       True
# 810  9421124056636258456170528528  4870483102636258454218172385      False
# 811  2667334909636258453792276022  9516943567636258458976017821      False
# 812  4870483102636258454218172385  5854555980636258458844230856      False
# 813  9516943567636258458976017821                          None      False
#
#      is_hidden            x            y        width  height
# 0            0     0.000000     0.000000  1183.000000  7998.0
# 1            0     0.000000     0.000000     0.000000     0.0
# 2            0     0.000000     0.000000     0.000000     0.0
# 3            0     0.000000     0.000000     0.000000     0.0
# 4            0     0.000000     0.000000     0.000000     0.0
# ..         ...          ...          ...          ...     ...
# 809          0  1115.890625  7976.265625    64.109375    15.0
# 810          1     0.000000     0.000000     0.000000     0.0
# 811          1     0.000000     0.000000     0.000000     0.0
# 812          1     0.000000     0.000000     0.000000     0.0
# 813          1     0.000000     0.000000     0.000000     0.0
#
# [814 rows x 11 columns]

# %%
predictions_df = rule_base_predict(df)
print(predictions_df.shape)
# predictions_df
# Out:
# 2021-06-07 14:00:27,874 -INFO - common:common.py:489 - Num radio buttons found: 15
# 2021-06-07 14:00:27,877 -INFO - common:common.py:493 - Num radio2 buttons found: 0
# 2021-06-07 14:00:27,880 -INFO - common:common.py:500 - Num checkboxes found: 0
# 2021-06-07 14:00:27,883 -INFO - common:common.py:507 - Num comboboxes/dropdowns found: 0
# 2021-06-07 14:00:27,886 -INFO - common:common.py:518 - Num textfields found: 52
# 2021-06-07 14:00:27,889 -INFO - common:common.py:523 - Num texfields for numbers found: 0
# 2021-06-07 14:00:27,891 -INFO - common:common.py:528 - Num ranges found: 4
# 2021-06-07 14:00:27,895 -INFO - common:common.py:533 - Num ordinary text inputs found: 0
# 2021-06-07 14:00:27,897 -INFO - common:common.py:536 - Num buttons found: 15
# 2021-06-07 14:00:27,899 -INFO - common:common.py:541 - Num buttons1 found: 1
# 2021-06-07 14:00:27,902 -INFO - common:common.py:546 - Num buttons2 (Material-UI) found: 0
# 2021-06-07 14:00:27,904 -INFO - common:common.py:551 - Num links found: 39
# (102, 8)

# %% [markdown]
# # **Enrich predictions**

# %%
# img = load_gray_image(f'dataset/images/{DATASET_NAME}.png')
# img_height, img_width = img.shape
# print(img_width, img_height)
# plt.figure(figsize=(15, 500))
# plt.imshow(img, cmap='gray')
# axes = plt.gca()

# for _, r in predictions_df.iterrows():
    
#     patch = patches.Rectangle((r.x, r.y), r.width, r.height, linewidth=2, alpha = .3, facecolor = 'red', edgecolor ='black')
#     axes.add_patch(patch)
#     plt.text(r.x, r.y, 
#              decoder_dict[r.label] + ':',  ## + r.element_id, 
#              fontsize = 10, 
#              color = 'white', 
#              backgroundcolor='black',
#              alpha=1.)

# %% [markdown]
# # Generate and Save Labels

# %%
# labels = build_to_yolo(df = predictions_df, img_width=img_width, img_heght=img_height)
# labels

# %%
# labeled_df = pd.DataFrame(labels, columns=['label', 'x', 'y', 'width', 'height'])
# labeled_df.label = labeled_df.label.astype(int)
# display(labeled_df)
# labeled_df.to_csv(f'dataset/annotations/{DATASET_NAME}.txt', header=False, sep=' ', index=False)

# %% [markdown]
# # Preview Labels

# %%
img = load_gray_image(f'dataset/images/{DATASET_NAME}.png')
img_height, img_width = img.shape

# %%
boxes_df = pd.read_csv(f'dataset/annotations/{DATASET_NAME}.txt', sep=' ', names = ['label', 'x', 'y', 'width', 'height'])
boxes_df
boxes_df['box'] = boxes_df.apply(lambda r: from_yolo(r.x, r.y, r.width, r.height, img_width=img_width, img_height=img_height), axis=1)
boxes_df.head()
# Out:
#    label         x         y     width    height                box
# 0      1  0.051667  0.003681  0.071667  0.004117   (19, 13, 86, 32)
# 1      1  0.127500  0.003681  0.065000  0.003369  (114, 16, 78, 27)
# 2      1  0.211667  0.003743  0.058333  0.007236   (219, 1, 69, 57)
# 3      1  0.288750  0.003681  0.100833  0.007112  (286, 1, 120, 57)
# 4      1  0.378750  0.003681  0.075833  0.007112   (409, 1, 90, 57)

# %%
# img = load_gray_image(f'dataset/images/{DATASET_NAME}.png')
# img_height, img_width = img.shape
# print(img_width, img_height)
# plt.figure(figsize=(15, 500))
# plt.imshow(img, cmap='gray')
# axes = plt.gca()

# for i, r in boxes_df.iterrows():
#     x, y, w, h = from_yolo(r.x, r.y, r.width, r.height, img_width=img_width, img_height=img_height)    
#     patch = patches.Rectangle((x, y), w, h, linewidth=2, alpha = .3, facecolor = 'red', edgecolor ='black')
#     axes.add_patch(patch)
#     plt.text(x, y, 
#              f'({i})' + decoder_dict[r.label] + ':',  ## + r.element_id, 
#              fontsize = 10, 
#              color = 'white', 
#              backgroundcolor='black',
#              alpha=1.)

# %%
# df = pd.read_parquet(f'dataset/df/{DATASET_NAME}.parquet')
df.columns
# Out:
# Index(['attributes', 'displayed', 'element_id', 'height', 'onmouseenter',
#        'onmouseover', 'parent_id', 'style', 'tag_name', 'text', 'width', 'x',
#        'y', 'is_hidden', 'upper_sibling', 'lower_sibling', 'siblings'],
#       dtype='object')

# %%
columns_to_drop = set(df.columns).intersection(set(['label', 'annotation_line_no', 'iou', 'tag', 'label_text']))
if len(columns_to_drop) >= 0:
    df.drop(columns=columns_to_drop, inplace=True)

# %%
df = assign_labels(df=df, annotations_file_path=f'dataset/annotations/{DATASET_NAME}.txt', img_width=img_width, img_height=img_height)
# Out:
# 2021-06-07 14:00:28,326 -INFO - labels:labels.py:38 - Assign labels from annotation file: dataset/annotations/bootstrap-form.txt
# 2021-06-07 14:00:28,327 -INFO - labels:labels.py:40 - Getting image size
# 2021-06-07 14:00:28,327 -INFO - labels:labels.py:42 - Image size (w,h): (1200, 8015)
# 2021-06-07 14:00:28,328 -INFO - labels:labels.py:47 - {'button': 0, 'link': 1, 'textfield': 2, 'dropdown': 3, 'checkbox': 4, 'radiobutton': 5, 'textarea': 6, 'fileinput': 7, 'iframe': 8, 'range': 9, 'progressbar': 10, 'datetimeselector': 11, 'colorpicker': 12, 'numberselector': 13, 'selector': 14, 'table': 15, 'slider-toggle': 16, 'slider': 17, 'tree-node': 18, 'steper': 19, 'tab': 20, 'n/a': 21}
# 2021-06-07 14:00:28,328 -INFO - labels:labels.py:55 - getting "n/a" class code
# 2021-06-07 14:00:28,329 -INFO - labels:labels.py:62 - "n/a" class code: 21
# 2021-06-07 14:00:28,332 -INFO - labels:labels.py:72 - 160 annotation has been read
# Assign labels:   0%|          | 0/160 [00:00<?, ?it/s]
# 2021-06-07 14:00:40,892 -INFO - labels:labels.py:121 - labels_df: Index(['idx', 'label', 'annotation_line_no', 'iou', 'tag', 'label_text'], dtype='object')
# 2021-06-07 14:00:40,892 -INFO - labels:labels.py:124 - 160 labels have been assigned

# %%
df.columns
# Out:
# Index(['attributes', 'displayed', 'element_id', 'height', 'onmouseenter',
#        'onmouseover', 'parent_id', 'style', 'tag_name', 'text', 'width', 'x',
#        'y', 'is_hidden', 'upper_sibling', 'lower_sibling', 'siblings', 'idx',
#        'label', 'annotation_line_no', 'iou', 'tag', 'label_text'],
#       dtype='object')

# %%
df.label.value_counts()
# Out:
# 21    654
# 2      52
# 1      23
# 4      19
# 5      16
# 0      13
# 14     12
# 3      10
# 7       4
# 17      4
# 6       3
# 16      3
# 18      1
# Name: label, dtype: int64

# %%
img = load_gray_image(f'dataset/images/{DATASET_NAME}.png')
img_height, img_width = img.shape
print(img_width, img_height)
plt.figure(figsize=(15, 500))
plt.imshow(img, cmap='gray')
axes = plt.gca()

for _, r in df[df.label_text != 'n/a'].iterrows():
    x, y, w, h = r.x, r.y, r.width, r.height  
    patch = patches.Rectangle((x, y), w, h, linewidth=2, alpha = .3, facecolor = 'red', edgecolor ='black')
    
    # print(r.tag_name, r.label_text, (x,y,w,h), r.element_id)
    
    axes.add_patch(patch)
    plt.text(x, y, 
             decoder_dict[r.label] + ':' + r.tag_name + ': ' +str(round(r.iou, 4)), # + ':' + str((x, y, w, h)),  ## + r.element_id, 
             fontsize = 10, 
             color = 'white', 
             backgroundcolor='black',
             alpha=1.)
# Out:
# 1200 8015
