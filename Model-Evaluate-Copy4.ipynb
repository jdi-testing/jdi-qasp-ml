# %%
import torch
from torch.utils.data import Dataset, DataLoader

from tqdm.auto import tqdm, trange
from sklearn.metrics import confusion_matrix

import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
# %matplotlib inline

import os, sys, re, gc, glob
from tqdm.auto import tqdm, trange
from utils import JDIDataset, JDIModel, get_grey_image, assign_labels, accuracy



import seaborn as sns
# Out:
# 2021-05-28 23:57:50,276 -INFO - config:config.py:16 - Module utils.config was loaded
# 2021-05-28 23:57:50,280 -INFO - common:common.py:569 - Module utils.common is loaded...
# 2021-05-28 23:57:50,280 -INFO - hidden:hidden.py:62 - hidden module is loaded
# 2021-05-28 23:57:50,283 -INFO - dataset_builder:dataset_builder.py:200 - dataset package is loaded...
# 2021-05-28 23:57:50,290 -INFO - dataset:dataset.py:650 - dataset module is loaded...

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
DEVICE
# Out:
# 'cuda'

# %%
DEVICE='cpu'

# %%
model = torch.load('model/model.pth').to(DEVICE)
model.eval()
# Out:
# JDIModel(
#   (input_layer): Linear(in_features=5629, out_features=128, bias=False)
#   (batchNorm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (leaky_relu1): LeakyReLU(negative_slope=0.1, inplace=True)
#   (hidden1): Linear(in_features=128, out_features=32, bias=False)
#   (batchNorm2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   (leaky_relu2): LeakyReLU(negative_slope=0.1, inplace=True)
#   (hidden2): Linear(in_features=32, out_features=22, bias=True)
# )

# %% [markdown]
# ## Load test dataset

# %%
dataset_name = 'cnews'

# %%
dataset = JDIDataset(dataset_names=[dataset_name], rebalance=False)
# Out:
# 2021-05-28 23:57:51,716 -INFO - dataset:dataset.py:247 - List of dataset_names:['cnews']
# 2021-05-28 23:57:51,717 -INFO - dataset:dataset.py:253 - Dataset for cnews
# 2021-05-28 23:57:51,850 -INFO - dataset:dataset.py:255 - Dataset shape: (2220, 13)
# 2021-05-28 23:57:51,850 -INFO - dataset:dataset.py:257 - cleaning tag_name from dummy/auxiliary words
# 2021-05-28 23:57:52,237 -INFO - hidden:hidden.py:48 - build field "is_hidden"
# 2021-05-28 23:57:52,457 -INFO - dataset:dataset.py:48 - select all leafs (nodes which are not parents)
# 2021-05-28 23:57:52,457 -INFO - dataset:dataset.py:51 - Leafs set size: 1324 (nodes which have no children)
# 2021-05-28 23:57:52,461 -INFO - dataset:dataset.py:54 - count number of references to leafs
# 2021-05-28 23:57:52,464 -INFO - dataset:dataset.py:58 - Nodes with leafs as children set size: 670 (nodes which have leafs as children)
# 2021-05-28 23:57:52,466 -INFO - dataset:dataset.py:61 - count num children for each node
# 2021-05-28 23:57:52,467 -INFO - dataset:dataset.py:63 - Nodes with children: 897
# 2021-05-28 23:57:52,469 -INFO - dataset:dataset.py:66 - sum of children widths, heights, counts
# 2021-05-28 23:57:52,474 -INFO - dataset:dataset.py:73 - Sum of children widths
# 2021-05-28 23:57:52,478 -INFO - dataset:dataset.py:79 - Sum of children hights
#   0%|          | 0/2220 [00:00<?, ?it/s]
# 2021-05-28 23:57:56,156 -INFO - dataset:dataset.py:275 - Dataset shape after merging with parents: (2220, 46)
# 2021-05-28 23:57:56,156 -WARNING - dataset:dataset.py:290 - assign dummy values [n/a] for labels if there is no annotations
# 2021-05-28 23:57:56,202 -INFO - dataset:dataset.py:297 - Concatenate datasets
# 2021-05-28 23:57:56,212 -INFO - dataset:dataset.py:299 - Dataset shape after reading: (2220, 48)
# 2021-05-28 23:57:56,214 -WARNING - dataset:dataset.py:630 - Loading count vectorizer for column "cv_class": model/count_vectorizer_class.pkl
# 2021-05-28 23:57:56,222 -INFO - dataset:dataset.py:647 - class_sm: (2220, 1081)
# 2021-05-28 23:57:56,223 -INFO - dataset:dataset.py:308 - Build OHE column for attribute role
# 2021-05-28 23:57:56,226 -INFO - dataset:dataset.py:308 - Build OHE column for attribute type
# 2021-05-28 23:57:56,229 -INFO - dataset:dataset.py:308 - Build OHE column for attribute ui
# 2021-05-28 23:57:56,231 -INFO - dataset:dataset.py:313 - Build OHE column for attribute role_parent
# 2021-05-28 23:57:56,234 -INFO - dataset:dataset.py:313 - Build OHE column for attribute type_parent
# 2021-05-28 23:57:56,238 -INFO - dataset:dataset.py:313 - Build OHE column for attribute ui_parent
# 2021-05-28 23:57:56,240 -INFO - dataset:dataset.py:317 - OHE tag_name
# 2021-05-28 23:57:56,241 -WARNING - dataset:dataset.py:487 - loading existing OHE for column "tag_name" from model/tag_name.pkl
# 2021-05-28 23:57:56,244 -INFO - dataset:dataset.py:319 - tag_name_sm.shape: (2220, 303)
# 2021-05-28 23:57:56,245 -INFO - dataset:dataset.py:321 - OHE tag_name_parent
# 2021-05-28 23:57:56,245 -WARNING - dataset:dataset.py:487 - loading existing OHE for column "tag_name_parent" from model/tag_name.pkl
# 2021-05-28 23:57:56,248 -INFO - dataset:dataset.py:325 - tag_name_parent_sm.shape: (2220, 303)
# 2021-05-28 23:57:56,248 -INFO - dataset:dataset.py:327 - OHE ohe_role
# 2021-05-28 23:57:56,249 -WARNING - dataset:dataset.py:487 - loading existing OHE for column "ohe_role" from model/ohe_role.pkl
# 2021-05-28 23:57:56,251 -INFO - dataset:dataset.py:329 - ohe_role_sm.shape: (2220, 37)
# 2021-05-28 23:57:56,252 -INFO - dataset:dataset.py:331 - OHE ohe_role_parent
# 2021-05-28 23:57:56,252 -WARNING - dataset:dataset.py:487 - loading existing OHE for column "ohe_role_parent" from model/ohe_role.pkl
# 2021-05-28 23:57:56,254 -INFO - dataset:dataset.py:335 - ohe_role_parent_sm.shape: (2220, 37)
# 2021-05-28 23:57:56,255 -INFO - dataset:dataset.py:337 - OHE ohe_type
# 2021-05-28 23:57:56,255 -WARNING - dataset:dataset.py:487 - loading existing OHE for column "ohe_type" from model/ohe_type.pkl
# 2021-05-28 23:57:56,261 -INFO - dataset:dataset.py:339 - ohe_type_sm.shape: (2220, 1548)
# 2021-05-28 23:57:56,261 -INFO - dataset:dataset.py:341 - OHE ohe_type_parent
# 2021-05-28 23:57:56,262 -WARNING - dataset:dataset.py:487 - loading existing OHE for column "ohe_type_parent" from model/ohe_type.pkl
# 2021-05-28 23:57:56,266 -INFO - dataset:dataset.py:345 - ohe_type_parent_sm.shape: (2220, 1548)
# 2021-05-28 23:57:56,267 -INFO - dataset:dataset.py:347 - OHE ohe_ui
# 2021-05-28 23:57:56,267 -WARNING - dataset:dataset.py:487 - loading existing OHE for column "ohe_ui" from model/ohe_ui.pkl
# 2021-05-28 23:57:56,269 -INFO - dataset:dataset.py:349 - ohe_ui_sm.shape: (2220, 14)
# 2021-05-28 23:57:56,269 -INFO - dataset:dataset.py:351 - OHE ohe_ui_parent
# 2021-05-28 23:57:56,270 -WARNING - dataset:dataset.py:487 - loading existing OHE for column "ohe_ui_parent" from model/ohe_ui.pkl
# 2021-05-28 23:57:56,272 -INFO - dataset:dataset.py:354 - ohe_ui_parent_sm.shape: (2220, 14)
# 2021-05-28 23:57:56,280 -INFO - dataset:dataset.py:359 - Fit CountVectorizer for column "attributes"
# 2021-05-28 23:57:56,280 -WARNING - dataset:dataset.py:511 - loading existing count vectorizer for column "attributes_text" from model/count_vectorizer_attributes_text.pkl
# 2021-05-28 23:57:56,290 -INFO - dataset:dataset.py:361 - attributes_sm.shape: (2220, 124)
# 2021-05-28 23:57:56,291 -WARNING - dataset:dataset.py:368 - Load CountVectorizer for column "chidren_tags": model/count_vectorizer_children_tags.pkl
# 2021-05-28 23:57:56,292 -INFO - dataset:dataset.py:378 - CountVectorizer "chilren_tags" size: 237
# 2021-05-28 23:57:56,298 -INFO - dataset:dataset.py:381 - chidren_tags_sm: (2220, 237)
# 2021-05-28 23:57:56,299 -WARNING - dataset:dataset.py:388 - Load CountVectorizer for column "followers_tags": model/count_vectorizer_followers_tags.pkl
# 2021-05-28 23:57:56,300 -INFO - dataset:dataset.py:398 - CountVectorizer "followers_tags" size: 237
# 2021-05-28 23:57:56,306 -INFO - dataset:dataset.py:401 - followers_tags_sm: (2220, 237)
# 2021-05-28 23:57:56,314 -INFO - dataset:dataset.py:410 - Fit CountVectorizer for column "attributes_parent"
# 2021-05-28 23:57:56,315 -WARNING - dataset:dataset.py:511 - loading existing count vectorizer for column "attributes_parent_text" from model/count_vectorizer_attributes_text.pkl
# 2021-05-28 23:57:56,324 -INFO - dataset:dataset.py:415 - attributes_parent_sm.shape: (2220, 124)
# 2021-05-28 23:57:56,342 -INFO - dataset:dataset.py:443 - OHE columns sparse matrix: (2220, 5629)

# %%
dataset.dataset.shape
# Out:
# (2220, 57)

# %%
dataset.labels
# Out:
# 0       n/a
# 1       n/a
# 2       n/a
# 3       n/a
# 4       n/a
#        ...
# 2215    n/a
# 2216    n/a
# 2217    n/a
# 2218    n/a
# 2219    n/a
# Name: label, Length: 2220, dtype: object

# %%
dataset.dataset.label
# Out:
# 0       21
# 1       21
# 2       21
# 3       21
# 4       21
#         ..
# 2215    21
# 2216    21
# 2217    21
# 2218    21
# 2219    21
# Name: label, Length: 2220, dtype: int32

# %%
dataloader=DataLoader(dataset, shuffle=False, batch_size=1, collate_fn=dataset.collate_fn, pin_memory=True)

# %%
results = []
with trange(len(dataloader)) as bar:
    with torch.no_grad():
        for x, y in dataloader:
           
            y_pred = torch.round(torch.nn.Softmax(dim=1)(model(x.to(DEVICE)).to('cpu'))).detach().numpy()
            y_pred = y_pred[0].argmax()
            y = y.item()           
            
            results.append({
                'y_true': y,
                'y_pred': y_pred,
                'y_true_label': dataset.classes_reverse_dict[y], 
                'y_pred_label': dataset.classes_reverse_dict[y_pred]
            })
            bar.update(1)

results_df = pd.DataFrame(results)
results_df['is_hidden'] = dataset.dataset.is_hidden.values
# Out:
#   0%|          | 0/2220 [00:00<?, ?it/s]

# %%
list(dataset.classes_dict.keys())
# Out:
# ['button',
#  'link',
#  'iframe',
#  'textfield',
#  'dropdown',
#  'checkbox_btn',
#  'checkbox_label',
#  'radiobutton_btn',
#  'radiobutton_label',
#  'textarea',
#  'text',
#  'fileinput',
#  'image',
#  'colorpicker',
#  'range',
#  'progressbar',
#  'datetimeselector',
#  'numberselector',
#  'dropdownselector',
#  'checklist',
#  'table',
#  'n/a']

# %%
confusion_matrix_df = pd.DataFrame(
    confusion_matrix(y_true=results_df.y_true_label.values,
                     y_pred=results_df.y_pred_label.values, 
                     labels=list(dataset.classes_dict.keys())
                    ), 
    columns=list(dataset.classes_dict.keys()),
    index=list(dataset.classes_dict.keys())
)

# %%
confusion_matrix_df
# Out:
#                    button  link  iframe  textfield  dropdown  checkbox_btn  \
# button                  0     0       0          0         0             0
# link                    0     0       0          0         0             0
# iframe                  0     0       0          0         0             0
# textfield               0     0       0          0         0             0
# dropdown                0     0       0          0         0             0
# checkbox_btn            0     0       0          0         0             0
# checkbox_label          0     0       0          0         0             0
# radiobutton_btn         0     0       0          0         0             0
# radiobutton_label       0     0       0          0         0             0
# textarea                0     0       0          0         0             0
# text                    0     0       0          0         0             0
# fileinput               0     0       0          0         0             0
# image                   0     0       0          0         0             0
# colorpicker             0     0       0          0         0             0
# range                   0     0       0          0         0             0
# progressbar             0     0       0          0         0             0
# datetimeselector        0     0       0          0         0             0
# numberselector          0     0       0          0         0             0
# dropdownselector        0     0       0          0         0             0
# checklist               0     0       0          0         0             0
# table                   0     0       0          0         0             0
# n/a                    21   254       0         12         9             0
#
#                    checkbox_label  radiobutton_btn  radiobutton_label  \
# button                          0                0                  0
# link                            0                0                  0
# iframe                          0                0                  0
# textfield                       0                0                  0
# dropdown                        0                0                  0
# checkbox_btn                    0                0                  0
# checkbox_label                  0                0                  0
# radiobutton_btn                 0                0                  0
# radiobutton_label               0                0                  0
# textarea                        0                0                  0
# text                            0                0                  0
# fileinput                       0                0                  0
# image                           0                0                  0
# colorpicker                     0                0                  0
# range                           0                0                  0
# progressbar                     0                0                  0
# datetimeselector                0                0                  0
# numberselector                  0                0                  0
# dropdownselector                0                0                  0
# checklist                       0                0                  0
# table                           0                0                  0
# n/a                            12                5                  0
#
#                    textarea  ...  image  colorpicker  range  progressbar  \
# button                    0  ...      0            0      0            0
# link                      0  ...      0            0      0            0
# iframe                    0  ...      0            0      0            0
# textfield                 0  ...      0            0      0            0
# dropdown                  0  ...      0            0      0            0
# checkbox_btn              0  ...      0            0      0            0
# checkbox_label            0  ...      0            0      0            0
# radiobutton_btn           0  ...      0            0      0            0
# radiobutton_label         0  ...      0            0      0            0
# textarea                  0  ...      0            0      0            0
# text                      0  ...      0            0      0            0
# fileinput                 0  ...      0            0      0            0
# image                     0  ...      0            0      0            0
# colorpicker               0  ...      0            0      0            0
# range                     0  ...      0            0      0            0
# progressbar               0  ...      0            0      0            0
# datetimeselector          0  ...      0            0      0            0
# numberselector            0  ...      0            0      0            0
# dropdownselector          0  ...      0            0      0            0
# checklist                 0  ...      0            0      0            0
# table                     0  ...      0            0      0            0
# n/a                       0  ...      6            0      0            0
#
#                    datetimeselector  numberselector  dropdownselector  \
# button                            0               0                 0
# link                              0               0                 0
# iframe                            0               0                 0
# textfield                         0               0                 0
# dropdown                          0               0                 0
# checkbox_btn                      0               0                 0
# checkbox_label                    0               0                 0
# radiobutton_btn                   0               0                 0
# radiobutton_label                 0               0                 0
# textarea                          0               0                 0
# text                              0               0                 0
# fileinput                         0               0                 0
# image                             0               0                 0
# colorpicker                       0               0                 0
# range                             0               0                 0
# progressbar                       0               0                 0
# datetimeselector                  0               0                 0
# numberselector                    0               0                 0
# dropdownselector                  0               0                 0
# checklist                         0               0                 0
# table                             0               0                 0
# n/a                               0               0                 0
#
#                    checklist  table   n/a
# button                     0      0     0
# link                       0      0     0
# iframe                     0      0     0
# textfield                  0      0     0
# dropdown                   0      0     0
# checkbox_btn               0      0     0
# checkbox_label             0      0     0
# radiobutton_btn            0      0     0
# radiobutton_label          0      0     0
# textarea                   0      0     0
# text                       0      0     0
# fileinput                  0      0     0
# image                      0      0     0
# colorpicker                0      0     0
# range                      0      0     0
# progressbar                0      0     0
# datetimeselector           0      0     0
# numberselector             0      0     0
# dropdownselector           0      0     0
# checklist                  0      0     0
# table                      0      0     0
# n/a                        0      1  1900
#
# [22 rows x 22 columns]

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
sns.heatmap(confusion_matrix_df, annot=True, fmt="4d", cmap="YlGnBu");

# %%
dataset_name
# Out:
# 'cnews'

# %%
accuracy(results_df)
# Out:
# <H2>Accuracy: 0.0 <H2>
# 2021-05-28 23:58:00,049 -INFO - common:common.py:438 - Accuracy:  0/236 = 0.0, for 2220 elements
# 0.0

# %%
dataset.classes_dict
# Out:
# {'button': 0,
#  'link': 1,
#  'iframe': 2,
#  'textfield': 3,
#  'dropdown': 4,
#  'checkbox_btn': 5,
#  'checkbox_label': 6,
#  'radiobutton_btn': 7,
#  'radiobutton_label': 8,
#  'textarea': 9,
#  'text': 10,
#  'fileinput': 11,
#  'image': 12,
#  'colorpicker': 13,
#  'range': 14,
#  'progressbar': 15,
#  'datetimeselector': 16,
#  'numberselector': 17,
#  'dropdownselector': 18,
#  'checklist': 19,
#  'table': 20,
#  'n/a': 21}

# %%
dataset.dataset['label_text_predicted'] = results_df.y_pred_label

# %%
gray_img = get_grey_image(f'dataset/images/{dataset_name}.png')
print(gray_img.shape)

IMG_SIZE = 15
_h = gray_img.shape[0]/gray_img.shape[1]*IMG_SIZE
_w = IMG_SIZE
plt.figure(figsize=(_w, _h))

plt.imshow(gray_img, cmap='gray')
axes = plt.gca()

for i, r in dataset.dataset[dataset.dataset.label_text_predicted != 'n/a'].iterrows():
    #print(r.predicted_label, r.x, r.y, r.width, r.height)
    
    if (r.x<0) or (r.y<0): # or (r.x>r.width): #or (r.y>r.height):
        continue
        
    patch = Rectangle((r.x, r.y), r.width, r.height, linewidth=2, alpha = .2, facecolor = 'blue')
    axes.add_patch(patch)
    axes.text(r.x, r.y, r.label_text_predicted, color='white', backgroundcolor='blue')

for i, r in dataset.dataset[dataset.dataset.label != dataset.dummy_class_value].iterrows():
    #print(r.predicted_label, r.x, r.y, r.width, r.height)
    patch = Rectangle((r.x, r.y), r.width, r.height, linewidth=2, alpha = .2, facecolor = 'red')
    axes.add_patch(patch)
    axes.text(r.x+15, r.y+15, dataset.classes_reverse_dict[r.label], color='white', backgroundcolor='red')
# Out:
# (7900, 1500)

# %%
results_df
# Out:
#       y_true  y_pred y_true_label y_pred_label  is_hidden
# 0         21      21          n/a          n/a          0
# 1         21      21          n/a          n/a          0
# 2         21      21          n/a          n/a          0
# 3         21      21          n/a          n/a          1
# 4         21      21          n/a          n/a          1
# ...      ...     ...          ...          ...        ...
# 2215      21      21          n/a          n/a          1
# 2216      21      21          n/a          n/a          1
# 2217      21      21          n/a          n/a          1
# 2218      21      21          n/a          n/a          1
# 2219      21      21          n/a          n/a          1
#
# [2220 rows x 5 columns]

# %%
dataset.dataset[:1].to_json(orient='records')
# Out:
# '[{"attributes":{"action":null,"alt":null,"aria-hidden":null,"aria-label":null,"aria-live":null,"aria-relevant":null,"async":null,"cellspacing":null,"charset":null,"checked":null,"class":null,"content":null,"crossorigin":null,"data-advert":null,"data-category":null,"data-char":null,"data-cnb":null,"data-comment":null,"data-dismiss":null,"data-filter":null,"data-id":null,"data-input":null,"data-next-page-url":null,"data-nocomment":null,"data-number":null,"data-page":null,"data-result":null,"data-search":null,"data-service":null,"data-show-id":null,"data-show-type":null,"data-src":null,"data-step":null,"data-style":null,"data-tariff":null,"data-toggle":null,"data-type":null,"data-zone":null,"defer":null,"for":null,"frameborder":null,"height":null,"href":null,"http-equiv":null,"id":null,"integrity":null,"max":null,"media":null,"method":null,"min":null,"name":null,"onclick":null,"placeholder":null,"property":null,"rel":null,"role":null,"sandbox":null,"scrolling":null,"selected":null,"src":null,"style":null,"tabindex":null,"target":null,"title":null,"translate":null,"type":null,"value":null,"width":null},"displayed":true,"element_id":"5726358925732730049581214771","height":7833.375,"onmouseenter":null,"onmouseover":null,"parent_id":"5726358925732730049581214771","style":["align-content","align-items","align-self","alignment-baseline","animation-delay","animation-direction","animation-duration","animation-fill-mode","animation-iteration-count","animation-name","animation-play-state","animation-timing-function","appearance","backdrop-filter","backface-visibility","background-attachment","background-blend-mode","background-clip","background-color","background-image","background-origin","background-position","background-repeat","background-size","baseline-shift","block-size","border-block-end-color","border-block-end-style","border-block-end-width","border-block-start-color","border-block-start-style","border-block-start-width","border-bottom-color","border-bottom-left-radius","border-bottom-right-radius","border-bottom-style","border-bottom-width","border-collapse","border-end-end-radius","border-end-start-radius","border-image-outset","border-image-repeat","border-image-slice","border-image-source","border-image-width","border-inline-end-color","border-inline-end-style","border-inline-end-width","border-inline-start-color","border-inline-start-style","border-inline-start-width","border-left-color","border-left-style","border-left-width","border-right-color","border-right-style","border-right-width","border-start-end-radius","border-start-start-radius","border-top-color","border-top-left-radius","border-top-right-radius","border-top-style","border-top-width","bottom","box-shadow","box-sizing","break-after","break-before","break-inside","buffered-rendering","caption-side","caret-color","clear","clip","clip-path","clip-rule","color","color-interpolation","color-interpolation-filters","color-rendering","column-count","column-gap","column-rule-color","column-rule-style","column-rule-width","column-span","column-width","content","cursor","cx","cy","d","direction","display","dominant-baseline","empty-cells","fill","fill-opacity","fill-rule","filter","flex-basis","flex-direction","flex-grow","flex-shrink","flex-wrap","float","flood-color","flood-opacity","font-family","font-kerning","font-optical-sizing","font-size","font-stretch","font-style","font-variant","font-variant-caps","font-variant-east-asian","font-variant-ligatures","font-variant-numeric","font-weight","grid-auto-columns","grid-auto-flow","grid-auto-rows","grid-column-end","grid-column-start","grid-row-end","grid-row-start","grid-template-areas","grid-template-columns","grid-template-rows","height","hyphens","image-orientation","image-rendering","inline-size","inset-block-end","inset-block-start","inset-inline-end","inset-inline-start","isolation","justify-content","justify-items","justify-self","left","letter-spacing","lighting-color","line-break","line-height","list-style-image ...
