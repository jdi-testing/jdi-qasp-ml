# %%
import os, sys, re
import numpy as np
import pandas as pd
import platform
from IPython.display import display, clear_output, HTML
from datetime import datetime
import pickle

from time import sleep
from tqdm.auto import tqdm
from utils import logger

import selenium
from selenium.webdriver.common.by import By
from selenium.webdriver import Firefox, ActionChains
from selenium.webdriver.common.keys import Keys

import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

START_TS = datetime.now()
# Out:
# 2021-03-26 05:22:47,654 - INFO - dataset:dataset.py:27 - dataset package is loaded...

# %%
from utils import get_all_elements, iou_xywh, screenshot, maximize_window, get_parents_list, build_tree_dict, DatasetBuilder

# %%
selenium.__version__
# Out:
# '3.141.0'

# %% [markdown]
# ## Parameters

# %%
SITE_URL = 'https://getbootstrap.com/docs/5.0/components/card/'
DATASET_NAME = 'bootstrap-1'
class JDIDatasetBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        driver.set_window_size(width=1920, height=1090)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        

with JDIDatasetBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True) as builder:
    elements_df = builder.dataset
    plt.imshow(plt.imread(f'dataset/images/{DATASET_NAME}.png'))
# Out:
# 2021-03-26 06:17:03,807 - INFO - dataset:dataset.py:186 - Dataset name: bootstrap-1
# 2021-03-26 06:17:03,808 - INFO - dataset:dataset.py:195 - Create directories to save the dataset
# 2021-03-26 06:17:03,809 - INFO - dataset:dataset.py:227 - Creating driver
# 2021-03-26 06:17:04,851 - INFO - dataset:dataset.py:234 - Chrome web driver is created
# 2021-03-26 06:17:04,968 - INFO - <ipython-input-12-a76523c44636>:<ipython-input-12-a76523c44636>:11 - getting url: https://getbootstrap.com/docs/5.0/components/card/
# 2021-03-26 06:17:09,000 - INFO - common:common.py:82 - Window maximized
# 2021-03-26 06:17:09,001 - INFO - dataset:dataset.py:237 - save scrinshot: dataset/images/bootstrap-1.png
# 2021-03-26 06:17:11,697 - INFO - dataset:dataset.py:280 - Collect features using JS script
# 2021-03-26 06:17:15,355 - INFO - dataset:dataset.py:288 - Save html to dataset/html/bootstrap-1.html
# 2021-03-26 06:17:15,381 - INFO - dataset:dataset.py:299 - Save parquet to dataset/df/bootstrap-1.parquet
# 2021-03-26 06:17:31,622 - INFO - dataset:dataset.py:209 - Close web driver

# %%
SITE_URL = 'https://getbootstrap.com/docs/5.0/content/reboot/'
DATASET_NAME = 'bootstrap-reboot'
class JDIDatasetBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        driver.set_window_size(width=1920, height=1090)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        maximize_window(driver=driver, extend_pix=500)
        sleep(3.0)
        #driver.find_element_by_tag_name('html').send_keys(Keys.CONTROL, Keys.END)
        #sleep(3.0)
        
        #maximize_window(driver=driver, extend_pix=500)
        #self.full_page(driver=driver)
        

with JDIDatasetBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True) as builder:
    elements_df = builder.dataset
    plt.imshow(plt.imread(f'dataset/images/{DATASET_NAME}.png'))
# Out:
# 2021-03-26 13:25:06,146 - INFO - dataset:dataset.py:186 - Dataset name: bootstrap-reboot
# 2021-03-26 13:25:06,147 - INFO - dataset:dataset.py:195 - Create directories to save the dataset
# 2021-03-26 13:25:06,149 - INFO - dataset:dataset.py:227 - Creating driver
# 2021-03-26 13:25:07,247 - INFO - dataset:dataset.py:234 - Chrome web driver is created
# 2021-03-26 13:25:07,363 - INFO - <ipython-input-19-453e480c6416>:<ipython-input-19-453e480c6416>:11 - getting url: https://getbootstrap.com/docs/5.0/content/reboot/
# 2021-03-26 13:25:08,569 - INFO - common:common.py:82 - Window maximized
# 2021-03-26 13:25:11,576 - INFO - dataset:dataset.py:237 - save scrinshot: dataset/images/bootstrap-reboot.png
# 2021-03-26 13:25:12,499 - INFO - dataset:dataset.py:280 - Collect features using JS script
# 2021-03-26 13:25:13,264 - INFO - dataset:dataset.py:288 - Save html to dataset/html/bootstrap-reboot.html
# 2021-03-26 13:25:13,274 - INFO - dataset:dataset.py:299 - Save parquet to dataset/df/bootstrap-reboot.parquet
# 2021-03-26 13:25:13,795 - INFO - dataset:dataset.py:209 - Close web driver

# %%
SITE_URL = 'https://getbootstrap.com/docs/5.0/forms/form-control/'
DATASET_NAME = 'bootstrap-form-control'
class JDIDatasetBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        driver.set_window_size(width=1920, height=1090)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        maximize_window(driver=driver, extend_pix=500)
        sleep(3.0)
        #driver.find_element_by_tag_name('html').send_keys(Keys.CONTROL, Keys.END)
        #sleep(3.0)
        
        #maximize_window(driver=driver, extend_pix=500)
        #self.full_page(driver=driver)
        

with JDIDatasetBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True) as builder:
    elements_df = builder.dataset
    plt.imshow(plt.imread(f'dataset/images/{DATASET_NAME}.png'))
# Out:
# 2021-03-26 13:43:06,749 - INFO - dataset:dataset.py:186 - Dataset name: bootstrap-form-control
# 2021-03-26 13:43:06,749 - INFO - dataset:dataset.py:195 - Create directories to save the dataset
# 2021-03-26 13:43:06,753 - INFO - dataset:dataset.py:227 - Creating driver
# 2021-03-26 13:43:07,851 - INFO - dataset:dataset.py:234 - Chrome web driver is created
# 2021-03-26 13:43:07,968 - INFO - <ipython-input-20-e591c5293e47>:<ipython-input-20-e591c5293e47>:11 - getting url: https://getbootstrap.com/docs/5.0/forms/form-control/
# 2021-03-26 13:43:12,734 - INFO - common:common.py:82 - Window maximized
# 2021-03-26 13:43:15,747 - INFO - dataset:dataset.py:237 - save scrinshot: dataset/images/bootstrap-form-control.png
# 2021-03-26 13:43:16,494 - INFO - dataset:dataset.py:280 - Collect features using JS script
# 2021-03-26 13:43:17,621 - INFO - dataset:dataset.py:288 - Save html to dataset/html/bootstrap-form-control.html
# 2021-03-26 13:43:17,639 - INFO - dataset:dataset.py:299 - Save parquet to dataset/df/bootstrap-form-control.parquet
# 2021-03-26 13:43:18,183 - INFO - dataset:dataset.py:209 - Close web driver

# %%
SITE_URL = 'https://gitlab.com'
DATASET_NAME = 'gitlab'
class JDIDatasetBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        driver.set_window_size(width=1920, height=7400)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        sleep(3.0)       
        driver.find_element_by_id('CybotCookiebotDialogBodyLevelButtonAccept').click()
        sleep(3.0)
        driver.find_element_by_id('Layer_1').click()        

with JDIDatasetBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True) as builder:
    elements_df = builder.dataset
    plt.imshow(plt.imread(f'dataset/images/{DATASET_NAME}.png'))
# Out:
# 2021-03-27 02:04:20,355 - INFO - dataset:dataset.py:186 - Dataset name: gitlab
# 2021-03-27 02:04:20,356 - INFO - dataset:dataset.py:195 - Create directories to save the dataset
# 2021-03-27 02:04:20,357 - INFO - dataset:dataset.py:227 - Creating driver
# 2021-03-27 02:04:21,452 - INFO - dataset:dataset.py:234 - Chrome web driver is created
# 2021-03-27 02:04:21,561 - INFO - <ipython-input-39-e4df7ea009f5>:<ipython-input-39-e4df7ea009f5>:11 - getting url: https://gitlab.com
# 2021-03-27 02:04:28,590 - INFO - dataset:dataset.py:237 - save scrinshot: dataset/images/gitlab.png
# 2021-03-27 02:04:29,499 - INFO - dataset:dataset.py:280 - Collect features using JS script
# 2021-03-27 02:04:30,842 - INFO - dataset:dataset.py:288 - Save html to dataset/html/gitlab.html
# 2021-03-27 02:04:30,863 - INFO - dataset:dataset.py:299 - Save parquet to dataset/df/gitlab.parquet
# 2021-03-27 02:04:31,359 - INFO - dataset:dataset.py:209 - Close web driver

# %%
SITE_URL = 'https://voice.google.com/u/0/about'
DATASET_NAME = 'google-voice'
class JDIDatasetBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        driver.set_window_size(width=1920, height=1090)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        maximize_window(driver=driver, extend_pix=0)
        sleep(3.0)
        #driver.find_element_by_tag_name('html').send_keys(Keys.CONTROL, Keys.END)
        #sleep(3.0)
        
        #maximize_window(driver=driver, extend_pix=500)
        #self.full_page(driver=driver)
        

with JDIDatasetBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True) as builder:
    elements_df = builder.dataset
    plt.imshow(plt.imread(f'dataset/images/{DATASET_NAME}.png'))
# Out:
# 2021-03-27 02:40:58,353 - INFO - dataset:dataset.py:186 - Dataset name: google-voice
# 2021-03-27 02:40:58,353 - INFO - dataset:dataset.py:195 - Create directories to save the dataset
# 2021-03-27 02:40:58,355 - INFO - dataset:dataset.py:227 - Creating driver
# 2021-03-27 02:40:59,588 - INFO - dataset:dataset.py:234 - Chrome web driver is created
# 2021-03-27 02:40:59,698 - INFO - <ipython-input-40-886762c6c834>:<ipython-input-40-886762c6c834>:11 - getting url: https://voice.google.com/u/0/about
# 2021-03-27 02:41:02,696 - INFO - common:common.py:82 - Window maximized
# 2021-03-27 02:41:05,710 - INFO - dataset:dataset.py:237 - save scrinshot: dataset/images/google-voice.png
# 2021-03-27 02:41:06,211 - INFO - dataset:dataset.py:280 - Collect features using JS script
# 2021-03-27 02:41:06,299 - INFO - dataset:dataset.py:288 - Save html to dataset/html/google-voice.html
# 2021-03-27 02:41:06,305 - INFO - dataset:dataset.py:299 - Save parquet to dataset/df/google-voice.parquet
# 2021-03-27 02:41:06,521 - INFO - dataset:dataset.py:209 - Close web driver

# %%
SITE_URL = 'https://support.microsoft.com/en-us/office?ui=en-us&rs=en-us&ad=us'
DATASET_NAME = 'ms-office'
class JDIDatasetBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        driver.set_window_size(width=1920, height=1090)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        maximize_window(driver=driver, extend_pix=0)
        sleep(3.0)
        #driver.find_element_by_tag_name('html').send_keys(Keys.CONTROL, Keys.END)
        #sleep(3.0)
        
        #maximize_window(driver=driver, extend_pix=500)
        #self.full_page(driver=driver)
        

with JDIDatasetBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True) as builder:
    elements_df = builder.dataset
    plt.imshow(plt.imread(f'dataset/images/{DATASET_NAME}.png'))
# Out:
# 2021-03-27 02:52:25,604 - INFO - dataset:dataset.py:186 - Dataset name: ms-office
# 2021-03-27 02:52:25,605 - INFO - dataset:dataset.py:195 - Create directories to save the dataset
# 2021-03-27 02:52:25,606 - INFO - dataset:dataset.py:227 - Creating driver
# 2021-03-27 02:52:26,706 - INFO - dataset:dataset.py:234 - Chrome web driver is created
# 2021-03-27 02:52:26,828 - INFO - <ipython-input-41-154f35ed1720>:<ipython-input-41-154f35ed1720>:11 - getting url: https://support.microsoft.com/en-us/office?ui=en-us&rs=en-us&ad=us
# 2021-03-27 02:52:30,299 - INFO - common:common.py:82 - Window maximized
# 2021-03-27 02:52:33,314 - INFO - dataset:dataset.py:237 - save scrinshot: dataset/images/ms-office.png
# 2021-03-27 02:52:34,091 - INFO - dataset:dataset.py:280 - Collect features using JS script
# 2021-03-27 02:52:34,630 - INFO - dataset:dataset.py:288 - Save html to dataset/html/ms-office.html
# 2021-03-27 02:52:34,649 - INFO - dataset:dataset.py:299 - Save parquet to dataset/df/ms-office.parquet
# 2021-03-27 02:52:34,884 - INFO - dataset:dataset.py:209 - Close web driver
