# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, "jdi-qasp-ml", "data/mui_dataset")

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window

# %%
from utils.config import logger

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'material-ui-Radio'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click() #path to elements packs
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click() #path to mui
        driver.find_element_by_xpath("//*[@id='__next']/div/div/div[1]/div/div[7]/div").click() #path to elements
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=False, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-12-20 17:22:32,113 -INFO - dataset_builder.py:100 - Dataset name: material-ui-Radio
# 2021-12-20 17:22:32,122 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-12-20 17:22:32,128 -INFO - dataset_builder.py:151 - Creating driver
# 2021-12-20 17:22:34,152 -INFO - dataset_builder.py:163 - Chrome web driver is created
# 2021-12-20 17:22:34,264 -INFO - 1390990284.py:10 - getting url: https://jdi-testing.github.io/jdi-light/
# ipykernel_launcher:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2021-12-20 17:22:46,909 -INFO - common.py:22 - Window maximized
# 2021-12-20 17:22:53,913 -INFO - dataset_builder.py:166 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/material-ui-Radio.png
# 2021-12-20 17:22:54,300 -INFO - dataset_builder.py:210 - Collect features using JS script
# 2021-12-20 17:22:54,884 -INFO - dataset_builder.py:218 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/material-ui-Radio.html
# 2021-12-20 17:22:54,912 -INFO - dataset_builder.py:230 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/material-ui-Radio.pkl
# 2021-12-20 17:22:54,919 -INFO - dataset_builder.py:233 - No attributes: (11, 13)
# 2021-12-20 17:22:55,284 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '3806836326101743077899682795',
#   'x': 269.0,
#   'y': 293.09375,
#   'width': 316.0625,
#   'height': 66.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 20860.125},
#  {'element_id': '4889952223101743068671518146',
#   'x': 269.0,
#   'y': 138.21875,
#   'width': 374.796875,
#   'height': 42.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 15741.46875},
#  {'element_id': '9410497743101743073347056862',
#   'x': 293.0,
#   'y': 463.953125,
#   'width': 179.796875,
#   'height': 84.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 15102.9375},
#  {'element_id': '0103471344101743068175056716',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6438058938101743064365793689',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7499600620101743063435114198',
#   'x': 0.0,
#   'y': 2064.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7489754802101743061032047148',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7456993694101743063892074793',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7416400053101743061853191532',
#   'x': 0.0,
#   'y': 96.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7388894239101743064343213998',
#   'x': 0.0,
#   'y': 2160.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7005688091101743063131627894',
#   'x': 0.0,
#   'y': 480.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6973956308101743062810025778',
#   'x': 0.0,
#   'y': 48.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6871548358101743063500146787',
#   'x': 0.0,
#   'y': 384.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6746686403101743060078522482',
#   'x': 0.0,
#   'y': 480.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6567790807101743069547318274',
#   'x': 0.0,
#   'y': 2064.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6469216751101743062692985067',
#   'x': 0.0,
#   'y': 2640.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6266184268101743066378470843',
#   'x': 0.0,
#   'y': 1536.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6360093857101743065622838945',
#   'x': 0.0,
#   'y': 2544.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7612723439101743062824718230',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6241071262101743064219774280',
#   'x': 0.0,
#   'y': 1104.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6231009106101743061085716244',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6223549231101743062827929443',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6109810385101743063795325720',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6091666448101743060126248513',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6051441880101743060988462364',
#   'x': 0.0,
#   'y': 432.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5823123068101743067730812660',
#   'x': 0.0,
#   'y': 2208.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5791029149101743060721315464',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5744934570101743061917182473',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5658216728101743068515812224',
#   'x': 0.0,
#   'y': 1920.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7603428139101743060278909912',
#   'x': 0.0,
#   'y': 2400.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7678135070101743068168988247',
#   'x': 0.0,
#   'y': 192.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5161689995101743061288239604',
#   'x': 0.0,
#   'y': 1152.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7692838004101743060278198485',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '
0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '4640592735101743069884067187',
#   'x': 0.0,
#   'y': 2016.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '4628115507101743065975159963',
#   'x': 0.0,
#   'y': 1584.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '4595742347101743061638653451',
#   'x': 0.0,
#   'y': 2352.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '4533889283101743068978034526',
#   'x': 0.0,
#   'y': 288.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '4416290727101743060279363173',
#   'x': 0.0,
#   'y': 1824.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '4276577621101743067295465266',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '4139437175101743068245740960',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3892832198101743065179089609',
#   'x': 0.0,
#   'y': 144.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3805428402101743065528655453',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3783720223101743065738700035',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3778112989101743066065580066',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3702118743101743067863159471',
#   'x': 0.0,
#   'y': 1104.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3663359558101743064732358010',
#   'x': 0.0,
#   'y': 144.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3598993584101743063295350699',
#   'x': 0.0,
#   'y': 1440.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3593936210101743069484687081',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3548461722101743069828388395',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3492161049101743067521835195',
#   'x': 0.0,
#   'y': 2448.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3240929914101743067700166657',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3203602937101743060687864603',
#   'x': 0.0,
#   'y': 192.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3108760947101743060589122423',
#   'x': 0.0,
#   'y': 2592.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3038712660101743061399321489',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '2976233762101743063694222952',
#   'x': 0.0,
#   'y': 2448.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '2816007435101743064496205203',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '9958074997101743068984943448',
#   'x': 0.0,
#   'y': 1872.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '0261188749101743071092992258',
#   'x': 293.0,
#   'y': 578.859375,
#   'width': 171.796875,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 6270.5859375}]
# CPU times: user 52.9 ms, sys: 12.7 ms, total: 65.6 ms
# Wall time: 1.69 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id      x            y       width  height  \
# 0  3806836326101743077899682795  269.0   293.093750  316.062500    66.0
# 1  4889952223101743068671518146  269.0   138.218750  374.796875    42.0
# 2  9410497743101743073347056862  293.0   463.953125  179.796875    84.0
# 3  0103471344101743068175056716    0.0  1728.000000  245.000000    48.0
# 4  6438058938101743064365793689    0.0  1392.000000  245.000000    48.0
#
#   predicted_label  predicted_probability     sort_key tag_name
# 0      radiogroup                    1.0  20860.12500      DIV
# 1      radiogroup                    1.0  15741.46875      DIV
# 2      radiogroup                    1.0  15102.93750      DIV
# 3          button                    1.0  11760.00000      DIV
# 4          button                    1.0  11760.00000      DIV

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
