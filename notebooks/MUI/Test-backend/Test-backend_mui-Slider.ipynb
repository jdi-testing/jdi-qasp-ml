# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
WORKING_DIR = re.sub('jdi-qasp-ml.*$','',os.path.normpath(os.getcwd())) + 'jdi-qasp-ml'
os.chdir(WORKING_DIR)

# %%
WORKING_DIR
# Out:
# 'C:\\WORK\\jdi-qasp-ml'

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-09-06 16:27:04,832 -INFO - config.py:25 - Module utils.config was loaded
# 2021-09-06 16:27:04,832 -INFO - common.py:618 - Module utils.common is loaded...
# 2021-09-06 16:27:04,832 -INFO - hidden.py:121 - hidden module is loaded
# 2021-09-06 16:27:04,840 -INFO - features_builder.py:305 - feature_bilder module is loaded...
# 2021-09-06 16:27:04,843 -INFO - dataset_builder.py:213 - dataset package is loaded...
# 2021-09-06 16:27:04,847 -INFO - dataset.py:277 - dataset module is loaded...

# %%
UTILS_LOGGER = 'utils.dataset'
LOG_FILE_PATH = 'tmp/log.txt'

os.makedirs(name='tmp', exist_ok=True)

logger = logging.getLogger(UTILS_LOGGER)
logger.setLevel(logging.DEBUG)


formatter = logging.Formatter('%(asctime)s -%(levelname)s - %(module)s:%(filename)s:%(lineno)d - %(message)s')

console_handler = logging.StreamHandler(sys.stdout)
console_handler.setFormatter(formatter)

file_handler = logging.FileHandler(filename=LOG_FILE_PATH, mode='w')
file_handler.setFormatter(formatter)

logger.addHandler(console_handler)
logger.addHandler(file_handler)

logger.info('Module utils.config was loaded')
# Out:
# 2021-09-06 16:27:04,911 -INFO - 632196539.py:21 - Module utils.config was loaded
# 2021-09-06 16:27:04,911 -INFO - 632196539:632196539.py:21 - Module utils.config was loaded

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# 'C:\\WORK\\jdi-qasp-ml'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'material-ui-Slider'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5000/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
# DATASET_NAME = 'mui-site122'

# %%
# SITE_URL = 'C:/WORK/jdi-qasp-ml/MUI_model/dataset/build/site122/index.html'

# %%
# PREDICT_URL = 'http://localhost:5000/mui-predict'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click() #path to elements packs
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click() #path to mui
        driver.find_element_by_xpath("//*[@id='__next']/div/div/div[1]/div/div[9]/div").click() #path to elements
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path='./MUI_model/dataset/') as builder:
    plt.imshow(plt.imread(f'MUI_model/dataset/images/{DATASET_NAME}.png'))
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2021-09-06 16:27:27,184 -INFO - dataset_builder.py:78 - Dataset name: material-ui-Slider
# 2021-09-06 16:27:27,184 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: material-ui-Slider
# 2021-09-06 16:27:27,188 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-09-06 16:27:27,188 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-09-06 16:27:27,195 -INFO - dataset_builder.py:126 - Creating driver
# 2021-09-06 16:27:27,195 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-09-06 16:27:28,453 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-09-06 16:27:28,453 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-09-06 16:27:28,578 -INFO - 1119333767.py:10 - getting url: https://jdi-testing.github.io/jdi-light/
# 2021-09-06 16:27:28,578 -INFO - 1119333767:1119333767.py:10 - getting url: https://jdi-testing.github.io/jdi-light/
# 2021-09-06 16:27:41,547 -INFO - common.py:75 - Window maximized
# 2021-09-06 16:27:41,547 -INFO - common:common.py:75 - Window maximized
# 2021-09-06 16:27:48,551 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/material-ui-Slider.png
# 2021-09-06 16:27:48,551 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/material-ui-Slider.png
# 2021-09-06 16:27:51,678 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-09-06 16:27:51,678 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-09-06 16:27:53,330 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/material-ui-Slider.html
# 2021-09-06 16:27:53,330 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/material-ui-Slider.html
# 2021-09-06 16:27:53,368 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/material-ui-Slider.pkl
# 2021-09-06 16:27:53,368 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/material-ui-Slider.pkl
# 2021-09-06 16:27:53,368 -INFO - dataset_builder.py:204 - No attributes: (14, 13)
# 2021-09-06 16:27:53,368 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (14, 13)
# 2021-09-06 16:27:54,733 -INFO - dataset_builder.py:103 - Close web driver
# 2021-09-06 16:27:54,733 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '2914012746348716924504503985',
#   'x': 274.0,
#   'y': 1075.984375,
#   'width': 1202.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.9999909401,
#   'sort_key': 28848.0},
#  {'element_id': '2515595683348716917256464226',
#   'x': 266.0,
#   'y': 159.765625,
#   'width': 416.0,
#   'height': 50.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 0.681311965,
#   'sort_key': 20800.0},
#  {'element_id': '5683200847348716917043498293',
#   'x': 266.0,
#   'y': 159.765625,
#   'width': 284.5625,
#   'height': 50.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 14228.125},
#  {'element_id': '9079552317348716925235726865',
#   'x': 266.0,
#   'y': 969.140625,
#   'width': 266.0,
#   'height': 50.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 13300.0},
#  {'element_id': '2292140499348716927647399612',
#   'x': 274.0,
#   'y': 423.390625,
#   'width': 400.0,
#   'height': 28.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999845028,
#   'sort_key': 11200.0},
#  {'element_id': '8235411998348716922236096630',
#   'x': 274.0,
#   'y': 231.359375,
#   'width': 400.0,
#   'height': 28.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999754429,
#   'sort_key': 11200.0},
#  {'element_id': '7316035553348716925433286196',
#   'x': 274.0,
#   'y': 700.265625,
#   'width': 400.0,
#   'height': 28.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.8435634971,
#   'sort_key': 11200.0},
#  {'element_id': '7157720402348716923430918757',
#   'x': 274.0,
#   'y': 359.796875,
#   'width': 400.0,
#   'height': 28.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9976250529,
#   'sort_key': 11200.0},
#  {'element_id': '1359858511348716928529738576',
#   'x': 274.0,
#   'y': 551.828125,
#   'width': 400.0,
#   'height': 28.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9996030927,
#   'sort_key': 11200.0},
#  {'element_id': '0450358288348716923512702481',
#   'x': 274.0,
#   'y': 848.703125,
#   'width': 400.0,
#   'height': 28.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9827229977,
#   'sort_key': 11200.0},
#  {'element_id': '0273506290348716926253946170',
#   'x': 274.0,
#   'y': 330.203125,
#   'width': 400.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.9999986887,
#   'sort_key': 9600.0},
#  {'element_id': '8210801275348716922215589716',
#   'x': 274.0,
#   'y': 393.796875,
#   'width': 400.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.9999004602,
#   'sort_key': 9600.0},
#  {'element_id': '7340972510348716921447438363',
#   'x': 274.0,
#   'y': 201.765625,
#   'width': 400.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 9600.0},
#  {'element_id': '1676114855348716929939262999',
#   'x': 274.0,
#   'y': 670.671875,
#   'width': 400.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.9999958277,
#   'sort_key': 9600.0},
#  {'element_id': '2527213127348716916065521673',
#   'x': 274.0,
#   'y': 138.171875,
#   'width': 400.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.9269047976,
#   'sort_key': 9600.0},
#  {'element_id': '8523904149348716922332262609',
#   'x': 274.0,
#   'y': 819.109375,
#   'width': 400.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.9999986887,
#   'sort_key': 9600.0},
#  {'element_id': '4624042600348716926683754830',
#   'x': 274.0,
#   'y': 522.234375,
#   'width': 400.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.9999958277,
#   'sort_key': 9600.0},
#  {'element_id': '6122777941348716929684031058',
#   'x': 306.0,
#   'y': 969.140625,
#   'width': 168.0,
#   'height': 50.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 8400.0},
#  {'element_id': '9927115582348716921863098057',
#   'x': 274.0,
#   'y': 1105.578125,
#   'width': 28.0,
#   'height': 300.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 8400.0},
#  {'element_id': '9036483478348716911507675003',
#   'x': 274.0,
#   'y': 167.765625,
#   'width': 268.5625,
#   'height': 28.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 7519.75},
#  {'element_id': '0223750393348716924086439767',
#   'x': 274.0,
#   'y': 947.546875,
#   'width': 250.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.9856930971,
#   'sort_key': 6000.0},
#  {'element_id': '9039048609348716925940101782',
#   'x': 314.0,
#   'y': 977.140625,
#   'width': 152.0,
#   'height': 28.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 4256.0},
#  {'element_id': '7120599719348716922836692248',
#   'x': 474.0,
#   'y': 971.640625,
#   'width': 58.0,
#   'height': 45.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 2610.0},
#  {'element_id': '0272140989348716923811545229',
#   'x': 266.0,
#   'y': 971.140625,
#   'width': 40.0,
#   'height': 46.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 1840.0},
#  {'element_id': '8927788857348716924689516816',
#   'x': 482.0,
#   'y': 979.640625,
#   'width': 42.0,
#   'height': 29.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999983311,
#   'sort_key': 1218.0},
#  {'element_id': '0091847919348716927068279665',
#   'x': 274.0,
#   'y': 713.265625,
#   'width': 320.0,
#   'height': 2.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999824762,
#   'sort_key': 640.0},
#  {'element_id': '6577263842348716923215927610',
#   'x': 274.0,
#   'y': 979.140625,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999984503,
#   'sort_key': 576.0},
#  {'element_id': '2059984925348716925984913141',
#   'x': 274.0,
#   'y': 244.359375,
#   'width': 120.0,
#   'height': 2.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 240.0},
#  {'element_id': '8607362342348716915044693911',
#   'x': 274.0,
#   'y': 180.765625,
#   'width': 80.5625,
#   'height': 2.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999961853,
#   'sort_key': 161.125},
#  {'element_id': '3697549999348716922843981422',
#   'x': 274.0,
#   'y': 436.390625,
#   'width': 80.0,
#   'height': 2.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 160.0},
#  {'element_id': '9838992031348716926364913774',
#   'x': 274.0,
#   'y': 564.828125,
#   'width': 80.0,
#   'height': 2.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999824762,
#   'sort_key': 160.0},
#  {'element_id': '5053714928348716922319803233',
#   'x': 274.0,
#   'y': 372.796875,
#   'width': 80.0,
#   'height': 2.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999961853,
#   'sort_key': 160.0},
#  {'element_id': '3722482263348716920750439925',
#   'x': 353.59375,
#   'y': 985.140625,
#   'width': 12.0,
#   'height': 12.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999980927,
#   'sort_key': 144.0},
#  {'element_id': '2110925514348716928595141346',
#   'x': 348.5625,
#   'y': 175.765625,
#   'width': 12.0,
#   'height': 12.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999980927,
#   'sort_key': 144.0},
#  {'element_id': '0916844434348716924102466036',
#   'x': 354.0,
#   'y': 861.703125,
#   'width': 68.0,
#   'height': 2.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999961853,
#   'sort_key': 136.0},
#  {'element_id': '5244509709348716928031932948',
#   'x': 314.0,
#   'y': 990.140625,
#   'width': 45.59375,
#   'height': 2.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999961853,
#   'sort_key': 91.1875},
#  {'element_id': '1992333515348716920184970366',
#   'x': 390.0,
#   'y': 241.359375,
#   'width': 8.0,
#   'height': 8.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 64.0}]
# Wall time: 4.11 s

# %%
from utils import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'MUI_model/dataset/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')

# %%
# set(df.element_id.values).intersection(set(preds.element_id.values))

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'MUI_model/dataset/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    patch = Rectangle((r.x, r.y), r.width, r.height, alpha=.2, color='red')
    axes.add_patch(patch)
    
    axes.text(r.x, r.y, 
              r.predicted_label + ':' +str(round(r.predicted_probability, 3)) + ':' + r.tag_name, 
              backgroundcolor='black', 
              color='white',
              bbox=dict(alpha=0.5))

# %%
img = load_gray_image(f'MUI_model/dataset/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df[predictions_df['predicted_probability'] >0.999].iterrows():
    patch = Rectangle((r.x, r.y), r.width, r.height, alpha=.2, color='red')
    axes.add_patch(patch)
    
    axes.text(r.x, r.y, 
              r.predicted_label + ':' +str(round(r.predicted_probability, 3)) + ':' + r.tag_name, 
              backgroundcolor='black', 
              color='white',
              bbox=dict(alpha=0.5))
