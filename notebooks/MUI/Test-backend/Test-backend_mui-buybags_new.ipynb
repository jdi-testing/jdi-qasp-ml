# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-11-24 15:54:13,851 -INFO - config.py:31 - Module utils.config was loaded
# 2021-11-24 15:54:13,875 -INFO - common.py:127 - Module utils.common is loaded...
# 2021-11-24 15:54:13,877 -INFO - dataset_builder.py:244 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'buybags'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://www.buybags.de'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        sleep(5.0)
        maximize_window(driver=driver, extend_pix=0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=False, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-11-24 16:07:01,004 -INFO - dataset_builder.py:100 - Dataset name: buybags
# 2021-11-24 16:07:01,006 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-11-24 16:07:01,008 -INFO - dataset_builder.py:150 - Creating driver
# 2021-11-24 16:07:03,132 -INFO - dataset_builder.py:162 - Chrome web driver is created
# 2021-11-24 16:07:13,866 -INFO - common.py:30 - Window maximized
# 2021-11-24 16:07:13,867 -INFO - dataset_builder.py:165 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/buybags.png
# 2021-11-24 16:07:14,300 -INFO - dataset_builder.py:209 - Collect features using JS script
# 2021-11-24 16:07:14,628 -INFO - dataset_builder.py:217 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/buybags.html
# 2021-11-24 16:07:14,644 -INFO - dataset_builder.py:229 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/buybags.pkl
# 2021-11-24 16:07:14,646 -INFO - dataset_builder.py:232 - No attributes: (14, 13)
# 2021-11-24 16:07:14,935 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '4806143021592343066012213126',
#   'x': 945.65625,
#   'y': 439.453125,
#   'width': 405.328125,
#   'height': 191.9375,
#   'predicted_label': 'accordion',
#   'predicted_probability': 1.0,
#   'sort_key': 77797.6669921875},
#  {'element_id': '8879372921592343067811294516',
#   'x': 119.0,
#   'y': 130.0,
#   'width': 1232.0,
#   'height': 40.0,
#   'predicted_label': 'breadcrumbs',
#   'predicted_probability': 0.9951117635,
#   'sort_key': 49280.0},
#  {'element_id': '6605026335592343068145217585',
#   'x': 324.640625,
#   'y': 91.0,
#   'width': 820.71875,
#   'height': 28.015625,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 22992.9487304688},
#  {'element_id': '2299629345592343063132430767',
#   'x': 945.65625,
#   'y': 647.390625,
#   'width': 405.328125,
#   'height': 55.0,
#   'predicted_label': 'accordion',
#   'predicted_probability': 1.0,
#   'sort_key': 22293.046875},
#  {'element_id': '8056654915592343066326058467',
#   'x': 945.65625,
#   'y': 331.40625,
#   'width': 405.328125,
#   'height': 42.25,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9981392622,
#   'sort_key': 17125.11328125},
#  {'element_id': '8661793294592343056786204221',
#   'x': 12.0,
#   'y': 8.0,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9849501848,
#   'sort_key': 2304.0},
#  {'element_id': '7405525654592343061858414986',
#   'x': 1410.0,
#   'y': 8.0,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9984220266,
#   'sort_key': 2304.0},
#  {'element_id': '0486472776592343061452019358',
#   'x': 616.15625,
#   'y': 101.0,
#   'width': 120.0625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1921.0},
#  {'element_id': '2691621607592343053036161004',
#   'x': 683.0,
#   'y': 35.0,
#   'width': 120.0,
#   'height': 16.0,
#   'predicted_label': 'drawer',
#   'predicted_probability': 0.8050977588,
#   'sort_key': 1920.0},
#  {'element_id': '6974829487592343065222980508',
#   'x': 208.875,
#   'y': 140.0,
#   'width': 99.5,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1890.5},
#  {'element_id': '1739207213592343066508511600',
#   'x': 324.640625,
#   'y': 101.0,
#   'width': 107.78125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1724.5},
#  {'element_id': '3080367801592343062840373485',
#   'x': 863.171875,
#   'y': 101.0,
#   'width': 87.03125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1392.5},
#  {'element_id': '8224453621592343066935226455',
#   'x': 962.203125,
#   'y': 101.0,
#   'width': 85.15625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1362.5},
#  {'element_id': '3573158563592343068192548815',
#   'x': 521.890625,
#   'y': 101.0,
#   'width': 82.265625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1316.25},
#  {'element_id': '5347801058592343062691426632',
#   'x': 119.0,
#   'y': 140.0,
#   'width': 67.234375,
#   'height': 19.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1277.453125},
#  {'element_id': '1214283059592343061921359565',
#   'x': 444.421875,
#   'y': 101.0,
#   'width': 65.46875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1047.5},
#  {'element_id': '5790447438592343062365123551',
#   'x': 748.21875,
#   'y': 101.0,
#   'width': 52.0625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 833.0},
#  {'element_id': '4825666787592343066192277507',
#   'x': 1059.359375,
#   'y': 101.0,
#   'width': 48.3125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 773.0},
#  {'element_id': '6383664195592343067491390772',
#   'x': 812.28125,
#   'y': 101.0,
#   'width': 38.890625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 622.25},
#  {'element_id': '0171817425592343069110797290',
#   'x': 1119.671875,
#   'y': 101.0,
#   'width': 25.6875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 411.0}]
# CPU times: user 29 ms, sys: 4.77 ms, total: 33.8 ms
# Wall time: 1.02 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id           x           y        width  \
# 0  4806143021592343066012213126  945.656250  439.453125   405.328125
# 1  8879372921592343067811294516  119.000000  130.000000  1232.000000
# 2  6605026335592343068145217585  324.640625   91.000000   820.718750
# 3  2299629345592343063132430767  945.656250  647.390625   405.328125
# 4  8056654915592343066326058467  945.656250  331.406250   405.328125
#
#        height predicted_label  predicted_probability      sort_key tag_name
# 0  191.937500       accordion               1.000000  77797.666992      DIV
# 1   40.000000     breadcrumbs               0.995112  49280.000000      NAV
# 2   28.015625            list               1.000000  22992.948730       UL
# 3   55.000000       accordion               1.000000  22293.046875      DIV
# 4   42.250000          button               0.998139  17125.113281        A

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))

# %%
PREDICT_URL = 'http://localhost:5050/get_tasks_statuses'
response = requests.post(
    PREDICT_URL, data=dataset_json[10]
)

# %%
response.json()
# Out:
# {'exc': 'Expecting value: line 1 column 1 (char 0)'}
