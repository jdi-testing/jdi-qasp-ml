# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, "jdi-qasp-ml", "data/mui_dataset")

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window

# %%
from utils.config import logger

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'material-ui-Radio'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click() #path to elements packs
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click() #path to mui
        driver.find_element_by_xpath("//*[@id='__next']/div/div/div[1]/div/div[7]/div").click() #path to elements
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=False, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-11-29 18:51:53,599 -INFO - dataset_builder.py:100 - Dataset name: material-ui-Radio
# 2021-11-29 18:51:53,612 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-11-29 18:51:53,621 -INFO - dataset_builder.py:151 - Creating driver
# 2021-11-29 18:51:55,642 -INFO - dataset_builder.py:163 - Chrome web driver is created
# 2021-11-29 18:51:55,755 -INFO - 1390990284.py:10 - getting url: https://jdi-testing.github.io/jdi-light/
# ipykernel_launcher:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2021-11-29 18:52:08,316 -INFO - common.py:22 - Window maximized
# 2021-11-29 18:52:15,320 -INFO - dataset_builder.py:166 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/material-ui-Radio.png
# 2021-11-29 18:52:15,698 -INFO - dataset_builder.py:210 - Collect features using JS script
# 2021-11-29 18:52:16,301 -INFO - dataset_builder.py:218 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/material-ui-Radio.html
# 2021-11-29 18:52:16,322 -INFO - dataset_builder.py:230 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/material-ui-Radio.pkl
# 2021-11-29 18:52:16,326 -INFO - dataset_builder.py:233 - No attributes: (11, 13)
# 2021-11-29 18:52:17,811 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '8246402278011357053092713147',
#   'x': 269.0,
#   'y': 293.09375,
#   'width': 316.0625,
#   'height': 66.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 20860.125},
#  {'element_id': '3636275118011357053705119564',
#   'x': 269.0,
#   'y': 138.21875,
#   'width': 374.796875,
#   'height': 42.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 15741.46875},
#  {'element_id': '3515269298011357052699636487',
#   'x': 293.0,
#   'y': 463.953125,
#   'width': 179.796875,
#   'height': 84.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 15102.9375},
#  {'element_id': '0071380193011357052338383135',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7450544758011357059980329849',
#   'x': 0.0,
#   'y': 2352.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6948420047011357052821300434',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 11760.0},
#  {'element_id': '6965748648011357046752001239',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 11760.0},
#  {'element_id': '7001808513011357043504220521',
#   'x': 0.0,
#   'y': 576.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7035800159011357043131117847',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 11760.0},
#  {'element_id': '7045618558011357047455541143',
#   'x': 0.0,
#   'y': 192.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 11760.0},
#  {'element_id': '7124177138011357041462521411',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7218661757011357041414433731',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7268990692011357047661363878',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7281225597011357047010165778',
#   'x': 0.0,
#   'y': 1104.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7303899250011357050226773318',
#   'x': 0.0,
#   'y': 2112.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 11760.0},
#  {'element_id': '7360576991011357041617805761',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7375968253011357052451478039',
#   'x': 0.0,
#   'y': 2544.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6917150591011357055245761382',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6827249947011357057182810184',
#   'x': 0.0,
#   'y': 1536.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6742028598011357054574721562',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5623362134011357044564522406',
#   'x': 0.0,
#   'y': 336.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '0324980339011357059873689719',
#   'x': 0.0,
#   'y': 1536.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 11760.0},
#  {'element_id': '5288462382011357054965951963',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5379800527011357046510163965',
#   'x': 0.0,
#   'y': 96.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 11760.0},
#  {'element_id': '5477132245011357048941905415',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 11760.0},
#  {'element_id': '5530456366011357054677407417',
#   'x': 0.0,
#   'y': 2064.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 11760.0},
#  {'element_id': '5599451663011357049600775714',
#   'x': 0.0,
#   'y': 288.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5662009900011357059417434166',
#   'x': 0.0,
#   'y': 2304.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 11760.0},
#  {'element_id': '6502394269011357057421092940',
#   'x': 0.0,
#   'y': 1824.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 11760.0},
#  {'element_id':

#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.7696325779,
#   'sort_key': 1764.0},
#  {'element_id': '9552803279011357058182678817',
#   'x': 499.65625,
#   'y': 305.09375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.7696325779,
#   'sort_key': 1764.0},
#  {'element_id': '3078450993011357051899338142',
#   'x': 522.90625,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9992170334,
#   'sort_key': 1764.0},
#  {'element_id': '8411641230011357053912461272',
#   'x': 438.609375,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.7696325779,
#   'sort_key': 1764.0},
#  {'element_id': '1142971505011357053758151557',
#   'x': 446.9375,
#   'y': 293.09375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.7696325779,
#   'sort_key': 1764.0},
#  {'element_id': '4781722977011357056328408157',
#   'x': 285.0,
#   'y': 317.09375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9471684694,
#   'sort_key': 1764.0},
#  {'element_id': '5628452605011357057817208097',
#   'x': 337.375,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.7696325779,
#   'sort_key': 1764.0},
#  {'element_id': '8731149719011357050911709192',
#   'x': 394.21875,
#   'y': 305.09375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.7696325779,
#   'sort_key': 1764.0},
#  {'element_id': '8725205408011357059897515060',
#   'x': 282.0,
#   'y': 505.953125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.97194314,
#   'sort_key': 1764.0},
#  {'element_id': '1437169486011357052318853816',
#   'x': 282.0,
#   'y': 463.953125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.97194314,
#   'sort_key': 1764.0}]
# CPU times: user 60.2 ms, sys: 13.5 ms, total: 73.7 ms
# Wall time: 1.79 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id      x            y       width  height  \
# 0  8246402278011357053092713147  269.0   293.093750  316.062500    66.0
# 1  3636275118011357053705119564  269.0   138.218750  374.796875    42.0
# 2  3515269298011357052699636487  293.0   463.953125  179.796875    84.0
# 3  0071380193011357052338383135    0.0  1488.000000  245.000000    48.0
# 4  7450544758011357059980329849    0.0  2352.000000  245.000000    48.0
#
#   predicted_label  predicted_probability     sort_key tag_name
# 0      radiogroup                    1.0  20860.12500      DIV
# 1      radiogroup                    1.0  15741.46875      DIV
# 2      radiogroup                    1.0  15102.93750      DIV
# 3          button                    1.0  11760.00000      DIV
# 4          button                    1.0  11760.00000      DIV

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
