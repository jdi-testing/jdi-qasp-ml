# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
WORKING_DIR = re.sub('jdi-qasp-ml.*$','',os.path.normpath(os.getcwd())) + 'jdi-qasp-ml'
os.chdir(WORKING_DIR)

# %%
WORKING_DIR
# Out:
# 'C:\\WORK\\jdi-qasp-ml'

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-09-07 12:29:13,978 -INFO - config.py:25 - Module utils.config was loaded
# 2021-09-07 12:29:13,981 -INFO - common.py:618 - Module utils.common is loaded...
# 2021-09-07 12:29:13,984 -INFO - hidden.py:121 - hidden module is loaded
# 2021-09-07 12:29:13,987 -INFO - features_builder.py:305 - feature_bilder module is loaded...
# 2021-09-07 12:29:13,996 -INFO - dataset_builder.py:213 - dataset package is loaded...
# 2021-09-07 12:29:14,002 -INFO - dataset.py:277 - dataset module is loaded...

# %%
UTILS_LOGGER = 'utils.dataset'
LOG_FILE_PATH = 'tmp/log.txt'

os.makedirs(name='tmp', exist_ok=True)

logger = logging.getLogger(UTILS_LOGGER)
logger.setLevel(logging.DEBUG)


formatter = logging.Formatter('%(asctime)s -%(levelname)s - %(module)s:%(filename)s:%(lineno)d - %(message)s')

console_handler = logging.StreamHandler(sys.stdout)
console_handler.setFormatter(formatter)

file_handler = logging.FileHandler(filename=LOG_FILE_PATH, mode='w')
file_handler.setFormatter(formatter)

logger.addHandler(console_handler)
logger.addHandler(file_handler)

logger.info('Module utils.config was loaded')
# Out:
# 2021-09-07 12:29:14,026 -INFO - 632196539.py:21 - Module utils.config was loaded
# 2021-09-07 12:29:14,026 -INFO - 632196539:632196539.py:21 - Module utils.config was loaded

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# 'C:\\WORK\\jdi-qasp-ml'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'mui-site122'

# %%
SITE_URL = 'C:/WORK/jdi-qasp-ml/MUI_model/dataset/build/site122/index.html'

# %%
PREDICT_URL = 'http://localhost:5000/mui-predict'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path='./MUI_model/dataset/') as builder:
    plt.imshow(plt.imread(f'MUI_model/dataset/images/{DATASET_NAME}.png'))
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2021-09-07 12:29:21,435 -INFO - dataset_builder.py:78 - Dataset name: mui-site122
# 2021-09-07 12:29:21,435 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: mui-site122
# 2021-09-07 12:29:21,438 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-09-07 12:29:21,438 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-09-07 12:29:21,442 -INFO - dataset_builder.py:126 - Creating driver
# 2021-09-07 12:29:21,442 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-09-07 12:29:22,762 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-09-07 12:29:22,762 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-09-07 12:29:22,884 -INFO - 3258695736.py:10 - getting url: C:/WORK/jdi-qasp-ml/MUI_model/dataset/build/site122/index.html
# 2021-09-07 12:29:22,884 -INFO - 3258695736:3258695736.py:10 - getting url: C:/WORK/jdi-qasp-ml/MUI_model/dataset/build/site122/index.html
# 2021-09-07 12:29:26,489 -INFO - common.py:75 - Window maximized
# 2021-09-07 12:29:26,489 -INFO - common:common.py:75 - Window maximized
# 2021-09-07 12:29:33,501 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site122.png
# 2021-09-07 12:29:33,501 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/mui-site122.png
# 2021-09-07 12:29:35,185 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-09-07 12:29:35,185 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-09-07 12:29:36,668 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site122.html
# 2021-09-07 12:29:36,668 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/mui-site122.html
# 2021-09-07 12:29:36,710 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site122.pkl
# 2021-09-07 12:29:36,710 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/mui-site122.pkl
# 2021-09-07 12:29:36,718 -INFO - dataset_builder.py:204 - No attributes: (26, 13)
# 2021-09-07 12:29:36,718 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (26, 13)
# 2021-09-07 12:29:37,897 -INFO - dataset_builder.py:103 - Close web driver
# 2021-09-07 12:29:37,897 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '9822326901069751996482418291',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 1500.0,
#   'height': 15000.0,
#   'predicted_label': 'popover',
#   'predicted_probability': 0.9931553006,
#   'sort_key': 22500000.0},
#  {'element_id': '5487242873069751999170267317',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 1500.0,
#   'height': 15000.0,
#   'predicted_label': 'popover',
#   'predicted_probability': 0.9931508303,
#   'sort_key': 22500000.0},
#  {'element_id': '2161351508069751987329580780',
#   'x': 110.0,
#   'y': 6250.234375,
#   'width': 1280.0,
#   'height': 4800.0,
#   'predicted_label': 'container',
#   'predicted_probability': 0.9998525381,
#   'sort_key': 6144000.0},
#  {'element_id': '0720458768069751982144517447',
#   'x': 134.0,
#   'y': 6250.234375,
#   'width': 1232.0,
#   'height': 4800.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 5913600.0},
#  {'element_id': '7726042775069751985003605328',
#   'x': 0.0,
#   'y': 1606.96875,
#   'width': 1500.0,
#   'height': 422.78125,
#   'predicted_label': 'dialog',
#   'predicted_probability': 0.8450890183,
#   'sort_key': 634171.875},
#  {'element_id': '4139116440069751986128424439',
#   'x': 0.0,
#   'y': 1264.96875,
#   'width': 1500.0,
#   'height': 342.0,
#   'predicted_label': 'dialog',
#   'predicted_probability': 0.5704894662,
#   'sort_key': 513000.0},
#  {'element_id': '2380626221069751987048104796',
#   'x': 0.0,
#   'y': 2342.75,
#   'width': 1500.0,
#   'height': 342.0,
#   'predicted_label': 'dialog',
#   'predicted_probability': 0.5154200196,
#   'sort_key': 513000.0},
#  {'element_id': '4672891915069751985199710661',
#   'x': 0.0,
#   'y': 942.96875,
#   'width': 1500.0,
#   'height': 322.0,
#   'predicted_label': 'table',
#   'predicted_probability': 0.9976317883,
#   'sort_key': 483000.0},
#  {'element_id': '3943277199069751982161012470',
#   'x': 0.0,
#   'y': 2029.75,
#   'width': 1500.0,
#   'height': 313.0,
#   'predicted_label': 'dialog',
#   'predicted_probability': 0.9938767552,
#   'sort_key': 469500.0},
#  {'element_id': '4851994271069751982211753080',
#   'x': 0.0,
#   'y': 11150.234375,
#   'width': 1500.0,
#   'height': 305.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 0.9999980927,
#   'sort_key': 457500.0},
#  {'element_id': '7548930238069751999995139336',
#   'x': 1190.4000244141,
#   'y': 6178.2001953125,
#   'width': 1467.9998779297,
#   'height': 108.0,
#   'predicted_label': 'menu',
#   'predicted_probability': 0.9985489249,
#   'sort_key': 158543.9868164062},
#  {'element_id': '5330993395069751996275457822',
#   'x': 1190.4000244141,
#   'y': 6178.2001953125,
#   'width': 1467.9998779297,
#   'height': 108.0,
#   'predicted_label': 'menu',
#   'predicted_probability': 0.9985489249,
#   'sort_key': 158543.9868164062},
#  {'element_id': '9010751307069751997620866276',
#   'x': 0.0,
#   'y': 11856.234375,
#   'width': 240.0,
#   'height': 434.0,
#   'predicted_label': 'drawer',
#   'predicted_probability': 1.0,
#   'sort_key': 104160.0},
#  {'element_id': '0928926557069751987111385064',
#   'x': 0.0,
#   'y': 2812.75,
#   'width': 240.0,
#   'height': 433.0,
#   'predicted_label': 'drawer',
#   'predicted_probability': 1.0,
#   'sort_key': 103920.0},
#  {'element_id': '9778387955069751982726377607',
#   'x': 0.0,
#   'y': 4810.75,
#   'width': 360.0,
#   'height': 282.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 101520.0},
#  {'element_id': '9643444857069751989816242034',
#   'x': 0.0,
#   'y': 4462.75,
#   'width': 360.0,
#   'height': 282.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 101520.0},
#  {'element_id': '4899489572069751985855279467',
#   'x': 0.0,
#   'y': 654.96875,
#   'width': 345.0,
#   'height': 288.0,
#   'predicted_label': 'card',
#   'predicted_probability': 1.0,
#   'sort_key': 99360.0},
#  {'element_id': '3974274711069751983304300701',
#   'x': 0.0,
#   'y': 5928.234375,
#   'width': 360.0,
#   'height': 234.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 84240.0},
#  {'element_id': '2587639104069751989191259838',
#   'x': 0.0,
#   'y': 4251.75,
#   'width': 360.0,
#   'height': 211.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999200106,
#   'sort_key': 75960.0},
#  {'element_id': '7498951183069751986178532461',
#   'x': 0.0,
#   'y': 4040.75,
#   'width': 360.0,
#   'height': 211.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999383688,
#   'sort_key': 75960.0},
#  {'element_id': '9928726303069751989626990343',
#   'x': 0.0,
#   'y': 3649.75,
#   'width': 360.0,
#   'height': 211.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.999071002,
#   'sort_key': 75960.0},
#  {'element_id': '7979314671069751997244805541',
#   'x': 0.0,
#   'y': 11557.234375,
#   'width': 360.0,
#   'height': 211.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9995520711,
#   'sort_key': 75960.0},
#  {'element_id': '6221983115069751989535806615',
#   'x': 0.0,
#   'y': 11050.234375,
#   'width': 1500.0,
#   'height': 48.0,
#   'predicted_label': 'app-bar',
#   'predicted_probability': 0.9090026021,
#   'sort_key': 72000.0},
#  {'element_id': '4445712610069751981241421830',
#   'x': 0.0,
#   'y': 6202.234375,
#   'width': 1500.0,
#   'height': 48.0,
#   'predicted_label': 'alert',
#   'predicted_probability': 1.0,
#   'sort_key': 72000.0},
#  {'element_id': '6553918596069751986352164639',
#   'x': 0.0,
#   'y': 3992.75,
#   'width': 1500.0,
#   'height': 48.0,
#   'predicted_label': 'alert',
#   'predicted_probability': 1.0,
#   'sort_key': 72000.0},
#  {'element_id': '1465808473069751992867992802',
#   'x': 0.0,
#   'y': 11921.234375,
#   'width': 239.0,
#   'height': 208.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 49712.0},
#  {'element_id': '0559418948069751982732102154',
#   'x': 0.0,
#   'y': 2876.75,
#   'width': 239.0,
#   'height': 208.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 49712.0},
#  {'element_id': '1462832034069751985070541028',
#   'x': 466.0,
#   'y': 1851.15625,
#   'width': 568.0,
#   'height': 72.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 40896.0},
#  {'element_id': '3722464760069751987750147951',
#   'x': 466.0,
#   'y': 1719.96875,
#   'width': 568.0,
#   'height': 72.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 40896.0},
#  {'element_id': '6142026227069751983379687906',
#   'x': 147.0,
#   'y': 36.0,
#   'width': 364.0,
#   'height': 108.0,
#   'predicted_label': 'backdrop',
#   'predicted_probability': 1.0,
#   'sort_key': 39312.0},
#  {'element_id': '6982117856069751987027282975',
#   'x': 0.0,
#   'y': 3085.75,
#   'width': 239.0,
#   'height': 160.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 38240.0},
#  {'element_id': '0762827527069751996226023340',
#   'x': 0.0,
#   'y': 12130.234375,
#   'width': 239.0,
#   'height': 160.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 38240.0},
#  {'element_id': '3877902162069751984648980833',
#   'x': 0.0,
#   'y': 3261.75,
#   'width': 112.25,
#   'height': 336.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 37716.0},
#  {'element_id': '7613195106069751988882001946',
#   'x': 17.0,
#   'y': 759.96875,
#   'width': 311.0,
#   'height': 120.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.9998127818,
#   'sort_key': 37320.0},
#  {'element_id': '9856068707069751980225985490',
#   'x': 0.0,
#   'y': 2788.75,
#   'width': 1500.0,
#   'height': 24.0,
#   'predicted_label': 'breadcrumbs',
#   'predicted_probability': 0.9999841452,
#   'sort_key': 36000.0},
#  {'element_id': '9763846562069751987798384146',
#   'x': 0.0,
#   'y': 2684.75,
#   'width': 1500.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 36000.0},
#  {'element_id': '5030690040069751983086352853',
#   'x': 0.0,
#   'y': 2748.75,
#   'width': 1500.0,
#   'height': 24.0,
#   'predicted_label': 'breadcrumbs',
#   'predicted_probability': 1.0,
#   'sort_key': 36000.0},
#  {'element_id': '3663721764069751984745180565',
#   'x': 0.0,
#   'y': 3968.75,
#   'width': 1500.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 0.999658227,
#   'sort_key': 36000.0},
#  {'element_id': '8195207584069751987705194871',
#   'x': 0.0,
#   'y': 2708.75,
#   'width': 1500.0,
#   'height': 24.0,
#   'predicted_label': 'breadcrumbs',
#   'predicted_probability': 0.9999760389,
#   'sort_key': 36000.0},
#  {'element_id': '1756420910069751987501200184',
#   'x': 0.0,
#   'y': 5124.75,
#   'width': 500.0,
#   'height': 56.0,
#   'predicted_label': 'bottom-navigation',
#   'predicted_probability': 1.0,
#   'sort_key': 28000.0},
#  {'element_id': '9094751412069751987453077512',
#   'x': 466.0,
#   'y': 1797.5625,
#   'width': 568.0,
#   'height': 48.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 27264.0},
#  {'element_id': '0450693936069751988972722231',
#   'x': 474.0,
#   'y': 2201.75,
#   'width': 552.0,
#   'height': 45.0,
#   'predicted_label': 'text-field',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 24840.0},
#  {'element_id': '1764868245069751998227394884',
#   'x': 0.0,
#   'y': 11768.234375,
#   'width': 500.0,
#   'height': 48.0,
#   'predicted_label': 'paper',
#   'predicted_probability': 1.0,
#   'sort_key': 24000.0},
#  {'element_id': '8191900467069751991650880768',
#   'x': 0.0,
#   'y': 11768.234375,
#   'width': 500.0,
#   'height': 48.0,
#   'predicted_label': 'tabs',
#   'predicted_probability': 1.0,
#   'sort_key': 24000.0},
#  {'element_id': '1304206173069751988964320555',
#   'x': 466.0,
#   'y': 1654.96875,
#   'width': 568.0,
#   'height': 32.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 18176.0},
#  {'element_id': '1815225021069751986960776366',
#   'x': 16.0,
#   'y': 24.0,
#   'width': 328.0,
#   'height': 52.890625,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 17348.125},
#  {'element_id': '6572024959069751981271172846',
#   'x': 16.0,
#   'y': 5656.75,
#   'width': 328.0,
#   'height': 52.890625,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 17348.125},
#  {'element_id': '3013870648069751987134980064',
#   'x': 16.0,
#   'y': 311.484375,
#   'width': 328.0,
#   'height': 52.890625,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 17348.125},
#  {'element_id': '7593155345069751987115756005',
#   'x': 16.0,
#   'y': 24.0,
#   'width': 277.1875,
#   'height': 52.890625,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 14660.6201171875},
#  {'element_id': '9911346980069751982940263256',
#   'x': 16.0,
#   'y': 5656.75,
#   'width': 277.1875,
#   'height': 52.890625,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 14660.6201171875},
#  {'element_id': '8892047517069751980325867372',
#   'x': 16.0,
#   'y': 311.484375,
#   'width': 277.1875,
#   'height': 52.890625,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 14660.6201171875},
#  {'element_id': '1986290178069751984146563240',
#   'x': 16.0,
#   'y': 5709.640625,
#   'width': 328.0,
#   'height': 40.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 13120.0},
#  {'element_id': '1981461103069751984812914657',
#   'x': 16.0,
#   'y': 364.375,
#   'width': 328.0,
#   'height': 40.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 13120.0},
#  {'element_id': '7672866978069751984236214077',
#   'x': 16.0,
#   'y': 76.890625,
#   'width': 328.0,
#   'height': 40.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 13120.0},
#  {'element_id': '6880809496069751983006336635',
#   'x': 16.0,
#   'y': 311.484375,
#   'width': 277.1875,
#   'height': 41.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 11364.6875},
#  {'element_id': '1899525248069751985979032663',
#   'x': 16.0,
#   'y': 24.0,
#   'width': 277.1875,
#   'height': 41.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 11364.6875},
#  {'element_id': '5229701041069751987599407491',
#   'x': 16.0,
#   'y': 5656.75,
#   'width': 277.1875,
#   'height': 41.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 11364.6875},
#  {'element_id': '0729648707069751980335847368',
#   'x': 8.0,
#   'y': 3904.75,
#   'width': 194.640625,
#   'height': 56.0,
#   'predicted_label': 'text-field',
#   'predicted_probability': 1.0,
#   'sort_key': 10899.875},
#  {'element_id': '3499493545069751987082273138',
#   'x': 16.0,
#   'y': 5790.640625,
#   'width': 328.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 7872.0},
#  {'element_id': '1859274662069751981405124921',
#   'x': 16.0,
#   'y': 445.375,
#   'width': 328.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 7872.0},
#  {'element_id': '4200221055069751989901484048',
#   'x': 16.0,
#   'y': 157.890625,
#   'width': 328.0,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 7872.0},
#  {'element_id': '5903062346069751989919365428',
#   'x': 645.5625,
#   'y': 11106.234375,
#   'width': 208.859375,
#   'height': 36.0,
#   'predicted_label': 'button-group',
#   'predicted_probability': 1.0,
#   'sort_key': 7518.9375},
#  {'element_id': '2378412096069751989467203455',
#   'x': 645.5625,
#   'y': 3605.75,
#   'width': 208.859375,
#   'height': 36.0,
#   'predicted_label': 'button-group',
#   'predicted_probability': 1.0,
#   'sort_key': 7518.9375},
#  {'element_id': '7564693727069751980269428461',
#   'x': -4.7675890923,
#   'y': 5551.982421875,
#   'width': 81.5351715088,
#   'height': 81.53515625,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 6647.9829488397},
#  {'element_id': '2098367648069751988577309943',
#   'x': 0.0,
#   'y': 5200.75,
#   'width': 179.984375,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 6479.4375},
#  {'element_id': '2553751294069751982411202532',
#   'x': 0.0,
#   'y': 5628.75,
#   'width': 1500.0,
#   'height': 4.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 0.8429635167,
#   'sort_key': 6000.0},
#  {'element_id': '4580691933069751983498903479',
#   'x': 10.0,
#   'y': 5246.75,
#   'width': 200.0,
#   'height': 28.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 5600.0},
#  {'element_id': '5510395344069751991097316524',
#   'x': 353.078125,
#   'y': 11455.234375,
#   'width': 166.9375,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 5342.0},
#  {'element_id': '4790490470069751996916869240',
#   'x': 218.984375,
#   'y': 11487.234375,
#   'width': 166.515625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 5328.5},
#  {'element_id': '5864856296069751985513531722',
#   'x': 1157.84375,
#   'y': 5092.75,
#   'width': 164.625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 5268.0},
#  {'element_id': '2376672925069751982715585723',
#   'x': 0.0,
#   'y': 3860.75,
#   'width': 132.875,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4783.5},
#  {'element_id': '0129169550069751983808783893',
#   'x': 911.75,
#   'y': 1953.75,
#   'width': 130.25,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4689.0},
#  {'element_id': '9398940157069751999035330381',
#   'x': 754.1875,
#   'y': 11455.234375,
#   'width': 142.9375,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 4574.0},
#  {'element_id': '6104005296069751980404158367',
#   'x': 683.953125,
#   'y': 2514.75,
#   'width': 132.09375,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 1.0,
#   'sort_key': 4227.0},
#  {'element_id': '0124103847069751983828707308',
#   'x': 683.953125,
#   'y': 1436.96875,
#   'width': 132.09375,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 1.0,
#   'sort_key': 4227.0},
#  {'element_id': '9601486277069751995490474026',
#   'x': 897.125,
#   'y': 11455.234375,
#   'width': 130.484375,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 4175.5},
#  {'element_id': '4093605621069751989963181811',
#   'x': 8.0,
#   'y': 538.96875,
#   'width': 114.53125,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4123.125},
#  {'element_id': '4009442514069751988758079295',
#   'x': 8.0,
#   'y': 251.484375,
#   'width': 114.53125,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4123.125},
#  {'element_id': '3390460331069751982296547747',
#   'x': 8.0,
#   'y': 5884.234375,
#   'width': 114.53125,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4123.125},
#  {'element_id': '9976445320069751986659220084',
#   'x': 1030.96875,
#   'y': 5092.75,
#   'width': 126.875,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 4060.0},
#  {'element_id': '4231120215069751991576143390',
#   'x': 121.390625,
#   'y': 11459.234375,
#   'width': 166.90625,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 4005.75},
#  {'element_id': '3489814099069751986826567431',
#   'x': 807.09375,
#   'y': 5092.75,
#   'width': 125.0,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 4000.0},
#  {'element_id': '7312782547069751994296553801',
#   'x': 1124.65625,
#   'y': 11455.234375,
#   'width': 121.640625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3892.5},
#  {'element_id': '8986017778069751996211348060',
#   'x': 0.0,
#   'y': 11455.234375,
#   'width': 121.390625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3884.5},
#  {'element_id': '8046797462069751997439967480',
#   'x': 0.0,
#   'y': 11487.234375,
#   'width': 113.421875,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3629.5},
#  {'element_id': '2426687619069751983696033307',
#   'x': 941.484375,
#   'y': 2266.75,
#   'width': 100.515625,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 3618.5625},
#  {'element_id': '0957806798069751985580168589',
#   'x': 0.0,
#   'y': 5092.75,
#   'width': 110.671875,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3541.5},
#  {'element_id': '6527107359069751984510123708',
#   'x': 659.875,
#   'y': 5096.75,
#   'width': 147.21875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3533.25},
#  {'element_id': '1352877890069751981445426969',
#   'x': 297.0625,
#   'y': 5096.75,
#   'width': 139.390625,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3345.375},
#  {'element_id': '0450071045069751981500416483',
#   'x': 557.484375,
#   'y': 5092.75,
#   'width': 102.390625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3276.5},
#  {'element_id': '6615278212069751995414955325',
#   'x': 1346.0,
#   'y': 11459.234375,
#   'width': 136.359375,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3272.625},
#  {'element_id': '6577479788069751996939159276',
#   'x': 520.015625,
#   'y': 11459.234375,
#   'width': 135.140625,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3243.375},
#  {'element_id': '0263055327069751990677432799',
#   'x': 655.15625,
#   'y': 11455.234375,
#   'width': 99.03125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3169.0},
#  {'element_id': '8061358058069751981743625673',
#   'x': 772.96875,
#   'y': 3605.75,
#   'width': 81.453125,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2932.3125},
#  {'element_id': '9878658630069751989089071962',
#   'x': 772.96875,
#   'y': 11106.234375,
#   'width': 81.453125,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2932.3125},
#  {'element_id': '1222186791069751981445698207',
#   'x': 436.453125,
#   'y': 5096.75,
#   'width': 121.03125,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2904.75},
#  {'element_id': '4986128213069751981300311556',
#   'x': 858.28125,
#   'y': 2266.75,
#   'width': 75.203125,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2707.3125},
#  {'element_id': '5895989893069751987469283639',
#   'x': 20.0,
#   'y': 5824.234375,
#   'width': 82.578125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2642.5},
#  {'element_id': '9895060553069751987700454018',
#   'x': 20.0,
#   'y': 191.484375,
#   'width': 82.578125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2642.5},
#  {'element_id': '4593749846069751984680876945',
#   'x': 20.0,
#   'y': 478.96875,
#   'width': 82.578125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2642.5},
#  {'element_id': '5268591874069751996899736472',
#   'x': 113.421875,
#   'y': 11491.234375,
#   'width': 105.5625,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2533.5},
#  {'element_id': '1477771189069751981302756793',
#   'x': 0.0,
#   'y': 4786.75,
#   'width': 104.46875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2507.25},
#  {'element_id': '6107098320069751997712740434',
#   'x': 1246.296875,
#   'y': 11459.234375,
#   'width': 99.703125,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2392.875},
#  {'element_id': '2455391714069751987600859005',
#   'x': 932.09375,
#   'y': 5096.75,
#   'width': 98.875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2373.0},
#  {'element_id': '7177121790069751984097443000',
#   'x': 708.109375,
#   'y': 3605.75,
#   'width': 65.859375,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2370.9375},
#  {'element_id': '5848599919069751985503310773',
#   'x': 708.109375,
#   'y': 11106.234375,
#   'width': 65.859375,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2370.9375},
#  {'element_id': '5302065517069751988356564079',
#   'x': 976.53125,
#   'y': 2608.75,
#   'width': 65.46875,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2356.875},
#  {'element_id': '2182654192069751984265449689',
#   'x': 976.53125,
#   'y': 1530.96875,
#   'width': 65.46875,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2356.875},
#  {'element_id': '9465567037069751995675545502',
#   'x': 1027.609375,
#   'y': 11459.234375,
#   'width': 97.046875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2329.125},
#  {'element_id': '3468826822069751981440677915',
#   'x': 110.671875,
#   'y': 5096.75,
#   'width': 97.03125,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2328.75},
#  {'element_id': '4819370210069751984553262903',
#   'x': 12.0,
#   'y': 11050.234375,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2304.0},
#  {'element_id': '6222200818069751986093909620',
#   'x': 994.0,
#   'y': 1646.96875,
#   'width': 48.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 2304.0},
#  {'element_id': '2660218192069751983590865650',
#   'x': -3.9809346199,
#   'y': 6158.2534179688,
#   'width': 47.9618682861,
#   'height': 47.9619140625,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 2300.3430050164},
#  {'element_id': '8428858651069751989043421031',
#   'x': 305.0190734863,
#   'y': 66.0190658569,
#   'width': 47.9618530273,
#   'height': 47.9618682861,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 2300.3400776563},
#  {'element_id': '1044375227069751984062864255',
#   'x': 645.5625,
#   'y': 11106.234375,
#   'width': 63.546875,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2287.6875},
#  {'element_id': '8021498936069751984927931135',
#   'x': 645.5625,
#   'y': 3605.75,
#   'width': 63.546875,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2287.6875},
#  {'element_id': '1670253843069751987794112814',
#   'x': 166.3125,
#   'y': 191.484375,
#   'width': 71.140625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2276.5},
#  {'element_id': '1755361729069751987767826940',
#   'x': 166.3125,
#   'y': 478.96875,
#   'width': 71.140625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2276.5},
#  {'element_id': '6206214611069751987308338511',
#   'x': 166.3125,
#   'y': 5824.234375,
#   'width': 71.140625,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2276.5},
#  {'element_id': '9182241647069751992801918758',
#   'x': 385.5,
#   'y': 11491.234375,
#   'width': 93.859375,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2252.625},
#  {'element_id': '7602371593069751982177052404',
#   'x': 207.703125,
#   'y': 5096.75,
#   'width': 89.359375,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2144.625},
#  {'element_id': '5336199306069751986391987099',
#   'x': 158.140625,
#   'y': 2708.75,
#   'width': 88.65625,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 2127.75},
#  {'element_id': '5678074117069751988856794191',
#   'x': 158.140625,
#   'y': 2748.75,
#   'width': 88.65625,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 2127.75},
#  {'element_id': '0874034866069751989221940052',
#   'x': 187.171875,
#   'y': 2788.75,
#   'width': 88.65625,
#   'height': 24.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 2127.75},
#  {'element_id': '4179022672069751993516817765',
#   'x': 288.296875,
#   'y': 11455.234375,
#   'width': 64.78125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2073.0},
#  {'element_id': '9824014937069751989360334091',
#   'x': 293.1875,
#   'y': 318.421875,
#   'width': 50.8125,
#   'height': 39.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 1981.6875},
#  {'element_id': '0833444978069751982157257650',
#   'x': 293.1875,
#   'y': 5663.6875,
#   'width': 50.8125,
#   'height': 39.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 1981.6875},
#  {'element_id': '0918175758069751983290904223',
#   'x': 293.1875,
#   'y': 30.9375,
#   'width': 50.8125,
#   'height': 39.0,
#   'predicted_label': 'grid',
#   'predicted_probability': 1.0,
#   'sort_key': 1981.6875},
#  {'element_id': '3021970618069751989907321338',
#   'x': 9.0,
#   'y': 903.96875,
#   'width': 64.0,
#   'height': 30.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 1920.0},
#  {'element_id': '5303795328069751985681199928',
#   'x': -11.0,
#   'y': 3471.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9551750422,
#   'sort_key': 1764.0},
#  {'element_id': '6535446844069751989332820847',
#   'x': -11.0,
#   'y': 3513.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '4432254835069751982968896258',
#   'x': -11.0,
#   'y': 3303.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '7163323639069751987251282674',
#   'x': -11.0,
#   'y': 3429.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '4001011705069751985561922887',
#   'x': -11.0,
#   'y': 3387.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '4215814703069751989537034395',
#   'x': -11.0,
#   'y': 3345.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '1512968000069751981112510889',
#   'x': -11.0,
#   'y': 3261.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '1954143896069751988848216442',
#   'x': -11.0,
#   'y': 4744.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '6490286375069751988973581756',
#   'x': -11.0,
#   'y': 3555.75,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999959469,
#   'sort_key': 1764.0},
#  {'element_id': '6441344543069751985734484961',
#   'x': 245.453125,
#   'y': 478.96875,
#   'width': 52.78125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 1689.0},
#  {'element_id': '7207795805069751989334464109',
#   'x': 245.453125,
#   'y': 191.484375,
#   'width': 52.78125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 1689.0},
#  {'element_id': '2991760432069751980886065557',
#   'x': 245.453125,
#   'y': 5824.234375,
#   'width': 52.78125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 1689.0},
#  {'element_id': '8412442900069751982742145980',
#   'x': 293.1875,
#   'y': 30.9375,
#   'width': 50.8125,
#   'height': 32.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 1626.0},
#  {'element_id': '7744670976069751980136220390',
#   'x': 293.1875,
#   'y': 5663.6875,
#   'width': 50.8125,
#   'height': 32.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 1626.0},
#  {'element_id': '0011915064069751982230688141',
#   'x': 293.1875,
#   'y': 318.421875,
#   'width': 50.8125,
#   'height': 32.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 1626.0},
#  {'element_id': '1799161484069751988370557433',
#   'x': 0.0,
#   'y': 3972.75,
#   'width': 100.53125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1608.5},
#  {'element_id': '4550725415069751996008586918',
#   'x': 0.0,
#   'y': 11816.234375,
#   'width': 40.0,
#   'height': 40.0,
#   'predicted_label': 'avatar',
#   'predicted_probability': 0.9999957085,
#   'sort_key': 1600.0},
#  {'element_id': '7757750361069751997625708403',
#   'x': 0.0,
#   'y': 12290.234375,
#   'width': 40.0,
#   'height': 40.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0},
#  {'element_id': '0816455698069751984952916919',
#   'x': 110.578125,
#   'y': 5824.234375,
#   'width': 47.734375,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 1527.5},
#  {'element_id': '5432518735069751986513459527',
#   'x': 110.578125,
#   'y': 478.96875,
#   'width': 47.734375,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 1527.5},
#  {'element_id': '7103320928069751980831529013',
#   'x': 110.578125,
#   'y': 191.484375,
#   'width': 47.734375,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 1527.5},
#  {'element_id': '8728738848069751983198790173',
#   'x': 692.953125,
#   'y': 1476.96875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '0997598254069751980733738609',
#   'x': 692.953125,
#   'y': 2554.75,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '8920956553069751993161608483',
#   'x': -11.0,
#   'y': 11519.234375,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '6126730682069751985293547612',
#   'x': 8.0,
#   'y': 5182.75,
#   'width': 87.703125,
#   'height': 16.0,
#   'predicted_label': 'box',
#   'predicted_probability': 1.0,
#   'sort_key': 1403.25},
#  {'element_id': '8969894638069751980745409414',
#   'x': 0.0,
#   'y': 2791.75,
#   'width': 79.890625,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1358.140625},
#  {'element_id': '9955273201069751987361932113',
#   'x': 0.0,
#   'y': 2751.75,
#   'width': 79.890625,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1358.140625},
#  {'element_id': '9295625530069751983189074469',
#   'x': 0.0,
#   'y': 2711.75,
#   'width': 79.890625,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1358.140625},
#  {'element_id': '9006180395069751982698145328',
#   'x': 101.375,
#   'y': 2751.75,
#   'width': 35.28125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 599.78125},
#  {'element_id': '5280726608069751988310330123',
#   'x': 115.890625,
#   'y': 2791.75,
#   'width': 35.28125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 599.78125},
#  {'element_id': '4468929670069751987702615248',
#   'x': 101.375,
#   'y': 2711.75,
#   'width': 35.28125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 599.78125},
#  {'element_id': '7999187051069751990688820178',
#   'x': 16.0,
#   'y': 11989.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999456406,
#   'sort_key': 576.0},
#  {'element_id': '8953921330069751994137632939',
#   'x': 5.0,
#   'y': 11459.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '8341800853069751982990127011',
#   'x': 16.0,
#   'y': 2992.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '8369347987069751995428167476',
#   'x': 16.0,
#   'y': 12037.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '9887366738069751985191742671',
#   'x': 71.328125,
#   'y': 5131.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '9436902545069751984760309596',
#   'x': 1006.0,
#   'y': 1658.96875,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.8485919237,
#   'sort_key': 576.0},
#  {'element_id': '8004445823069751992585543093',
#   'x': 8.0,
#   'y': 12338.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'badge',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '9132059462069751980814659525',
#   'x': 16.0,
#   'y': 2896.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '8661622366069751984215692748',
#   'x': 238.0,
#   'y': 5132.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '8467132447069751997347598901',
#   'x': 16.0,
#   'y': 12085.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999456406,
#   'sort_key': 576.0},
#  {'element_id': '8437900676069751980242896742',
#   'x': 24.0,
#   'y': 5580.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 576.0},
#  {'element_id': '0395580066069751982710874982',
#   'x': 5.0,
#   'y': 5096.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '3908903641069751980370362778',
#   'x': 24.0,
#   'y': 6033.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '1354056724069751987733462329',
#   'x': 16.0,
#   'y': 2944.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999456406,
#   'sort_key': 576.0},
#  {'element_id': '1960979669069751992749222243',
#   'x': 223.984375,
#   'y': 11491.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '3630619070069751984291477714',
#   'x': 24.0,
#   'y': 5036.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '4839869352069751991960566257',
#   'x': 16.0,
#   'y': 11941.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '1404024112069751982515326804',
#   'x': 16.0,
#   'y': 3105.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '5103427499069751986507434456',
#   'x': 24.0,
#   'y': 4688.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '5173991300069751980595600748',
#   'x': 404.671875,
#   'y': 5132.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '5925656204069751983404127304',
#   'x': 16.0,
#   'y': 3040.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999456406,
#   'sort_key': 576.0},
#  {'element_id': '5940361530069751986170511019',
#   'x': 24.0,
#   'y': 5960.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '6082921563069751989646111901',
#   'x': 16.0,
#   'y': 3201.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '6047420312069751992578079311',
#   'x': 16.0,
#   'y': 12246.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '4589038337069751992491354634',
#   'x': 16.0,
#   'y': 12150.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999859333,
#   'sort_key': 576.0},
#  {'element_id': '3696298179069751984873787569',
#   'x': 24.0,
#   'y': 6106.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '3801580281069751999133186520',
#   'x': 16.0,
#   'y': 12198.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999456406,
#   'sort_key': 576.0},
#  {'element_id': '7393297921069751993222028014',
#   'x': 228.0,
#   'y': 11780.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 576.0},
#  {'element_id': '3665039620069751986957578032',
#   'x': 16.0,
#   'y': 3153.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999456406,
#   'sort_key': 576.0},
#  {'element_id': '6916088739069751999184816308',
#   'x': 68.0,
#   'y': 11780.234375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 576.0},
#  {'element_id': '4508193107069751981226967116',
#   'x': 76.0,
#   'y': 11058.234375,
#   'width': 16.984375,
#   'height': 32.0,
#   'predicted_label': 'typography',
#   'predicted_probability': 1.0,
#   'sort_key': 543.5},
#  {'element_id': '8948471375069751986253612649',
#   'x': 0.0,
#   'y': 2687.75,
#   'width': 29.953125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 509.203125},
#  {'element_id': '5881442588069751996508342567',
#   'x': 493.015625,
#   'y': 11460.234375,
#   'width': 22.0,
#   'height': 22.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 484.0},
#  {'element_id': '0655493171069751980065610370',
#   'x': 82.671875,
#   'y': 5097.75,
#   'width': 22.0,
#   'height': 22.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 484.0},
#  {'element_id': '9647828140069751984520480458',
#   'x': 1129.84375,
#   'y': 5097.75,
#   'width': 22.0,
#   'height': 22.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 484.0},
#  {'element_id': '1017971453069751994744892413',
#   'x': 94.390625,
#   'y': 11460.234375,
#   'width': 22.0,
#   'height': 22.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 484.0},
#  {'element_id': '6928921798069751999576228711',
#   'x': 358.5,
#   'y': 11492.234375,
#   'width': 22.0,
#   'height': 22.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 484.0},
#  {'element_id': '3650185478069751999140688255',
#   'x': 86.421875,
#   'y': 11492.234375,
#   'width': 22.0,
#   'height': 22.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 484.0},
#  {'element_id': '2109285192069751981147141060',
#   'x': 87.890625,
#   'y': 2790.75,
#   'width': 20.0,
#   'height': 20.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 400.0},
#  {'element_id': '9541255539069751986180917918',
#   'x': 159.171875,
#   'y': 2790.75,
#   'width': 20.0,
#   'height': 20.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 400.0},
#  {'element_id': '4439681156069751980730435735',
#   'x': 0.0,
#   'y': 4890.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 360.0},
#  {'element_id': '0417356896069751999689543067',
#   'x': 0.0,
#   'y': 11711.234375,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 360.0},
#  {'element_id': '4076003303069751997680765133',
#   'x': 0.0,
#   'y': 11613.234375,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999997616,
#   'sort_key': 360.0},
#  {'element_id': '0711864962069751988846674265',
#   'x': 0.0,
#   'y': 4096.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999997616,
#   'sort_key': 360.0},
#  {'element_id': '4332789417069751989323387862',
#   'x': 0.0,
#   'y': 3803.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 360.0},
#  {'element_id': '4950000106069751985385979329',
#   'x': 0.0,
#   'y': 4307.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999997616,
#   'sort_key': 360.0},
#  {'element_id': '8399371231069751980794493507',
#   'x': 0.0,
#   'y': 4405.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 360.0},
#  {'element_id': '2386990556069751989288551053',
#   'x': 0.0,
#   'y': 4194.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 360.0},
#  {'element_id': '4526278069069751984145533732',
#   'x': 0.0,
#   'y': 4542.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 360.0},
#  {'element_id': '6641424929069751980679955885',
#   'x': 0.0,
#   'y': 3705.75,
#   'width': 360.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999997616,
#   'sort_key': 360.0},
#  {'element_id': '9176809567069751986030421655',
#   'x': 440.453125,
#   'y': 5099.75,
#   'width': 18.0,
#   'height': 18.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '9778542212069751995091339723',
#   'x': 124.390625,
#   'y': 11462.234375,
#   'width': 18.0,
#   'height': 18.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '6239504330069751988731744760',
#   'x': 301.0625,
#   'y': 5099.75,
#   'width': 18.0,
#   'height': 18.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '0366880247069751987186996464',
#   'x': 113.671875,
#   'y': 5099.75,
#   'width': 18.0,
#   'height': 18.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 324.0},
#  {'element_id': '2251690557069751987823404256',
#   'x': 72.0,
#   'y': 6008.234375,
#   'width': 288.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 288.0},
#  {'element_id': '4651939626069751985628578778',
#   'x': 72.0,
#   'y': 4639.75,
#   'width': 288.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 288.0},
#  {'element_id': '1769370852069751987061875856',
#   'x': 72.0,
#   'y': 4987.75,
#   'width': 288.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 288.0},
#  {'element_id': '1620885786069751988134170879',
#   'x': 72.0,
#   'y': 6081.234375,
#   'width': 288.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 288.0},
#  {'element_id': '3380019930069751985574212594',
#   'x': 187.703125,
#   'y': 5100.75,
#   'width': 16.0,
#   'height': 16.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 256.0},
#  {'element_id': '2634784312069751991834375796',
#   'x': 198.984375,
#   'y': 11495.234375,
#   'width': 16.0,
#   'height': 16.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 256.0},
#  {'element_id': '6233517973069751993556507236',
#   'x': 635.15625,
#   'y': 11463.234375,
#   'width': 16.0,
#   'height': 16.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 256.0},
#  {'element_id': '6682929926069751990132062793',
#   'x': 1462.359375,
#   'y': 11463.234375,
#   'width': 16.0,
#   'height': 16.0,
#   'predicted_label': 'icon',
#   'predicted_probability': 1.0,
#   'sort_key': 256.0},
#  {'element_id': '4094618471069751994040337112',
#   'x': 0.0,
#   'y': 12129.234375,
#   'width': 239.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 239.0},
#  {'element_id': '6920040850069751998140192543',
#   'x': 0.0,
#   'y': 11920.234375,
#   'width': 239.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 1.0,
#   'sort_key': 239.0},
#  {'element_id': '4511804150069751982239312014',
#   'x': 0.0,
#   'y': 3084.75,
#   'width': 239.0,
#   'height': 1.0,
#   'predicted_label': 'divider',
#   'predicted_probability': 0.9999992847,
#   'sort_key': 239.0}]
# Wall time: 5.05 s

# %%
from utils import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'MUI_model/dataset/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')

# %%
# set(df.element_id.values).intersection(set(preds.element_id.values))

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'MUI_model/dataset/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df[predictions_df['predicted_probability'] >0.995].iterrows():
    patch = Rectangle((r.x, r.y), r.width, r.height, alpha=.2, color='red')
    axes.add_patch(patch)
    
    axes.text(r.x, r.y, 
              r.predicted_label + ':' +str(round(r.predicted_probability, 3)) + ':' + r.tag_name, 
              backgroundcolor='black', 
              color='white')
