# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'HTML5_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/html5_dataset')

# %%
DATASET_NAME = 'mozilla'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://developer.mozilla.org/ru/docs/Learn/HTML'
PREDICT_URL = 'http://localhost:5050/html5-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 2
# HEADLESS = True

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        maximize_window(driver=driver, extend_pix=0)
        sleep(2.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2022-01-14 11:08:33,311 -INFO - dataset_builder.py:100 - Dataset name: mozilla
# 2022-01-14 11:08:33,313 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2022-01-14 11:08:33,317 -INFO - dataset_builder.py:152 - Creating driver
# 2022-01-14 11:08:34,359 -INFO - dataset_builder.py:164 - Chrome web driver is created
# 2022-01-14 11:08:35,535 -INFO - common.py:22 - Window maximized
# 2022-01-14 11:08:37,540 -INFO - dataset_builder.py:167 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/images/mozilla.png
# 2022-01-14 11:08:44,146 -INFO - dataset_builder.py:211 - Collect features using JS script
# 2022-01-14 11:08:45,074 -INFO - dataset_builder.py:219 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/html/mozilla.html
# 2022-01-14 11:08:45,095 -INFO - dataset_builder.py:231 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/df/mozilla.pkl
# 2022-01-14 11:08:45,098 -INFO - dataset_builder.py:234 - No attributes: (409, 14)
# 2022-01-14 11:08:45,198 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '1798532075477241664359838651',
#   'x': 424.0,
#   'y': 859.515625,
#   'width': 756.359375,
#   'height': 144.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 108915.75},
#  {'element_id': '9635461908477241666965693631',
#   'x': 424.0,
#   'y': 340.640625,
#   'width': 756.359375,
#   'height': 120.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 90763.125},
#  {'element_id': '7657942450477241679104800052',
#   'x': 50.0,
#   'y': 3221.984375,
#   'width': 1400.0,
#   'height': 55.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 77000.0},
#  {'element_id': '7508525286477241678097273505',
#   'x': 424.0,
#   'y': 1849.265625,
#   'width': 756.359375,
#   'height': 96.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 72610.5},
#  {'element_id': '1790720218477241661490396475',
#   'x': 0.0,
#   'y': -320.0,
#   'width': 1500.0,
#   'height': 48.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 72000.0},
#  {'element_id': '5620123562477241667000041128',
#   'x': 0.0,
#   'y': -320.0,
#   'width': 1500.0,
#   'height': 48.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 72000.0},
#  {'element_id': '9677139470477241661738484771',
#   'x': 0.0,
#   'y': -320.0,
#   'width': 1500.0,
#   'height': 48.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 72000.0},
#  {'element_id': '9106230889477241665489127267',
#   'x': 424.0,
#   'y': 266.046875,
#   'width': 1002.0,
#   'height': 58.59375,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 58710.9375},
#  {'element_id': '5719985759477241668022202814',
#   'x': 424.0,
#   'y': 1027.515625,
#   'width': 756.359375,
#   'height': 72.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 54457.875},
#  {'element_id': '2275048647477241660797103827',
#   'x': 424.0,
#   'y': 547.515625,
#   'width': 756.359375,
#   'height': 72.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 54457.875},
#  {'element_id': '0607776382477241678561591574',
#   'x': 424.0,
#   'y': 1786.390625,
#   'width': 1002.0,
#   'height': 46.875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 46968.75},
#  {'element_id': '6207540485477241672599243899',
#   'x': 424.0,
#   'y': 1123.515625,
#   'width': 1002.0,
#   'height': 46.875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 46968.75},
#  {'element_id': '3407042446477241679681627666',
#   'x': 424.0,
#   'y': 1969.265625,
#   'width': 1002.0,
#   'height': 46.875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 46968.75},
#  {'element_id': '0627686254477241666257501025',
#   'x': 424.0,
#   'y': 484.640625,
#   'width': 1002.0,
#   'height': 46.875,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 46968.75},
#  {'element_id': '5431592739477241669429865900',
#   'x': 424.0,
#   'y': 483.640625,
#   'width': 922.421875,
#   'height': 47.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 43353.828125},
#  {'element_id': '5667421077477241673795535495',
#   'x': 424.0,
#   'y': 2248.140625,
#   'width': 1002.0,
#   'height': 37.5,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 37575.0},
#  {'element_id': '7424255217477241675340544905',
#   'x': 424.0,
#   'y': 1186.390625,
#   'width': 756.359375,
#   'height': 48.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 36305.25},
#  {'element_id': '2340400911477241665069588349',
#   'x': 424.0,
#   'y': 958.515625,
#   'width': 689.453125,
#   'height': 41.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 28267.578125},
#  {'element_id': '7278146068477241674307193827',
#   'x': 424.0,
#   'y': 1785.390625,
#   'width': 558.59375,
#   'height': 47.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 26253.90625},
#  {'element_id': '1141877111477241673522658006',
#   'x': 424.0,
#   'y': 2445.640625,
#   'width': 1002.0,
#   'height': 24.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 24048.0},
#  {'element_id': '5041579490477241660820215048',
#   'x': 100.0,
#   'y': 209.046875,
#   'width': 1306.078125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 22203.328125},
#  {'element_id': '2028552978477241671723132022',
#   'x': 424.0,
#   'y': 1968.265625,
#   'width': 341.5,
#   'height': 47.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 16050.5},
#  {'element_id': '9399367652477241663663865786',
#   'x': 74.0,
#   'y': 36.0,
#   'width': 210.984375,
#   'height': 70.046875,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 14778.7961425781},
#  {'element_id': '4593529166477241662326993508',
#   'x': 998.984375,
#   'y': 51.015625,
#   'width': 357.015625,
#   'height': 40.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 14280.625},
#  {'element_id': '6589276683477241670126342435',
#   'x': 50.0,
#   'y': 2829.21875,
#   'width': 200.0,
#   'height': 66.765625,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 13353.125},
#  {'element_id': '5965868239477241673921345763',
#   'x': 86.0,
#   'y': 1414.984375,
#   'width': 288.375,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10845.603515625},
#  {'element_id': '4970488934477241674058352703',
#   'x': 86.0,
#   'y': 2183.125,
#   'width': 287.828125,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10825.0358886719},
#  {'element_id': '8093355651477241672806053821',
#   'x': 74.0,
#   'y': 1131.71875,
#   'width': 282.828125,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10636.9890136719},
#  {'element_id': '4753247966477241675764130581',
#   'x': 86.0,
#   'y': 2240.734375,
#   'width': 280.671875,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10555.8937988281},
#  {'element_id': '0123816121477241678595745065',
#   'x': 86.0,
#   'y': 1333.375,
#   'width': 278.359375,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10468.9221191406},
#  {'element_id': '0986918568477241678017880034',
#   'x': 86.0,
#   'y': 3085.75,
#   'width': 276.984375,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10417.2092285156},
#  {'element_id': '6300294921477241673109225015',
#   'x': 86.0,
#   'y': 2809.65625,
#   'width': 275.78125,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10371.9604492188},
#  {'element_id': '7407928247477241672053488748',
#   'x': 74.0,
#   'y': 1647.8125,
#   'width': 272.8125,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10260.3076171875},
#  {'element_id': '9808634099477241670826966338',
#   'x': 86.0,
#   'y': 2159.125,
#   'width': 271.296875,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10203.3059082031},
#  {'element_id': '3987291478477241674225696766',
#   'x': 86.0,
#   'y': 2682.4375,
#   'width': 270.46875,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10172.1606445312},
#  {'element_id': '6546511201477241674237747458',
#   'x': 86.0,
#   'y': 1638.25,
#   'width': 270.453125,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10171.5729980469},
#  {'element_id': '7170009372477241677331797416',
#   'x': 86.0,
#   'y': 874.890625,
#   'width': 268.953125,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10115.1589355469},
#  {'element_id': '0967167537477241676068623543',
#   'x': 86.0,
#   'y': 2687.21875,
#   'width': 268.078125,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 10082.2507324219},
#  {'element_id': '4510173074477241670049467818',
#   'x': 86.0,
#   'y': 2720.828125,
#   'width': 265.625,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9989.990234375},
#  {'element_id': '0367336633477241674383637634',
#   'x': 86.0,
#   'y': 1583.03125,
#   'width': 264.84375,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9960.6079101562},
#  {'element_id': '4577982276477241677591170796',
#   'x': 74.0,
#   'y': 2394.34375,
#   'width': 264.21875,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9937.1020507812},
#  {'element_id': '2546642566477241674941992858',
#   'x': 86.0,
#   'y': 2363.171875,
#   'width': 264.140625,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9934.1638183594},
#  {'element_id': '1084555857477241676675284971',
#   'x': 86.0,
#   'y': 2864.875,
#   'width': 263.921875,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9925.9367675781},
#  {'element_id': '6719592904477241676236487699',
#   'x': 86.0,
#   'y': 2975.3125,
#   'width': 261.390625,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9830.7380371094},
#  {'element_id': '1653290521477241678876021414',
#   'x': 86.0,
#   'y': 3140.96875,
#   'width': 260.140625,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9783.7263183594},
#  {'element_id': '6071285765477241670885881476',
#   'x': 86.0,
#   'y': 2264.734375,
#   'width': 259.9375,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9776.0869140625},
#  {'element_id': '7824174962477241677331405871',
#   'x': 86.0,
#   'y': 1691.03125,
#   'width': 256.6875,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9653.8564453125},
#  {'element_id': '6601666534477241670432033244',
#   'x': 86.0,
#   'y': 2423.171875,
#   'width': 255.953125,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9626.2370605469},
#  {'element_id': '4610194999477241672480438101',
#   'x': 86.0,
#   'y': 2852.875,
#   'width': 255.9375,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9625.6494140625},
#  {'element_id': '9437134610477241675055357184',
#   'x': 86.0,
#   'y': 1604.640625,
#   'width': 255.8125,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9620.9482421875},
#  {'element_id': '9712150338477241676147591688',
#   'x': 86.0,
#   'y': 2996.921875,
#   'width': 253.109375,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9519.2854003906},
#  {'element_id': '6895417630477241671271492083',
#   'x': 86.0,
#   'y': 1218.15625,
#   'width': 249.828125,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9395.8796386719},
#  {'element_id': '9493143300477241678062801072',
#   'x': 86.0,
#   'y': 2742.4375,
#   'width': 246.359375,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9265.4221191406},
#  {'element_id': '7772996908477241671141475013',
#   'x': 86.0,
#   'y': 1527.8125,
#   'width': 244.9375,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9211.9462890625},
#  {'element_id': '0122246727477241669385943592',
#   'x': 560.5625,
#   'y': 47.015625,
#   'width': 190.953125,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 9165.75},
#  {'element_id': '8883549639477241677182777752',
#   'x': 74.0,
#   'y': 478.0,
#   'width': 302.0,
#   'height': 30.015625,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 9064.71875},
#  {'element_id': '6288248672477241663912720453',
#   'x': 74.0,
#   'y': 266.046875,
#   'width': 302.0,
#   'height': 30.015625,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 9064.71875},
#  {'element_id': '4367796804477241670852616213',
#   'x': 86.0,
#   'y': 2797.65625,
#   'width': 240.296875,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 9037.4152832031},
#  {'element_id': '3203143168477241678156561996',
#   'x': 86.0,
#   'y': 1849.46875,
#   'width': 239.265625,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8998.6306152344},
#  {'element_id': '3242405227477241676369780292',
#   'x': 86.0,
#   'y': 2353.5625,
#   'width': 238.90625,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8985.1147460938},
#  {'element_id': '4856066955477241663534175303',
#   'x': 74.0,
#   'y': 313.0625,
#   'width': 245.625,
#   'height': 36.1875,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8888.5546875},
#  {'element_id': '8836833534477241677980165996',
#   'x': 86.0,
#   'y': 1438.984375,
#   'width': 232.296875,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8736.5402832031},
#  {'element_id': '6444485472477241673341682390',
#   'x': 86.0,
#   'y': 3064.140625,
#   'width': 232.078125,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8728.3132324219},
#  {'element_id': '3979025478477241673993810187',
#   'x': 86.0,
#   'y': 646.84375,
#   'width': 227.140625,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8542.6169433594},
#  {'element_id': '7930899163477241676759789640',
#   'x': 86.0,
#   'y': 898.890625,
#   'width': 225.921875,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8496.7805175781},
#  {'element_id': '2131690392477241677009061634',
#   'x': 86.0,
#   'y': 1388.59375,
#   'width': 225.8125,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8492.6669921875},
#  {'element_id': '0535237692477241678471277761',
#   'x': 86.0,
#   'y': 2920.09375,
#   'width': 225.765625,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 8490.9040527344},
#  {'element_id': '6073382500477241675468477749',
#   'x': 86.0,
#   'y': 2403.953125,
#   'width': 207.84375,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7816.8735351562},
#  {'element_id': '8404158783477241673738488092',
#   'x': 50.0,
#   'y': 2963.984375,
#   'width': 175.765625,
#   'height': 44.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7733.6875},
#  {'element_id': '7199753890477241670307070782',
#   'x': 86.0,
#   'y': 2908.09375,
#   'width': 203.515625,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7654.0954589844},
#  {'element_id': '8559900936477241675518920713',
#   'x': 86.0,
#   'y': 2627.21875,
#   'width': 200.640625,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7545.9685058594},
#  {'element_id': '4662571750477241672458756021',
#   'x': 424.0,
#   'y': 1122.515625,
#   'width': 160.3125,
#   'height': 47.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7534.6875},
#  {'element_id': '8959285788477241662908191386',
#   'x': 571.75,
#   'y': 934.515625,
#   'width': 427.828125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7273.078125},
#  {'element_id': '3623648740477241672445834294',
#   'x': 86.0,
#   'y': 2632.0,
#   'width': 189.1875,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 7115.2236328125},
#  {'element_id': '9616160891477241679977420268',
#   'x': 759.734375,
#   'y': 2963.984375,
#   'width': 156.28125,
#   'height': 44.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6876.375},
#  {'element_id': '5085193200477241668711199169',
#   'x': 281.25,
#   'y': 154.046875,
#   'width': 282.875,
#   'height': 24.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6789.0},
#  {'element_id': '9335580438477241666382592255',
#   'x': 332.859375,
#   'y': 47.015625,
#   'width': 131.9375,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 6333.0},
#  {'element_id': '9494648797477241677724078648',
#   'x': 86.0,
#   'y': 2528.78125,
#   'width': 164.34375,
#   'height': 37.609375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6180.8657226562},
#  {'element_id': '2647107004477241673081128310',
#   'x': 424.0,
#   'y': 1852.265625,
#   'width': 361.578125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 6146.828125},
#  {'element_id': '6308403943477241673910297544',
#   'x': 50.0,
#   'y': 2919.984375,
#   'width': 129.453125,
#   'height': 44.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 5695.9375},
#  {'element_id': '4109365168477241679092503346',
#   'x': 464.0,
#   'y': 2368.640625,
#   'width': 320.859375,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 5454.609375},
#  {'element_id': '8272954300477241666051583520',
#   'x': 847.28125,
#   'y': 47.015625,
#   'width': 103.8125,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4983.0},
#  {'element_id': '3230323128477241669228277207',
#   'x': 74.0,
#   'y': 154.046875,
#   'width': 207.25,
#   'height': 24.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4974.0},
#  {'element_id': '7564176837477241678000274005',
#   'x': 424.0,
#   'y': 2035.140625,
#   'width': 276.234375,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4695.984375},
#  {'element_id': '1567717052477241678565846387',
#   'x': 86.0,
#   'y': 2149.515625,
#   'width': 287.6875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4603.0},
#  {'element_id': '4996651953477241673153194433',
#   'x': 86.0,
#   'y': 1390.984375,
#   'width': 285.34375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4565.5},
#  {'element_id': '2474854800477241673469211222',
#   'x': 86.0,
#   'y': 1323.765625,
#   'width': 284.84375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4557.5},
#  {'element_id': '0167703804477241663161013759',
#   'x': 464.0,
#   'y': 646.515625,
#   'width': 262.734375,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4466.484375},
#  {'element_id': '6552277199477241672481947712',
#   'x': 86.0,
#   'y': 1083.71875,
#   'width': 279.140625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4466.25},
#  {'element_id': '8007954891477241675938805615',
#   'x': 86.0,
#   'y': 1443.8125,
#   'width': 273.96875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4383.5},
#  {'element_id': '4335342959477241670469363677',
#   'x': 86.0,
#   'y': 3030.53125,
#   'width': 273.921875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4382.75},
#  {'element_id': '9785335201477241677087463351',
#   'x': 86.0,
#   'y': 2115.90625,
#   'width': 273.59375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4377.5},
#  {'element_id': '0095487933477241660334554487',
#   'x': 1146.640625,
#   'y': 152.046875,
#   'width': 171.796875,
#   'height': 25.34375,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4353.9770507812},
#  {'element_id': '6565665572477241675167389199',
#   'x': 86.0,
#   'y': 2492.78125,
#   'width': 271.109375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4337.75},
#  {'element_id': '2215238537477241675977081476',
#   'x': 86.0,
#   'y': 3052.140625,
#   'width': 269.765625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4316.25},
#  {'element_id': '7246258520477241672479671449',
#   'x': 86.0,
#   'y': 2776.046875,
#   'width': 269.15625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4306.5},
#  {'element_id': '3166828182477241674107038650',
#   'x': 86.0,
#   'y': 1477.421875,
#   'width': 266.125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4258.0},
#  {'element_id': '6447155428477241670176068288',
#   'x': 86.0,
#   'y': 1806.25,
#   'width': 264.71875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4235.5},
#  {'element_id': '0848543785477241676346023636',
#   'x': 86.0,
#   'y': 2653.609375,
#   'width': 264.296875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4228.75},
#  {'element_id': '9445216876477241675133440832',
#   'x': 86.0,
#   'y': 2560.0,
#   'width': 258.796875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4140.75},
#  {'element_id': '1101694894477241674544334303',
#   'x': 86.0,
#   'y': 2617.609375,
#   'width': 257.328125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4117.25},
#  {'element_id': '3725897097477241677326244799',
#   'x': 86.0,
#   'y': 1909.46875,
#   'width': 256.015625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4096.25},
#  {'element_id': '0714199292477241670262138135',
#   'x': 86.0,
#   'y': 930.109375,
#   'width': 255.6875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4091.0},
#  {'element_id': '3082472409477241674623846025',
#   'x': 86.0,
#   'y': 2526.390625,
#   'width': 254.015625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4064.25},
#  {'element_id': '8344098152477241671638112552',
#   'x': 74.0,
#   'y': 1486.984375,
#   'width': 253.203125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4051.25},
#  {'element_id': '9655275778477241676903948363',
#   'x': 86.0,
#   'y': 884.5,
#   'width': 252.453125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 4039.25},
#  {'element_id': '2850746371477241672308570590',
#   'x': 86.0,
#   'y': 2459.171875,
#   'width': 248.25,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3972.0},
#  {'element_id': '0325974035477241675590611782',
#   'x': 86.0,
#   'y': 783.671875,
#   'width': 242.0,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3872.0},
#  {'element_id': '0051450885477241673204540468',
#   'x': 424.0,
#   'y': 1381.390625,
#   'width': 227.125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3861.125},
#  {'element_id': '5661247509477241671528314999',
#   'x': 86.0,
#   'y': 1578.25,
#   'width': 240.296875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3844.75},
#  {'element_id': '0801077419477241676359954723',
#   'x': 86.0,
#   'y': 2271.953125,
#   'width': 238.59375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3817.5},
#  {'element_id': '9138429869477241677378121131',
#   'x': 86.0,
#   'y': 2593.609375,
#   'width': 238.375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3814.0},
#  {'element_id': '8308108944477241671377677185',
#   'x': 86.0,
#   'y': 1511.03125,
#   'width': 235.53125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3768.5},
#  {'element_id': '3345030628477241672412252711',
#   'x': 86.0,
#   'y': 1494.203125,
#   'width': 234.578125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3753.25},
#  {'element_id': '0432976799477241672771848443',
#   'x': 86.0,
#   'y': 702.0625,
#   'width': 231.34375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3701.5},
#  {'element_id': '6828624651477241673724146615',
#   'x': 86.0,
#   'y': 954.109375,
#   'width': 229.765625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3676.25},
#  {'element_id': '8042498919477241679300670992',
#   'x': 86.0,
#   'y': 1458.203125,
#   'width': 229.59375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3673.5},
#  {'element_id': '1221969136477241672910882362',
#   'x': 86.0,
#   'y': 1815.859375,
#   'width': 228.90625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3662.5},
#  {'element_id': '9476254732477241677447964208',
#   'x': 86.0,
#   'y': 2125.515625,
#   'width': 227.265625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3636.25},
#  {'element_id': '7951731165477241677859169018',
#   'x': 424.0,
#   'y': 2534.15625,
#   'width': 173.0,
#   'height': 21.0,
#   'predicted_label': 'dropdown',
#   'predicted_probability': 1.0,
#   'sort_key': 3633.0},
#  {'element_id': '2941051454477241660781798185',
#   'x': 74.0,
#   'y': 390.625,
#   'width': 213.125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3623.125},
#  {'element_id': '1951046105477241679419662811',
#   'x': 50.0,
#   'y': 3007.984375,
#   'width': 82.296875,
#   'height': 44.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3621.0625},
#  {'element_id': '5860872502477241675761074218',
#   'x': 86.0,
#   'y': 2207.125,
#   'width': 226.09375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3617.5},
#  {'element_id': '9706547974477241675835187408',
#   'x': 86.0,
#   'y': 918.109375,
#   'width': 223.28125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3572.5},
#  {'element_id': '8414002134477241674887557690',
#   'x': 86.0,
#   'y': 1405.375,
#   'width': 221.890625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3550.25},
#  {'element_id': '0539453453477241675484890802',
#   'x': 86.0,
#   'y': 2288.734375,
#   'width': 221.8125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3549.0},
#  {'element_id': '5463075714477241673943959787',
#   'x': 86.0,
#   'y': 1294.984375,
#   'width': 220.28125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3524.5},
#  {'element_id': '5907330298477241677177168445',
#   'x': 86.0,
#   'y': 2295.953125,
#   'width': 216.609375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3465.75},
#  {'element_id': '6808826439477241677759387153',
#   'x': 759.734375,
#   'y': 3007.984375,
#   'width': 78.703125,
#   'height': 44.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3462.9375},
#  {'element_id': '4252034002477241674963047217',
#   'x': 86.0,
#   'y': 1410.203125,
#   'width': 215.828125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3453.25},
#  {'element_id': '0791784022477241678516643117',
#   'x': 86.0,
#   'y': 1657.421875,
#   'width': 215.5,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3448.0},
#  {'element_id': '0679798545477241673332952428',
#   'x': 86.0,
#   'y': 1623.8125,
#   'width': 215.421875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3446.75},
#  {'element_id': '9652300548477241672768152945',
#   'x': 86.0,
#   'y': 1571.03125,
#   'width': 214.65625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3434.5},
#  {'element_id': '1838464374477241678055251981',
#   'x': 86.0,
#   'y': 3196.1875,
#   'width': 214.546875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3432.75},
#  {'element_id': '7550312754477241677890996739',
#   'x': 86.0,
#   'y': 1299.765625,
#   'width': 213.34375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3413.5},
#  {'element_id': '4877677784477241679798400976',
#   'x': 86.0,
#   'y': 2552.78125,
#   'width': 212.890625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3406.25},
#  {'element_id': '7465907000477241678719768419',
#   'x': 86.0,
#   'y': 2418.390625,
#   'width': 212.640625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3402.25},
#  {'element_id': '6646417553477241678710131748',
#   'x': 86.0,
#   'y': 1525.421875,
#   'width': 211.546875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3384.75},
#  {'element_id': '9129395178477241674084307373',
#   'x': 74.0,
#   'y': 1830.25,
#   'width': 211.546875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3384.75},
#  {'element_id': '1522216079477241673223317739',
#   'x': 86.0,
#   'y': 2370.34375,
#   'width': 211.09375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3377.5},
#  {'element_id': '1863155271477241679682434358',
#   'x': 86.0,
#   'y': 2173.515625,
#   'width': 209.359375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3349.75},
#  {'element_id': '3252284151477241676381480443',
#   'x': 74.0,
#   'y': 855.671875,
#   'width': 207.78125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3324.5},
#  {'element_id': '1353914787477241673183684672',
#   'x': 609.40625,
#   'y': 2531.15625,
#   'width': 129.703125,
#   'height': 25.609375,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 3321.6159667969},
#  {'element_id': '6302085030477241678467665470',
#   'x': 86.0,
#   'y': 1347.765625,
#   'width': 206.984375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3311.75},
#  {'element_id': '5295981842477241671423052784',
#   'x': 86.0,
#   'y': 2043.90625,
#   'width': 205.921875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3294.75},
#  {'element_id': '8628697846477241678584207943',
#   'x': 86.0,
#   'y': 1967.078125,
#   'width': 205.890625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3294.25},
#  {'element_id': '7764949320477241675476451647',
#   'x': 86.0,
#   'y': 3229.796875,
#   'width': 204.859375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3277.75},
#  {'element_id': '0933549007477241670965945921',
#   'x': 86.0,
#   'y': 1160.546875,
#   'width': 203.953125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3263.25},
#  {'element_id': '2456277725477241675153825920',
#   'x': 86.0,
#   'y': 2231.125,
#   'width': 201.59375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3225.5},
#  {'element_id': '9425133189477241673565637705',
#   'x': 86.0,
#   'y': 870.109375,
#   'width': 201.359375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3221.75},
#  {'element_id': '7652648560477241678638781661',
#   'x': 86.0,
#   'y': 985.328125,
#   'width': 201.015625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3216.25},
#  {'element_id': '4492455098477241675829681218',
#   'x': 86.0,
#   'y': 1018.9375,
#   'width': 200.65625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3210.5},
#  {'element_id': '6020984855477241670705772026',
#   'x': 86.0,
#   'y': 2329.5625,
#   'width': 199.890625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3198.25},
#  {'element_id': '8781763117477241679057668356',
#   'x': 86.0,
#   'y': 2319.953125,
#   'width': 199.640625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3194.25},
#  {'element_id': '8563126940477241670005457505',
#   'x': 935.921875,
#   'y': 1030.515625,
#   'width': 187.875,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3193.875},
#  {'element_id': '3814365693477241661537763807',
#   'x': 972.546875,
#   'y': 982.515625,
#   'width': 187.875,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3193.875},
#  {'element_id': '5210542648477241678320121329',
#   'x': 86.0,
#   'y': 2091.90625,
#   'width': 197.28125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3156.5},
#  {'element_id': '6953316248477241677368489349',
#   'x': 86.0,
#   'y': 2963.3125,
#   'width': 192.671875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3082.75},
#  {'element_id': '3357299751477241674718038764',
#   'x': 50.0,
#   'y': 3051.984375,
#   'width': 69.921875,
#   'height': 44.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3076.5625},
#  {'element_id': '9577583083477241675864712262',
#   'x': 86.0,
#   'y': 2620.0,
#   'width': 191.921875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3070.75},
#  {'element_id': '2513915261477241673542011312',
#   'x': 86.0,
#   'y': 774.0625,
#   'width': 190.296875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3044.75},
#  {'element_id': '0370365800477241675179999103',
#   'x': 86.0,
#   'y': 997.328125,
#   'width': 190.015625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3040.25},
#  {'element_id': '1968545650477241671302519051',
#   'x': 86.0,
#   'y': 1511.03125,
#   'width': 188.96875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3023.5},
#  {'element_id': '3010560217477241676841058127',
#   'x': 86.0,
#   'y': 2010.296875,
#   'width': 187.8125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3005.0},
#  {'element_id': '6562845839477241675411688423',
#   'x': 86.0,
#   'y': 992.5,
#   'width': 187.65625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3002.5},
#  {'element_id': '6631588339477241670702288860',
#   'x': 86.0,
#   'y': 1563.8125,
#   'width': 186.8125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2989.0},
#  {'element_id': '8516903317477241673382889313',
#   'x': 74.0,
#   'y': 534.015625,
#   'width': 183.34375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2933.5},
#  {'element_id': '1521660602477241677325411706',
#   'x': 86.0,
#   'y': 2058.296875,
#   'width': 182.828125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2925.25},
#  {'element_id': '0604555998477241675985847476',
#   'x': 86.0,
#   'y': 2355.953125,
#   'width': 179.75,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2876.0},
#  {'element_id': '6471542590477241676426886285',
#   'x': 86.0,
#   'y': 1693.46875,
#   'width': 179.734375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2875.75},
#  {'element_id': '5229066735477241676364811827',
#   'x': 86.0,
#   'y': 1503.8125,
#   'width': 179.390625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2870.25},
#  {'element_id': '5975405604477241673788555330',
#   'x': 86.0,
#   'y': 1633.421875,
#   'width': 178.875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2862.0},
#  {'element_id': '7051794284477241674234709232',
#   'x': 86.0,
#   'y': 2651.21875,
#   'width': 178.375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2854.0},
#  {'element_id': '9923244390477241679291233798',
#   'x': 86.0,
#   'y': 1976.6875,
#   'width': 178.171875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2850.75},
#  {'element_id': '1773908707477241675229856344',
#   'x': 86.0,
#   'y': 2442.390625,
#   'width': 178.046875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2848.75},
#  {'element_id': '2545524402477241672384961669',
#   'x': 86.0,
#   'y': 2255.125,
#   'width': 175.65625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2810.5},
#  {'element_id': '1741593847477241679343038328',
#   'x': 86.0,
#   'y': 963.71875,
#   'width': 174.53125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2792.5},
#  {'element_id': '7072471794477241675363781747',
#   'x': 86.0,
#   'y': 1943.078125,
#   'width': 174.046875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2784.75},
#  {'element_id': '0365563552477241672358904203',
#   'x': 86.0,
#   'y': 2476.0,
#   'width': 173.390625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2774.25},
#  {'element_id': '7462068973477241677454079674',
#   'x': 86.0,
#   'y': 1477.421875,
#   'width': 171.78125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2748.5},
#  {'element_id': '7317875891477241677973561706',
#   'x': 86.0,
#   'y': 2869.65625,
#   'width': 171.734375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2747.75},
#  {'element_id': '4743700049477241673889750787',
#   'x': 74.0,
#   'y': 637.234375,
#   'width': 171.234375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2739.75},
#  {'element_id': '4990440696477241679707711546',
#   'x': 86.0,
#   'y': 1232.546875,
#   'width': 171.046875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2736.75},
#  {'element_id': '0514526829477241670189823042',
#   'x': 86.0,
#   'y': 1102.9375,
#   'width': 171.03125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2736.5},
#  {'element_id': '2061182539477241672688435755',
#   'x': 86.0,
#   'y': 2082.296875,
#   'width': 169.328125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2709.25},
#  {'element_id': '6454442069477241678707441757',
#   'x': 86.0,
#   'y': 2408.78125,
#   'width': 168.25,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2692.0},
#  {'element_id': '9840690715477241671583997546',
#   'x': 86.0,
#   'y': 2687.21875,
#   'width': 167.78125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2684.5},
#  {'element_id': '7324125693477241678793003145',
#   'x': 86.0,
#   'y': 1117.328125,
#   'width': 167.046875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2672.75},
#  {'element_id': '4766957920477241675403422740',
#   'x': 86.0,
#   'y': 2197.515625,
#   'width': 166.890625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2670.25},
#  {'element_id': '1173087124477241679443047108',
#   'x': 732.96875,
#   'y': 2400.640625,
#   'width': 156.46875,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2659.96875},
#  {'element_id': '7289331236477241674005014221',
#   'x': 86.0,
#   'y': 1141.328125,
#   'width': 166.140625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2658.25},
#  {'element_id': '5068293347477241670462111931',
#   'x': 86.0,
#   'y': 1537.421875,
#   'width': 164.8125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2637.0},
#  {'element_id': '3832351553477241677317034474',
#   'x': 86.0,
#   'y': 2024.6875,
#   'width': 164.53125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2632.5},
#  {'element_id': '3504797953477241679740062295',
#   'x': 86.0,
#   'y': 1868.6875,
#   'width': 164.484375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2631.75},
#  {'element_id': '1002946345477241673698327782',
#   'x': 86.0,
#   'y': 1126.9375,
#   'width': 163.890625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2622.25},
#  {'element_id': '5745677122477241678696184189',
#   'x': 86.0,
#   'y': 1667.03125,
#   'width': 163.71875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2619.5},
#  {'element_id': '3208373218477241673260536268',
#   'x': 86.0,
#   'y': 1150.9375,
#   'width': 162.34375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2597.5},
#  {'element_id': '0254521884477241675139359037',
#   'x': 86.0,
#   'y': 2000.6875,
#   'width': 162.234375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2595.75},
#  {'element_id': '5804409859477241673443690625',
#   'x': 86.0,
#   'y': 613.234375,
#   'width': 160.96875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2575.5},
#  {'element_id': '6005348829477241677393908717',
#   'x': 86.0,
#   'y': 1424.59375,
#   'width': 159.703125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2555.25},
#  {'element_id': '4653022273477241671856695092',
#   'x': 86.0,
#   'y': 1026.109375,
#   'width': 158.296875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2532.75},
#  {'element_id': '3257603865477241673344854859',
#   'x': 86.0,
#   'y': 1050.109375,
#   'width': 157.265625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2516.25},
#  {'element_id': '8192200977477241670693420450',
#   'x': 86.0,
#   'y': 1002.109375,
#   'width': 156.609375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2505.75},
#  {'element_id': '6983373900477241670634907000',
#   'x': 86.0,
#   'y': 750.0625,
#   'width': 156.59375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2505.5},
#  {'element_id': '7142725023477241677420196570',
#   'x': 86.0,
#   'y': 1530.203125,
#   'width': 155.125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2482.0},
#  {'element_id': '3465101588477241672267559462',
#   'x': 86.0,
#   'y': 2312.734375,
#   'width': 155.046875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2480.75},
#  {'element_id': '9297389298477241678030744214',
#   'x': 86.0,
#   'y': 934.890625,
#   'width': 154.984375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2479.75},
#  {'element_id': '2482425799477241674300060614',
#   'x': 86.0,
#   'y': 1496.59375,
#   'width': 154.234375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2467.75},
#  {'element_id': '6225115651477241672595085779',
#   'x': 650.78125,
#   'y': 2448.640625,
#   'width': 144.984375,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2464.734375},
#  {'element_id': '9493308684477241670517612756',
#   'x': 590.46875,
#   'y': 1078.515625,
#   'width': 144.046875,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2448.796875},
#  {'element_id': '0279408886477241667903369483',
#   'x': 488.640625,
#   'y': 574.515625,
#   'width': 144.0,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2448.0},
#  {'element_id': '5547967178477241678572693616',
#   'x': 86.0,
#   'y': 850.890625,
#   'width': 152.796875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2444.75},
#  {'element_id': '1679363416477241679042072208',
#   'x': 86.0,
#   'y': 2139.90625,
#   'width': 152.09375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2433.5},
#  {'element_id': '0138477413477241674783677284',
#   'x': 86.0,
#   'y': 1443.8125,
#   'width': 151.96875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2431.5},
#  {'element_id': '8969627668477241672248811391',
#   'x': 86.0,
#   'y': 841.28125,
#   'width': 151.625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2426.0},
#  {'element_id': '2137640597477241676482465719',
#   'x': 86.0,
#   'y': 2389.5625,
#   'width': 150.15625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2402.5},
#  {'element_id': '4351395216477241678360227696',
#   'x': 424.0,
#   'y': 1261.390625,
#   'width': 140.03125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2380.53125},
#  {'element_id': '8109771500477241676731028293',
#   'x': 86.0,
#   'y': 1700.640625,
#   'width': 148.734375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2379.75},
#  {'element_id': '9412922350477241671894571034',
#   'x': 86.0,
#   'y': 2322.34375,
#   'width': 147.890625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2366.25},
#  {'element_id': '4013214679477241676811885895',
#   'x': 86.0,
#   'y': 1342.984375,
#   'width': 147.09375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2353.5},
#  {'element_id': '2732453371477241676909316539',
#   'x': 86.0,
#   'y': 2903.265625,
#   'width': 146.1875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2339.0},
#  {'element_id': '3498027038477241672840930076',
#   'x': 86.0,
#   'y': 807.671875,
#   'width': 144.5625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2313.0},
#  {'element_id': '7494517933477241678862220187',
#   'x': 86.0,
#   'y': 1035.71875,
#   'width': 143.921875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2302.75},
#  {'element_id': '8743974450477241673700948734',
#   'x': 86.0,
#   'y': 1266.15625,
#   'width': 143.265625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2292.25},
#  {'element_id': '1545180018477241674358209393',
#   'x': 74.0,
#   'y': 2656.0,
#   'width': 142.078125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2273.25},
#  {'element_id': '4082401548477241677883480976',
#   'x': 86.0,
#   'y': 1938.296875,
#   'width': 141.53125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2264.5},
#  {'element_id': '7190968482477241670125673712',
#   'x': 86.0,
#   'y': 831.671875,
#   'width': 141.03125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2256.5},
#  {'element_id': '9044967206477241672566301990',
#   'x': 86.0,
#   'y': 1801.46875,
#   'width': 140.734375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2251.75},
#  {'element_id': '8487243047477241677109585267',
#   'x': 86.0,
#   'y': 1748.640625,
#   'width': 138.265625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2212.25},
#  {'element_id': '2796059673477241678982872102',
#   'x': 464.0,
#   'y': 2336.640625,
#   'width': 130.015625,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2210.265625},
#  {'element_id': '6998624307477241671999102949',
#   'x': 86.0,
# ...
#   'y': 903.71875,
#   'width': 116.21875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1859.5},
#  {'element_id': '3474783237477241677409526950',
#   'x': 86.0,
#   'y': 2836.046875,
#   'width': 116.21875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1859.5},
#  {'element_id': '3946317733477241677617723681',
#   'x': 86.0,
#   'y': 2077.515625,
#   'width': 116.125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1858.0},
#  {'element_id': '0113598793477241671208265218',
#   'x': 759.734375,
#   'y': 2919.984375,
#   'width': 41.59375,
#   'height': 44.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1830.125},
#  {'element_id': '3889260400477241661242099925',
#   'x': 1318.4375,
#   'y': 155.046875,
#   'width': 107.5625,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1828.5625},
#  {'element_id': '9260164341477241672672563065',
#   'x': 86.0,
#   'y': 1357.375,
#   'width': 114.0625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1825.0},
#  {'element_id': '2675088315477241672572608326',
#   'x': 464.0,
#   'y': 2304.640625,
#   'width': 106.96875,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1818.46875},
#  {'element_id': '6346136588477241675184456562',
#   'x': 424.0,
#   'y': 1645.390625,
#   'width': 106.640625,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1812.890625},
#  {'element_id': '1868098580477241672287381899',
#   'x': 86.0,
#   'y': 1767.859375,
#   'width': 112.890625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1806.25},
#  {'element_id': '0313121672477241673872497038',
#   'x': 86.0,
#   'y': 2768.828125,
#   'width': 111.78125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1788.5},
#  {'element_id': '2110549418477241679234305811',
#   'x': 86.0,
#   'y': 2238.34375,
#   'width': 110.546875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1768.75},
#  {'element_id': '3530082572477241676116798110',
#   'x': 86.0,
#   'y': 1631.03125,
#   'width': 110.546875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1768.75},
#  {'element_id': '5233787133477241678211513721',
#   'x': 86.0,
#   'y': 1904.6875,
#   'width': 108.4375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1735.0},
#  {'element_id': '5872037063477241673838639816',
#   'x': 113.34375,
#   'y': 3306.984375,
#   'width': 72.15625,
#   'height': 24.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1731.75},
#  {'element_id': '6782575866477241671851407575',
#   'x': 86.0,
#   'y': 2480.78125,
#   'width': 108.140625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1730.25},
#  {'element_id': '6636227988477241672020158112',
#   'x': 582.3125,
#   'y': 3255.984375,
#   'width': 100.78125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1713.28125},
#  {'element_id': '8190363993477241675184605489',
#   'x': 86.0,
#   'y': 1227.765625,
#   'width': 104.703125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1675.25},
#  {'element_id': '1898754792477241671580805427',
#   'x': 86.0,
#   'y': 2247.953125,
#   'width': 104.1875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1667.0},
#  {'element_id': '3439366825477241674246100250',
#   'x': 86.0,
#   'y': 1069.328125,
#   'width': 103.453125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1655.25},
#  {'element_id': '1714322735477241676871616923',
#   'x': 86.0,
#   'y': 2413.5625,
#   'width': 103.328125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1653.25},
#  {'element_id': '2411491625477241676320287018',
#   'x': 86.0,
#   'y': 1362.203125,
#   'width': 102.703125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1643.25},
#  {'element_id': '0140403409477241679515841070',
#   'x': 86.0,
#   'y': 1597.421875,
#   'width': 101.734375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1627.75},
#  {'element_id': '5107428707477241671851974867',
#   'x': 86.0,
#   'y': 817.28125,
#   'width': 100.890625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1614.25},
#  {'element_id': '1588544612477241670222851673',
#   'x': 759.734375,
#   'y': 3121.984375,
#   'width': 66.546875,
#   'height': 24.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 1597.125},
#  {'element_id': '9055561858477241674472347758',
#   'x': 86.0,
#   'y': 951.71875,
#   'width': 99.59375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1593.5},
#  {'element_id': '8097937643477241673305810431',
#   'x': 86.0,
#   'y': 2584.0,
#   'width': 98.34375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1573.5},
#  {'element_id': '3289301055477241679206121269',
#   'x': 86.0,
#   'y': 769.28125,
#   'width': 95.078125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1521.25},
#  {'element_id': '1640318134477241677840903865',
#   'x': 50.0,
#   'y': 3306.984375,
#   'width': 63.34375,
#   'height': 24.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1520.25},
#  {'element_id': '2203888938477241676524028544',
#   'x': 86.0,
#   'y': 1093.328125,
#   'width': 94.6875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1515.0},
#  {'element_id': '4336447101477241676778217808',
#   'x': 86.0,
#   'y': 2452.0,
#   'width': 91.75,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1468.0},
#  {'element_id': '8621777984477241669865050316',
#   'x': 464.0,
#   'y': 750.515625,
#   'width': 85.53125,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1454.03125},
#  {'element_id': '7623131944477241673265112249',
#   'x': 86.0,
#   'y': 1059.71875,
#   'width': 90.65625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1450.5},
#  {'element_id': '2697382515477241675823844809',
#   'x': 86.0,
#   'y': 968.5,
#   'width': 89.109375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1425.75},
#  {'element_id': '7299167706477241677949910831',
#   'x': 86.0,
#   'y': 2495.171875,
#   'width': 88.75,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1420.0},
#  {'element_id': '6433865145477241676589358363',
#   'x': 86.0,
#   'y': 1599.8125,
#   'width': 88.4375,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1415.0},
#  {'element_id': '4546615108477241676733739658',
#   'x': 86.0,
#   'y': 2379.953125,
#   'width': 87.53125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1400.5},
#  {'element_id': '9518773586477241673982019734',
#   'x': 86.0,
#   'y': 1184.546875,
#   'width': 86.140625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1378.25},
#  {'element_id': '9226962985477241670189188304',
#   'x': 86.0,
#   'y': 802.890625,
#   'width': 85.53125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1368.5},
#  {'element_id': '2943781557477241675229896560',
#   'x': 86.0,
#   'y': 1328.59375,
#   'width': 85.03125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1360.5},
#  {'element_id': '9490835822477241677731217832',
#   'x': 928.828125,
#   'y': 1549.390625,
#   'width': 78.75,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1338.75},
#  {'element_id': '3511510626477241674198303552',
#   'x': 86.0,
#   'y': 1174.9375,
#   'width': 80.328125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1285.25},
#  {'element_id': '9857264060477241672347687357',
#   'x': 86.0,
#   'y': 2586.390625,
#   'width': 78.53125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1256.5},
#  {'element_id': '1383505910477241675602514473',
#   'x': 86.0,
#   'y': 2346.34375,
#   'width': 73.671875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1178.75},
#  {'element_id': '6173643290477241677419754160',
#   'x': 50.0,
#   'y': 3121.984375,
#   'width': 47.953125,
#   'height': 24.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 1150.875},
#  {'element_id': '9635769001477241672519870463',
#   'x': 86.0,
#   'y': 1107.71875,
#   'width': 71.71875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1147.5},
#  {'element_id': '6817235594477241665787491332',
#   'x': 74.0,
#   'y': 361.4375,
#   'width': 57.046875,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 969.796875},
#  {'element_id': '2153552704477241672439713702',
#   'x': 86.0,
#   'y': 1544.640625,
#   'width': 60.3125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 965.0},
#  {'element_id': '6748018182477241670404292083',
#   'x': 86.0,
#   'y': 1208.546875,
#   'width': 50.125,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 802.0},
#  {'element_id': '8353405714477241678072858028',
#   'x': 113.953125,
#   'y': 3111.984375,
#   'width': 18.0,
#   'height': 44.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 792.0},
#  {'element_id': '4021136384477241671085596382',
#   'x': 870.28125,
#   'y': 3111.984375,
#   'width': 18.0,
#   'height': 44.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 792.0},
#  {'element_id': '6970508517477241671124668277',
#   'x': 842.28125,
#   'y': 3111.984375,
#   'width': 18.0,
#   'height': 44.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 792.0},
#  {'element_id': '8252123249477241670433976627',
#   'x': 141.953125,
#   'y': 3111.984375,
#   'width': 18.0,
#   'height': 44.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 792.0},
#  {'element_id': '5794724005477241668789039584',
#   'x': 783.328125,
#   'y': 343.640625,
#   'width': 42.796875,
#   'height': 17.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 727.546875},
#  {'element_id': '0376255995477241679272509829',
#   'x': 86.0,
#   'y': 1242.15625,
#   'width': 38.65625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 618.5},
#  {'element_id': '0755290227477241662677103785',
#   'x': 1322.0,
#   'y': 61.015625,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '6146422432477241679028309331',
#   'x': 86.0,
#   'y': 1275.765625,
#   'width': 31.796875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 508.75},
#  {'element_id': '0800742274477241669251885164',
#   'x': 997.984375,
#   'y': 50.015625,
#   'width': 1.0,
#   'height': 1.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1.0},
#  {'element_id': '5913723108477241678044623597',
#   'x': 423.0,
#   'y': 2530.15625,
#   'width': 1.0,
#   'height': 1.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1.0},
#  {'element_id': '5968437300477241662962542050',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7387667065477241664503258908',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2829854101477241660695591461',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7531997073477241666678711200',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2848303579477241662645500092',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4529275513477241663066584355',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4545130481477241664644668696',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '5431780069477241663709841959',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7320283330477241666550638864',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '9276124921477241663665562671',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '4071807657477241669356988258',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '2545561904477241664385483222',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '0802223552477241665018770931',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6110650395477241661609389390',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '8420621649477241663328324640',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6856839832477241669807400300',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3990148972477241664754081190',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3912315750477241663589564517',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7594702546477241665579982495',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '6600000735477241663695241416',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '3802436168477241662769127206',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0},
#  {'element_id': '7555773486477241660479190675',
#   'x': 0.0,
#   'y': 0.0,
#   'width': 0.0,
#   'height': 0.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 0.0}]
# CPU times: user 134 ms, sys: 20.4 ms, total: 154 ms
# Wall time: 3.25 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id      x            y        width  height  \
# 0  1798532075477241664359838651  424.0   859.515625   756.359375   144.0
# 1  9635461908477241666965693631  424.0   340.640625   756.359375   120.0
# 2  7657942450477241679104800052   50.0  3221.984375  1400.000000    55.0
# 3  7508525286477241678097273505  424.0  1849.265625   756.359375    96.0
# 4  1790720218477241661490396475    0.0  -320.000000  1500.000000    48.0
#
#   predicted_label  predicted_probability    sort_key tag_name
# 0            text                    1.0  108915.750        P
# 1            text                    1.0   90763.125        P
# 2            text                    1.0   77000.000        P
# 3            text                    1.0   72610.500        P
# 4            link                    1.0   72000.000        A

# %%
predictions_df.predicted_label.unique()
# Out:
# array(['text', 'link', 'title', 'datetimeselector', 'button', 'dropdown',
#        'label'], dtype=object)

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                str(r.predicted_label) + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
