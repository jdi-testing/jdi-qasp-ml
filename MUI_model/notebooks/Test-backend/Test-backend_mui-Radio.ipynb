# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
WORKING_DIR = re.sub('jdi-qasp-ml.*$','',os.path.normpath(os.getcwd())) + 'jdi-qasp-ml'
os.chdir(WORKING_DIR)

# %%
WORKING_DIR
# Out:
# 'C:\\WORK\\jdi-qasp-ml'

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-09-20 13:15:37,965 -INFO - config.py:25 - Module utils.config was loaded
# 2021-09-20 13:15:37,967 -INFO - common.py:618 - Module utils.common is loaded...
# 2021-09-20 13:15:37,971 -INFO - hidden.py:121 - hidden module is loaded
# 2021-09-20 13:15:37,973 -INFO - features_builder.py:305 - feature_bilder module is loaded...
# 2021-09-20 13:15:37,978 -INFO - dataset_builder.py:213 - dataset package is loaded...
# 2021-09-20 13:15:37,982 -INFO - dataset.py:277 - dataset module is loaded...

# %%
UTILS_LOGGER = 'utils.dataset'
LOG_FILE_PATH = 'tmp/log.txt'

os.makedirs(name='tmp', exist_ok=True)

logger = logging.getLogger(UTILS_LOGGER)
logger.setLevel(logging.DEBUG)


formatter = logging.Formatter('%(asctime)s -%(levelname)s - %(module)s:%(filename)s:%(lineno)d - %(message)s')

console_handler = logging.StreamHandler(sys.stdout)
console_handler.setFormatter(formatter)

file_handler = logging.FileHandler(filename=LOG_FILE_PATH, mode='w')
file_handler.setFormatter(formatter)

logger.addHandler(console_handler)
logger.addHandler(file_handler)

logger.info('Module utils.config was loaded')
# Out:
# 2021-09-20 13:15:39,626 -INFO - 632196539.py:21 - Module utils.config was loaded
# 2021-09-20 13:15:39,626 -INFO - 632196539:632196539.py:21 - Module utils.config was loaded

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# 'C:\\WORK\\jdi-qasp-ml'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'material-ui-Radio'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5000/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
# DATASET_NAME = 'mui-site122'

# %%
# SITE_URL = 'C:/WORK/jdi-qasp-ml/MUI_model/dataset/build/site122/index.html'

# %%
# PREDICT_URL = 'http://localhost:5000/mui-predict'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click() #path to elements packs
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click() #path to mui
        driver.find_element_by_xpath("//*[@id='__next']/div/div/div[1]/div/div[7]/div").click() #path to elements
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path='./MUI_model/dataset/') as builder:
    plt.imshow(plt.imread(f'MUI_model/dataset/images/{DATASET_NAME}.png'))
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2021-09-20 13:15:59,065 -INFO - dataset_builder.py:78 - Dataset name: material-ui-Radio
# 2021-09-20 13:15:59,065 -INFO - dataset_builder:dataset_builder.py:78 - Dataset name: material-ui-Radio
# 2021-09-20 13:15:59,068 -INFO - dataset_builder.py:88 - Create directories to save the dataset
# 2021-09-20 13:15:59,068 -INFO - dataset_builder:dataset_builder.py:88 - Create directories to save the dataset
# 2021-09-20 13:15:59,071 -INFO - dataset_builder.py:126 - Creating driver
# 2021-09-20 13:15:59,071 -INFO - dataset_builder:dataset_builder.py:126 - Creating driver
# 2021-09-20 13:16:00,466 -INFO - dataset_builder.py:137 - Chrome web driver is created
# 2021-09-20 13:16:00,466 -INFO - dataset_builder:dataset_builder.py:137 - Chrome web driver is created
# 2021-09-20 13:16:00,582 -INFO - 3999822795.py:10 - getting url: https://jdi-testing.github.io/jdi-light/
# 2021-09-20 13:16:00,582 -INFO - 3999822795:3999822795.py:10 - getting url: https://jdi-testing.github.io/jdi-light/
# 2021-09-20 13:16:16,981 -INFO - common.py:75 - Window maximized
# 2021-09-20 13:16:16,981 -INFO - common:common.py:75 - Window maximized
# 2021-09-20 13:16:23,999 -INFO - dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/material-ui-Radio.png
# 2021-09-20 13:16:23,999 -INFO - dataset_builder:dataset_builder.py:140 - save scrinshot: ./MUI_model/dataset/images/material-ui-Radio.png
# 2021-09-20 13:16:25,369 -INFO - dataset_builder.py:184 - Collect features using JS script
# 2021-09-20 13:16:25,369 -INFO - dataset_builder:dataset_builder.py:184 - Collect features using JS script
# 2021-09-20 13:16:26,088 -INFO - dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/material-ui-Radio.html
# 2021-09-20 13:16:26,088 -INFO - dataset_builder:dataset_builder.py:192 - Save html to ./MUI_model/dataset/html/material-ui-Radio.html
# 2021-09-20 13:16:26,109 -INFO - dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/material-ui-Radio.pkl
# 2021-09-20 13:16:26,109 -INFO - dataset_builder:dataset_builder.py:202 - Save parquet to ./MUI_model/dataset/df/material-ui-Radio.pkl
# 2021-09-20 13:16:26,117 -INFO - dataset_builder.py:204 - No attributes: (11, 13)
# 2021-09-20 13:16:26,117 -INFO - dataset_builder:dataset_builder.py:204 - No attributes: (11, 13)
# 2021-09-20 13:16:26,935 -INFO - dataset_builder.py:103 - Close web driver
# 2021-09-20 13:16:26,935 -INFO - dataset_builder:dataset_builder.py:103 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '4098346367329853795623298601',
#   'x': 274.0,
#   'y': 293.015625,
#   'width': 316.0625,
#   'height': 66.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 20860.125},
#  {'element_id': '2567192260329853791952583688',
#   'x': 274.0,
#   'y': 138.171875,
#   'width': 374.796875,
#   'height': 42.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 15741.46875},
#  {'element_id': '7494694392329853794975809388',
#   'x': 298.0,
#   'y': 577.859375,
#   'width': 171.796875,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999856949,
#   'sort_key': 6184.6875},
#  {'element_id': '0054091095329853793836898340',
#   'x': 342.375,
#   'y': 138.171875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.5028845668,
#   'sort_key': 1764.0},
#  {'element_id': '1028654776329853792271283444',
#   'x': 263.0,
#   'y': 138.171875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.5028845668,
#   'sort_key': 1764.0},
#  {'element_id': '1472198819329853795224594810',
#   'x': 443.609375,
#   'y': 138.171875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.5028845668,
#   'sort_key': 1764.0},
#  {'element_id': '1739502665329853793435918693',
#   'x': 287.0,
#   'y': 505.859375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.909945786,
#   'sort_key': 1764.0},
#  {'element_id': '1998407010329853799871692058',
#   'x': 527.90625,
#   'y': 138.171875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999938011,
#   'sort_key': 1764.0},
#  {'element_id': '3982082333329853791480671819',
#   'x': 451.9375,
#   'y': 293.015625,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.5028845668,
#   'sort_key': 1764.0},
#  {'element_id': '6454885371329853793371043271',
#   'x': 504.65625,
#   'y': 305.015625,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.5028845668,
#   'sort_key': 1764.0},
#  {'element_id': '8427065570329853793970389416',
#   'x': 399.21875,
#   'y': 305.015625,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.5028845668,
#   'sort_key': 1764.0},
#  {'element_id': '9008067468329853798614248737',
#   'x': 287.0,
#   'y': 463.859375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.909945786,
#   'sort_key': 1764.0}]
# Wall time: 4.06 s

# %%
from utils import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'MUI_model/dataset/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')

# %%
# set(df.element_id.values).intersection(set(preds.element_id.values))

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'MUI_model/dataset/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    patch = Rectangle((r.x, r.y), r.width, r.height, alpha=.2, color='red')
    axes.add_patch(patch)
    
    axes.text(r.x, r.y, 
              r.predicted_label + ':' +str(round(r.predicted_probability, 3)) + ':' + r.tag_name, 
              backgroundcolor='black', 
              color='white',
              bbox=dict(alpha=0.5))
