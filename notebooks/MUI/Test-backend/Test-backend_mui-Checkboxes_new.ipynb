# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-11-25 08:50:55,172 -INFO - config.py:31 - Module utils.config was loaded
# 2021-11-25 08:50:55,205 -INFO - common.py:127 - Module utils.common is loaded...
# 2021-11-25 08:50:55,207 -INFO - dataset_builder.py:244 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'material-ui-Checkbox'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click() #path to elements packs
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click() #path to mui
        driver.find_element_by_xpath("//*[@id='__next']/div/div/div[1]/div/div[4]/div").click() #path to checkboxes
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-11-25 08:51:00,509 -INFO - dataset_builder.py:100 - Dataset name: material-ui-Checkbox
# 2021-11-25 08:51:00,511 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-11-25 08:51:00,515 -INFO - dataset_builder.py:150 - Creating driver
# 2021-11-25 08:51:01,089 -INFO - dataset_builder.py:162 - Chrome web driver is created
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   # This is added back by InteractiveShellApp.init_path()
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if sys.path[0] == '':
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   del sys.path[0]
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   app.launch_new_instance()
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2021-11-25 08:51:13,863 -INFO - common.py:30 - Window maximized
# 2021-11-25 08:51:20,865 -INFO - dataset_builder.py:165 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/material-ui-Checkbox.png
# 2021-11-25 08:51:26,198 -INFO - dataset_builder.py:209 - Collect features using JS script
# 2021-11-25 08:51:26,861 -INFO - dataset_builder.py:217 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/material-ui-Checkbox.html
# 2021-11-25 08:51:26,875 -INFO - dataset_builder.py:229 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/material-ui-Checkbox.pkl
# 2021-11-25 08:51:26,877 -INFO - dataset_builder.py:232 - No attributes: (12, 13)
# 2021-11-25 08:51:30,868 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '7808437049194862047916228144',
#   'x': 274.0,
#   'y': 138.21875,
#   'width': 1202.0,
#   'height': 42.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 0.9999995232,
#   'sort_key': 50484.0},
#  {'element_id': '8685473696194862048429264848',
#   'x': 274.0,
#   'y': 245.078125,
#   'width': 1202.0,
#   'height': 42.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 50484.0},
#  {'element_id': '8710996903194862045818648851',
#   'x': 274.0,
#   'y': 645.703125,
#   'width': 316.0625,
#   'height': 66.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 20860.125},
#  {'element_id': '8533188164194862048904721341',
#   'x': 298.0,
#   'y': 391.9375,
#   'width': 151.671875,
#   'height': 126.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 0.999992609,
#   'sort_key': 19110.65625},
#  {'element_id': '2149273305194862044649550521',
#   'x': 497.671875,
#   'y': 391.9375,
#   'width': 151.671875,
#   'height': 126.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 0.9999930859,
#   'sort_key': 19110.65625},
#  {'element_id': '8106819337194862030718348669',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7815725662194862034286282696',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7726958057194862044356508879',
#   'x': 0.0,
#   'y': 1632.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999934435,
#   'sort_key': 12000.0},
#  {'element_id': '7542135552194862045747448044',
#   'x': 0.0,
#   'y': 1536.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7511975059194862043477129860',
#   'x': 0.0,
#   'y': 1824.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7467120529194862049638196770',
#   'x': 0.0,
#   'y': 2640.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7376411061194862036718840123',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0219862768194862030418700901',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7256982965194862042800600296',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6871423928194862033749321220',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6810448954194862037471058667',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6697856824194862037093595089',
#   'x': 0.0,
#   'y': 144.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '
,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999966621,
#   'sort_key': 1764.0},
#  {'element_id': '9515690061194862047617228216',
#   'x': 386.5,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '5382017524194862046912238540',
#   'x': 274.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '9126372039194862042111839925',
#   'x': 486.671875,
#   'y': 475.9375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '8988462435194862044009441108',
#   'x': 400.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '6056605976194862046993027426',
#   'x': 504.65625,
#   'y': 657.703125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999966621,
#   'sort_key': 1764.0},
#  {'element_id': '6441468765194862045178745320',
#   'x': 442.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '4587362762194862040050529636',
#   'x': 287.0,
#   'y': 475.9375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '4277524461194862043810506399',
#   'x': 848.796875,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '6797839115194862046700774536',
#   'x': 526.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '7442409111194862041168329991',
#   'x': 1141.078125,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '2041990149194862046595636992',
#   'x': 629.015625,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '2168254444194862044396190276',
#   'x': 486.671875,
#   'y': 433.9375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '4181977295194862041122992353',
#   'x': 738.90625,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '6834257670194862046435501994',
#   'x': 287.0,
#   'y': 391.9375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '3986841581194862048243373181',
#   'x': 287.0,
#   'y': 433.9375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '2437169400194862047377915517',
#   'x': 486.671875,
#   'y': 391.9375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '2595454260194862044953366895',
#   'x': 451.9375,
#   'y': 645.703125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999966621,
#   'sort_key': 1764.0},
#  {'element_id': '2622403542194862047655833211',
#   'x': 489.796875,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '7247702191194862044304360703',
#   'x': 263.0,
#   'y': 245.078125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '2890698966194862048117450496',
#   'x': 399.21875,
#   'y': 657.703125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999966621,
#   'sort_key': 1764.0},
#  {'element_id': '3601715251194862042417248662',
#   'x': 358.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '2967092688194862040115545523',
#   'x': 484.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '5121629977194862049330454293',
#   'x': 316.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1764.0},
#  {'element_id': '1495090302194862045203080420',
#   'x': 568.0,
#   'y': 140.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '6883812005194862047536576287',
#   'x': 1279.609375,
#   'y': 247.078125,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0}]
# CPU times: user 71.1 ms, sys: 23.9 ms, total: 95 ms
# Wall time: 4.31 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id           x           y        width  height  \
# 0  7808437049194862047916228144  274.000000  138.218750  1202.000000    42.0
# 1  8685473696194862048429264848  274.000000  245.078125  1202.000000    42.0
# 2  8710996903194862045818648851  274.000000  645.703125   316.062500    66.0
# 3  8533188164194862048904721341  298.000000  391.937500   151.671875   126.0
# 4  2149273305194862044649550521  497.671875  391.937500   151.671875   126.0
#
#   predicted_label  predicted_probability     sort_key tag_name
# 0      radiogroup               1.000000  50484.00000      DIV
# 1      radiogroup               1.000000  50484.00000      DIV
# 2      radiogroup               1.000000  20860.12500      DIV
# 3      radiogroup               0.999993  19110.65625      DIV
# 4      radiogroup               0.999993  19110.65625      DIV

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
