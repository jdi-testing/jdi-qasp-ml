# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'HTML5_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/html5_dataset')

# %%
DATASET_NAME = 'validator'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://validator.w3.org/nu/'
PREDICT_URL = 'http://localhost:5050/html5-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 2
# HEADLESS = True

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2022-01-25 15:41:51,904 -INFO - config.py:31 - Module utils.config was loaded
# 2022-01-25 15:41:51,929 -INFO - common.py:119 - Module utils.common is loaded...
# 2022-01-25 15:41:51,931 -INFO - dataset_builder.py:246 - dataset package is loaded...

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
# Out:
# 2022-01-25 15:41:52,445 -INFO - dataset_builder.py:100 - Dataset name: validator
# 2022-01-25 15:41:52,447 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2022-01-25 15:41:52,450 -INFO - dataset_builder.py:152 - Creating driver
# 2022-01-25 15:41:53,483 -INFO - dataset_builder.py:164 - Chrome web driver is created
# 2022-01-25 15:41:55,163 -INFO - common.py:22 - Window maximized
# 2022-01-25 15:42:02,166 -INFO - dataset_builder.py:167 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/images/validator.png
# 2022-01-25 15:42:07,398 -INFO - dataset_builder.py:211 - Collect features using JS script
# 2022-01-25 15:42:07,454 -INFO - dataset_builder.py:219 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/html/validator.html
# 2022-01-25 15:42:07,462 -INFO - dataset_builder.py:231 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/html5_dataset/df/validator.pkl
# 2022-01-25 15:42:07,464 -INFO - dataset_builder.py:234 - No attributes: (10, 14)
# 2022-01-25 15:42:07,470 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '9172200031145274031104802888',
#   'is_hidden': 0,
#   'x': 45.0,
#   'y': 24.0,
#   'width': 1410.0,
#   'height': 47.59375,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 67107.1875},
#  {'element_id': '6343417676145274033379213097',
#   'is_hidden': 0,
#   'x': 69.140625,
#   'y': 239.1875,
#   'width': 1316.25,
#   'height': 24.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 31590.0},
#  {'element_id': '4680088833145274034102959377',
#   'is_hidden': 0,
#   'x': 69.140625,
#   'y': 183.171875,
#   'width': 1363.71875,
#   'height': 23.015625,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 31386.8393554688},
#  {'element_id': '9215860511145274039212832854',
#   'is_hidden': 0,
#   'x': 67.140625,
#   'y': 271.1875,
#   'width': 1365.71875,
#   'height': 21.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 28680.09375},
#  {'element_id': '7072775763145274035238555189',
#   'is_hidden': 0,
#   'x': 45.0,
#   'y': 89.59375,
#   'width': 1410.0,
#   'height': 18.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 25380.0},
#  {'element_id': '0182613393145274033329468777',
#   'is_hidden': 0,
#   'x': 45.0,
#   'y': 120.859375,
#   'width': 1455.0,
#   'height': 16.0,
#   'predicted_label': 'title',
#   'predicted_probability': 1.0,
#   'sort_key': 23280.0},
#  {'element_id': '1700334576145274039434877329',
#   'is_hidden': 0,
#   'x': 45.0,
#   'y': 409.234375,
#   'width': 1410.0,
#   'height': 14.0,
#   'predicted_label': 'text',
#   'predicted_probability': 1.0,
#   'sort_key': 19740.0},
#  {'element_id': '2516257551145274036278815848',
#   'is_hidden': 0,
#   'x': 604.53125,
#   'y': 184.1875,
#   'width': 425.921875,
#   'height': 22.0,
#   'predicted_label': 'datalist',
#   'predicted_probability': 1.0,
#   'sort_key': 9370.28125},
#  {'element_id': '0565755582145274036118032092',
#   'is_hidden': 0,
#   'x': 519.15625,
#   'y': 185.171875,
#   'width': 521.296875,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 8862.046875},
#  {'element_id': '4717976517145274035810832904',
#   'is_hidden': 0,
#   'x': 56.0,
#   'y': 33.0,
#   'width': 194.890625,
#   'height': 28.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 5456.9375},
#  {'element_id': '9838025695145274031040433951',
#   'is_hidden': 0,
#   'x': 1040.453125,
#   'y': 185.171875,
#   'width': 194.875,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 3312.875},
#  {'element_id': '2230343431145274036730810821',
#   'is_hidden': 0,
#   'x': 69.140625,
#   'y': 218.1875,
#   'width': 152.703125,
#   'height': 17.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 2595.953125},
#  {'element_id': '3456528794145274031457870024',
#   'is_hidden': 0,
#   'x': 45.0,
#   'y': 408.234375,
#   'width': 115.171875,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1842.75},
#  {'element_id': '1759117281145274037795728222',
#   'is_hidden': 0,
#   'x': 352.828125,
#   'y': 184.171875,
#   'width': 75.28125,
#   'height': 21.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 1580.90625},
#  {'element_id': '5785405641145274038009428928',
#   'is_hidden': 0,
#   'x': 138.84375,
#   'y': 218.1875,
#   'width': 83.0,
#   'height': 19.0,
#   'predicted_label': 'dropdown',
#   'predicted_probability': 1.0,
#   'sort_key': 1577.0},
#  {'element_id': '2842604696145274039138974567',
#   'is_hidden': 0,
#   'x': 172.859375,
#   'y': 408.234375,
#   'width': 98.0625,
#   'height': 16.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1569.0},
#  {'element_id': '0793883750145274032042775427',
#   'is_hidden': 0,
#   'x': 1170.328125,
#   'y': 184.171875,
#   'width': 65.0,
#   'height': 22.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 1.0,
#   'sort_key': 1430.0},
#  {'element_id': '3935870790145274039082078760',
#   'is_hidden': 0,
#   'x': 394.109375,
#   'y': 189.171875,
#   'width': 108.046875,
#   'height': 12.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 1296.5625},
#  {'element_id': '9302258408145274035100995932',
#   'is_hidden': 0,
#   'x': 69.140625,
#   'y': 271.1875,
#   'width': 53.796875,
#   'height': 21.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 1129.734375},
#  {'element_id': '3241078244145274035475918496',
#   'is_hidden': 0,
#   'x': 254.0625,
#   'y': 189.171875,
#   'width': 81.765625,
#   'height': 12.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 981.1875},
#  {'element_id': '1420756464145274036623148871',
#   'is_hidden': 0,
#   'x': 116.609375,
#   'y': 189.171875,
#   'width': 53.03125,
#   'height': 12.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 636.375},
#  {'element_id': '2813038136145274034672716700',
#   'is_hidden': 0,
#   'x': 185.640625,
#   'y': 189.171875,
#   'width': 52.421875,
#   'height': 12.0,
#   'predicted_label': 'label',
#   'predicted_probability': 1.0,
#   'sort_key': 629.0625},
#  {'element_id': '5628812680145274032298664035',
#   'is_hidden': 0,
#   'x': 258.0625,
#   'y': 186.171875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '6870467143145274035008266383',
#   'is_hidden': 0,
#   'x': 189.640625,
#   'y': 186.171875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '7616478573145274038793333221',
#   'is_hidden': 0,
#   'x': 120.609375,
#   'y': 186.171875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0},
#  {'element_id': '9730190585145274038482275943',
#   'is_hidden': 0,
#   'x': 398.109375,
#   'y': 186.171875,
#   'width': 13.0,
#   'height': 13.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 1.0,
#   'sort_key': 169.0}]
# CPU times: user 23.5 ms, sys: 7.54 ms, total: 31.1 ms
# Wall time: 408 ms

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id  is_hidden          x           y       width  \
# 0  9172200031145274031104802888          0  45.000000   24.000000  1410.00000
# 1  6343417676145274033379213097          0  69.140625  239.187500  1316.25000
# 2  4680088833145274034102959377          0  69.140625  183.171875  1363.71875
# 3  9215860511145274039212832854          0  67.140625  271.187500  1365.71875
# 4  7072775763145274035238555189          0  45.000000   89.593750  1410.00000
#
#       height   predicted_label  predicted_probability      sort_key tag_name
# 0  47.593750             title                    1.0  67107.187500       H1
# 1  24.000000  datetimeselector                    1.0  31590.000000    INPUT
# 2  23.015625              text                    1.0  31386.839355        P
# 3  21.000000              text                    1.0  28680.093750        P
# 4  18.000000              text                    1.0  25380.000000        P

# %%
predictions_df.predicted_label.unique()
# Out:
# array(['title', 'datetimeselector', 'text', 'datalist', 'label', 'link',
#        'button', 'dropdown', 'checkbox'], dtype=object)

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
        if r.is_hidden==0:
                patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
                axes.add_patch(patch)
                axes.text(r.x*2, r.y*2, 
                        str(r.predicted_label) + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                        backgroundcolor='black', 
                        color='white',
                        bbox=dict(alpha=0.5))
