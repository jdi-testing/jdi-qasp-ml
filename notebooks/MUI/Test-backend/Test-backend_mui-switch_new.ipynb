# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-12-01 15:45:54,727 -INFO - config.py:31 - Module utils.config was loaded
# 2021-12-01 15:45:54,752 -INFO - common.py:119 - Module utils.common is loaded...
# 2021-12-01 15:45:54,753 -INFO - dataset_builder.py:245 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'mui-switch'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/basic_switches'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-12-01 15:45:54,840 -INFO - dataset_builder.py:100 - Dataset name: mui-switch
# 2021-12-01 15:45:54,841 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-12-01 15:45:54,843 -INFO - dataset_builder.py:151 - Creating driver
# 2021-12-01 15:45:55,765 -INFO - dataset_builder.py:163 - Chrome web driver is created
# 2021-12-01 15:45:59,686 -INFO - common.py:22 - Window maximized
# 2021-12-01 15:46:06,689 -INFO - dataset_builder.py:166 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/mui-switch.png
# 2021-12-01 15:46:11,870 -INFO - dataset_builder.py:210 - Collect features using JS script
# 2021-12-01 15:46:12,395 -INFO - dataset_builder.py:218 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/mui-switch.html
# 2021-12-01 15:46:12,407 -INFO - dataset_builder.py:230 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/mui-switch.pkl
# 2021-12-01 15:46:12,411 -INFO - dataset_builder.py:233 - No attributes: (9, 13)
# 2021-12-01 15:46:18,158 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '0006167055627718767414537147',
#   'x': 0,
#   'y': 2016.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '6567256498627718761040894694',
#   'x': 0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '6118691687627718769571323628',
#   'x': 0,
#   'y': 1536.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6123787511627718768363285865',
#   'x': 0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6133600750627718762706641145',
#   'x': 0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6251572461627718752591935842',
#   'x': 0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6348060996627718758236180355',
#   'x': 0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '6409722148627718763617597634',
#   'x': 0,
#   'y': 1632.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '6594225290627718760200808110',
#   'x': 0,
#   'y': 2496.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4802940094627718762332136764',
#   'x': 0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6637270374627718757182855646',
#   'x': 0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '6676401101627718759294455859',
#   'x': 0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '6677321947627718769761898026',
#   'x': 0,
#   'y': 2064.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6702235394627718766191662003',
#   'x': 0,
#   'y': 1440.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '6847746844627718758215924326',
#   'x': 0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6858059530627718760426287361',
#   'x': 0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6053596012627718757376334161',
#   'x': 0,
#   'y': 192.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5930431768627718761048110098',
#   'x': 0,
#   'y': 1248.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5858727981627718763488107330',
#   'x': 0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5784296929627718763529612787',
#   'x': 0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5734454768627718769502104695',
#   'x': 0,
#   'y': 2544.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5708882549627718760348381653',
#   'x': 0,
#   'y': 2112.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5673104666627718767688907499',
#   'x': 0,
#   'y': 2448.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5565588696627718759921868677',
#   'x': 0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5520312293627718765012817157',
#   'x': 0,
#   'y': 1824.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5476375133627718754764473306',
#   'x': 0,
#   'y': 96.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5357901949627718769155246022',
#   'x': 0,
#   'y': 1104.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5268391971627718763930792767',
#   'x': 0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5261492545627718762657320941',
#   'x': 0,
#   'y': 2544.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5222133774627718754346796238',
#   'x': 0,
#   'y': 336.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5126858973627718754071716338',
#   'x': 0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5022302328627718756253681615',
#   'x': 0,
#   'y': 288.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0071320832627718752286625011',
#   'x': 0,
#   'y': 144.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '6961164362627718761665745211',
#   'x': 0,
#   'y': 2448.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7030707879627718755036593882',
#   'x': 0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '7164457067627718758463088311',
#   'x': 0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8439020881627718767039864425',
#   'x': 0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '9874502654627718765046622709',
#   'x': 0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '9621992535627718750196379674',
#   'x': 0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '9549526674627718757404566320',
#   'x': 0,
#   'y': 240.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '9492097640627718765814647460',
#   'x': 0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9460166204627718751610993953',
#   'x': 0,
#   'y': 576.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9223326670627718753292881219',
#   'x': 0,
#   'y': 432.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '8954400458627718763015303381',
#   'x': 0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '8872061604627718764151229322',
#   'x': 0,
#   'y': 2640.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id':
,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0236908622627718751187979217',
#   'x': 0,
#   'y': 480.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '0168591249627718766009531306',
#   'x': 0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0162153365627718757058227096',
#   'x': 0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4644270147627718761742738507',
#   'x': 0,
#   'y': 2112.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '2377459433627718755600293688',
#   'x': 0,
#   'y': 48.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '2570183852627718756183434865',
#   'x': 0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '3396029919627718769392068007',
#   'x': 0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '4603915544627718750476615396',
#   'x': 0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4560016523627718758029093581',
#   'x': 0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4555618738627718756065582834',
#   'x': 0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4520896824627718762076694192',
#   'x': 0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4439132572627718765414655590',
#   'x': 0,
#   'y': 2160.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '4434833318627718754903950276',
#   'x': 0,
#   'y': 288.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '4271419556627718756546126881',
#   'x': 0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '3885930420627718760070518791',
#   'x': 0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3881466174627718767184568411',
#   'x': 0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3839401367627718763659056412',
#   'x': 0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '3839207737627718767364875539',
#   'x': 0,
#   'y': 2016.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3766461264627718757567887643',
#   'x': 0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '3521926195627718764843359345',
#   'x': 0,
#   'y': 2640.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3657218742627718763576294041',
#   'x': 0,
#   'y': 1536.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '2948192834627718757087928433',
#   'x': 0,
#   'y': 192.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '3367259073627718753754547014',
#   'x': 0,
#   'y': 96.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2575140735627718766894795803',
#   'x': 0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2608622326627718763331808546',
#   'x': 0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '2633449755627718760195981137',
#   'x': 0,
#   'y': 2400.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2835251297627718766100377137',
#   'x': 0,
#   'y': 1104.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2867994938627718752552011750',
#   'x': 0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '2901676010627718756661507643',
#   'x': 0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9963150359627718769228357382',
#   'x': 0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '2979083585627718761227284738',
#   'x': 0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '3074735828627718759023911359',
#   'x': 0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '3168038752627718769779847220',
#   'x': 0,
#   'y': 2208.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '3325591069627718764729308812',
#   'x': 0,
#   'y': 2304.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '7584971665627718767273423710',
#   'x': 390,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '3931293704627718762808573212',
#   'x': 294,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '5695199623627718764124071702',
#   'x': 283,
#   'y': 333.078125,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '0443162412627718761841412516',
#   'x': 526,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '3293895454627718766437958726',
#   'x': 352,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '7135183388627718763946741337',
#   'x': 283,
#   'y': 257.078125,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '9639617355627718769571965152',
#   'x': 263,
#   'y': 295.078125,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '4615619054627718766336585033',
#   'x': 584,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0},
#  {'element_id': '8048500990627718764360023581',
#   'x': 448,
#   'y': 138.21875,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 1444.0}]
# CPU times: user 61.1 ms, sys: 14.4 ms, total: 75.5 ms
# Wall time: 1.63 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id  x       y  width  height predicted_label  \
# 0  0006167055627718767414537147  0  2016.0  250.0    48.0            list
# 1  6567256498627718761040894694  0  1056.0  250.0    48.0            list
# 2  6118691687627718769571323628  0  1536.0  250.0    48.0          button
# 3  6123787511627718768363285865  0  1344.0  250.0    48.0          button
# 4  6133600750627718762706641145  0  1584.0  250.0    48.0          button
#
#    predicted_probability  sort_key tag_name
# 0               0.999999   12000.0      DIV
# 1               0.999999   12000.0      DIV
# 2               1.000000   12000.0      DIV
# 3               1.000000   12000.0      DIV
# 4               1.000000   12000.0      DIV

# %%
preds
# Out:
#                        element_id    x            y  width  height  \
# 0    0006167055627718767414537147    0  2016.000000  250.0    48.0
# 1    6567256498627718761040894694    0  1056.000000  250.0    48.0
# 2    6118691687627718769571323628    0  1536.000000  250.0    48.0
# 3    6123787511627718768363285865    0  1344.000000  250.0    48.0
# 4    6133600750627718762706641145    0  1584.000000  250.0    48.0
# ..                            ...  ...          ...    ...     ...
# 136  3293895454627718766437958726  352   138.218750   38.0    38.0
# 137  7135183388627718763946741337  283   257.078125   38.0    38.0
# 138  9639617355627718769571965152  263   295.078125   38.0    38.0
# 139  4615619054627718766336585033  584   138.218750   38.0    38.0
# 140  8048500990627718764360023581  448   138.218750   38.0    38.0
#
#     predicted_label  predicted_probability  sort_key
# 0              list               0.999999   12000.0
# 1              list               0.999999   12000.0
# 2            button               1.000000   12000.0
# 3            button               1.000000   12000.0
# 4            button               1.000000   12000.0
# ..              ...                    ...       ...
# 136          switch               1.000000    1444.0
# 137          switch               1.000000    1444.0
# 138          switch               1.000000    1444.0
# 139          switch               1.000000    1444.0
# 140          switch               1.000000    1444.0
#
# [141 rows x 8 columns]

# %%
from_pkl = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')
from_pkl[from_pkl.element_id == '1049561488694071642269580342']
# Out:
# Empty DataFrame
# Columns: [attributes, displayed, element_id, height, onmouseenter, onmouseover, parent_id, style, tag_name, text, width, x, y]
# Index: []

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))

# %%
PREDICT_URL = 'http://localhost:5050/get_tasks_statuses'
response = requests.post(
    PREDICT_URL, data=dataset_json[10]
)

# %%
response.json()
# Out:
# {'exc': 'Expecting value: line 1 column 1 (char 0)'}
