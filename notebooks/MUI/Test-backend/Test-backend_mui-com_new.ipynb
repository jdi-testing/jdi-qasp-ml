# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-12-01 15:40:07,314 -INFO - config.py:31 - Module utils.config was loaded
# 2021-12-01 15:40:07,340 -INFO - common.py:119 - Module utils.common is loaded...
# 2021-12-01 15:40:07,341 -INFO - dataset_builder.py:245 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'mui-com'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://mui.com'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-12-01 15:40:07,536 -INFO - dataset_builder.py:100 - Dataset name: mui-com
# 2021-12-01 15:40:07,537 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-12-01 15:40:07,540 -INFO - dataset_builder.py:151 - Creating driver
# 2021-12-01 15:40:08,505 -INFO - dataset_builder.py:163 - Chrome web driver is created
# 2021-12-01 15:40:13,513 -INFO - common.py:22 - Window maximized
# 2021-12-01 15:40:20,518 -INFO - dataset_builder.py:166 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/mui-com.png
# 2021-12-01 15:40:26,412 -INFO - dataset_builder.py:210 - Collect features using JS script
# 2021-12-01 15:40:27,482 -INFO - dataset_builder.py:218 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/mui-com.html
# 2021-12-01 15:40:27,504 -INFO - dataset_builder.py:230 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/mui-com.pkl
# 2021-12-01 15:40:27,507 -INFO - dataset_builder.py:233 - No attributes: (42, 13)
# 2021-12-01 15:40:32,351 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '0101828815624264190373397777',
#   'x': 781.0,
#   'y': 1462.0,
#   'width': 443.1875,
#   'height': 434.375,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 0.8149173856,
#   'sort_key': 192509.5703125},
#  {'element_id': '8358851288624264193490446752',
#   'x': 577.65625,
#   'y': 3173.984375,
#   'width': 343.65625,
#   'height': 162.03125,
#   'predicted_label': 'table',
#   'predicted_probability': 1.0,
#   'sort_key': 55683.0517578125},
#  {'element_id': '1039189780624264196039696646',
#   'x': 1180.0,
#   'y': 736.0,
#   'width': 360.0,
#   'height': 86.015625,
#   'predicted_label': 'accordion',
#   'predicted_probability': 0.7074410319,
#   'sort_key': 30965.625},
#  {'element_id': '3910821885624264198011214112',
#   'x': 780.0,
#   'y': 600.0,
#   'width': 360.0,
#   'height': 48.5,
#   'predicted_label': 'button-group',
#   'predicted_probability': 0.9999979734,
#   'sort_key': 17460.0},
#  {'element_id': '7856076899624264195195228294',
#   'x': 1180.0,
#   'y': 394.0,
#   'width': 360.0,
#   'height': 48.0,
#   'predicted_label': 'tabs',
#   'predicted_probability': 0.9860899448,
#   'sort_key': 17280.0},
#  {'element_id': '8223085017624264192405079535',
#   'x': 336.890625,
#   'y': 563.96875,
#   'width': 291.15625,
#   'height': 56.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9977485538,
#   'sort_key': 16304.75},
#  {'element_id': '3908692032624264201543227430',
#   'x': 336.890625,
#   'y': 5230.0,
#   'width': 291.15625,
#   'height': 56.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9977485538,
#   'sort_key': 16304.75},
#  {'element_id': '6903343473624264190987710996',
#   'x': 566.65625,
#   'y': 2856.0,
#   'width': 355.65625,
#   'height': 34.5,
#   'predicted_label': 'tabs',
#   'predicted_probability': 0.964872241,
#   'sort_key': 12270.140625},
#  {'element_id': '3543157793624264191914420148',
#   'x': 953.3125,
#   'y': 2856.0,
#   'width': 355.65625,
#   'height': 34.5,
#   'predicted_label': 'tabs',
#   'predicted_probability': 0.964872241,
#   'sort_key': 12270.140625},
#  {'element_id': '3182366119624264191649878340',
#   'x': 181.0,
#   'y': 2856.0,
#   'width': 354.65625,
#   'height': 34.5,
#   'predicted_label': 'tabs',
#   'predicted_probability': 0.9638299346,
#   'sort_key': 12235.640625},
#  {'element_id': '8176085937624264182827765736',
#   'x': 224.0,
#   'y': 11.5,
#   'width': 275.453125,
#   'height': 41.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11293.578125},
#  {'element_id': '4662213675624264191910038049',
#   'x': 1038.640625,
#   'y': 2962.0,
#   'width': 195.0,
#   'height': 56.0,
#   'predicted_label': 'text-field',
#   'predicted_probability': 1.0,
#   'sort_key': 10920.0},
#  {'element_id': '6820333688624264193413440844',
#   'x': 652.9375,
#   'y': 2965.984375,
#   'width': 193.078125,
#   'height': 48.015625,
#   'predicted_label': 'alert',
#   'predicted_probability': 1.0,
#   'sort_key': 9270.7668457031},
#  {'element_id': '7616175380624264193336507322',
#   'x': 289.375,
#   'y': 2971.75,
#   'width': 147.90625,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 5398.578125},
#  {'element_id': '6542008682624264197721392876',
#   'x': 825.546875,
#   'y': 1789.1875,
#   'width': 361.421875,
#   'height': 14.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999976158,
#   'sort_key': 5059.90625},
#  {'element_id': '9968111494624264205995110795',
#   'x': 424.0625,
#   'y': 5629.0,
#   'width': 105.9375,
#   'height': 44.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4714.21875},
#  {'element_id': '0974771455624264195887881104',
#   'x': 1227.0,
#   'y': 511.0,
#   'width': 30.0,
#   'height': 156.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 4680.0},
#  {'element_id': '0331752560624264195040053041',
#   'x': 302.90625,
#   'y': 3236.75,
#   'width': 120.84375,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4410.796875},
#  {'element_id': '5367183611624264194415770163',
#   'x': 1026.21875,
#   'y': 688.5,
#   'width': 113.78125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3641.0},
#  {'element_id': '1854825213624264189459694618',
#   'x': 421.03125,
#   'y': 11.5,
#   'width': 78.421875,
#   'height': 41.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3215.296875},
#  {'element_id': '4674468321624264197243379385',
#   'x': 847.25,
#   'y': 1483.1875,
#   'width': 202.421875,
#   'height': 14.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9999830723,
#   'sort_key': 2833.90625},
#  {'element_id': '0273010460624264192375979496',
#   'x': 1099.671875,
#   'y': 2801.0,
#   'width': 113.140625,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2715.375},
#  {'element_id': '8816276591624264180850537071',
#   'x': 355.0,
#   'y': 11.5,
#   'width': 66.03125,
#   'height': 41.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2707.28125},
#  {'element_id': '1489323152624264193911144771',
#   'x': 849.796875,
#   'y': 1318.5,
#   'width': 111.0,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2664.0},
#  {'element_id': '9872957137624264199778508259',
#   'x': 927.546875,
#   'y': 688.5,
#   'width': 82.671875,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2645.5},
#  {'element_id': '8038212619624264191055341358',
#   'x': 771.0,
#   'y': 1428.0,
#   'width': 109.828125,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2635.875},
#  {'element_id': '1816096448624264203537456857',
#   'x': 1060.0,
#   'y': 5559.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '4705532633624264203040607513',
#   'x': 1060.0,
#   'y': 5621.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '2406211395624264203138428838',
#   'x': 1205.0,
#   'y': 5621.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '7058590082624264205313169325',
#   'x': 915.0,
#   'y': 5621.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '6561056318624264205906844010',
#   'x': 1060.0,
#   'y': 5528.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '2537541631624264200438546022',
#   'x': 1060.0,
#   'y': 5590.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '2625594256624264206645169226',
#   'x': 915.0,
#   'y': 5528.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '5979690851624264205433074945',
#   'x': 770.0,
#   'y': 5559.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '5938831184624264207299949448',
#   'x': 1060.0,
#   'y': 5652.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '2039299189624264209215352930',
#   'x': 770.0,
#   'y': 5590.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '5510112434624264209475530744',
#   'x': 1205.0,
#   'y': 5528.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '3469605082624264202821755087',
#   'x': 915.0,
#   'y': 5559.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '7882164667624264200105052308',
#   'x': 915.0,
#   'y': 5652.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '2015432473624264209839412248',
#   'x': 1205.0,
#   'y': 5559.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '3249215135624264205404234267',
#   'x': 770.0,
#   'y': 5528.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '4581252809624264202660941450',
#   'x': 915.0,
#   'y': 5590.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '4329619422624264208479957466',
#   'x': 1205.0,
#   'y': 5652.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '9684678503624264200506506045',
#   'x': 770.0,
#   'y': 5621.25,
#   'width': 125.0,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 2625.0},
#  {'element_id': '7330204867624264196784482553',
#   'x': 1222.8125,
#   'y': 2801.0,
#   'width': 107.1875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2572.5},
#  {'element_id': '2697745377624264192051787383',
#   'x': 247.0,
#   'y': 1640.0,
#   'width': 96.296875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 0.9380301833,
#   'sort_key': 2311.125},
#  {'element_id': '8481426288624264198506297147',
#   'x': 247.0,
#   'y': 1896.0,
#   'width': 96.296875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 0.9380301833,
#   'sort_key': 2311.125},
#  {'element_id': '5145226115624264192189369435',
#   'x': 247.0,
#   'y': 1768.0,
#   'width': 96.296875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 0.9380301833,
#   'sort_key': 2311.125},
#  {'element_id': '5273580285624264195079315625',
#   'x': 247.0,
#   'y': 1512.0,
#   'width': 96.296875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 0.9380301833,
#   'sort_key': 2311.125},
#  {'element_id': '4052800264624264198781831794',
#   'x': 890.828125,
#   'y': 1429.0,
#   'width': 104.171875,
#   'height': 22.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2291.78125},
#  {'element_id': '4140891140624264182145177539',
#   'x': 303.046875,
#   'y': 11.5,
#   'width': 51.953125,
#   'height': 41.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2130.078125},
#  {'element_id': '1801709287624264193536118240',
#   'x': 926.71875,
#   'y': 1573.1875,
#   'width': 151.8125,
#   'height': 14.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9997634292,
#   'sort_key': 2125.375},
#  {'element_id': '1176560721624264191325737047',
#   'x': 883.375,
#   'y': 1645.1875,
#   'width': 137.359375,
#   'height': 14.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9304336309,
#   'sort_key': 1923.03125},
#  {'element_id': '8257040140624264207393908636',
#   'x': 619.171875,
#   'y': 4834.0,
#   'width': 77.484375,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1627.171875},
#  {'element_id': '4775321721624264195120814394',
#   'x': 1182.1875,
#   'y': 1311.5,
#   'width': 38.0,
#   'height': 38.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9983028173,
#   'sort_key': 1444.0},
#  {'element_id': '6877566237624264182285732136',
#   'x': 1254.0,
#   'y': 15.5,
#   'width': 33.0,
#   'height': 33.0,
#   'predicted_label': 'badge',
#   'predicted_probability': 0.9999742508,
#   'sort_key': 1089.0},
#  {'element_id': '9330488778624264182436088361',
#   'x': 1297.0,
#   'y': 15.5,
#   'width': 33.0,
#   'height': 33.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999428988,
#   'sort_key': 1089.0},
#  {'element_id': '5856545370624264185732814753',
#   'x': 170.0,
#   'y': 16.0,
#   'width': 34.0,
#   'height': 32.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1088.0},
#  {'element_id': '6281563967624264191057447659',
#   'x': 805.0,
#   'y': 341.984375,
#   'width': 259.5625,
#   'height': 4.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 1038.25},
#  {'element_id': '9183055904624264193434885889',
#   'x': 987.0,
#   'y': 502.953125,
#   'width': 32.0,
#   'height': 32.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999759197,
#   'sort_key': 1024.0},
#  {'element_id': '3676276560624264195947072460',
#   'x': 222.0,
#   'y': 3566.0,
#   'width': 32.0,
#   'height': 32.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999759197,
#   'sort_key': 1024.0},
#  {'element_id': '4102605261624264202633778352',
#   'x': 1205.0,
#   'y': 5590.25,
#   'width': 48.578125,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9960848093,
#   'sort_key': 1020.140625},
#  {'element_id': '1814315780624264192750545998',
#   'x': 1210.1875,
#   'y': 1234.484375,
#   'width': 30.0,
#   'height': 30.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999608994,
#   'sort_key': 900.0},
#  {'element_id': '9898346619624264198248937465',
#   'x': 1194.5625,
#   'y': 204.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '9003636398624264193491062538',
#   'x': 1296.84375,
#   'y': 260.5,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '0440765607624264199729991630',
#   'x': 1245.703125,
#   'y': 232.625,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '5921361325624264190592581808',
#   'x': 1296.84375,
#   'y': 204.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '0852847053624264193690382225',
#   'x': 1194.5625,
#   'y': 232.625,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '1389747488624264198698175143',
#   'x': 1296.84375,
#   'y': 232.625,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '6232802756624264194026088291',
#   'x': 1245.703125,
#   'y': 260.5,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '6187561941624264197560757288',
#   'x': 1245.703125,
#   'y': 204.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '6099426898624264196499635814',
#   'x': 1194.5625,
#   'y': 260.5,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '5190664081624264193582355543',
#   'x': 1245.703125,
#   'y': 288.375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '3546580896624264190970591598',
#   'x': 1296.84375,
#   'y': 288.375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '5009475645624264191663726629',
#   'x': 1194.5625,
#   'y': 288.375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '7732294999624264195026820352',
#   'x': 855.546875,
#   'y': 694.5,
#   'width': 20.0,
#   'height': 20.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.9851090908,
#   'sort_key': 400.0},
#  {'element_id': '0343248791624264190280269214',
#   'x': 792.0,
#   'y': 694.5,
#   'width': 20.0,
#   'height': 20.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 0.565713048,
#   'sort_key': 400.0},
#  {'element_id': '1183728390624264198006897096',
#   'x': 636.0,
#   'y': 3575.875,
#   'width': 16.0,
#   'height': 16.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.7831358314,
#   'sort_key': 256.0},
#  {'element_id': '5110783265624264194086806967',
#   'x': 654.0,
#   'y': 3575.875,
#   'width': 16.0,
#   'height': 16.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.7831358314,
#   'sort_key': 256.0},
#  {'element_id': '2829540687624264191136439947',
#   'x': 618.0,
#   'y': 3575.875,
#   'width': 16.0,
#   'height': 16.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.7831358314,
#   'sort_key': 256.0},
#  {'element_id': '8000599239624264195736891496',
#   'x': 1238.0,
#   'y': 624.0,
#   'width': 8.0,
#   'height': 8.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 64.0},
#  {'element_id': '4283116285624264193237736919',
#   'x': 1238.0,
#   'y': 585.0,
#   'width': 8.0,
#   'height': 8.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 64.0}]
# CPU times: user 88.3 ms, sys: 30.7 ms, total: 119 ms
# Wall time: 2.95 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id           x            y      width  \
# 0  0101828815624264190373397777   781.00000  1462.000000  443.18750
# 1  8358851288624264193490446752   577.65625  3173.984375  343.65625
# 2  1039189780624264196039696646  1180.00000   736.000000  360.00000
# 3  3910821885624264198011214112   780.00000   600.000000  360.00000
# 4  7856076899624264195195228294  1180.00000   394.000000  360.00000
#
#        height predicted_label  predicted_probability       sort_key tag_name
# 0  434.375000      radiogroup               0.814917  192509.570312     CODE
# 1  162.031250           table               1.000000   55683.051758    TABLE
# 2   86.015625       accordion               0.707441   30965.625000      DIV
# 3   48.500000    button-group               0.999998   17460.000000      DIV
# 4   48.000000            tabs               0.986090   17280.000000      DIV

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))

# %%
PREDICT_URL = 'http://localhost:5050/get_tasks_statuses'
response = requests.post(
    PREDICT_URL, data=dataset_json[10]
)

# %%
response.json()
# Out:
# {'exc': 'Expecting value: line 1 column 1 (char 0)'}
