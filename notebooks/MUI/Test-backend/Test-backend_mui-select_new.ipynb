# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-12-01 16:21:30,731 -INFO - config.py:31 - Module utils.config was loaded
# 2021-12-01 16:21:30,756 -INFO - common.py:119 - Module utils.common is loaded...
# 2021-12-01 16:21:30,757 -INFO - dataset_builder.py:245 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'mui-select'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/selects'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-12-01 16:21:30,850 -INFO - dataset_builder.py:100 - Dataset name: mui-select
# 2021-12-01 16:21:30,852 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-12-01 16:21:30,854 -INFO - dataset_builder.py:151 - Creating driver
# 2021-12-01 16:21:31,777 -INFO - dataset_builder.py:163 - Chrome web driver is created
# 2021-12-01 16:21:35,688 -INFO - common.py:22 - Window maximized
# 2021-12-01 16:21:42,692 -INFO - dataset_builder.py:166 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/mui-select.png
# 2021-12-01 16:21:47,826 -INFO - dataset_builder.py:210 - Collect features using JS script
# 2021-12-01 16:21:48,381 -INFO - dataset_builder.py:218 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/mui-select.html
# 2021-12-01 16:21:48,397 -INFO - dataset_builder.py:230 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/mui-select.pkl
# 2021-12-01 16:21:48,403 -INFO - dataset_builder.py:233 - No attributes: (25, 13)
# 2021-12-01 16:21:52,524 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '0160413594649078322037533730',
#   'x': 0.0,
#   'y': 2064.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7035069006649078325463186108',
#   'x': 0.0,
#   'y': 432.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6390995137649078328508785828',
#   'x': 0.0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '6459410651649078320733883676',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '6549264465649078328346121508',
#   'x': 0.0,
#   'y': 48.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6553431663649078320336781655',
#   'x': 0.0,
#   'y': 2640.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6608059640649078329541678903',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '6673213379649078321138013178',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7105009598649078321132374833',
#   'x': 0.0,
#   'y': 2064.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '6358180364649078328605704801',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7186685756649078324663553079',
#   'x': 0.0,
#   'y': 2304.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '7204899579649078320438133625',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '7240188812649078328888192200',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '7350904134649078323447021735',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7415468262649078325804612192',
#   'x': 0.0,
#   'y': 432.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '7556160422649078322243775383',
#   'x': 0.0,
#   'y': 240.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '6364778280649078325324106179',
#   'x': 0.0,
#   'y': 576.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6345673822649078326481277376',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5064080682649078329821333306',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5595414877649078325593178841',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5069636332649078329120391359',
#   'x': 0.0,
#   'y': 1824.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0161332596649078323561875622',
#   'x': 0.0,
#   'y': 2208.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5342509261649078322336544863',
#   'x': 0.0,
#   'y': 2160.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5372671605649078328096147341',
#   'x': 0.0,
#   'y': 2592.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5525673417649078320789482026',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5530376189649078326830680765',
#   'x': 0.0,
#   'y': 960.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5805491678649078324087926809',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '6196577606649078325331959510',
#   'x': 0.0,
#   'y': 2112.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5876680683649078323884813642',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5929238794649078322993674241',
#   'x': 0.0,
#   'y': 1872.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5951220296649078322998398351',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6064080188649078323979673338',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6117191199649078323526519071',
#   'x': 0.0,
#   'y': 2400.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6185337541649078321249673477',
#   'x': 0.0,
#   'y': 1440.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7572857073649078323751066633',
#   'x': 0.0,
#   'y': 2448.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7606102499649078325600541724',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '7630640929649078320518705091',
#   'x': 0.0,
#   'y': 1536.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9458691024649078320803425257',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '9205844518649078325225116071',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '9252977219649078328399989992',
#   'x': 0.0,
#   'y': 336.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9344262143649078320432154905',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9394435470649078326354284105',
#   'x': 0.0,
#   'y': 2352.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '9410066179649078320138045429',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '9438387534649078327763392574',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9504781484649078321684343075',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '7706454623649078323448309997',
#   'x': 0.0,
#   'y': 48.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '9622075549649078329637551336',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9638938988649078320953576984',
#   'x': 0.0,
#   'y': 96.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '9675052992649078329960868088',
#   'x': 0.0,
#   'y': 2592.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9747938757649078325545474268',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9761027629649078322033440522',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '9946117122649078327723168051',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '8978592114649078322146253010',
#   'x': 0.0,
#   'y': 1104.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8942040352649078323862940319',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '8857202395649078320488649257',
#   'x': 0.0,
#   'y': 384.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8832815342649078325929124457',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '8784846796649078322679272930',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '8738899378649078329599453547',
#   'x': 0.0,
#   'y': 2496.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '8694262464649078325632770685',
#   'x': 0.0,
#   'y': 1536.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '8679630156649078320288311576',
#   'x': 0.0,
#   'y': 192.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8609780861649078320212448892',
#   'x': 0.0,
#   'y': 288.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '8583623274649078328290746489',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8241563477649078329009266904',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8237539558649078321920116539',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '8073327286649078326081764628',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7965840883649078326892711666',
#   'x': 0.0,
#   'y': 480.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7912356334649078328588853121',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7795092658649078325434896691',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7772264885649078329593307045',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '5065433821649078323293870402',
#   'x': 0.0,
#   'y': 672.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '5274140007649078328940528244',
#   'x': 0.0,
#   'y': 480.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '2481698555649078326210857869',
#   'x': 0.0,
#   'y': 192.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '1963729270649078321924513694',
#   'x': 0.0,
#   'y': 144.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '1581658848649078326240170654',
#   'x': 0.0,
#   'y': 2160.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '1676894580649078324642747642',
#   'x': 0.0,
#   'y': 1920.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '1849483787649078320895907198',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '1927633249649078324673792217',
#   'x': 0.0,
#   'y': 960.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '1930713588649078322484890788',
#   'x': 0.0,
#   'y': 2304.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '1951394119649078325227940840',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2135028010649078325234896448',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '1315522975649078322020113242',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2206538031649078324949024464',
#   'x': 0.0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2288542582649078325878525555',
#   'x': 0.0,
#   'y': 1440.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '2426935164649078320045082599',
#   'x': 0.0,
#   'y': 240.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4946267761649078326196800149',
#   'x': 0.0,
#   'y': 2208.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2662021488649078321997390051',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2669196990649078323411259421',
#   'x': 0.0,
#   'y': 1104.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '1380290000649078325140168285',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '1290764754649078323545699562',
#   'x': 0.0,
#   'y': 2400.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '2930562766649078321383610188',
#   'x': 0.0,
#   'y': 1872.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '0575547069649078322914282513',
#   'x': 0.0,
#   'y': 96.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0162645994649078324099790568',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0194776352649078321161109737',
#   'x': 0.0,
#   'y': 2016.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0269485056649078323512699346',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0300876804649078325513044105',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '0321393953649078322598420959',
#   'x': 0.0,
#   'y': 2640.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '0321439281649078322022694749',
#   'x': 0.0,
#   'y': 1152.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '0577930023649078320266221730',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '1239991356649078328585188350',
#   'x': 0.0,
#   'y': 1152.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0631939262649078324393672128',
#   'x': 0.0,
#   'y': 144.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0749983656649078326344549225',
#   'x': 0.0,
#   'y': 1824.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '0764209302649078323686300261',
#   'x': 0.0,
#   'y': 528.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '0825789268649078323298426516',
#   'x': 0.0,
#   'y': 2496.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0866701240649078325752780148',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '1035868098649078320134830003',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '2886073129649078326141786333',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '9951978035649078329388324498',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '3702590423649078323849729024',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4386952112649078328230194365',
#   'x': 0.0,
#   'y': 576.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '4073519581649078327185152992',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4310135083649078324040507062',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4329620263649078321213490314',
#   'x': 0.0,
#   'y': 288.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4363860980649078324782566351',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3569314172649078324095702085',
#   'x': 0.0,
#   'y': 336.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '3555576149649078328648951023',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '3537121990649078323561309013',
#   'x': 0.0,
#   'y': 384.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '4376757307649078329401241699',
#   'x': 0.0,
#   'y': 2352.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3483320641649078326013499776',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3473158185649078322681133892',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3422052247649078323606191661',
#   'x': 0.0,
#   'y': 1920.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '4216062206649078328813621178',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3363929801649078327690157580',
#   'x': 0.0,
#   'y': 2112.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '4482198172649078321408364864',
#   'x': 0.0,
#   'y': 2544.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '4526439622649078324878208083',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3245166786649078324093180572',
#   'x': 0.0,
#   'y': 2016.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '4691355690649078321330837180',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '4799974171649078325921472057',
#   'x': 0.0,
#   'y': 2544.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4911399719649078322514529671',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '3153456589649078323759439596',
#   'x': 0.0,
#   'y': 2448.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '4911735433649078324476552183',
#   'x': 0.0,
#   'y': 1248.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '3148730908649078329712763492',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.9999991655,
#   'sort_key': 12000.0},
#  {'element_id': '4134918324649078321936108296',
#   'x': 0.0,
#   'y': 1632.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12000.0},
#  {'element_id': '4948504779649078338437823163',
#   'x': 554.0,
#   'y': 490.84375,
#   'width': 120.0,
#   'height': 56.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.9996988773,
#   'sort_key': 6720.0},
#  {'element_id': '1337277692649078337614011461',
#   'x': 274.0,
#   'y': 892.328125,
#   'width': 140.6875,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9996271133,
#   'sort_key': 5135.09375},
#  {'element_id': '4264265636649078323274175091',
#   'x': 418.0,
#   'y': 419.9375,
#   'width': 155.671875,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.9829266071,
#   'sort_key': 4981.5},
#  {'element_id': '6726169317649078326449840425',
#   'x': 282.0,
#   'y': 291.078125,
#   'width': 150.0,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.9999985695,
#   'sort_key': 4800.0},
#  {'element_id': '7809702975649078339132310730',
#   'x': 282.0,
#   'y': 658.609375,
#   'width': 150.0,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.999997735,
#   'sort_key': 4800.0},
#  {'element_id': '3205698888649078327163784299',
#   'x': 282.0,
#   'y': 162.21875,
#   'width': 150.0,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.999997735,
#   'sort_key': 4800.0},
#  {'element_id': '8909301374649078327534384671',
#   'x': 589.671875,
#   'y': 419.9375,
#   'width': 144.4375,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.98481673,
#   'sort_key': 4622.0},
#  {'element_id': '6073285589649078334986867814',
#   'x': 418.0,
#   'y': 787.46875,
#   'width': 120.0,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.999999404,
#   'sort_key': 3840.0},
#  {'element_id': '9364449841649078338268592888',
#   'x': 282.0,
#   'y': 787.46875,
#   'width': 120.0,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.996515274,
#   'sort_key': 3840.0},
#  {'element_id': '3107721763649078330877364553',
#   'x': 282.0,
#   'y': 952.828125,
#   'width': 120.0,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.999999404,
#   'sort_key': 3840.0},
#  {'element_id': '1702214752649078337366897673',
#   'x': 750.109375,
#   'y': 419.9375,
#   'width': 120.0,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.9889512658,
#   'sort_key': 3840.0},
#  {'element_id': '8362776738649078331369773498',
#   'x': 282.0,
#   'y': 506.84375,
#   'width': 120.0,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.9889512658,
#   'sort_key': 3840.0},
#  {'element_id': '3266239206649078332374363741',
#   'x': 1158.109375,
#   'y': 419.9375,
#   'width': 120.0,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.9874861836,
#   'sort_key': 3840.0},
#  {'element_id': '2291845984649078320884022410',
#   'x': 282.0,
#   'y': 419.9375,
#   'width': 120.0,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.9889512658,
#   'sort_key': 3840.0},
#  {'element_id': '9837519662649078334028460758',
#   'x': 1294.109375,
#   'y': 419.9375,
#   'width': 120.0,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.9889512658,
#   'sort_key': 3840.0},
#  {'element_id': '7203211916649078338680105867',
#   'x': 1022.109375,
#   'y': 419.9375,
#   'width': 120.0,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.9957470298,
#   'sort_key': 3840.0},
#  {'element_id': '3057765713649078336040099974',
#   'x': 886.109375,
#   'y': 419.9375,
#   'width': 120.0,
#   'height': 32.0,
#   'predicted_label': 'select',
#   'predicted_probability': 0.996512115,
#   'sort_key': 3840.0}]
# CPU times: user 67.5 ms, sys: 27.8 ms, total: 95.2 ms
# Wall time: 1.65 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id    x       y  width  height predicted_label  \
# 0  0160413594649078322037533730  0.0  2064.0  250.0    48.0          button
# 1  7035069006649078325463186108  0.0   432.0  250.0    48.0          button
# 2  6390995137649078328508785828  0.0  1584.0  250.0    48.0            list
# 3  6459410651649078320733883676  0.0  1008.0  250.0    48.0            list
# 4  6549264465649078328346121508  0.0    48.0  250.0    48.0          button
#
#    predicted_probability  sort_key tag_name
# 0               1.000000   12000.0      DIV
# 1               1.000000   12000.0      DIV
# 2               0.999999   12000.0      DIV
# 3               0.999999   12000.0      DIV
# 4               1.000000   12000.0      DIV

# %%
preds
# Out:
#                        element_id            x          y  width  height  \
# 0    0160413594649078322037533730     0.000000  2064.0000  250.0    48.0
# 1    7035069006649078325463186108     0.000000   432.0000  250.0    48.0
# 2    6390995137649078328508785828     0.000000  1584.0000  250.0    48.0
# 3    6459410651649078320733883676     0.000000  1008.0000  250.0    48.0
# 4    6549264465649078328346121508     0.000000    48.0000  250.0    48.0
# ..                            ...          ...        ...    ...     ...
# 144  3266239206649078332374363741  1158.109375   419.9375  120.0    32.0
# 145  2291845984649078320884022410   282.000000   419.9375  120.0    32.0
# 146  9837519662649078334028460758  1294.109375   419.9375  120.0    32.0
# 147  7203211916649078338680105867  1022.109375   419.9375  120.0    32.0
# 148  3057765713649078336040099974   886.109375   419.9375  120.0    32.0
#
#     predicted_label  predicted_probability  sort_key
# 0            button               1.000000   12000.0
# 1            button               1.000000   12000.0
# 2              list               0.999999   12000.0
# 3              list               0.999999   12000.0
# 4            button               1.000000   12000.0
# ..              ...                    ...       ...
# 144          select               0.987486    3840.0
# 145          select               0.988951    3840.0
# 146          select               0.988951    3840.0
# 147          select               0.995747    3840.0
# 148          select               0.996512    3840.0
#
# [149 rows x 8 columns]

# %%
from_pkl = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')
from_pkl[from_pkl.element_id == '1049561488694071642269580342']
# Out:
# Empty DataFrame
# Columns: [attributes, displayed, element_id, height, onmouseenter, onmouseover, parent_id, style, tag_name, text, width, x, y]
# Index: []

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))

# %%
PREDICT_URL = 'http://localhost:5050/get_tasks_statuses'
response = requests.post(
    PREDICT_URL, data=dataset_json[10]
)

# %%
response.json()
# Out:
# {'exc': 'Expecting value: line 1 column 1 (char 0)'}
