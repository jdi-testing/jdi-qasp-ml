# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-12-20 10:43:44,783 -INFO - config.py:31 - Module utils.config was loaded
# 2021-12-20 10:43:44,814 -INFO - common.py:119 - Module utils.common is loaded...
# 2021-12-20 10:43:44,816 -INFO - dataset_builder.py:245 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'mui-stepper'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/steppers'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-12-20 10:43:44,925 -INFO - dataset_builder.py:100 - Dataset name: mui-stepper
# 2021-12-20 10:43:44,926 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-12-20 10:43:44,928 -INFO - dataset_builder.py:151 - Creating driver
# 2021-12-20 10:43:45,893 -INFO - dataset_builder.py:163 - Chrome web driver is created
# 2021-12-20 10:43:49,874 -INFO - common.py:22 - Window maximized
# 2021-12-20 10:43:56,878 -INFO - dataset_builder.py:166 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/mui-stepper.png
# 2021-12-20 10:44:03,002 -INFO - dataset_builder.py:210 - Collect features using JS script
# 2021-12-20 10:44:03,643 -INFO - dataset_builder.py:218 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/mui-stepper.html
# 2021-12-20 10:44:03,666 -INFO - dataset_builder.py:230 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/mui-stepper.pkl
# 2021-12-20 10:44:03,669 -INFO - dataset_builder.py:233 - No attributes: (24, 13)
# 2021-12-20 10:44:09,145 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '0999572130862430091370643537',
#   'x': 274.0,
#   'y': 532.9375,
#   'width': 1202.0,
#   'height': 292.5,
#   'predicted_label': 'stepper',
#   'predicted_probability': 1.0,
#   'sort_key': 351585.0},
#  {'element_id': '0967272776862430090216476461',
#   'x': 274.0,
#   'y': 138.21875,
#   'width': 1202.0,
#   'height': 72.0,
#   'predicted_label': 'stepper',
#   'predicted_probability': 1.0,
#   'sort_key': 86544.0},
#  {'element_id': '4477237663862430090812044481',
#   'x': 274.0,
#   'y': 335.578125,
#   'width': 1202.0,
#   'height': 72.0,
#   'predicted_label': 'stepper',
#   'predicted_probability': 1.0,
#   'sort_key': 86544.0},
#  {'element_id': '4011252496862430091635793900',
#   'x': 274.0,
#   'y': 914.296875,
#   'width': 400.0,
#   'height': 50.0,
#   'predicted_label': 'accordion',
#   'predicted_probability': 1.0,
#   'sort_key': 20000.0},
#  {'element_id': '8973444877862430098255214621',
#   'x': 274.0,
#   'y': 1332.15625,
#   'width': 400.0,
#   'height': 48.0,
#   'predicted_label': 'stepper',
#   'predicted_probability': 1.0,
#   'sort_key': 19200.0},
#  {'element_id': '7696283027862430092180264840',
#   'x': 274.0,
#   'y': 1219.296875,
#   'width': 400.0,
#   'height': 48.0,
#   'predicted_label': 'stepper',
#   'predicted_probability': 1.0,
#   'sort_key': 19200.0},
#  {'element_id': '2068201777862430092117971262',
#   'x': 274.0,
#   'y': 1469.015625,
#   'width': 400.0,
#   'height': 48.0,
#   'predicted_label': 'stepper',
#   'predicted_probability': 1.0,
#   'sort_key': 19200.0},
#  {'element_id': '7209882103862430092619284820',
#   'x': 0.0,
#   'y': 2352.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7323786655862430091778322227',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7388810163862430094843590502',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0023139018862430091748884815',
#   'x': 0.0,
#   'y': 2160.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7434334070862430083198411491',
#   'x': 0.0,
#   'y': 192.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7455601502862430097872137958',
#   'x': 0.0,
#   'y': 2640.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7645225850862430090666077360',
#   'x': 0.0,
#   'y': 1632.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7667408804862430090133541821',
#   'x': 0.0,
#   'y': 1872.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7739869787862430090236901011',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7921484950862430097927575356',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7191258560862430091833734211',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7141258956862430095248361822',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7176542098862430099165610492',
#   'x': 0.0,
#   'y': 2016.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '7990998946862430092553066191',
#   'x': 0.0,
#   'y': 1248.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6897793546862430091838388085',
#   'x': 0.0,
#   'y': 2160.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6872636689862430091737544904',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6783911428862430094657900953',
#   'x': 0.0,
#   'y': 1104.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6753261328862430081352887104',
#   'x': 0.0,
#   'y': 48.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6403257456862430082355119088',
#   'x': 0.0,
#   'y': 240.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6346116876862430092220268972',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '6321177007862430091161266053',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '
0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0891180210862430097647697334',
#   'x': 0.0,
#   'y': 1920.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0871988849862430082399749159',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0801855125862430092932222220',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0731575976862430094233966304',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '0503780127862430094600599081',
#   'x': 0.0,
#   'y': 960.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2908855875862430098116484198',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '2730284807862430094554133443',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3266870210862430092226391793',
#   'x': 0.0,
#   'y': 1872.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4483701792862430099728253022',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5246551230862430084552804554',
#   'x': 0.0,
#   'y': 432.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5205730343862430085410735996',
#   'x': 0.0,
#   'y': 240.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5167105399862430085910781057',
#   'x': 0.0,
#   'y': 384.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5075277411862430096576157656',
#   'x': 0.0,
#   'y': 1584.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5054161178862430097666798455',
#   'x': 0.0,
#   'y': 2304.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5037329480862430093976101794',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '5011682700862430080547299095',
#   'x': 0.0,
#   'y': 336.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4827468801862430098925453123',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4810034077862430099514433181',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4797172301862430092062058424',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4783496186862430085481353114',
#   'x': 0.0,
#   'y': 576.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3274438340862430093882751818',
#   'x': 0.0,
#   'y': 2208.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4509333679862430092955161688',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3945208238862430080715793822',
#   'x': 0.0,
#   'y': 672.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3985083387862430093290336522',
#   'x': 0.0,
#   'y': 1920.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3298396262862430096527952951',
#   'x': 0.0,
#   'y': 1152.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3406237674862430090383642318',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3700907803862430091316902171',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '3781126156862430092668401993',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4297894505862430099608311858',
#   'x': 0.0,
#   'y': 2496.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '9872026291862430098278805612',
#   'x': 0.0,
#   'y': 2400.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4206918933862430093460832549',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4215206413862430096055128375',
#   'x': 0.0,
#   'y': 2112.0,
#   'width': 250.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 12000.0},
#  {'element_id': '4159933907862430098165167961',
#   'x': 402.0,
#   'y': 431.578125,
#   'width': 130.5625,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4765.53125},
#  {'element_id': '9272188107862430094280013250',
#   'x': 403.0,
#   'y': 620.9375,
#   'width': 68.8125,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2511.65625},
#  {'element_id': '7411846126862430092385437150',
#   'x': 274.0,
#   'y': 234.21875,
#   'width': 64.0,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2336.0},
#  {'element_id': '1670094138862430094755199246',
#   'x': 338.0,
#   'y': 431.578125,
#   'width': 64.0,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2336.0},
#  {'element_id': '2076159724862430093093734304',
#   'x': 331.0,
#   'y': 620.9375,
#   'width': 64.0,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2336.0},
#  {'element_id': '5317746138862430094809233133',
#   'x': 338.0,
#   'y': 234.21875,
#   'width': 64.0,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2336.0},
#  {'element_id': '8776649504862430090509678081',
#   'x': 274.0,
#   'y': 431.578125,
#   'width': 64.0,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2336.0},
#  {'element_id': '0369841965862430097922740647',
#   'x': 378.34375,
#   'y': 1491.015625,
#   'width': 192.0,
#   'height': 4.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 0.9999989271,
#   'sort_key': 768.0}]
# CPU times: user 75 ms, sys: 41.4 ms, total: 116 ms
# Wall time: 2.33 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id      x            y   width  height  \
# 0  0999572130862430091370643537  274.0   532.937500  1202.0   292.5
# 1  0967272776862430090216476461  274.0   138.218750  1202.0    72.0
# 2  4477237663862430090812044481  274.0   335.578125  1202.0    72.0
# 3  4011252496862430091635793900  274.0   914.296875   400.0    50.0
# 4  8973444877862430098255214621  274.0  1332.156250   400.0    48.0
#
#   predicted_label  predicted_probability  sort_key tag_name
# 0         stepper                    1.0  351585.0      DIV
# 1         stepper                    1.0   86544.0      DIV
# 2         stepper                    1.0   86544.0      DIV
# 3       accordion                    1.0   20000.0      DIV
# 4         stepper                    1.0   19200.0      DIV

# %%
preds
# Out:
#                        element_id          x            y   width  height  \
# 0    0999572130862430091370643537  274.00000   532.937500  1202.0   292.5
# 1    0967272776862430090216476461  274.00000   138.218750  1202.0    72.0
# 2    4477237663862430090812044481  274.00000   335.578125  1202.0    72.0
# 3    4011252496862430091635793900  274.00000   914.296875   400.0    50.0
# 4    8973444877862430098255214621  274.00000  1332.156250   400.0    48.0
# ..                            ...        ...          ...     ...     ...
# 122  1670094138862430094755199246  338.00000   431.578125    64.0    36.5
# 123  2076159724862430093093734304  331.00000   620.937500    64.0    36.5
# 124  5317746138862430094809233133  338.00000   234.218750    64.0    36.5
# 125  8776649504862430090509678081  274.00000   431.578125    64.0    36.5
# 126  0369841965862430097922740647  378.34375  1491.015625   192.0     4.0
#
#     predicted_label  predicted_probability  sort_key
# 0           stepper               1.000000  351585.0
# 1           stepper               1.000000   86544.0
# 2           stepper               1.000000   86544.0
# 3         accordion               1.000000   20000.0
# 4           stepper               1.000000   19200.0
# ..              ...                    ...       ...
# 122          button               1.000000    2336.0
# 123          button               1.000000    2336.0
# 124          button               1.000000    2336.0
# 125          button               1.000000    2336.0
# 126        progress               0.999999     768.0
#
# [127 rows x 8 columns]

# %%
from_pkl = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')
from_pkl[from_pkl.element_id == '1049561488694071642269580342']
# Out:
# Empty DataFrame
# Columns: [attributes, displayed, element_id, height, onmouseenter, onmouseover, parent_id, style, tag_name, text, width, x, y]
# Index: []

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))

# %%
PREDICT_URL = 'http://localhost:5050/get_tasks_statuses'
response = requests.post(
    PREDICT_URL, data=dataset_json[10]
)

# %%
response.json()
# Out:
# {'exc': 'Expecting value: line 1 column 1 (char 0)'}
