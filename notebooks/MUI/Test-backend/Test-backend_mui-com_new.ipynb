# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, 'jdi-qasp-ml', 'data/mui_dataset')

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-11-24 13:49:33,329 -INFO - config.py:31 - Module utils.config was loaded
# 2021-11-24 13:49:33,359 -INFO - common.py:127 - Module utils.common is loaded...
# 2021-11-24 13:49:33,364 -INFO - dataset_builder.py:244 - dataset package is loaded...

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'mui-com'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://mui.com'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        self.driver.get(self.url)
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-11-24 13:49:33,532 -INFO - dataset_builder.py:100 - Dataset name: mui-com
# 2021-11-24 13:49:33,534 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-11-24 13:49:33,535 -INFO - dataset_builder.py:150 - Creating driver
# 2021-11-24 13:49:33,998 -INFO - dataset_builder.py:162 - Chrome web driver is created
# 2021-11-24 13:49:39,136 -INFO - common.py:30 - Window maximized
# 2021-11-24 13:49:46,141 -INFO - dataset_builder.py:165 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/mui-com.png
# 2021-11-24 13:49:51,862 -INFO - dataset_builder.py:209 - Collect features using JS script
# 2021-11-24 13:49:52,945 -INFO - dataset_builder.py:217 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/mui-com.html
# 2021-11-24 13:49:52,965 -INFO - dataset_builder.py:229 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/mui-com.pkl
# 2021-11-24 13:49:52,967 -INFO - dataset_builder.py:232 - No attributes: (42, 13)
# 2021-11-24 13:49:57,547 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '4327984726509918692332797690',
#   'x': 0.0,
#   'y': 64.0,
#   'width': 1500.0,
#   'height': 5177.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 0.9999643564,
#   'sort_key': 7765500.0},
#  {'element_id': '1326173598509918692930488157',
#   'x': 781.0,
#   'y': 1462.0,
#   'width': 443.1875,
#   'height': 434.375,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 0.9999313354,
#   'sort_key': 192509.5703125},
#  {'element_id': '0248896804509918700428861514',
#   'x': 577.65625,
#   'y': 3173.984375,
#   'width': 343.65625,
#   'height': 162.03125,
#   'predicted_label': 'table',
#   'predicted_probability': 1.0,
#   'sort_key': 55683.0517578125},
#  {'element_id': '4141022400509918704470580027',
#   'x': 170.0,
#   'y': 5435.0,
#   'width': 560.0,
#   'height': 72.5,
#   'predicted_label': 'text-field',
#   'predicted_probability': 0.9995993972,
#   'sort_key': 40600.0},
#  {'element_id': '3070214874509918693609454099',
#   'x': 1180.0,
#   'y': 736.0,
#   'width': 360.0,
#   'height': 86.015625,
#   'predicted_label': 'accordion',
#   'predicted_probability': 1.0,
#   'sort_key': 30965.625},
#  {'element_id': '4008140156509918695543849433',
#   'x': 780.0,
#   'y': 600.0,
#   'width': 360.0,
#   'height': 48.5,
#   'predicted_label': 'button-group',
#   'predicted_probability': 0.7800893188,
#   'sort_key': 17460.0},
#  {'element_id': '8980552503509918702682054626',
#   'x': 336.890625,
#   'y': 5064.0,
#   'width': 291.15625,
#   'height': 56.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.7994747758,
#   'sort_key': 16304.75},
#  {'element_id': '6084971353509918691706626768',
#   'x': 336.890625,
#   'y': 563.96875,
#   'width': 291.15625,
#   'height': 56.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.7994747758,
#   'sort_key': 16304.75},
#  {'element_id': '8140099991509918702980905280',
#   'x': 566.65625,
#   'y': 2856.0,
#   'width': 355.65625,
#   'height': 34.5,
#   'predicted_label': 'tabs',
#   'predicted_probability': 1.0,
#   'sort_key': 12270.140625},
#  {'element_id': '9994876745509918702931224296',
#   'x': 953.3125,
#   'y': 2856.0,
#   'width': 355.65625,
#   'height': 34.5,
#   'predicted_label': 'tabs',
#   'predicted_probability': 1.0,
#   'sort_key': 12270.140625},
#  {'element_id': '4959698315509918703330926041',
#   'x': 181.0,
#   'y': 2856.0,
#   'width': 354.65625,
#   'height': 34.5,
#   'predicted_label': 'tabs',
#   'predicted_probability': 1.0,
#   'sort_key': 12235.640625},
#  {'element_id': '4832382639509918693086740821',
#   'x': 224.0,
#   'y': 11.5,
#   'width': 275.453125,
#   'height': 41.0,
#   'predicted_label': 'list',
#   'predicted_probability': 1.0,
#   'sort_key': 11293.578125},
#  {'element_id': '9559941193509918706886304858',
#   'x': 1038.640625,
#   'y': 2962.0,
#   'width': 195.0,
#   'height': 56.0,
#   'predicted_label': 'text-field',
#   'predicted_probability': 1.0,
#   'sort_key': 10920.0},
#  {'element_id': '6520946945509918708968127648',
#   'x': 652.9375,
#   'y': 2965.984375,
#   'width': 193.078125,
#   'height': 48.015625,
#   'predicted_label': 'alert',
#   'predicted_probability': 1.0,
#   'sort_key': 9270.7668457031},
#  {'element_id': '0844886016509918706959630105',
#   'x': 289.375,
#   'y': 2971.75,
#   'width': 147.90625,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 5398.578125},
#  {'element_id': '6863440709509918704542340698',
#   'x': 424.0625,
#   'y': 5463.0,
#   'width': 105.9375,
#   'height': 44.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999060631,
#   'sort_key': 4714.21875},
#  {'element_id': '1043216856509918697601800726',
#   'x': 1227.0,
#   'y': 511.0,
#   'width': 30.0,
#   'height': 156.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 4680.0},
#  {'element_id': '9080191831509918706890700487',
#   'x': 302.90625,
#   'y': 3236.75,
#   'width': 120.84375,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 4410.796875},
#  {'element_id': '4983053436509918709057590939',
#   'x': 1079.0,
#   'y': 3283.75,
#   'width': 114.28125,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999728203,
#   'sort_key': 4171.265625},
#  {'element_id': '0048127841509918698046298069',
#   'x': 1026.21875,
#   'y': 688.5,
#   'width': 113.78125,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 3641.0},
#  {'element_id': '4878509744509918699710486941',
#   'x': 421.03125,
#   'y': 11.5,
#   'width': 78.421875,
#   'height': 41.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 3215.296875},
#  {'element_id': '5803955585509918695719808592',
#   'x': 847.25,
#   'y': 1483.1875,
#   'width': 202.421875,
#   'height': 14.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.977930069,
#   'sort_key': 2833.90625},
#  {'element_id': '7302544615509918700670623480',
#   'x': 1099.671875,
#   'y': 2801.0,
#   'width': 113.140625,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2715.375},
#  {'element_id': '2465903544509918696360718681',
#   'x': 355.0,
#   'y': 11.5,
#   'width': 66.03125,
#   'height': 41.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2707.28125},
#  {'element_id': '4780040911509918699724467911',
#   'x': 849.796875,
#   'y': 1318.5,
#   'width': 111.0,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2664.0},
#  {'element_id': '3250896884509918693475593762',
#   'x': 927.546875,
#   'y': 688.5,
#   'width': 82.671875,
#   'height': 32.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 1.0,
#   'sort_key': 2645.5},
#  {'element_id': '0449770695509918695586539311',
#   'x': 771.0,
#   'y': 1428.0,
#   'width': 109.828125,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2635.875},
#  {'element_id': '7907682843509918703161416643',
#   'x': 1222.8125,
#   'y': 2801.0,
#   'width': 107.1875,
#   'height': 24.0,
#   'predicted_label': 'chip',
#   'predicted_probability': 0.999973774,
#   'sort_key': 2572.5},
#  {'element_id': '1371782273509918693072372753',
#   'x': 247.0,
#   'y': 1896.0,
#   'width': 96.296875,
#   'height': 24.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.7585371137,
#   'sort_key': 2311.125},
#  {'element_id': '2401440210509918690493256726',
#   'x': 247.0,
#   'y': 1768.0,
#   'width': 96.296875,
#   'height': 24.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.7585371137,
#   'sort_key': 2311.125},
#  {'element_id': '4187653921509918698809418379',
#   'x': 247.0,
#   'y': 1640.0,
#   'width': 96.296875,
#   'height': 24.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.7585371137,
#   'sort_key': 2311.125},
#  {'element_id': '0077926888509918698620149242',
#   'x': 247.0,
#   'y': 1512.0,
#   'width': 96.296875,
#   'height': 24.0,
#   'predicted_label': 'list',
#   'predicted_probability': 0.7585371137,
#   'sort_key': 2311.125},
#  {'element_id': '0478187548509918690064656954',
#   'x': 890.828125,
#   'y': 1429.0,
#   'width': 104.171875,
#   'height': 22.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 2291.78125},
#  {'element_id': '5475451420509918694998572572',
#   'x': 303.046875,
#   'y': 11.5,
#   'width': 51.953125,
#   'height': 41.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 2130.078125},
#  {'element_id': '9872973494509918708712696616',
#   'x': 926.71875,
#   'y': 1573.1875,
#   'width': 151.8125,
#   'height': 14.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 0.8941307664,
#   'sort_key': 2125.375},
#  {'element_id': '9123783475509918706028281925',
#   'x': 1219.171875,
#   'y': 4668.0,
#   'width': 77.484375,
#   'height': 21.0,
#   'predicted_label': 'link',
#   'predicted_probability': 1.0,
#   'sort_key': 1627.171875},
#  {'element_id': '7650673401509918695406443959',
#   'x': 805.0,
#   'y': 341.984375,
#   'width': 259.5625,
#   'height': 4.0,
#   'predicted_label': 'progress',
#   'predicted_probability': 1.0,
#   'sort_key': 1038.25},
#  {'element_id': '3452032179509918692794049743',
#   'x': 893.671875,
#   'y': 11.0,
#   'width': 30.0,
#   'height': 30.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9997431636,
#   'sort_key': 900.0},
#  {'element_id': '7795596994509918694396151541',
#   'x': 1210.1875,
#   'y': 1234.484375,
#   'width': 30.0,
#   'height': 30.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9976428151,
#   'sort_key': 900.0},
#  {'element_id': '8210417075509918694813418909',
#   'x': 1194.5625,
#   'y': 232.625,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '0227536780509918690585901422',
#   'x': 1296.84375,
#   'y': 176.875,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '9030903472509918692576418568',
#   'x': 1296.84375,
#   'y': 204.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '8755637048509918698703608435',
#   'x': 1245.703125,
#   'y': 176.875,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '9125269999509918694140056443',
#   'x': 1194.5625,
#   'y': 288.375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '5302232976509918690128384441',
#   'x': 1296.84375,
#   'y': 288.375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '1132915058509918696361170149',
#   'x': 1296.84375,
#   'y': 260.5,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '7604852208509918690010545421',
#   'x': 1245.703125,
#   'y': 232.625,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '3562004965509918691953179287',
#   'x': 1194.5625,
#   'y': 260.5,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '7030114539509918694106548281',
#   'x': 1245.703125,
#   'y': 204.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '6757265253509918691686018310',
#   'x': 1245.703125,
#   'y': 288.375,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '6231136737509918695168942947',
#   'x': 1194.5625,
#   'y': 204.75,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '3327302244509918691635033684',
#   'x': 1245.703125,
#   'y': 260.5,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '4744174223509918691094047658',
#   'x': 1296.84375,
#   'y': 232.625,
#   'width': 24.0,
#   'height': 24.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 576.0},
#  {'element_id': '6572285310509918690593515025',
#   'x': 855.546875,
#   'y': 694.5,
#   'width': 20.0,
#   'height': 20.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 400.0},
#  {'element_id': '7295769401509918699674769984',
#   'x': 792.0,
#   'y': 694.5,
#   'width': 20.0,
#   'height': 20.0,
#   'predicted_label': 'switch',
#   'predicted_probability': 1.0,
#   'sort_key': 400.0},
#  {'element_id': '8542947045509918693781853450',
#   'x': 1238.0,
#   'y': 585.0,
#   'width': 8.0,
#   'height': 8.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 64.0}]
# CPU times: user 83.6 ms, sys: 23.1 ms, total: 107 ms
# Wall time: 3.12 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id           x            y       width  \
# 0  4327984726509918692332797690     0.00000    64.000000  1500.00000
# 1  1326173598509918692930488157   781.00000  1462.000000   443.18750
# 2  0248896804509918700428861514   577.65625  3173.984375   343.65625
# 3  4141022400509918704470580027   170.00000  5435.000000   560.00000
# 4  3070214874509918693609454099  1180.00000   736.000000   360.00000
#
#         height predicted_label  predicted_probability      sort_key tag_name
# 0  5177.000000      radiogroup               0.999964  7.765500e+06     MAIN
# 1   434.375000      radiogroup               0.999931  1.925096e+05     CODE
# 2   162.031250           table               1.000000  5.568305e+04    TABLE
# 3    72.500000      text-field               0.999599  4.060000e+04     FORM
# 4    86.015625       accordion               1.000000  3.096562e+04      DIV

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))

# %%
PREDICT_URL = 'http://localhost:5050/get_tasks_statuses'
response = requests.post(
    PREDICT_URL, data=dataset_json[10]
)

# %%
response.json()
# Out:
# {'exc': 'Expecting value: line 1 column 1 (char 0)'}
