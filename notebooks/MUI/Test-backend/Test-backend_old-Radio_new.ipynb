# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'Old_model/model')
dataset_path = os.path.join(prefix, "jdi-qasp-ml", "data/mui_dataset")

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-11-11 21:11:08,843 -INFO - config.py:31 - Module utils.config was loaded
# 2021-11-11 21:11:08,882 -INFO - common.py:127 - Module utils.common is loaded...
# 2021-11-11 21:11:08,884 -INFO - dataset_builder.py:217 - dataset package is loaded...

# %%
from utils.config import logger

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'material-ui-Radio'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click() #path to elements packs
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click() #path to mui
        driver.find_element_by_xpath("//*[@id='__next']/div/div/div[1]/div/div[7]/div").click() #path to elements
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=False, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-11-11 21:11:20,126 -INFO - dataset_builder.py:82 - Dataset name: material-ui-Radio
# 2021-11-11 21:11:20,128 -INFO - dataset_builder.py:92 - Create directories to save the dataset
# 2021-11-11 21:11:20,131 -INFO - dataset_builder.py:130 - Creating driver
# 2021-11-11 21:11:23,217 -INFO - dataset_builder.py:141 - Chrome web driver is created
# 2021-11-11 21:11:23,375 -INFO - 1390990284.py:10 - getting url: https://jdi-testing.github.io/jdi-light/
# ipykernel_launcher:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ipykernel_launcher:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2021-11-11 21:11:36,008 -INFO - common.py:30 - Window maximized
# 2021-11-11 21:11:43,014 -INFO - dataset_builder.py:144 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/material-ui-Radio.png
# 2021-11-11 21:11:43,428 -INFO - dataset_builder.py:188 - Collect features using JS script
# 2021-11-11 21:11:43,943 -INFO - dataset_builder.py:196 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/material-ui-Radio.html
# 2021-11-11 21:11:43,958 -INFO - dataset_builder.py:206 - Save parquet to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/material-ui-Radio.pkl
# 2021-11-11 21:11:43,960 -INFO - dataset_builder.py:208 - No attributes: (11, 13)
# 2021-11-11 21:11:44,224 -INFO - dataset_builder.py:107 - Close web driver

# %%
df = pd.read_pickle(f"{dataset_path}/df/{DATASET_NAME}.pkl")
df["label_text"] = df.attributes.apply(
                        lambda x: x.get("data-label") if x is not None else "n/a"
                    ).fillna("n/a")
df.label_text.unique()
# Out:
# array(['n/a'], dtype=object)

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '0983043861543034365818027799',
#   'x': 0.0,
#   'y': 48.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '6317982208543034360421269531',
#   'x': 0.0,
#   'y': 1824.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '8215065674543034360785832833',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '6131892740543034362414183202',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '1590222637543034364167361963',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '2580277783543034369688351614',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4992488739543034364873361904',
#   'x': 0.0,
#   'y': 1632.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9997888207,
#   'sort_key': 11760.0},
#  {'element_id': '4396345709543034369966434489',
#   'x': 0.0,
#   'y': 1584.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '0356005163543034364447259330',
#   'x': 0.0,
#   'y': 1536.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '1333268972543034368272019664',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4022910148543034363255373341',
#   'x': 0.0,
#   'y': 1440.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.8550747037,
#   'sort_key': 11760.0},
#  {'element_id': '2337100899543034361398754197',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '5605912013543034363176678273',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '0571834610543034361734982091',
#   'x': 0.0,
#   'y': 96.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '1130161302543034366062139510',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '5520473341543034362401835725',
#   'x': 0.0,
#   'y': 1440.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '0803430864543034365584978833',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '3000802313543034365596161906',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '2564627224543034369982855885',
#   'x': 0.0,
#   'y': 1872.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '5618533468543034360113508105',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '2818532773543034363368221638',
#   'x': 0.0,
#   'y': 1920.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '8319677312543034363171457109',
#   'x': 0.0,
#   'y': 2640.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '3445495415543034365158556908',
#   'x': 0.0,
#   'y': 2592.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4238801323543034368766385610',
#   'x': 0.0,
#   'y': 2544.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '7144227234543034366456716695',
#   'x': 0.0,
#   'y': 2496.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4702986894543034369514106386',
#   'x': 0.0,
#   'y': 2448.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4621608105543034360523119456',
#   'x': 0.0,
#   'y': 2400.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '2597357410543034363512942420',
#   'x': 0.0,
#   'y': 2352.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '3492542952543034368930670637',
#   'x': 0.0,
#   'y': 2304.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '0182089169543034361074514475',
#   'x': 0.0,
#   'y': 2256.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.8550747037,
#   'sort_key': 11760.0},
#  {'element_id': '5492722170543034368781979545',
#   'x': 0.0,
#   'y': 2208.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '5889359164543034363475978152',
#   'x': 0.0,
#   'y': 2160.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '5808789900543034364388765079',
#   'x': 0.0,
#   'y': 2112.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '9372917774543034361121805113',
#   'x': 0.0,
#   'y': 2064.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '5144631277543034362064142371',
#   'x': 0.0,
#   'y': 2016.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '2109066212543034360070537028',
#   'x': 0.0,
#   'y': 1968.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.8550747037,
#   'sort_key': 11760.0},
#  {'element_id': '9265223281543034361861310015',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4092669264543034361805652772',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4430432983543034369091150048',
#   'x': 0.0,
#   'y': 1248.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999933243,
#   'sort_key': 11760.0},
#  {'element_id': '4600761470543034368012545121',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999935627,
#   'sort_key': 11760.0},
#  {'element_id': '1251084759543034366879249617',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '2835415390543034368972314789',
#   'x': 0.0,
#   'y': 672.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9997888207,
#   'sort_key': 11760.0},
#  {'element_id': '4000754920543034368846162790',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4562145974543034367612382582',
#   'x': 0.0,
#   'y': 1152.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '3576178415543034367956170415',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4170961537543034360165684694',
#   'x': 0.0,
#   'y': 576.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '9685878689543034366389832992',
#   'x': 0.0,
#   'y': 528.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9997888207,
#   'sort_key': 11760.0},
#  {'element_id': '1894713293543034364842691032',
#   'x': 0.0,
#   'y': 480.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '9067770802543034364006893543',
#   'x': 0.0,
#   'y': 432.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '2083466764543034367158632645',
#   'x': 0.0,
#   'y': 384.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '7484581839543034362137526646',
#   'x': 0.0,
#   'y': 336.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '8908414139543034363264778638',
#   'x': 0.0,
#   'y': 288.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '8841451427543034361375763492',
#   'x': 0.0,
#   'y': 240.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4273437663543034365027216059',
#   'x': 0.0,
#   'y': 192.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4914080198543034365147556347',
#   'x': 0.0,
#   'y': 144.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '0195669203543034362777371751',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '9892330315543034365066392404',
#   'x': 0.0,
#   'y': 576.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999722242,
#   'sort_key': 11760.0},
#  {'element_id': '0035467139543034365192272546',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4014875233543034367139195272',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '2825378997543034365531959665',
#   'x': 0.0,
#   'y': 1104.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '1027745441543034360753015341',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '5888731822543034368536441838',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '6010736955543034360896202047',
#   'x': 0.0,
#   'y': 960.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.8550747037,
#   'sort_key': 11760.0},
#  {'element_id': '1687736794543034360928962155',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '5479671438543034366978181932',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '5780252367543034360656834196',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4368508769543034364346170688',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '0554600254543034364695088118',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9997888207,
#   'sort_key': 11760.0},
#  {'element_id': '5938744891543034369423379648',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '3927415943543034363059769452',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '4513643053543034366285195283',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '1124759666543034367130625843',
#   'x': 0.0,
#   'y': 960.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '3761387334543034365751568538',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '7045160670543034365693883695',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9159721136,
#   'sort_key': 11760.0},
#  {'element_id': '5860698199543034374295229676',
#   'x': 293.0,
#   'y': 577.859375,
#   'width': 171.796875,
#   'height': 36.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.999992609,
#   'sort_key': 6184.6875},
#  {'element_id': '6095963875543034374419015607',
#   'x': 324.0,
#   'y': 514.859375,
#   'width': 76.5625,
#   'height': 24.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9755651951,
#   'sort_key': 1837.5},
#  {'element_id': '8206265882543034361558072460',
#   'x': 337.375,
#   'y': 138.171875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999853373,
#   'sort_key': 1764.0},
#  {'element_id': '7956124466543034360477227104',
#   'x': 438.609375,
#   'y': 138.171875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999853373,
#   'sort_key': 1764.0},
#  {'element_id': '1075996701543034367123201519',
#   'x': 258.0,
#   'y': 138.171875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999853373,
#   'sort_key': 1764.0},
#  {'element_id': '2421734889543034376361120300',
#   'x': 285.0,
#   'y': 317.015625,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999853373,
#   'sort_key': 1764.0},
#  {'element_id': '8925600419543034375583683266',
#   'x': 394.21875,
#   'y': 305.015625,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999853373,
#   'sort_key': 1764.0},
#  {'element_id': '5123705524543034378360641377',
#   'x': 446.9375,
#   'y': 293.015625,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999853373,
#   'sort_key': 1764.0},
#  {'element_id': '6020361315543034375816358377',
#   'x': 499.65625,
#   'y': 305.015625,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999853373,
#   'sort_key': 1764.0},
#  {'element_id': '3960390300543034379009347874',
#   'x': 282.0,
#   'y': 463.859375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999853373,
#   'sort_key': 1764.0},
#  {'element_id': '9235374237543034379214076252',
#   'x': 282.0,
#   'y': 505.859375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999853373,
#   'sort_key': 1764.0},
#  {'element_id': '8865984617543034374039230507',
#   'x': 522.90625,
#   'y': 138.171875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999853373,
#   'sort_key': 1764.0},
#  {'element_id': '7831134998543034376003640643',
#   'x': 324.0,
#   'y': 472.859375,
#   'width': 67.203125,
#   'height': 24.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9755651951,
#   'sort_key': 1612.875}]
# CPU times: user 60.6 ms, sys: 12.8 ms, total: 73.4 ms
# Wall time: 983 ms

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id    x       y  width  height predicted_label  \
# 0  0983043861543034365818027799  0.0    48.0  245.0    48.0          button
# 1  6317982208543034360421269531  0.0  1824.0  245.0    48.0          button
# 2  8215065674543034360785832833  0.0  1728.0  245.0    48.0          button
# 3  6131892740543034362414183202  0.0  1680.0  245.0    48.0          button
# 4  1590222637543034364167361963  0.0  1728.0  245.0    48.0          button
#
#    predicted_probability  sort_key tag_name
# 0               0.915972   11760.0      DIV
# 1               0.915972   11760.0      DIV
# 2               0.915972   11760.0      DIV
# 3               0.915972   11760.0      DIV
# 4               0.915972   11760.0      DIV

# %%
preds
# Out:
#                       element_id          x            y       width  height  \
# 0   0983043861543034365818027799    0.00000    48.000000  245.000000    48.0
# 1   6317982208543034360421269531    0.00000  1824.000000  245.000000    48.0
# 2   8215065674543034360785832833    0.00000  1728.000000  245.000000    48.0
# 3   6131892740543034362414183202    0.00000  1680.000000  245.000000    48.0
# 4   1590222637543034364167361963    0.00000  1728.000000  245.000000    48.0
# ..                           ...        ...          ...         ...     ...
# 82  6020361315543034375816358377  499.65625   305.015625   42.000000    42.0
# 83  3960390300543034379009347874  282.00000   463.859375   42.000000    42.0
# 84  9235374237543034379214076252  282.00000   505.859375   42.000000    42.0
# 85  8865984617543034374039230507  522.90625   138.171875   42.000000    42.0
# 86  7831134998543034376003640643  324.00000   472.859375   67.203125    24.0
#
#    predicted_label  predicted_probability   sort_key
# 0           button               0.915972  11760.000
# 1           button               0.915972  11760.000
# 2           button               0.915972  11760.000
# 3           button               0.915972  11760.000
# 4           button               0.915972  11760.000
# ..             ...                    ...        ...
# 82     radiobutton               0.999985   1764.000
# 83     radiobutton               0.999985   1764.000
# 84     radiobutton               0.999985   1764.000
# 85     radiobutton               0.999985   1764.000
# 86        checkbox               0.975565   1612.875
#
# [87 rows x 8 columns]

# %%
from_pkl = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')
from_pkl[from_pkl.element_id == '1049561488694071642269580342']
# Out:
# Empty DataFrame
# Columns: [attributes, displayed, element_id, height, onmouseenter, onmouseover, parent_id, style, tag_name, text, width, x, y]
# Index: []

# %%
# set(df.element_id.values).intersection(set(preds.element_id.values))

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
    axes.add_patch(patch)
    
    axes.text(r.x*2, r.y*2, 
              r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
              backgroundcolor='black', 
              color='white',
              bbox=dict(alpha=0.5))

# %%
print(pd.read_pickle("/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/EXTRACT_ATTRIBUTES_LIST.pkl"))
# Out:
# ['fill', 'disabled', 'title', 'data-field', 'tabindex', 'stroke-width', 'cy', 'text-anchor', 'data-rowindex', 'typenumber', 'data-jss', 'readonly', 'novalidate', 'aria-orientation', 'content', 'aria-colcount', 'rel', 'data-meta', 'data-test', 'data-id', 'aria-disabled', 'aria-multiselectable', 'aria-current', 'rows', 'charset', 'aria-sort', 'aria-valuemax', 'viewBox', 'lang', 'checked', 'aria-haspopup', 'focusable', 'id', 'colspan', 'aria-checked', 'aria-hidden', 'data-value', 'scope', 'data-rowselected', 'for', 'aria-invalid', 'y', 'aria-valuemin', 'draggable', 'src', 'aria-rowindex', 'aria-labelledby', 'data-label', 'aria-selected', 'aria-valuenow', 'name', 'menuprops', 'r', 'multiple', 'required', 'aria-controls', 'value', 'x', 'aria-rowcount', 'data-index', 'data-colindex', 'data-indeterminate', 'autocomplete', 'cx', 'aria-expanded', 'd', 'data-shrink', 'aria-colindex', 'data-mode', 'placeholder', 'aria-label', 'aria-describedby', 'direction', 'style']

# %%
df["attributes"]
# Out:
# 0                                         {'lang': 'en'}
# 1                                                   None
# 2      {'href': 'https://fonts.googleapis.com/css?fam...
# 3                                   {'charset': 'utf-8'}
# 4                                                   None
#                              ...
# 639    {'src': '/jdi-light/material/_next/static/chun...
# 640    {'src': '/jdi-light/material/_next/static/chun...
# 641    {'src': '/jdi-light/material/_next/static/chun...
# 642    {'src': '/jdi-light/material/_next/static/chun...
# 643    {'src': '/jdi-light/material/_next/static/chun...
# Name: attributes, Length: 644, dtype: object
