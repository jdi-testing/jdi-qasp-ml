# %%
import os, sys, re, gc, glob

# set working dir
WORKING_DIR = re.sub('jdi-qasp-ml.*$','',os.path.normpath(os.getcwd())) + 'jdi-qasp-ml'
os.chdir(WORKING_DIR)

import torch
from torch.utils.data import Dataset, DataLoader

from tqdm.auto import tqdm, trange
from sklearn.metrics import confusion_matrix
import json

import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
# %matplotlib inline

from tqdm.auto import tqdm, trange
from utils import JDNDataset, JDIModel, get_grey_image, assign_labels, logger, maximize_window, DatasetBuilder, load_gray_image
from time import sleep
from flask import jsonify

import datetime as dt
import requests

START_DT = dt.datetime.now()

# %%
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
PREDICT_URL = 'http://localhost:5000/predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
HEADLESS = True #False

# %% [markdown]
# ### getting json

# %%
DATASET_NAME = 'dummy'

# %%
class JDIDatasetBuilder(DatasetBuilder):

    def setUp(self, driver):
        self.logger.info(f'getting page')
        driver.get(SITE_URL)
        
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        
        driver.find_element_by_link_text("Elements packs").click()
        driver.find_element_by_link_text("HTML 5").click()
        sleep(WAIT_TIME_SECONDS)
        
#         driver.find_element_by_link_text("Service").click()
#         driver.find_element_by_link_text("Complex Table").click()
        maximize_window(driver=driver)
        sleep(WAIT_TIME_SECONDS)
        

with JDIDatasetBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=True) as builder:
    elements_df = builder.dataset
    plt.imshow(plt.imread(f'dataset/images/{DATASET_NAME}.png'))
    login_json = builder.dataset_json
# Out:
# 2021-06-21 13:23:02,670 -WARNING - dataset_builder:dataset_builder.py:75 - The default dataset name "dummy" will be used
# 2021-06-21 13:23:02,671 -INFO - dataset_builder:dataset_builder.py:86 - Create directories to save the dataset
# 2021-06-21 13:23:02,672 -INFO - dataset_builder:dataset_builder.py:123 - Creating driver
# 2021-06-21 13:23:03,929 -INFO - dataset_builder:dataset_builder.py:131 - Chrome web driver is created
# 2021-06-21 13:23:03,930 -INFO - <ipython-input-14-2adf1649d110>:<ipython-input-14-2adf1649d110>:4 - getting page
# 2021-06-21 13:23:21,651 -INFO - common:common.py:75 - Window maximized
# 2021-06-21 13:23:28,666 -INFO - dataset_builder:dataset_builder.py:134 - save scrinshot: dataset/images/dummy.png
# 2021-06-21 13:23:29,074 -INFO - dataset_builder:dataset_builder.py:178 - Collect features using JS script
# 2021-06-21 13:23:29,582 -INFO - dataset_builder:dataset_builder.py:186 - Save html to dataset/html/dummy.html
# 2021-06-21 13:23:29,592 -INFO - dataset_builder:dataset_builder.py:196 - Save parquet to dataset/df/dummy.parquet
# 2021-06-21 13:23:29,594 -INFO - dataset_builder:dataset_builder.py:198 - No attributes: (254, 13)
# 2021-06-21 13:23:29,867 -INFO - dataset_builder:dataset_builder.py:101 - Close web driver

# %%
PREDICT_URL
# Out:
# 'http://localhost:5000/predict'

# %% [markdown]
# ### Predict: sending json to backend and getting predictions

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(login_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '3585704704710090787620030680',
#   'x': 240.0,
#   'y': 1557.0,
#   'width': 217.0,
#   'height': 56.0,
#   'predicted_label': 'textarea',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 12152.0},
#  {'element_id': '4609446439710090789916845988',
#   'x': 600.140625,
#   'y': 5419.0,
#   'width': 492.015625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 8856.28125},
#  {'element_id': '3520630474710090784073820446',
#   'x': 502.859375,
#   'y': 0.0,
#   'width': 140.484375,
#   'height': 60.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 8429.0625},
#  {'element_id': '2466534907710090787953342253',
#   'x': 600.140625,
#   'y': 3617.0,
#   'width': 462.5,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 8325.0},
#  {'element_id': '5733966996710090780627448477',
#   'x': 600.140625,
#   'y': 3873.0,
#   'width': 462.5,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 8325.0},
#  {'element_id': '0807157760710090786634248008',
#   'x': 600.140625,
#   'y': 5935.0,
#   'width': 453.765625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 8167.78125},
#  {'element_id': '9003969069710090787781378474',
#   'x': 600.140625,
#   'y': 5247.0,
#   'width': 446.53125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 8037.5625},
#  {'element_id': '4172516062710090780886357840',
#   'x': 600.140625,
#   'y': 4641.0,
#   'width': 440.375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7926.75},
#  {'element_id': '8224745391710090786363004293',
#   'x': 600.140625,
#   'y': 5763.0,
#   'width': 438.15625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7886.8125},
#  {'element_id': '6839807837710090783862686589',
#   'x': 600.140625,
#   'y': 4185.0,
#   'width': 437.609375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7876.96875},
#  {'element_id': '8539205418710090781806467149',
#   'x': 600.140625,
#   'y': 4413.0,
#   'width': 436.59375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7858.6875},
#  {'element_id': '8585894212710090782918585766',
#   'x': 600.140625,
#   'y': 5591.0,
#   'width': 434.1875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7815.375},
#  {'element_id': '2963677435710090787906666967',
#   'x': 0.0,
#   'y': 60.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 7800.0},
#  {'element_id': '2000982225710090788758811839',
#   'x': 0.0,
#   'y': 101.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 7800.0},
#  {'element_id': '3257290248710090786681821544',
#   'x': 0.0,
#   'y': 142.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9999992847,
#   'sort_key': 7800.0},
#  {'element_id': '9429957530710090781817431633',
#   'x': 0.0,
#   'y': 183.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 7800.0},
#  {'element_id': '7564714614710090784134156165',
#   'x': 0.0,
#   'y': 224.0,
#   'width': 200.0,
#   'height': 39.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9999990463,
#   'sort_key': 7800.0},
#  {'element_id': '6074596568710090783470479462',
#   'x': 600.140625,
#   'y': 1225.0,
#   'width': 429.484375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9161877632,
#   'sort_key': 7730.71875},
#  {'element_id': '8881745789710090786115770144',
#   'x': 600.140625,
#   'y': 1969.0,
#   'width': 425.265625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7654.78125},
#  {'element_id': '0698378493710090787562048590',
#   'x': 0.0,
#   'y': 415.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 7600.0},
#  {'element_id': '9191370157710090788268354241',
#   'x': 0.0,
#   'y': 453.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 7600.0},
#  {'element_id': '0342451104710090788368307257',
#   'x': 0.0,
#   'y': 491.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 7600.0},
#  {'element_id': '2806121605710090782609921421',
#   'x': 0.0,
#   'y': 529.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 7600.0},
#  {'element_id': '6441347497710090789121047526',
#   'x': 0.0,
#   'y': 377.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 7600.0},
#  {'element_id': '7835711425710090783656136419',
#   'x': 0.0,
#   'y': 301.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 7600.0},
#  {'element_id': '2559332905710090788680761996',
#   'x': 0.0,
#   'y': 263.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.999999404,
#   'sort_key': 7600.0},
#  {'element_id': '9855649967710090784015687134',
#   'x': 0.0,
#   'y': 339.0,
#   'width': 200.0,
#   'height': 38.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 7600.0},
#  {'element_id': '2415397866710090781244064312',
#   'x': 600.140625,
#   'y': 4931.0,
#   'width': 421.25,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7582.5},
#  {'element_id': '9296637087710090786003213847',
#   'x': 600.140625,
#   'y': 1629.0,
#   'width': 418.15625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7526.8125},
#  {'element_id': '9874201601710090783511581545',
#   'x': 600.140625,
#   'y': 3389.0,
#   'width': 413.75,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7447.5},
#  {'element_id': '1265507872710090782641036617',
#   'x': 600.140625,
#   'y': 5075.0,
#   'width': 410.484375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7388.71875},
#  {'element_id': '9317169242710090788686473656',
#   'x': 600.140625,
#   'y': 444.0,
#   'width': 410.3125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7385.625},
#  {'element_id': '9008907156710090789784874737',
#   'x': 287.453125,
#   'y': 0.0,
#   'width': 121.859375,
#   'height': 60.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 7311.5625},
#  {'element_id': '5622252257710090788554219213',
#   'x': 600.140625,
#   'y': 3105.0,
#   'width': 405.03125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7290.5625},
#  {'element_id': '7354689275710090785279503872',
#   'x': 600.140625,
#   'y': 2453.0,
#   'width': 405.03125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7290.5625},
#  {'element_id': '9197697570710090786494907058',
#   'x': 600.140625,
#   'y': 2765.0,
#   'width': 405.03125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7290.5625},
#  {'element_id': '2372279879710090788527266087',
#   'x': 598.25,
#   'y': 5391.0,
#   'width': 404.25,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7276.5},
#  {'element_id': '9328549151710090782777798617',
#   'x': 1035.46875,
#   'y': 0.0,
#   'width': 119.53125,
#   'height': 60.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.999999404,
#   'sort_key': 7171.875},
#  {'element_id': '0700039229710090784536470424',
#   'x': 600.140625,
#   'y': 2225.0,
#   'width': 393.1875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 7077.375},
#  {'element_id': '7409521998710090789174272971',
#   'x': 322.984375,
#   'y': 5352.0,
#   'width': 170.796875,
#   'height': 40.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 0.9999958277,
#   'sort_key': 6831.875},
#  {'element_id': '6329891124710090786787433007',
#   'x': 600.140625,
#   'y': 941.0,
#   'width': 377.453125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6794.15625},
#  {'element_id': '2171465226710090787869996223',
#   'x': 598.25,
#   'y': 3845.0,
#   'width': 374.515625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6741.28125},
#  {'element_id': '8412858135710090784768735312',
#   'x': 598.25,
#   'y': 3589.0,
#   'width': 374.515625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6741.28125},
#  {'element_id': '7219747829710090784772329984',
#   'x': 598.25,
#   'y': 1197.0,
#   'width': 367.6875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9161877632,
#   'sort_key': 6618.375},
#  {'element_id': '7021174040710090788189290724',
#   'x': 240.0,
#   'y': 5891.0,
#   'width': 300.0,
#   'height': 22.0,
#   'predicted_label': 'numberselector',
#   'predicted_probability': 0.9999998808,
#   'sort_key': 6600.0},
#  {'element_id': '4011967161710090784944446469',
#   'x': 598.25,
#   'y': 5907.0,
#   'width': 364.65625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6563.8125},
#  {'element_id': '9541141994710090788687640497',
#   'x': 598.25,
#   'y': 5219.0,
#   'width': 358.21875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6447.9375},
#  {'element_id': '8283752815710090785180580985',
#   'x': 598.25,
#   'y': 4613.0,
#   'width': 352.0625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6337.125},
#  {'element_id': '8627261369710090785510555213',
#   'x': 598.25,
#   'y': 5735.0,
#   'width': 350.015625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6300.28125},
#  {'element_id': '1029386746710090781130867736',
#   'x': 598.25,
#   'y': 4157.0,
#   'width': 349.265625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6286.78125},
#  {'element_id': '8822897359710090788977565610',
#   'x': 598.25,
#   'y': 4385.0,
#   'width': 347.921875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6262.59375},
#  {'element_id': '1805267626710090782996187581',
#   'x': 598.25,
#   'y': 5563.0,
#   'width': 345.75,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6223.5},
#  {'element_id': '5298599917710090784734021189',
#   'x': 598.25,
#   'y': 5047.0,
#   'width': 345.140625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6212.53125},
#  {'element_id': '4537155667710090786174944581',
#   'x': 598.25,
#   'y': 1941.0,
#   'width': 344.34375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6198.1875},
#  {'element_id': '4060091426710090787845458323',
#   'x': 598.25,
#   'y': 2737.0,
#   'width': 338.375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6090.75},
#  {'element_id': '7780579427710090789430117363',
#   'x': 598.25,
#   'y': 3077.0,
#   'width': 338.375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 6090.75},
#  {'element_id': '4315651118710090780190876933',
#   'x': 240.0,
#   'y': 5203.0,
#   'width': 150.796875,
#   'height': 40.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 0.9999952316,
#   'sort_key': 6031.875},
#  {'element_id': '8821323057710090789627197368',
#   'x': 240.0,
#   'y': 468.0,
#   'width': 171.90625,
#   'height': 34.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999901056,
#   'sort_key': 5844.8125},
#  {'element_id': '7423291271710090781165017001',
#   'x': 409.3125,
#   'y': 0.0,
#   'width': 93.546875,
#   'height': 60.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9999040365,
#   'sort_key': 5612.8125},
#  {'element_id': '2313166541710090788983880095',
#   'x': 240.0,
#   'y': 416.0,
#   'width': 163.421875,
#   'height': 34.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999802113,
#   'sort_key': 5556.34375},
#  {'element_id': '9849096712710090786388784036',
#   'x': 240.0,
#   'y': 593.0,
#   'width': 160.984375,
#   'height': 34.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.8482085466,
#   'sort_key': 5473.46875},
#  {'element_id': '9258603800710090789503405729',
#   'x': 598.25,
#   'y': 4903.0,
#   'width': 301.3125,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 5423.625},
#  {'element_id': '3487993904710090789552278530',
#   'x': 598.25,
#   'y': 1601.0,
#   'width': 298.09375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 5365.6875},
#  {'element_id': '5262883421710090787711089577',
#   'x': 318.421875,
#   'y': 5008.0,
#   'width': 132.796875,
#   'height': 40.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 0.9999955893,
#   'sort_key': 5311.875},
#  {'element_id': '3405049517710090784501466859',
#   'x': 598.25,
#   'y': 3361.0,
#   'width': 294.34375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 5298.1875},
#  {'element_id': '9455308550710090780473000438',
#   'x': 240.0,
#   'y': 1617.0,
#   'width': 139.0,
#   'height': 38.0,
#   'predicted_label': 'textarea',
#   'predicted_probability': 0.9999997616,
#   'sort_key': 5282.0},
#  {'element_id': '9769018537710090789297882594',
#   'x': 598.25,
#   'y': 416.0,
#   'width': 290.375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 5226.75},
#  {'element_id': '7109719296710090781839577157',
#   'x': 240.0,
#   'y': 1897.0,
#   'width': 237.0,
#   'height': 22.0,
#   'predicted_label': 'fileinput',
#   'predicted_probability': 0.7873506546,
#   'sort_key': 5214.0},
#  {'element_id': '1656494976710090782616249655',
#   'x': 240.0,
#   'y': 1919.0,
#   'width': 237.0,
#   'height': 22.0,
#   'predicted_label': 'fileinput',
#   'predicted_probability': 0.7839953899,
#   'sort_key': 5214.0},
#  {'element_id': '4532850476710090784548974683',
#   'x': 323.09375,
#   'y': 2670.0,
#   'width': 70.015625,
#   'height': 74.0,
#   'predicted_label': 'selector',
#   'predicted_probability': 0.9999980927,
#   'sort_key': 5181.15625},
#  {'element_id': '9308166638710090780311380173',
#   'x': 240.0,
#   'y': 645.0,
#   'width': 151.546875,
#   'height': 34.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999880791,
#   'sort_key': 5152.59375},
#  {'element_id': '6488787237710090785625037674',
#   'x': 598.25,
#   'y': 2425.0,
#   'width': 285.1875,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 5133.375},
#  {'element_id': '2085503088710090783834174038',
#   'x': 598.25,
#   'y': 2197.0,
#   'width': 272.890625,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 4912.03125},
#  {'element_id': '3075602678710090780103620857',
#   'x': 240.0,
#   'y': 697.0,
#   'width': 136.609375,
#   'height': 34.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999712706,
#   'sort_key': 4644.71875},
#  {'element_id': '7780977693710090788671101497',
#   'x': 598.25,
#   'y': 913.0,
#   'width': 257.84375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8414088488,
#   'sort_key': 4641.1875},
#  {'element_id': '9988839338710090783370964030',
#   'x': 240.0,
#   'y': 749.0,
#   'width': 134.34375,
#   'height': 34.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9997989535,
#   'sort_key': 4567.6875},
#  {'element_id': '6927802343710090783409073488',
#   'x': 240.0,
#   'y': 541.0,
#   'width': 133.984375,
#   'height': 34.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999935627,
#   'sort_key': 4555.46875},
#  {'element_id': '4828383717710090787934725766',
#   'x': 240.0,
#   'y': 801.0,
#   'width': 121.40625,
#   'height': 34.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.8482085466,
#   'sort_key': 4127.8125},
#  {'element_id': '6669297770710090787631771867',
#   'x': 222.9375,
#   'y': 0.0,
#   'width': 64.515625,
#   'height': 60.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 3870.9375},
#  {'element_id': '1255841091710090786560843081',
#   'x': 308.046875,
#   'y': 5696.0,
#   'width': 137.796875,
#   'height': 24.796875,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 0.9999955893,
#   'sort_key': 3416.9318847656},
#  {'element_id': '4432524316710090782723578514',
#   'x': 326.265625,
#   'y': 1130.0,
#   'width': 155.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 3410.0},
#  {'element_id': '7246129077710090786218317694',
#   'x': 240.0,
#   'y': 3317.0,
#   'width': 155.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 0.9998922348,
#   'sort_key': 3410.0},
#  {'element_id': '9319883847710090786111008518',
#   'x': 317.46875,
#   'y': 1155.0,
#   'width': 155.0,
#   'height': 22.0,
#   'predicted_label': 'textfield',
#   'predicted_probability': 0.9999995232,
#   'sort_key': 3410.0},
#  {'element_id': '5068810008710090786435387439',
#   'x': 255.8125,
#   'y': 3553.0,
#   'width': 180.828125,
#   'height': 18.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999837875,
#   'sort_key': 3254.90625},
#  {'element_id': '7843456758710090785387204926',
#   'x': 344.390625,
#   'y': 5524.0,
#   'width': 68.6875,
#   'height': 40.0,
#   'predicted_label': 'datetimeselector',
#   'predicted_probability': 0.9999957085,
#   'sort_key': 2747.5},
#  {'element_id': '8507172894710090787876710523',
#   'x': 20.0,
#   'y': 16.953125,
#   'width': 86.0,
#   'height': 31.265625,
#   'predicted_label': 'link',
#   'predicted_probability': 0.6153100729,
#   'sort_key': 2688.84375},
#  {'element_id': '7894672848710090780269030178',
#   'x': 356.03125,
#   'y': 3010.0,
#   'width': 73.90625,
#   'height': 34.0,
#   'predicted_label': 'selector',
#   'predicted_probability': 0.9999997616,
#   'sort_key': 2512.8125},
#  {'element_id': '6396778576710090788384981414',
#   'x': 240.0,
#   'y': 1941.0,
#   'width': 112.9375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9997834563,
#   'sort_key': 2032.875},
#  {'element_id': '4666515817710090781971788209',
#   'x': 334.203125,
#   'y': 4836.0,
#   'width': 140.0,
#   'height': 14.0,
#   'predicted_label': 'progressbar',
#   'predicted_probability': 0.9999989271,
#   'sort_key': 1960.0},
#  {'element_id': '4977297246710090788179997490',
#   'x': 118.0,
#   'y': 19.0,
#   'width': 76.9375,
#   'height': 24.0,
#   'predicted_label': 'table',
#   'predicted_probability': 0.8947291374,
#   'sort_key': 1846.5},
#  {'element_id': '8790630648710090787992134608',
#   'x': 327.453125,
#   'y': 2358.0,
#   'width': 76.0,
#   'height': 22.0,
#   'predicted_label': 'selector',
#   'predicted_probability': 1.0,
#   'sort_key': 1672.0},
#  {'element_id': '5688532820710090784449792017',
#   'x': 406.265625,
#   'y': 2358.0,
#   'width': 76.0,
#   'height': 22.0,
#   'predicted_label': 'selector',
#   'predicted_probability': 1.0,
#   'sort_key': 1672.0},
#  {'element_id': '0866072300710090785881033796',
#   'x': 240.0,
#   'y': 4678.0,
#   'width': 100.0,
#   'height': 16.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0},
#  {'element_id': '3525963473710090788487529561',
#   'x': 240.0,
#   'y': 4719.0,
#   'width': 100.0,
#   'height': 16.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0},
#  {'element_id': '8318939839710090784080420583',
#   'x': 240.0,
#   'y': 4760.0,
#   'width': 100.0,
#   'height': 16.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0},
#  {'element_id': '1556928813710090784412068129',
#   'x': 240.0,
#   'y': 4799.0,
#   'width': 100.0,
#   'height': 16.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 1600.0},
#  {'element_id': '3778966497710090785744355645',
#   'x': 20.0,
#   'y': 21.0,
#   'width': 86.0,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.8790593147,
#   'sort_key': 1548.0},
#  {'element_id': '4045193232710090787343886798',
#   'x': 255.8125,
#   'y': 3809.0,
#   'width': 80.890625,
#   'height': 18.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999768734,
#   'sort_key': 1456.03125},
#  {'element_id': '5713362036710090780306227226',
#   'x': 255.8125,
#   'y': 3861.0,
#   'width': 74.65625,
#   'height': 18.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999768734,
#   'sort_key': 1343.8125},
#  {'element_id': '9901507860710090787157194798',
#   'x': 255.8125,
#   'y': 3913.0,
#   'width': 69.5,
#   'height': 18.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999768734,
#   'sort_key': 1251.0},
#  {'element_id': '3176694836710090787807279852',
#   'x': 240.0,
#   'y': 874.0,
#   'width': 61.609375,
#   'height': 18.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.999856472,
#   'sort_key': 1108.96875},
#  {'element_id': '1393104731710090786350758421',
#   'x': 255.8125,
#   'y': 4199.0,
#   'width': 56.28125,
#   'height': 18.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999990463,
#   'sort_key': 1013.0625},
#  {'element_id': '4662962852710090781779073996',
#   'x': 240.0,
#   'y': 4318.0,
#   'width': 44.0,
#   'height': 23.0,
#   'predicted_label': 'colorpicker',
#   'predicted_probability': 1.0,
#   'sort_key': 1012.0},
#  {'element_id': '6278028255710090786426081471',
#   'x': 240.0,
#   'y': 4345.0,
#   'width': 44.0,
#   'height': 23.0,
#   'predicted_label': 'colorpicker',
#   'predicted_probability': 1.0,
#   'sort_key': 1012.0},
#  {'element_id': '6388080945710090784324525605',
#   'x': 255.8125,
#   'y': 3887.0,
#   'width': 55.703125,
#   'height': 18.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999768734,
#   'sort_key': 1002.65625},
#  {'element_id': '0253070502710090786323209046',
#   'x': 255.8125,
#   'y': 4147.0,
#   'width': 53.75,
#   'height': 18.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999990463,
#   'sort_key': 967.5},
#  {'element_id': '0925646818710090790866983292',
#   'x': 1115.890625,
#   'y': 6169.0,
#   'width': 64.109375,
#   'height': 15.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 961.640625},
#  {'element_id': '7046436934710090785188478290',
#   'x': 255.8125,
#   'y': 3835.0,
#   'width': 46.328125,
#   'height': 18.0,
#   'predicted_label': 'checkbox',
#   'predicted_probability': 0.9999768734,
#   'sort_key': 833.90625},
#  {'element_id': '8117852985710090789520412072',
#   'x': 255.8125,
#   'y': 4173.0,
#   'width': 45.578125,
#   'height': 18.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999990463,
#   'sort_key': 820.40625},
#  {'element_id': '1786671267710090789656766090',
#   'x': 1160.0,
#   'y': 20.0,
#   'width': 40.0,
#   'height': 20.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9999980927,
#   'sort_key': 800.0},
#  {'element_id': '9409187113710090781020256164',
#   'x': 255.8125,
#   'y': 4121.0,
#   'width': 41.859375,
#   'height': 18.0,
#   'predicted_label': 'radiobutton',
#   'predicted_probability': 0.9999990463,
#   'sort_key': 753.46875},
#  {'element_id': '2968844245710090787281338263',
#   'x': 266.734375,
#   'y': 4624.0,
#   'width': 100.0,
#   'height': 7.0,
#   'predicted_label': 'slider',
#   'predicted_probability': 1.0,
#   'sort_key': 700.0},
#  {'element_id': '6031166023710090799234609417',
#   'x': 1052.71875,
#   'y': 6169.0,
#   'width': 30.265625,
#   'height': 15.0,
#   'predicted_label': 'link',
#   'predicted_probability': 0.9947745204,
#   'sort_key': 453.984375},
#  {'element_id': '9196057037710090780352829883',
#   'x': 1000.46875,
#   'y': 20.0,
#   'width': 20.0,
#   'height': 20.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999758005,
#   'sort_key': 400.0}]
# Wall time: 3.36 s

# %%
response
# Out:
# <Response [200]>

# %%
print('Elapsed time:', dt.datetime.now() - START_DT)
# Out:
# Elapsed time: 0:00:31.184207

# %%
predictions_df = pd.DataFrame(json.loads(response.text))

# %%
img = load_gray_image(f'dataset/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    patch = Rectangle((r.x, r.y), r.width, r.height, alpha=.5, color='red')
    axes.add_patch(patch)
    
    axes.text(r.x, r.y, r.predicted_label + ':' +str(round(r.predicted_probability, 3)), backgroundcolor='black', color='white')
