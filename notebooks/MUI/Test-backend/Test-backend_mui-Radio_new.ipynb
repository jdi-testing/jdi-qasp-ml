# %%
import sys
import os
import re
import gc
import json
import logging
import requests
import itertools
import numba

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse.csr import csr_matrix
from time import sleep


from tqdm.auto import trange, tqdm
from collections import Counter, defaultdict
from scipy.sparse import hstack
import pickle
from torch.utils.data import Dataset
from glob import glob
from IPython.display import display as ipython_displpay
from IPython.display import HTML

# %%
prefix = os.getcwd().split('jdi-qasp-ml')[0]
sys.path.append(os.path.join(prefix, 'jdi-qasp-ml'))

model_path = os.path.join(prefix, 'jdi-qasp-ml', 'MUI_model/model')
dataset_path = os.path.join(prefix, "jdi-qasp-ml", "data/mui_dataset")

# %%
from utils.dataset_builder import DatasetBuilder
from utils.common import maximize_window
# Out:
# 2021-11-24 13:25:21,702 -INFO - config.py:31 - Module utils.config was loaded
# 2021-11-24 13:25:21,726 -INFO - common.py:127 - Module utils.common is loaded...
# 2021-11-24 13:25:21,728 -INFO - dataset_builder.py:244 - dataset package is loaded...

# %%
from utils.config import logger

# %%
WAIT_TIME_SECONDS = 3

# %%
os.getcwd()
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/notebooks/MUI/Test-backend'

# %% [markdown]
# ### Predicting

# %%
DATASET_NAME = 'material-ui-Radio'
WAIT_TIME_SECONDS = 7
SITE_URL = 'https://jdi-testing.github.io/jdi-light/'
# SITE_URL = 'https://jdi-testing.github.io/jdi-light/material/buttons'
PREDICT_URL = 'http://localhost:5050/mui-predict'

LOGIN = 'Roman'
PASSWORD = 'Jdi1234'
SAVE_SCREEN = True
WAIT_TIME_SECONDS = 7
# HEADLESS = True

# %%
dataset_path
# Out:
# '/Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset'

# %%
class DSBuilder(DatasetBuilder):
    def setUp(self, driver):
        """
            This method may be overwitten if you need to login to the site
            and navigate to a specific url,
            otherwise it just returns 
        """
        
        driver.set_window_size(width=1500, height=15000)
        logger.info(f'getting url: {self.url}')
        self.driver.get(self.url)
        driver.find_element_by_id("user-icon").click()
        driver.find_element_by_id("name").send_keys(LOGIN)
        driver.find_element_by_id("password").send_keys(PASSWORD)
        driver.find_element_by_id("login-button").click()
        sleep(WAIT_TIME_SECONDS)
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/a/div").click() #path to elements packs
        driver.find_element_by_xpath("/html/body/div/div[1]/div/div[1]/div/div[1]/ul/li[5]/ul/li[8]/a").click() #path to mui
        driver.find_element_by_xpath("//*[@id='__next']/div/div/div[1]/div/div[7]/div").click() #path to elements
        sleep(3.0)
        maximize_window(driver=driver, extend_pix=0)
        sleep(7.0)
        
with DSBuilder(url=SITE_URL, dataset_name=DATASET_NAME, headless=False, dataset_root_path=dataset_path) as builder:
    df = builder.dataset
    dataset_json = builder.dataset_json
    plt.figure(figsize = (20,5))
    plt.imshow(plt.imread(f'{dataset_path}/images/{DATASET_NAME}.png'))
# Out:
# 2021-11-24 13:25:21,864 -INFO - dataset_builder.py:100 - Dataset name: material-ui-Radio
# 2021-11-24 13:25:21,866 -INFO - dataset_builder.py:110 - Create directories to save the dataset
# 2021-11-24 13:25:21,867 -INFO - dataset_builder.py:150 - Creating driver
# 2021-11-24 13:25:23,905 -INFO - dataset_builder.py:162 - Chrome web driver is created
# 2021-11-24 13:25:24,056 -INFO - 1390990284.py:10 - getting url: https://jdi-testing.github.io/jdi-light/
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if sys.path[0] == '':
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   del sys.path[0]
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   from ipykernel import kernelapp as app
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# /Users/Mikhail_Bulgakov/opt/anaconda3/envs/jdi-qasp-ml/lib/python3.7/site-packages/ipykernel_launcher.py:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 2021-11-24 13:25:36,275 -INFO - common.py:30 - Window maximized
# 2021-11-24 13:25:43,279 -INFO - dataset_builder.py:165 - save scrinshot: /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/images/material-ui-Radio.png
# 2021-11-24 13:25:43,614 -INFO - dataset_builder.py:209 - Collect features using JS script
# 2021-11-24 13:25:44,088 -INFO - dataset_builder.py:217 - Save html to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/html/material-ui-Radio.html
# 2021-11-24 13:25:44,103 -INFO - dataset_builder.py:229 - Save peakle to /Users/Mikhail_Bulgakov/GitRepo/jdi-qasp-ml/data/mui_dataset/df/material-ui-Radio.pkl
# 2021-11-24 13:25:44,105 -INFO - dataset_builder.py:232 - No attributes: (11, 13)
# 2021-11-24 13:25:44,340 -INFO - dataset_builder.py:125 - Close web driver

# %%
# %%time

response = requests.post(
    PREDICT_URL, data=json.dumps(dataset_json)
)

if response.status_code == 200:
    display(json.loads(response.text))
else:
    raise Exception(response.text)
# Out:
# [{'element_id': '8100054811495436197217967608',
#   'x': 269.0,
#   'y': 293.09375,
#   'width': 316.0625,
#   'height': 66.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 20860.125},
#  {'element_id': '6982602688495436194712768030',
#   'x': 269.0,
#   'y': 138.21875,
#   'width': 374.796875,
#   'height': 42.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 15741.46875},
#  {'element_id': '8304080830495436195363860889',
#   'x': 293.0,
#   'y': 463.953125,
#   'width': 179.796875,
#   'height': 84.0,
#   'predicted_label': 'radiogroup',
#   'predicted_probability': 1.0,
#   'sort_key': 15102.9375},
#  {'element_id': '0138375112495436195606533066',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7562867714495436199651191222',
#   'x': 0.0,
#   'y': 2640.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6674208155495436193757881821',
#   'x': 0.0,
#   'y': 1872.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6669968147495436191831107943',
#   'x': 0.0,
#   'y': 2112.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6252094095495436199924349688',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6177394788495436190560674646',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6102162380495436195138715536',
#   'x': 0.0,
#   'y': 624.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6098308617495436195470438401',
#   'x': 0.0,
#   'y': 1824.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '6041318201495436199367602645',
#   'x': 0.0,
#   'y': 240.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5848871677495436196617019561',
#   'x': 0.0,
#   'y': 2160.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5611381972495436196167504602',
#   'x': 0.0,
#   'y': 1440.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5523298990495436195214733493',
#   'x': 0.0,
#   'y': 384.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5510466338495436191069421672',
#   'x': 0.0,
#   'y': 2544.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5444953743495436198198441707',
#   'x': 0.0,
#   'y': 2448.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5429539093495436190912603230',
#   'x': 0.0,
#   'y': 1776.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '0140942465495436199057551755',
#   'x': 0.0,
#   'y': 288.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7166422109495436194326866166',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7636561367495436197532262522',
#   'x': 0.0,
#   'y': 1248.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999996424,
#   'sort_key': 11760.0},
#  {'element_id': '4627215695495436197251968202',
#   'x': 0.0,
#   'y': 1008.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '9255977985495436191877167821',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '9870719853495436199725802207',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '9677272244495436190010093413',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '9581777687495436190384454528',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '9572803017495436198529031303',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '9505741097495436191144396511',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '9394234964495436195433112011',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '8808749061495436194685905468',
#   'x': 0.0,
#   'y': 1104.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7730892303495436190328176160',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '8642307046495436195311293386',
#   'x': 0.0,
#   'y': 2304.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '8165890580495436193654391952',
#   'x': 0.0,
#   'y': 2496.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '8160731253495436190364570666',
#   'x': 0.0,
#   'y': 1920.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '8073426081495436194475808008',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '8018691547495436191040742748',
#   'x': 0.0,
#   'y': 576.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7898109849495436199243490836',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '5210007724495436199137123541',
#   'x': 0.0,
#   'y': 672.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.999994874,
#   'sort_key': 11760.0},
#  {'element_id': '5393513637495436196543516089',
#   'x': 0.0,
#   'y': 528.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.999994874,
#   'sort_key': 11760.0},
#  {'element_id': '2396467817495436192066961358',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '1355253064495436198748833302',
#   'x': 0.0,
#   'y': 960.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '4552923034495436191118926610',
#   'x': 0.0,
#   'y': 720.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.9999985695,
#   'sort_key': 11760.0},
#  {'element_id': '2156243029495436198615267629',
#   'x': 0.0,
#   'y': 768.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '1924330105495436194628229571',
#   'x': 0.0,
#   'y': 1728.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '1866358367495436193056712903',
#   'x': 0.0,
#   'y': 1344.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '1802801465495436197482921830',
#   'x': 0.0,
#   'y': 1488.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '1736248108495436198419707632',
#   'x': 0.0,
#   'y': 96.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '1676211867495436195014438070',
#   'x': 0.0,
#   'y': 1296.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '1328536400495436192697646254',
#   'x': 0.0,
#   'y': 2592.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '2531100855495436196292341315',
#   'x': 0.0,
#   'y': 2016.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '1152844900495436194510748084',
#   'x': 0.0,
#   'y': 48.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '1115797534495436192060031967',
#   'x': 0.0,
#   'y': 1392.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '1073584062495436195086827470',
#   'x': 0.0,
#   'y': 1584.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '0561840152495436196939194187',
#   'x': 0.0,
#   'y': 1536.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '0396134865495436197462147802',
#   'x': 0.0,
#   'y': 816.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.999994874,
#   'sort_key': 11760.0},
#  {'element_id': '0390146549495436192729778603',
#   'x': 0.0,
#   'y': 1632.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 0.999994874,
#   'sort_key': 11760.0},
#  {'element_id': '0230151866495436197540962937',
#   'x': 0.0,
#   'y': 864.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '2499952055495436197776959197',
#   'x': 0.0,
#   'y': 1056.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '9967248476495436191171533888',
#   'x': 0.0,
#   'y': 432.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '4350443162495436195652949304',
#   'x': 0.0,
#   'y': 192.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '2848596937495436197975870223',
#   'x': 0.0,
#   'y': 2208.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '2951177950495436198888615358',
#   'x': 0.0,
#   'y': 480.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '4235187489495436196118248030',
#   'x': 0.0,
#   'y': 336.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3952137381495436197924915454',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3886481605495436193173800372',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3090293506495436192142210935',
#   'x': 0.0,
#   'y': 2352.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3870989220495436190653464268',
#   'x': 0.0,
#   'y': 1680.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3129491621495436198384392537',
#   'x': 0.0,
#   'y': 2400.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '2724270510495436192569241802',
#   'x': 0.0,
#   'y': 2064.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3284321630495436193756489420',
#   'x': 0.0,
#   'y': 912.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3655377493495436193114771874',
#   'x': 0.0,
#   'y': 1152.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '3750126528495436190117535014',
#   'x': 0.0,
#   'y': 144.0,
#   'width': 245.0,
#   'height': 48.0,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 11760.0},
#  {'element_id': '7528659352495436193604486264',
#   'x': 293.0,
#   'y': 578.859375,
#   'width': 171.796875,
#   'height': 36.5,
#   'predicted_label': 'button',
#   'predicted_probability': 1.0,
#   'sort_key': 6270.5859375},
#  {'element_id': '9289961494495436190627165609',
#   'x': 522.90625,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9999454021,
#   'sort_key': 1764.0},
#  {'element_id': '3869701837495436198267366051',
#   'x': 446.9375,
#   'y': 293.09375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.5365092158,
#   'sort_key': 1764.0},
#  {'element_id': '8425538479495436194000204777',
#   'x': 282.0,
#   'y': 463.953125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9726901054,
#   'sort_key': 1764.0},
#  {'element_id': '8242739364495436193136514669',
#   'x': 258.0,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.5365092158,
#   'sort_key': 1764.0},
#  {'element_id': '1712486343495436199875778289',
#   'x': 438.609375,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.5365092158,
#   'sort_key': 1764.0},
#  {'element_id': '3061901567495436196940484113',
#   'x': 337.375,
#   'y': 138.21875,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.5365092158,
#   'sort_key': 1764.0},
#  {'element_id': '6313247139495436193004836245',
#   'x': 394.21875,
#   'y': 305.09375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.5365092158,
#   'sort_key': 1764.0},
#  {'element_id': '8042084925495436192165379632',
#   'x': 285.0,
#   'y': 317.09375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.7646771669,
#   'sort_key': 1764.0},
#  {'element_id': '2817550640495436192099641202',
#   'x': 499.65625,
#   'y': 305.09375,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.5365092158,
#   'sort_key': 1764.0},
#  {'element_id': '5029603042495436198013059715',
#   'x': 282.0,
#   'y': 505.953125,
#   'width': 42.0,
#   'height': 42.0,
#   'predicted_label': 'radio',
#   'predicted_probability': 0.9726901054,
#   'sort_key': 1764.0}]
# CPU times: user 49.5 ms, sys: 4.94 ms, total: 54.4 ms
# Wall time: 1.7 s

# %%
from utils.common import load_gray_image
from matplotlib.patches import Rectangle

# %%
df = pd.read_pickle(f'{dataset_path}/df/{DATASET_NAME}.pkl')[['element_id', 'tag_name']]
df['element_id'] = df['element_id'].astype(str)
preds = pd.DataFrame(json.loads(response.text))
preds['element_id'] = preds['element_id'].astype(str)
predictions_df = preds.merge(df, on='element_id')
predictions_df.head()
# Out:
#                      element_id      x            y       width  height  \
# 0  8100054811495436197217967608  269.0   293.093750  316.062500    66.0
# 1  6982602688495436194712768030  269.0   138.218750  374.796875    42.0
# 2  8304080830495436195363860889  293.0   463.953125  179.796875    84.0
# 3  0138375112495436195606533066    0.0   624.000000  245.000000    48.0
# 4  7562867714495436199651191222    0.0  2640.000000  245.000000    48.0
#
#   predicted_label  predicted_probability     sort_key tag_name
# 0      radiogroup                    1.0  20860.12500      DIV
# 1      radiogroup                    1.0  15741.46875      DIV
# 2      radiogroup                    1.0  15102.93750      DIV
# 3          button                    1.0  11760.00000      DIV
# 4          button                    1.0  11760.00000      DIV

# %%
predictions_df['predicted_probability'].hist()
# Out:
# <AxesSubplot:>

# %%
img = load_gray_image(f'{dataset_path}/images/{DATASET_NAME}.png')
plt.figure(figsize=(13,300))
plt.imshow(img, cmap='gray')

axes = plt.gca()

for _, r in predictions_df.iterrows():
    if r.predicted_probability > 0.0:
        patch = Rectangle((r.x*2, r.y*2), r.width*2, r.height*2, alpha=.2, color='red')
        axes.add_patch(patch)
        
        axes.text(r.x*2, r.y*2, 
                r.predicted_label + ':' +str(round(r.predicted_probability, 2)) + ':' + r.tag_name, 
                backgroundcolor='black', 
                color='white',
                bbox=dict(alpha=0.5))
